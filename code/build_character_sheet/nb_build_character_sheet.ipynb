# %%
import pandas as pd
# import htmlgenerator as hg
import os
import json
import numpy as np

while os.getcwd()[-10:] != 'no1_system':
    os.chdir('..')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\DonalHarrison\\Documents\\admin\\ach\\no1\\no1_system'

# %% [markdown]
# ## Training start

# %%
df_training = pd.read_csv('./docs/_data/training.csv')

# %%
pd.set_option('display.max_colwidth', 255)
df_training.head(5)
# Out:
#         Name   Type Prerequisites  \
# 0   Aberrant  Basic     Uncanny 2
# 1    Acolyte  Basic      Steady 2
# 2  Alchemist  Basic       Savvy 2
# 3      Brute  Basic   Dangerous 2
# 4  Channeler  Basic           NaN
#
#                                                                                                                             Description  \
# 0  You tap into mysterious and otherworldly power sources, harnessing enigmatic and often dangerous powers beyond mortal comprehension.
# 1                      You are a follower of a religion or spiritual practice, granting you kowledge of and powers from its principles.
# 2                                                You are adept at potion-making and transmutation, wielding transformative concoctions.
# 3                                                  You are a savage & resilient combatant, focusing on destroying one target at a time.
# 4                            You harness and manipulate fundamental energies of existence, acting as a conduit to the elemental forces.
#
#                                img_path  \
# 0   /no1_system/assets/img/aberrant.png
# 1    /no1_system/assets/img/acolyte.png
# 2  /no1_system/assets/img/alchemist.png
# 3      /no1_system/assets/img/brute.png
# 4  /no1_system/assets/img/channeler.png
#
#                                     page_path  \
# 0   /no1_system/characters/training/aberrant/
# 1    /no1_system/characters/training/acolyte/
# 2  /no1_system/characters/training/alchemist/
# 3      /no1_system/characters/training/brute/
# 4  /no1_system/characters/training/channeler/
#
#                                                                                              tag_img_src  \
# 0   https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/aberrant.png
# 1    https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/acolyte.png
# 2  https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/alchemist.png
# 3      https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/brute.png
# 4  https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/channeler.png
#
#           attr_training_rank_nm  \
# 0   attr_training_rank_aberrant
# 1    attr_training_rank_acolyte
# 2  attr_training_rank_alchemist
# 3      attr_training_rank_brute
# 4  attr_training_rank_channeler
#
#                                                                                                                                                                                                                                                           div_str
# 0  <div class="grid-character-training-item"><img src="https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/aberrant.png" alt="Aberrant Icon" width="80px" height="80px">Aberrant<input class="sheet-training-ranks" type="...
# 1  <div class="grid-character-training-item"><img src="https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/acolyte.png" alt="Acolyte Icon" width="80px" height="80px">Acolyte<input class="sheet-training-ranks" type="num...
# 2  <div class="grid-character-training-item"><img src="https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/alchemist.png" alt="Alchemist Icon" width="80px" height="80px">Alchemist<input class="sheet-training-ranks" typ...
# 3  <div class="grid-character-training-item"><img src="https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/brute.png" alt="Brute Icon" width="80px" height="80px">Brute<input class="sheet-training-ranks" type="number" n...
# 4  <div class="grid-character-training-item"><img src="https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/channeler.png" alt="Channeler Icon" width="80px" height="80px">Channeler<input class="sheet-training-ranks" typ...

# %%
df_training['tag_img_src'] = df_training['img_path'].str.replace("/no1_system/", "https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/")
df_training['attr_training_rank_nm'] = "attr_training_rank_" + df_training['Name'].str.lower()

# %%
df_training['div_str'] = '<div class="grid-character-training-item"><img src="' + df_training['tag_img_src'] + '" alt="' + df_training['Name'] + ' Icon" width="50px" height="50px" style="vertical-align: middle;"><span style="vertical-align: middle;">' + df_training['Name'] + '    <input class="sheet-training-ranks" type="number" name="' + df_training['attr_training_rank_nm'] + '" step="1" value="0"min="0" max="20" /></span></div>'

# %%
training_divs = ''
for i in df_training.index:
    training_divs += df_training.iloc[i]['div_str']

# %%
f = open('./code/character_sheet/html_raw_training.html', 'w')
f.write(training_divs)
f.close()

# %% [markdown]
# ## Talents Start

# %%
f = open('./docs/_data/talents.json', 'r')
json.load(f)
f.close()

# %%
df_talents_raw = pd.read_json('./docs/_data/talents.json')

# %%
df_talents_raw
# Out:
#                                                                                                                                                                                                                                                             talents
# 0    {'tree': 'Acolyte', 'name': 'Commune with Divinity', 'type': 'Ability', 'rank': '1', 'requires': 'Divine Doctrine', 'replaces': None, 'effect': ['Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concor...
# 1    {'tree': 'Acolyte', 'name': 'Divine Doctrine', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['You follow set of principles in your belief system or religious practice, referred to as your Divine Doctrine.  Each Divine D...
# 2                                                                                            {'tree': 'Acolyte', 'name': 'Composure (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Composure Rank to 2 (d8).']}
# 3                                                                                          {'tree': 'Acolyte', 'name': 'Domain (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase one of your Domain Ranks to 2 (d8).']}
# 4                                                                                          {'tree': 'Acolyte', 'name': 'Domain (2)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase one of your Domain Ranks to 2 (d8).']}
# 5                                                                                         {'tree': 'Acolyte', 'name': 'Domain (3)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase one of your Domain Ranks to 3 (d10).']}
# 6    {'tree': 'Aberrant', 'name': 'Aberration', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['You have an innate ability that deviates from the normal.', 'When you gain this Talent, choose one of the following Effect Skill ...
# 7                                                                                 {'tree': 'Aberrant', 'name': 'Aberration (2)', 'type': 'Static', 'rank': '2', 'requires': 'Aberration', 'replaces': None, 'effect': ['Increase your Abberation Rank to 2 (d8).']}
# 8                             {'tree': 'Aberrant', 'name': 'Break the Mold', 'type': 'Trigger', 'rank': '2', 'requires': 'Aberration', 'replaces': None, 'effect': ['When you score 3+ Hits with your Aberration's Effect Triggers, increase the Momentum by +2.']}
# 9                                                                               {'tree': 'Aberrant', 'name': 'Aberration (3)', 'type': 'Ability', 'rank': '3', 'requires': 'Aberration', 'replaces': None, 'effect': ['Increase your Abberation Rank to 3 (d10).']}
# 10   {'tree': 'Aberrant', 'name': 'Living Anomaly', 'type': 'Ability', 'rank': '3', 'requires': 'Aberration', 'replaces': None, 'effect': ['When you score 5+ Hits with your Aberration's Effect Triggers, you may immediately use a different Effect Trigger fr...
# 11   {'tree': 'Mystic', 'name': 'Seek Mysteries', 'type': 'Static', 'rank': '1', 'requires': 'Strain Susceptibility', 'replaces': None, 'effect': ['You hold knowledge of the mysteries of the cosmos, bending secret powers to your will.  You gain access to <...
# 12   {'tree': 'Mystic', 'name': 'Strain Susceptibility', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Your pursuit of Arcana expose you to <strong>Strain</strong>.', 'When you roll one of your Affinity to invoke and Arcana...
# 13                                                                           {'tree': 'Mystic', 'name': 'Manage Strain', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Use your Insight to reduce your current Strain by Hits.']}
# 14                                                                                               {'tree': 'Mystic', 'name': 'Insight (3)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Insight Rank to 3 (d10).']}
# 15                                                                                      {'tree': 'Mystic', 'name': 'Affinity (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase one of your Affinity Ranks to 2 (d8).']}
# 16                                                                                      {'tree': 'Mystic', 'name': 'Affinity (2)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase one of your Affinity Ranks to 2 (d8).']}
# 17                                                                                     {'tree': 'Mystic', 'name': 'Affinity (3)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase one of your Affinity Ranks to 3 (d10).']}
# 18   {'tree': 'Alchemist', 'name': 'Prepare concoctions', 'type': 'Ability', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Craft at Challenge 3 to gain Hits + Savvy in Concoction Ranks to prepare Concocions.', 'You may use this Ability witho...
# 19                                                                                                 {'tree': 'Alchemist', 'name': 'Craft (1)', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase your Craft Rank to 1 (d6).']}
# 20                                                                                                 {'tree': 'Alchemist', 'name': 'Craft (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Craft Rank to 2 (d8).']}
# 21                                                                                                {'tree': 'Alchemist', 'name': 'Craft (3)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase your Craft Rank to 3 (d10).']}
# 22                                         {'tree': 'Alchemist', 'name': 'Dangerous Distillation', 'type': 'Trigger', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.']}
# 23     {'tree': 'Alchemist', 'name': 'Practiced Applications', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Once per turn you can use or apply a Concoction that requires a Shift to Use Your Equipment wihtout using a Shift.']}
# 24                  {'tree': 'Alchemist', 'name': 'Brew Broker', 'type': '', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['When you Persuade or Deceive a target to sell your Concoctions and score 2+ Hits, gain +1 Wealth from the transaction.']}
# 25             {'tree': 'Alchemist', 'name': 'Premium Potables', 'type': '', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['When you Persuade or Deceive a target to sell your Concoctions and score 3+ Hits, gain +1 Wealth from the transaction.']}
# 26                                         {'tree': 'Alchemist', 'name': 'Accomplished Alchemist', 'type': 'Trigger', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.']}
# 27                                                                                                                            {'tree': 'Archmage', 'name': 'Master the arcane', 'type': 'Ability', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['']}
# 28    {'tree': 'Assassin', 'name': 'Coup de Grace', 'type': 'Ability', 'rank': '2', 'requires': 'Sneak Attack', 'replaces': None, 'effect': ['Spend 3 Momentum and immediately Strike a target in your Current Zone that is Prone.  On 6+ Hits, the target dies.']}
# 29                                        {'tree': 'Assassin', 'name': 'Sneak Attack', 'type': 'Trigger', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['When you score Hits against a target while Hidden, add +1d6 bonus Hits to the result set.']}
# 30                                                                 {'tree': 'Assassin', 'name': 'Poison Expert', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['You are a master of using Poison, doubling the Poison's effects.']}
# 31                                                           {'tree': 'Assassin', 'name': 'Unseen Shot', 'rank': '1', 'type': 'Static', 'requires': None, 'replaces': None, 'effect': ['You do not lose your Hidden rating when you Shoot a target while Hidden.']}
# 32   {'tree': 'Assassin', 'name': 'Silent Takedown', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Strike an opponent whil Hidden, attempting to subdue them quietly.  If you score 4+ Hits, the tareget suffers no damage to ...
# 33             {'tree': 'Assassin', 'name': 'Death from the Shadows', 'type': 'Trigger', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['When you Strike or Shoot your target to death, you may immediately use your Stealth without using a Shift.']}
# 34   {'tree': 'Assassin', 'name': 'Marked for Death', 'type': 'Shift', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Use your Tactics to mark your target, giving them Aura X, where X is equal to Hits in your result set.  Your target is Vulne...
# 35                                                            {'tree': 'Assassin', 'name': 'Vanish', 'type': 'Ability', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Spend X Momentum to gain Hidden X, where X is the amount of Momentum spent.']}
# 36   {'tree': 'Assassin', 'name': 'Ambush Expert', 'type': 'Trigger', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['When you make an Initiative Test in an Ambush, you may spend Momentum to increase Hits scored by X, where X is the number of ...
# 37   {'tree': 'Assassin', 'name': 'Never Unnarmed', 'type': 'Trigger', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['When you are being searched by someone attempting to disarm you of your weapons and implements, you may use Legerdemain to h...
# 38                           {'tree': 'Assassin', 'name': 'At Home in the Shadows', 'rank': '1', 'type': 'Trigger', 'requires': None, 'replaces': None, 'effect': ['When you Defy Danger to Hide! and score 2+ Hits, you can take an additional Shift this turn.']}
# 39             {'tree': 'Assassin', 'name': 'Assassinate', 'type': '3', 'rank': '', 'requires': 'Marked for Death, Sneak Attack', 'replaces': None, 'effect': ['When you Sneak Attack a target you have Marked for Death, add +2d6 Bonus Hits to the result set.']}
# 40                                                                                              {'tree': 'Assassin', 'name': 'Fearsome Reputation', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Gain +3 Renown and +1 Enemies']}
# 41            {'tree': 'Assassin', 'name': 'Contract Killer', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Persuade one target in your Current Zone to negotiate terms of a contract, adding +2 Bonus Hits to the result set.']}
# 42   {'tree': 'Assassin', 'name': 'The Job's Not Done', 'type': 'Trigger', 'rank': '2', 'requires': 'Marked for Death', 'replaces': None, 'effect': ['When a target you have Marked for Death escapes, immediately spend 1 Momentum to gain Favor 1.  You can on...
# 43                                         {'tree': 'Athlete', 'name': 'Powerlifter', 'type': 'Ability', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Exert yourself to accomplish a feat of strength, adding +1d4 bonus hits to the result set.']}
# 44                                                       {'tree': 'Athlete', 'name': 'Sprinter', 'type': 'Static', 'rank': '1', 'requires': 'Deft 2', 'replaces': None, 'effect': ['When you Shift to move to an adjacent Zone, you may move an additional Zone.']}
# 45                                                                                                   {'tree': 'Athlete', 'name': 'Exert (2)', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase your Exert Rank to 2 (d8).']}
# 46                                                                                                 {'tree': 'Athlete', 'name': 'Tumble (2)', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase your Tumble rank to 2 (d8).']}
# 47                                                                                                  {'tree': 'Athlete', 'name': 'Exert (3)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Exert Rank to 3 (d10).']}
# 48                                                                                                {'tree': 'Athlete', 'name': 'Tumble (3)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Tumble rank to 3 (d10).']}
# 49                                                         {'tree': 'Athlete', 'name': 'Acrobat', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['You are adept in acrobatics, adding +2 Bonus Hits any result sets using Tumble.']}
# 50                                                    {'tree': 'Athlete', 'name': 'Freerunner', 'type': 'Trigger', 'rank': '3', 'requires': 'Acrobat', 'replaces': None, 'effect': ['When you Defy Danger using Parkour!, add +1d4 Bonus Hits to the result set.']}
# 51                                                                                         {'tree': 'Athlete', 'name': 'Peak Conditioning', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['When you Recover, regain +2 Defenses.']}
# 52   {'tree': 'Heretic', 'name': 'Commune with Divinity', 'type': 'Ability', 'rank': '1', 'requires': 'Divine Doctrine', 'replaces': None, 'effect': ['Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concor...
# 53   {'tree': 'Tactician', 'name': 'Inspire Allies', 'type': 'Ability', 'rank': '1', 'requires': 'Leadd 2', 'replaces': None, 'effect': ['Lead all allies in your Current Zone, allowing a number of them equal to the Hits in the result set to immediately do ...
# 54   {'tree': 'Tactician', 'name': 'Reposition', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Use your Tactics allies in your current Zones, allowing X allies to immediately use a Shift, where X is equal to Hits in the re...
# 55                                 {'tree': 'Tactician', 'name': 'Seize the Initiative', 'type': 'Trigger', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['When an enemy scores 1 or 0 Hits in their result set, your team regains the initiative.']}
# 56   {'tree': 'Tactician', 'name': 'Battlefield Command', 'type': 'Ability', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Lead all allies in your Current Zone, granting X allies +2 Bonus Hits on their next roll, where X is the number of Hit...
# 57     {'tree': 'Tactician', 'name': 'Tactical Assessment', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['You are adept at planning battles and missions.  You add +1d4 Bonus Hits when you use your Tactics to plan a mission.']}
# 58   {'tree': 'Tactician', 'name': 'Coordinated Attack', 'type': '', 'rank': '', 'requires': None, 'replaces': None, 'effect': ['Lead the assault in combat designating one target in your Current Zone.  The target gains Vulnerable X, where X is equal to Hit...
# 59   {'tree': 'Tactician', 'name': 'Defensive Maneuver', 'type': '', 'rank': '', 'requires': None, 'replaces': None, 'effect': ['Spend X Momentum to grant all allies in your Current Zone to regain +X to their Primary Defenses, where X is equal to the Momen...
# 60   {'tree': 'Tactician', 'name': 'Tactical Retreat', 'type': '2', 'rank': 'Ability', 'requires': None, 'replaces': None, 'effect': ['Use your Tactics to guide allies in your current and all adjacent Zones in a tactical retreat, allowing a number of allie...
# 61                         {'tree': 'Tactician', 'name': 'Rallying Cry', 'type': '', 'rank': '', 'requires': None, 'replaces': None, 'effect': ['Lead allies in your Current Zone, adding Hits -1 to the Momentum and Creating 1 Advantage in your Current Zone.']}
# 62   {'tree': 'Tactician', 'name': 'Flanking Maneuver', 'type': '', 'rank': '', 'requires': None, 'replaces': None, 'effect': ['Spend 3 Momentum and use your Tactics to outmanuever your enemies.  On 2+ Hits, you may designate up to 3 targets in your Curren...
# 63   {'tree': 'Tactician', 'name': 'Tactical Strike', 'type': 'Abiltiy', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Use your Tactics instead of Strike to attack an enemy in yoru Current Zone.  The target suffers Hits -2 to their Defense a...
# 64                                                                                             {'tree': 'Tactician', 'name': 'Tactics (2)', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase your Tactics Rank to 2 (d8).']}
# 65                                                                                            {'tree': 'Tactician', 'name': 'Tactics (3)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Tactics Rank to 3 (d10).']}
# 66                                                                                            {'tree': 'Tactician', 'name': 'Tactics (4)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase your Tactics Rank to 4 (d12).']}
# 67                                                                                                   {'tree': 'Tactician', 'name': 'Lead (2)', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase your Lead Rank to 2 (d8).']}
# 68            {'tree': 'Tactician', 'name': 'Combat Reflexes', 'type': 'Trigger', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['When a hostile target Shifts away from you in melee combat, they add an additional Hazard die to their next roll.']}
# 69   {'tree': 'Tactician', 'name': 'Decisive Action', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['You are adept take swift and decisive action to turn the tide.  If you Lead or use your Tactics on the first turn of a Time...
# 70                                                       {'tree': 'Tactician', 'name': 'Tactical Mastermind', 'type': 'Trigger', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['When you use your Tactics, adding +1 Bonus Hits to the result set.']}
# 71   {'tree': 'Heretic', 'name': 'Divine Doctrine', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['You follow set of principles in your belief system or religious practice, referred to as your Divine Doctrine.  Each Divine D...
# 72   {'tree': 'Heretic', 'name': 'Unorthodox Doctrine', 'type': 'Static', 'rank': '1', 'requires': 'Divine Doctrine', 'replaces': None, 'effect': ['Select 1 additional Effect Skill from the list below to add to your Domain:<br>Bellor, Inferno, Lux, Mori, N...
# 73                                      {'tree': 'Heretic', 'name': 'Heterodoxy', 'rank': '3', 'type': 'Ability', 'requires': 'Heterodox Practice', 'replaces': None, 'effect': ['Use a Shift to maintain your Composure, immediately gaining 1d4+1 Concordance.']}
# 74                           {'tree': 'Heretic', 'name': 'Profane Smite', 'rank': '2', 'type': 'Ability', 'requires': None, 'replaces': None, 'effect': ['Spend your Concordance to add Xd4 to your Strike, where X is equal to the amount of Concordance spent.']}
# 75   {'tree': 'Heretic', 'name': 'Divine Rebuke', 'rank': '2', 'type': 'Trigger', 'requires': None, 'replaces': None, 'effect': ['When you suffer Hits from an attack in your Current or and Adjacent Zone, you may spend 1 Concordance to deal +1d4 Bonus Hits ...
# 76                                                                        {'tree': 'Heretic', 'name': 'Heretical Knowledge', 'rank': '2', 'type': 'Static', 'requires': None, 'replaces': None, 'effect': ['Increase your Cosmology or Theology Ranks to 2 (d8).']}
# 77                 {'tree': 'Heretic', 'name': 'Divine Defiance', 'rank': '2', 'type': 'Trigger', 'requires': None, 'replaces': None, 'effect': ['When you suffer Hits from a Power effects, you may spend 1 Concordance to regain +1d6 to your Primary Defense.']}
# 78   {'tree': 'Heretic', 'name': 'Profane Aura', 'rank': '3', 'type': 'Ability', 'requires': None, 'replaces': None, 'effect': ['Focus to gain an Aura X, where X is the number of Hits in the result set.<br>While the Aura persists, all Allies in your Curren...
# 79                      {'tree': 'Heretic', 'name': 'Heretic's Shield', 'rank': '2', 'type': 'Trigger', 'requires': None, 'replaces': None, 'effect': ['When you suffer Hits from an attack you can see, you can spend 1 Concordance to reduce the Hits by -1d4.']}
# 80   {'tree': 'Heretic', 'name': 'Dark Revelation', 'rank': '3', 'type': 'Ability', 'requires': 'Heretical Knowledge', 'replaces': None, 'effect': ['Once per Waypoint, use your Insight to uncover an unwanted truth.  If you score 3+ Hits, ask the BAMF one q...
# 81   {'tree': 'Heretic', 'name': 'Defiant Healing', 'rank': '2', 'type': 'Ability', 'requires': None, 'replaces': None, 'effect': ['You can spend 1 Concordance to call on the Vivus energy.  You and one ally in your Current Zone ragin Hits to your Grit or P...
# 82   {'tree': 'Heretic', 'name': 'Sacred Disruption', 'rank': '3', 'type': 'Trigger', 'requires': 'Divine Defiance', 'replaces': None, 'effect': ['When a target you can see uses a Power, you can spend 1 Concordance to use one Effect Skill in your Domain.  ...
# 83   {'tree': 'Heretic', 'name': 'Divine Reversal', 'rank': '3', 'type': 'Trigger', 'requires': 'Sacred Disruption', 'replaces': None, 'effect': ['When you successfully use your Sacred Disruption, you deal Hits in your Domain Skill result set to the target...
# 84                                          {'tree': 'Heretic', 'name': 'Heretic's Wrath', 'rank': '3', 'type': 'Trigger', 'requires': 'Profane Smite', 'replaces': None, 'effect': ['When you use your Profane Smite and score 3+ Hits, your target gain Blind.']}
# 85                                                                                                                                             {'tree': 'Bastion', 'name': '', 'type': 'Ability', 'rank': None, 'requires': None, 'replaces': None, 'effect': ['']}
# 86                                                                                                 {'tree': 'Berserker', 'name': 'Exert (2)', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase your Exert Rank to 2 (d8).']}
# 87   {'tree': 'Berserker', 'name': 'Rage', 'type': 'Shift', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Exert yourself, entering a trance-like fury to crush your enemies, see them driven before you, and to hear the lamentations of their wo...
# 88                                            {'tree': 'Berserker', 'name': 'Frenzy', 'type': 'Trigger', 'rank': '2', 'requires': 'Rage', 'replaces': None, 'effect': ['When you are in a Rage and score 4+ Hits in melee combat, increase your Rage Aura by +2.']}
# 89      {'tree': 'Berserker', 'name': 'Undying Rage', 'type': 'Trigger', 'rank': '2', 'requires': 'Rage', 'replaces': None, 'effect': ['When you are in a Rage and use the Recover Acation, you may regain +3 to your Grit and decrease your Dying rating by -1.']}
# 90   {'tree': 'Berserker', 'name': 'Berkserker's Fury', 'type': 'Ability', 'rank': '2', 'requires': 'Rage', 'replaces': None, 'effect': ['Decrease your Rage Aura by -2 and choose one (1):<ul><li>Strike or use your Martial Arts against one target in your Cu...
# 91   {'tree': 'Berserker', 'name': 'Indomitable Rage', 'type': 'Static', 'rank': '2', 'requires': 'Rage', 'replaces': None, 'effect': ['While you are in a Rage, you automatically regain +1 point to your Primary Defense at the beginning of your turn and you...
# 92   {'tree': 'Berserker', 'name': 'Vicious Rage', 'type': 'Trigger', 'rank': '3', 'requires': 'Rage', 'replaces': None, 'effect': ['When  you are in a Rage and score 5+ Hits using Grapple, Martial Arts, Strike, or Throw, you may reduce your Rage Aura by -...
# 93                                                                                                {'tree': 'Berserker', 'name': 'Exert (3)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase your Exert Rank to 3 (d10).']}
# 94                                     {'tree': 'Berserker', 'name': 'Bloodlust', 'type': 'Trigger', 'rank': '3', 'requires': 'Rage', 'replaces': None, 'effect': ['When you are in a Rage and suffer 2+ Hits from a melee attack, increase you Rage Aura by +1.']}
# 95                                                                                 {'tree': 'Black Belt', 'name': 'Martial Arts (3)', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase your Martial Arts Rank to 3 (d10).']}
# 96                 {'tree': 'Black Belt', 'name': 'Flying Kick', 'type': 'Ability', 'rank': 1, 'requires': None, 'replaces': None, 'effect': ['Use a Shift to move into an adjacent Zone, then immediately Strike your target, adding +2 Hits to the result set.']}
# 97   {'tree': 'Black Belt', 'name': 'Cross Block', 'type': 'Trigger', 'rank': 2, 'requires': 'Any Defensive Stance', 'replaces': None, 'effect': ['When you are in a Defensive Stance and take 3+ Hits in melee combat from an attacker you can see, reduce the ...
# 98     {'tree': 'Black Belt', 'name': 'Kansetsu Geri', 'type': 'Trigger', 'rank': '3', 'requires': 'Any Aggressive Stance', 'replaces': None, 'effect': ['When you are in a Aggressive Stance and score 4+ Hits in melee combat, your target gains Vulnerable 2.']}
# 99   {'tree': 'Black Belt', 'name': 'Renraku Waza', 'type': 'Ability', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Use your Martial Arts against a target in your Current Zone.', 'If you score 3+ Hits, add +1d4 Bonus Hits to the results set...
# 100                                                                                {'tree': 'Black Belt', 'name': 'Martial Arts (4)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase your Martial Arts Rank to 4 (d12).']}
# 101                                           {'tree': 'Black Belt', 'name': 'Sound Mind, Sound Body', 'type': 'Trigger', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['When you use an Action to Recover Defenses, you may regain up to +1 Grit.']}
# 102                                                                                                                                       {'tree': 'Blade Weaver', 'name': '', 'type': 'Ability', 'rank': None, 'requires': None, 'replaces': None, 'effect': ['']}
# 103                                                                                  {'tree': 'Bounty Hunter', 'name': 'Implements (1)', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase your Implements Rank to 1 (d6).']}
# 104  {'tree': 'Bounty Hunter', 'name': 'I Can Bring You In Warm, Or I Can Bring You In Cold.', 'type': 'Ability', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Intimidate a target in yout Current Zone that you are trying to apprehend, adding...
# 105                                                                                  {'tree': 'Bounty Hunter', 'name': 'Implements (2)', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase your Implements Rank to 2 (d8).']}
# 106  {'tree': 'Bounty Hunter', 'name': 'Bolas', 'type': 'Ability', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Use your Implements to ensnare one target in your Current or and Adjacent Zone.  The target gains Prone and Restrained X, where ...
# 107  {'tree': 'Bounty Hunter', 'name': 'Manacles', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Use your Implements to bind the hands of one target in your Current Zone.  On 2+ Hits, the target gains Restrained X, where X...
# 108                                                                                     {'tree': 'Bounty Hunter', 'name': 'Survival (3)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Survival Rank to 3 (d10).']}
# 109                                                                                        {'tree': 'Bounty Hunter', 'name': 'Insight (2)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase your Insight Rank to 2 (d8).']}
# 110                                                                                  {'tree': 'Bounty Hunter', 'name': 'Streetwise (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Streetwise Rank to 2 (d8).']}
# 111                                                        {'tree': 'Bounty Hunter', 'name': '. . .A Complicated Profession.', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Gain +2 Enemies and either +1 Renown or +3 Wealth.']}
# 112  {'tree': 'Bounty Hunter', 'name': 'Shrewd Contractor', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Persuade, Intimidate, or use your Insight when discussing the terms of a bounty, addin +1d4 Bonus Hits to the result...
# 113  {'tree': 'Bounty Hunter', 'name': 'Word on the Street', 'type': 'Ability', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Use your Streetwise to gain valuable information or find the right person to talk to about you target.  On 3+ Hits,...
# 114                                                                                 {'tree': 'Bounty Hunter', 'name': 'Intimidate (2)', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Intimidate Rank to 2 (d8).']}
# 115                                     {'tree': 'Bounty Hunter', 'name': 'It's A Dirty Job. . .', 'type': 'Trigger', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['When you successfully apprehend a wanted target, gain +1 Renown or +2 Wealth.']}
# 116  {'tree': 'Bounty Hunter', 'name': 'No Disintegrations', 'type': 'Trigger', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Strike one target in your Current Zone or Shoot one target in your Current or an Adjacent Zone aiming to subdue the...
# 117                                               {'tree': 'Brute', 'name': 'Brutal Strike', 'type': 'Ability', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Strike one target with unrelenting force, adding +1d4 Bonus Hits to the result set.']}
# 118  {'tree': 'Brute', 'name': 'Just Getting Started', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Exert yourself when you are below your maximum Grit, then choose 1:<ul><li>Regain Hits to your Primary Defense.</li><li>I...
# 119                                                                                                    {'tree': 'Brute', 'name': 'Exert (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Exert Rank to 2 (d8).']}
# 120                                                                                          {'tree': 'Brute', 'name': 'Intimidate (2)', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase your Intimidate Rank to 2 (d8).']}
# 121  {'tree': 'Brute', 'name': 'Who's Next', 'type': 'Ability', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Intimidate all targets in your Current Zone.  If you score Hits greater than their current Nerve, they become <a href:'/no1_system/...
# 122  {'tree': 'Brute', 'name': 'You're Next', 'type': 'Trigger', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['When you Strike your target to death, you can Initiate a Contest with one hostile target in your Current Zone wihtout using a Shif...
# 123  {'tree': 'Brute', 'name': 'Grisly Slaughter', 'type': 'Trigger', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['When you Strike your target to death, describe the gruesome end you delivered.  Then all hostile targets in your Current Zone...
# 124  {'tree': 'Channeler', 'name': 'Channeling', 'type': 'Ability', 'rank': '1', 'requires': 'Recoil', 'replaces': None, 'effect': ['Your Affinity for these forces all you to use <a href='/no1_system/characters/powers/techniques/'>Techniques</a> that chann...
# 125  {'tree': 'Channeler', 'name': 'Recoil', 'type': 'Trigger', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['If a Technique you use has a 1 in the result set, all targets within your Current Zone sustain Hits from the Techniques's effect eq...
# 126                                                                                  {'tree': 'Channeler', 'name': 'Affinity (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase one of your Affinity Ranks to 2 (d8).']}
# 127                                                                                        {'tree': 'Channeler', 'name': 'Composure (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Composure Rank to 2 (d8).']}
# 128                                                                                              {'tree': 'Channeler', 'name': 'Endure (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Endure Rank to 2 (d8).']}
# 129                                                                                                {'tree': 'Channeler', 'name': 'Focus (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Focus Rank to 2 (d8).']}
# 130                                                                                  {'tree': 'Channeler', 'name': 'Affinity (2)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase one of your Affinity Ranks to 2 (d8).']}
# 131                                                                                 {'tree': 'Channeler', 'name': 'Affinity (3)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase one of your Affinity Ranks to 3 (d10).']}
# 132  {'tree': 'Conduit', 'name': 'Attune with Essence', 'type': 'Ability', 'rank': '1', 'requires': 'Bonded Essence', 'replaces': None, 'effect': ['Focus or use your Insight to connect with your power, gaining Hits in Attunement.', 'Attunment measures the ...
# 133  {'tree': 'Conduit', 'name': 'Bonded Essence', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['When you gain this Talent, select 1 Effect Skill from the list below to be an <em>Affinity</em> allowing you to further empowe...
# 134                                                                                   {'tree': 'Conduit', 'name': 'Affinity (2)', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase one of your Affinity Ranks to 2 (d8).']}
# 135                                                                                                  {'tree': 'Conduit', 'name': 'Focus (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Focus Rank to 2 (d8).']}
# 136                                                                                              {'tree': 'Conduit', 'name': 'Insight (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Insight Rank to 2 (d8).']}
# 137                                                                                   {'tree': 'Conduit', 'name': 'Affinity (3)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase one of your Affinity Ranks to 3 (d10).']}
# 138                                                                                            {'tree': 'Conduit', 'name': 'Insight (3)', 'type': 'Static', 'rank': None, 'requires': None, 'replaces': None, 'effect': ['Increase your Insight Rank to 3 (d10).']}
# 139                                                                                                {'tree': 'Conduit', 'name': 'Focus (3)', 'type': 'Static', 'rank': None, 'requires': None, 'replaces': None, 'effect': ['Increase your Focus Rank to 3 (d10).']}
# 140       {'tree': 'Conduit', 'name': 'Attuning Conflux', 'type': 'Shift', 'rank': '3', 'requires': 'Attune with Essence', 'replaces': None, 'effect': ['Spend X Hits from the result set of the next Marvel you use this turn to increase your Attunement by X.']}
# 141                                                                                                                                          {'tree': 'Confessor', 'name': '', 'type': 'Ability', 'rank': None, 'requires': None, 'replaces': None, 'effect': ['']}
# 142  {'tree': 'Corsair', 'name': 'Sea Legs', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['You are adept at fighting on accustomed to the rolling decks of ships. While you are moving on board a shipYou add +1d4 Bonus Hits w...
# 143                                       {'tree': 'Corsair', 'name': 'Pirate's Charm', 'type': 'Ability', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Persuade a sailor, pirate, or maritime merchant, adding +2 Bonus Hits to the result set.']}
# 144                                                                                      {'tree': 'Corsair', 'name': 'Nautical Navigator', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase your Navigate Rank to 2 (d8).']}
# 145                                                                                        {'tree': 'Corsair', 'name': 'Sword of the Seas', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Strike Rank to 3 (d10).']}
# 146                                                                                    {'tree': 'Corsair', 'name': 'Sea Lore', 'type': '2', 'rank': 'Static', 'requires': None, 'replaces': None, 'effect': ['Increase your Cosmology or History rank to 2 (d8).']}
# 147                                                                                              {'tree': 'Corsair', 'name': 'Fearsome Reputation', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Gain +3 Renown and +1 Enemies']}
# 148  {'tree': 'Corsair', 'name': 'Plunderer's Instinct', 'type': 'Ability', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Perceive or Investigate to find hidden compartments, treaure, or valuable cargo, adding +1d4 Bonus Hits to the result s...
# 149  {'tree': 'Corsair', 'name': 'Broadside Barrage', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Lead the crew of a ship in unleashing a devastating broadside attack.  On 2+ Hits, the ballistae to deal double Hits on th...
# 150                    {'tree': 'Corsair', 'name': 'Mariner's Endurance', 'type': 'Trigger', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['When you Recover to reduce Fatigue, recover any remaining Hits to Vigor once your Fatigue rating is 0.']}
# 151                                                                                               {'tree': 'Corsair', 'name': 'Operate 3', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Operate Rank to 3 (d10).']}
# 152                                                                                                 {'tree': 'Corsair', 'name': 'Strike 3', 'type': 'Strike', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Strike Rank to 3 (d10).']}
# 153  {'tree': 'Corsair', 'name': 'Grappling Hook', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Use your Implements to throw a grappling hook, allowing you to use your Shift to Move to an Adjacent Zone that is vertical fr...
# 154  {'tree': 'Corsair', 'name': 'Tidal Strike', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Spend Momentum to Strike with the rage of the seas adding +X Bonus Hits to the result set, where X is the amount of Momentum sp...
# 155     {'tree': 'Corsair', 'name': 'Weather the Storm', 'type': '', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Lead your crew through a severe storm or troubled waters.  On 2+ Hits, all crew Actions add +2 Bonus Hits to their Result Set.']}
# 156                             {'tree': 'Corsair', 'name': 'Smuggler's Cunning', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Deceive a target that holds a position of authority, adding +1d4 Bonus Hits to the result set.']}
# 157  {'tree': 'Corsair', 'name': 'Captain's Command', 'type': 'Ability', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Lead all allies in your Current Zone allowing X allies to immediately use a Shoft or Trigger, where X is the number of Hit...
# 158                                                                        {'tree': 'Courtier', 'name': 'Silver Tongue', 'type': 'Ability', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Persuade your target, adding +2 Hits to the result set.']}
# 159         {'tree': 'Courtier', 'name': 'Diplomatic Immunity!', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Once per Waypoint, you may invoke your dipmoatic staus to avoid arrest or legal consequences for minor offenses.']}
# 160  {'tree': 'Courtier', 'name': 'Favor Broker', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['You are an expert at arranging advantageous deals and alliances, leveraging your noble prowess to gain favors and resources.<br...
# 161                                                             {'tree': 'Courtier', 'name': 'Subtle Manipulation', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Deceive your target, adding +2 Bonus Hits to the result set.']}
# 162  {'tree': 'Courtier', 'name': 'Secrets Unveiled', 'type': 'Trigger', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['When you use your Insight or Investigate a situation to uncover information that someone is trying to conceal, add +1d4 Hi...
# 163      {'tree': 'Courtier', 'name': 'Elegant Defense', 'type': 'Trigger', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['When you suffer Hits from a target you can see and your Nerve is above 0, spend 1 Nerve to reduce the total Hits by +2.']}
# 164                                       {'tree': 'Courtier', 'name': 'Intrigue Mastery', 'type': 'Ability', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase your History Rank to 3 (d10) and your Persuasion or Insight Rank to 3 (d10).']}
# 165           {'tree': 'Courtier', 'name': 'Social Chameleon', 'type': 'Ability', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Deceive to adopt the mannerisms and speech of a different social class, adding +1d4 Bonus Hits to the result set.']}
# 166  {'tree': 'Courtier', 'name': 'Rumor Mill', 'type': 'Ability', 'rank': '3', 'requires': 'Shadow Network', 'replaces': None, 'effect': ['You can utilize your Shadow Network to spread a rumor or piece of misinformation. While you are in a city, Spend 2 W...
# 167                                           {'tree': 'Courtier', 'name': 'Inspiring Presence', 'type': 'Ability', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Lead all allies in your Current Zone, restoring Hits to their Primary Defenses.']}
# 168  {'tree': 'Courtier', 'name': 'The Better Part of Valor', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['You excel at forming discrete alliances ensuring mutual benefits without drawing unwanted attention, allowing you t...
# 169                       {'tree': 'Courtier', 'name': 'Crisis Averted', 'type': 'Trigger', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['When you successfully diffuse a social situation in the benefit of you and your allies, gain +1 Renown.']}
# 170  {'tree': 'Courtier', 'name': 'Shadow Network', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['You maintain a network of informants and are skilled at finding enterprising local to gather valuable intelligence.  You may ...
# 171               {'tree': 'Courtier', 'name': 'Regal Bearing', 'type': 'Trigger', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['When you are engaged in a Contest and Persuade or Intimidate your opponent, add +2 Bonus Hits to the result set.']}
# 172                                           {'tree': 'Courtier', 'name': 'Political Savvy', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your History Rank to 2 (d8) and your Persuasion or Insight Rank to 2 (d8).']}
# 173  {'tree': 'Courtier', 'name': 'Flawless Etiquette', 'type': 'Trigger', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['When you are in a formal setting and Persuade a target, you may use a Savvy Trait reroll to reroll all dice instead of j...
# 174  {'tree': 'Courtier', 'name': 'Whispered Secrets', 'type': 'Ability', 'rank': '2', 'requires': 'The Better Part of Valor', 'replaces': None, 'effect': ['You are a master at communicating subtly and discreetly, exchanging critical information without ar...
# 175                        {'tree': 'Defender', 'name': 'Focused Defense', 'type': 'Ability', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Focus to defend yourself in combat, assuming a Defensive Stance adding +Hits to your Primary Defense.']}
# 176                                                                             {'tree': 'Defender', 'name': 'Stay Close to Me', 'type': 'Shift', 'rank': '1', 'requires': '', 'replaces': None, 'effect': ['Use a Shift to protect 1 ally in your Current Zone.']}
# 177                                                                                                 {'tree': 'Defender', 'name': 'Focus (2)', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase your Focus Rank to 2 (d8).']}
# 178  {'tree': 'Defender', 'name': 'Harm's Way', 'type': 'Trigger', 'rank': '2', 'requires': 'Stay Close to Me', 'replaces': None, 'effect': ['When you protect an ally in your Current Zone and they are Hit by an attack you can see, you may redirect a number...
# 179                                                                                           {'tree': 'Defender', 'name': 'Shake it off', 'type': 'Trigger', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['When you Recover, regain +2 Defenses.']}
# 180                                                                     {'tree': 'Defender', 'name': 'Armor Training', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['You gain an additional +2 rating from any Armor you equip.']}
# 181                                                                                               {'tree': 'Defender', 'name': 'Endure (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Endure Rank to 2 (d8).']}
# 182                                                                         {'tree': 'Guardian', 'name': 'Armor Expert', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['You gain an addition +4 rating from any Armor you equip.']}
# ...
# 773                                                                                                                                             {'tree': 'Zenith', 'name': '', 'type': 'Ability', 'rank': None, 'requires': None, 'replaces': None, 'effect': ['']}
# 774                                                                            {'tree': 'Soldier', 'name': 'Dangerous Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Dangerous Trait rating by +1.']}
# 775                                                                              {'tree': 'Brute', 'name': 'Dangerous Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Dangerous Trait rating by +1.']}
# 776                                                                           {'tree': 'Scrapper', 'name': 'Dangerous Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Dangerous Trait rating by +1.']}
# 777                                                                          {'tree': 'Berserker', 'name': 'Dangerous Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Dangerous Trait rating by +1.']}
# 778                                                                             {'tree': 'Reaver', 'name': 'Dangerous Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Dangerous Trait rating by +1.']}
# 779                                                                             {'tree': 'Sniper', 'name': 'Dangerous Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Dangerous Trait rating by +1.']}
# 780                                                                           {'tree': 'Assassin', 'name': 'Dangerous Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Dangerous Trait rating by +1.']}
# 781                                                                         {'tree': 'Black Belt', 'name': 'Dangerous Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Dangerous Trait rating by +1.']}
# 782                                                                             {'tree': 'Knight', 'name': 'Dangerous Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Dangerous Trait rating by +1.']}
# 783                                                                      {'tree': 'Weapon Master', 'name': 'Dangerous Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Dangerous Trait rating by +1.']}
# 784                                                                             {'tree': 'Ranger', 'name': 'Dangerous Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Dangerous Trait rating by +1.']}
# 785                                                                                        {'tree': 'Thief', 'name': 'Deft Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Deft Trait rating by +1.']}
# 786                                                                                        {'tree': 'Scout', 'name': 'Deft Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Deft Trait rating by +1.']}
# 787                                                                                       {'tree': 'Ranger', 'name': 'Deft Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Deft Trait rating by +1.']}
# 788                                                                                  {'tree': 'Infiltrator', 'name': 'Deft Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Deft Trait rating by +1.']}
# 789                                                                                          {'tree': 'Spy', 'name': 'Deft Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Deft Trait rating by +1.']}
# 790                                                                                 {'tree': 'Swashbuckler', 'name': 'Deft Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Deft Trait rating by +1.']}
# 791                                                                                      {'tree': 'Athlete', 'name': 'Deft Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Deft Trait rating by +1.']}
# 792                                                                                    {'tree': 'Tactician', 'name': 'Deft Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Deft Trait rating by +1.']}
# 793                                                                                     {'tree': 'Operator', 'name': 'Deft Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Deft Trait rating by +1.']}
# 794                                                                                   {'tree': 'Diplomat', 'name': 'Savvy Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Savvy Trait rating by +1.']}
# 795                                                                                    {'tree': 'Coutier', 'name': 'Savvy Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Savvy Trait rating by +1.']}
# 796                                                                                  {'tree': 'Scoundrel', 'name': 'Savvy Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Savvy Trait rating by +1.']}
# 797                                                                                 {'tree': 'Magic-User', 'name': 'Savvy Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Savvy Trait rating by +1.']}
# 798                                                                                       {'tree': 'Mage', 'name': 'Savvy Trait Increase', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase you Savvy Trait rating by +1.']}
# 799                                                                                       {'tree': 'Detective', 'name': 'Savvy Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you  Trait rating by +1.']}
# 800                                                                                        {'tree': 'Spy', 'name': 'Savvy Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Savvy Trait rating by +1.']}
# 801  {'tree': 'Balladeer', 'name': 'Practiced Trouper', 'type': 'Static', 'rank': '2', 'requires': 'Consummate Performer', 'replaces': None, 'effect': ['You can Craft to recite an Epic.', 'If you lose focus on an Ongoing Epic before completing its final ve...
# 802  {'tree': 'Balladeer', 'name': 'Consummate Performer', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['You are unshakable in your performances, allowing you to use Focus or Composure to Maintain Focus on your Ongoing Epic...
# 803                                                                                  {'tree': 'Balladeer', 'name': 'Savvy Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Savvy Trait rating by +1.']}
# 804  {'tree': 'Balladeer', 'name': 'Lyricist', 'type': 'Static', 'rank': '1', 'requires': 'Practiced Trouper', 'replaces': None, 'effect': ['You have honed your craft in reciting Ballads.  You add +1 Bonus Hits to the result set when you Craft and Epic wit...
# 805                                                                                                {'tree': 'Balladeer', 'name': 'Craft (2)', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['Increase your Craft Rank to 2 (d8).']}
# 806                                                                                        {'tree': 'Balladeer', 'name': 'Composure (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Composure Rank to 2 (d8).']}
# 807                                                                                       {'tree': 'Balladeer', 'name': 'Composure (3)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase your Composure Rank to 3 (d10).']}
# 808                                                                                          {'tree': 'Balladeer', 'name': 'Persuade (2)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase your Persuade Rank to 2 (d8).']}
# 809                                                    {'tree': 'Balladeer', 'name': 'Tavern Busker', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Streetwise Rank to 2 (d8) and your Persuasion Rank to 2 (d8).']}
# 810                                                   {'tree': 'Balladeer', 'name': 'Paid Regular', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Streetwise Rank to 3 (d10) and your Persuasion Rank to 3 (d10).']}
# 811                                                                                               {'tree': 'Balladeer', 'name': 'Craft (3)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Craft Rank to 3 (d10).']}
# 812                                                                                               {'tree': 'Balladeer', 'name': 'Craft (4)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase your Craft Rank to 4 (d12).']}
# 813                                                                                                        {'tree': 'Balladeer', 'name': 'Established Performer', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Gain +3 Wealth.']}
# 814                                                                                 {'tree': 'Rhapsodist', 'name': 'Savvy Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Savvy Trait rating by +1.']}
# 815                                                                                    {'tree': 'Scholar', 'name': 'Savvy Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Savvy Trait rating by +1.']}
# 816                                                                                    {'tree': 'Scholar', 'name': 'Savvy Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Savvy Trait rating by +1.']}
# 817                                                                                  {'tree': 'Defender', 'name': 'Steady Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Savvy Trait rating by +1.']}
# 818                                                                                 {'tree': 'Guardian', 'name': 'Steady Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Steady Trait rating by +1.']}
# 819                                                                                     {'tree': 'Tank', 'name': 'Steady Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Steady Trait rating by +1.']}
# 820                                                                                   {'tree': 'Knight', 'name': 'Steady Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Steady Trait rating by +1.']}
# 821                                                                                  {'tree': 'Samurai', 'name': 'Steady Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Steady Trait rating by +1.']}
# 822                                                                                   {'tree': 'Priest', 'name': 'Steady Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Steady Trait rating by +1.']}
# 823                                                                                   {'tree': 'Hunter', 'name': 'Steady Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Steady Trait rating by +1.']}
# 824                                                                                   {'tree': 'Healer', 'name': 'Steady Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Steady Trait rating by +1.']}
# 825                                                                                   {'tree': 'Ranger', 'name': 'Steady Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Steady Trait rating by +1.']}
# 826                                                                                  {'tree': 'Witch', 'name': 'Uncanny Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Uncanny Trait rating by +1.']}
# 827                                                                                   {'tree': 'Seer', 'name': 'Uncanny Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Uncanny Trait rating by +1.']}
# 828                                                                               {'tree': 'Aberrant', 'name': 'Uncanny Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Uncanny Trait rating by +1.']}
# 829                                                                               {'tree': 'Aberrant', 'name': 'Uncanny Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Uncanny Trait rating by +1.']}
# 830                                                                             {'tree': 'Petitioner', 'name': 'Uncanny Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Uncanny Trait rating by +1.']}
# 831                                                                                 {'tree': 'Thrall', 'name': 'Uncanny Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Uncanny Trait rating by +1.']}
# 832                                                                                 {'tree': 'Mystic', 'name': 'Uncanny Trait Increase', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase you Uncanny Trait rating by +1.']}
# 833                                                                                  {'tree': 'Adept', 'name': 'Uncanny Trait Increase', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase you Uncanny Trait rating by +1.']}

# %%
t= pd.DataFrame(df_talents_raw.iloc[0, 0])
t.groupby(['tree','name','type','rank','requires'])['effect'].apply('<br>'.join).reset_index()
# Out:
#       tree                   name     type rank         requires  \
# 0  Acolyte  Commune with Divinity  Ability    1  Divine Doctrine
#
#                                                                                                                                                                                                                                                            effect
# 0  Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.<br>Your Concordance measures how closely you are aligned with your Divine Doctrine.<br>You may use this Ability without using...

# %%
df_talents = pd.DataFrame()
for i in df_talents_raw.index:
    t = pd.DataFrame(df_talents_raw.iloc[i, 0])
    if len(t['effect']) > 1:
        v = t.groupby(['tree','name','type','rank','requires'])['effect'].apply('<br>'.join).reset_index()
    else:
        v = t.copy()
    df_talents = pd.concat([df_talents, v], axis=0)
df_talents.reset_index(drop=True, inplace=True)
df_talents['name'] = df_talents['name'].astype('str')

# %%
df_talents[df_talents['tree']=='Marksman'].head()
# Out:
#          tree            name     type rank requires  \
# 337  Marksman             Aim    Shift    1     None
# 338  Marksman    Patient Shot    Shift    2     None
# 339  Marksman    Pinning Shot  Ability    2     None
# 340  Marksman  Piercing Shots   Static    3     None
# 341  Marksman     Reflex Shot  Trigger    3     None
#
#                                                                                                                                                                                                     effect  \
# 337                                                                                                            Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.
# 338  Use a Shift to Wait For It with the condition that an ally scores 1+ Hits against your target in melee combat.  When the the condition is met, Shoot your target dealing Hits directly to their Grit.
# 339                                                                                                          Shoot your target, reducing Hits in the result set by -2 but giving your target Restrained 2.
# 340                                                                              You know how punch through your targets' defenses, scoring +1 Bonus Hits to their Grit when you score 1+ Hits with Shoot.
# 341                                                                                                                 When you are the target on Ambush, you immediately dela +1d4 Bonus Hits to one target.
#
#     replaces
# 337      NaN
# 338      NaN
# 339      NaN
# 340      NaN
# 341      NaN

# %%
skills = ["Exert","Grapple","Intimidate","Martial Arts","Shoot","Strike","Throw","Bellor","Inferno","Sangui","Tempest","Implements","Insight","Legerdemain","Operate","Stealth","Tactics","Tumble","Mori","Nox","Plaga","Squall","Craft","Pilot","Analyze","Computers","Cosmology","Current Events","Deceive","History","Linguistics","Nature","Navigate","Persuade","Research","Skrimisiology","Streetwise","Survival","Theology","Arithm","Medicine","Mentis","Phylla","Rime","Torrent","Composure","Endure","Focus","Investigate","Lead","Perceive","Forma","Locus","Lux","Ordi","Tellus","Aether","Destroy","Intuit","Luck","Nihil","Resist","Tempor","Vivus"]

# %%
for s in skills:
    df_talents[s] = [s if s in eff else None for eff in df_talents['effect']]
    df_talents[s].dropna(inplace=True)

# %%
df_talents[skills].head()
# Out:
#   Exert Grapple Intimidate Martial Arts Shoot Strike Throw Bellor Inferno  \
# 0  None    None       None         None  None   None  None   None    None
# 1  None    None       None         None  None   None  None   None    None
# 2  None    None       None         None  None   None  None   None    None
# 3  None    None       None         None  None   None  None   None    None
# 4  None    None       None         None  None   None  None   None    None
#
#   Sangui  ...  Ordi Tellus Aether Destroy Intuit  Luck Nihil Resist Tempor  \
# 0   None  ...  None   None   None    None   None  None  None   None   None
# 1   None  ...  None   None   None    None   None  None  None   None   None
# 2   None  ...  None   None   None    None   None  None  None   None   None
# 3   None  ...  None   None   None    None   None  None  None   None   None
# 4   None  ...  None   None   None    None   None  None  None   None   None
#
#   Vivus
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
#
# [5 rows x 64 columns]

# %%
df_talents['list_skills'] = df_talents[skills].copy().values.tolist()

# %%
df_talents['list_skills'].head()
# Out:
# 0    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None...
# 1    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None...
# 2    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None...
# 3    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None...
# 4    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None...
# Name: list_skills, dtype: object

# %%
x=[]
for i in df_talents.index:
    sl = df_talents.iloc[i]['list_skills'].copy()
    x += [[s for s in sl if s is not None]]
    
df_talents['skills'] = x

# %%
df_talents['skills'].head()
# Out:
# 0    [Composure]
# 1    [Composure]
# 2             []
# 3             []
# 4             []
# Name: skills, dtype: object

# %%
def build_powercard(name, effect, skill, type):
    skill_clean = skill.lower()
    skill_clean = skill_clean.replace(' ', '_')
    powercard = '''!power {{
    --name|@{name} - ''' + name + '''
    --1s|[^talent.ones]
    --Hits|[^talent.ss]
    --Effect|''' + effect + '''
    --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_''' + skill_clean + '''}>4]]
    --format|''' + type.lower() + '''check
    }}'''
    return(powercard)

# %%
n['name']
# Out:
# 'Uncanny Trait Increase'

# %%
df_talents['str_pcard'] = ''

# %%
i=0
n = df_talents.iloc[i][:]
if len(n.skills) > 0:
    pcs = []
    for s in n.skills:
        x = build_powercard(n['name'], n['effect'], s, n['type'])
        pcs.append(x)
    df_talents.loc[i, 'str_pcard'] = pcs

# %%
print(pcs[0])
# Out:
# !power {{
#     --name|@{name} - Commune with Divinity
#     --Effect|Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.<br>Your Concordance measures how closely you are aligned with your Divine Doctrine.<br>You may use this Ability without using an Action at the beginning of each Waypoint.  If you use it during a Waypoint, it requires 8 - Steady Actions (minimum 1 Action).
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_composure}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}

# %%
pcs = []
for i in df_talents.index:
    n = df_talents.iloc[i][:]
    x = []
    if n['type'] != 'Static':
        if len(n['skills']) > 0:
            for s in n['skills']:
                x.append(build_powercard(n['name'], n['effect'], s, n['type']))
    pcs.append(x)
    
df_talents['str_pcard'] = pcs
    # print(i)

# %%
# pcs

# %%
# df_talents['str_pcard']

# %%
df_talents.head(1)
# Out:
#       tree                   name     type rank         requires  \
# 0  Acolyte  Commune with Divinity  Ability    1  Divine Doctrine
#
#                                                                                                                                                                                                                                                            effect  \
# 0  Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.<br>Your Concordance measures how closely you are aligned with your Divine Doctrine.<br>You may use this Ability without using...
#
#   replaces Exert Grapple Intimidate  ... Destroy Intuit  Luck Nihil Resist  \
# 0      NaN  None    None       None  ...    None   None  None  None   None
#
#   Tempor Vivus  \
# 0   None  None
#
#                                                                                                                                                                                                                                                       list_skills  \
# 0  [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None...
#
#         skills  \
# 0  [Composure]
#
#                                                                                                                                                                                                                                                         str_pcard
# 0  [!power {{\n    --name|@{name} - Commune with Divinity\n    --Effect|Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.<br>Your Concordance measures how closely you are aligned...
#
# [1 rows x 74 columns]

# %%
# df_talents.info()

# %%
df_talents['tree'].unique()
# Out:
# array(['Acolyte', 'Aberrant', 'Mystic', 'Alchemist', 'Archmage',
#        'Assassin', 'Athlete', 'Heretic', 'Tactician', 'Bastion',
#        'Berserker', 'Black Belt', 'Blade Weaver', 'Bounty Hunter',
#        'Brute', 'Channeler', 'Conduit', 'Confessor', 'Corsair',
#        'Courtier', 'Defender', 'Guardian', 'Detective', 'Diabolist',
#        'Diplomat', 'Dragoon', 'Driver', 'Druid', 'Duelist',
#        'Elementalist', 'Engineer', 'Fury', 'Grandmaster', 'Healer',
#        'Hunter', 'Infiltrator', 'Intiltrator', 'Juggernaut', 'Knight',
#        'Lich', 'Mage', 'Mageknight', 'Magic-User', 'Marksman', 'Soldier',
#        'Martial Artist', 'Medic', 'Templar', '', 'Scoundrel', 'Mesmer',
#        'Overseer', 'Necromancer', 'Beastmaster', 'Paragon', 'Pilot',
#        'Priest', 'Probabilist', 'Psion', 'Nexus', 'Pugilist',
#        'Raindancer', 'Ranger', 'Reaver', 'Samurai', 'Scholar', 'Scout',
#        'Scrapper', 'Seer', 'Shaman', 'Shifter', 'Shinobi',
#        'Shock Trooper', 'Shugenja', 'Skald', 'Sniper', 'Spellreaver',
#        'Spy', 'Summoner', 'Swashbuckler', 'Tank', 'Thief', 'Operator',
#        'Petitioner', 'Thrall', 'Transmuter', 'Traveler', 'Troubadour',
#        'Rhapsodist', 'Vanguard', 'Warlord', 'Witch', 'Wrestler', 'Zealot',
#        'Zenith', 'Weapon Master', 'Coutier', 'Balladeer', 'Adept'],
#       dtype=object)

# %%
df_talents[df_talents['name']=="Strike with Conviction"]
# Out:
#         tree                    name   type rank      requires  \
# 372  Templar  Strike with Conviction  Shift    1  Avowed Quest
#
#                                                                                                                                                        effect  \
# 372  Spend 2 Conviction.  The next time you Strike, Shoot, or use Martial Arts against a target this turn, automatically us one Effect Trigger from you Boon.
#
#     replaces Exert Grapple Intimidate  ... Destroy Intuit  Luck Nihil Resist  \
# 372      NaN  None    None       None  ...    None   None  None  None   None
#
#     Tempor Vivus  \
# 372   None  None
#
#                                                                                                                                                                                                                                                         list_skills  \
# 372  [None, None, None, Martial Arts, Shoot, Strike, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None,...
#
#                             skills  \
# 372  [Martial Arts, Shoot, Strike]
#
#                                                                                                                                                                                                                                                           str_pcard
# 372  [!power {{{{\n    --name|@{{name}} - Strike with Conviction\n    --Effect|Spend 2 Conviction.  The next time you Strike, Shoot, or use Martial Arts against a target this turn, automatically us one Effect Trigger from you Boon.\n    --Result Set|[[ [$t...
#
# [1 rows x 74 columns]

# %%
for p in df_talents[df_talents['name']=="Strike with Conviction"]['str_pcard']:
    for i in p:
        print(i)
# Out:
# !power {{
#     --name|@{name} - Strike with Conviction
#     --Effect|Spend 2 Conviction.  The next time you Strike, Shoot, or use Martial Arts against a target this turn, automatically us one Effect Trigger from you Boon.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_martial_arts}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}
# !power {{
#     --name|@{name} - Strike with Conviction
#     --Effect|Spend 2 Conviction.  The next time you Strike, Shoot, or use Martial Arts against a target this turn, automatically us one Effect Trigger from you Boon.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_shoot}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}
# !power {{
#     --name|@{name} - Strike with Conviction
#     --Effect|Spend 2 Conviction.  The next time you Strike, Shoot, or use Martial Arts against a target this turn, automatically us one Effect Trigger from you Boon.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_strike}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}

# %%
df_talents[df_talents['name']=='Aim']
# Out:
#          tree name   type rank requires  \
# 271    Hunter  Aim  Shift    2     None
# 337  Marksman  Aim  Shift    1     None
# 564   Soldier  Aim  Shift    2     None
#
#                                                                                           effect  \
# 271  Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.
# 337  Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.
# 564  Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.
#
#     replaces Exert Grapple Intimidate  ... Destroy Intuit  Luck Nihil Resist  \
# 271      NaN  None    None       None  ...    None   None  None  None   None
# 337      NaN  None    None       None  ...    None   None  None  None   None
# 564      NaN  None    None       None  ...    None   None  None  None   None
#
#     Tempor Vivus  \
# 271   None  None
# 337   None  None
# 564   None  None
#
#                                                                                                                                                                                                                                                         list_skills  \
# 271  [None, None, None, None, Shoot, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, Non...
# 337  [None, None, None, None, Shoot, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, Non...
# 564  [None, None, None, None, Shoot, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, Non...
#
#       skills  \
# 271  [Shoot]
# 337  [Shoot]
# 564  [Shoot]
#
#                                                                                                                                                                                                                                                           str_pcard
# 271  [!power {{\n    --name|@{name} - Aim\n    --Effect|Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.\n    --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_shoot}>4]]\n    --Hits|[^talent.ss]\n    --1s|...
# 337  [!power {{\n    --name|@{name} - Aim\n    --Effect|Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.\n    --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_shoot}>4]]\n    --Hits|[^talent.ss]\n    --1s|...
# 564  [!power {{\n    --name|@{name} - Aim\n    --Effect|Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.\n    --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_shoot}>4]]\n    --Hits|[^talent.ss]\n    --1s|...
#
# [3 rows x 74 columns]

# %%
type='Shift'
tals = df_talents[(df_talents['type']==type)]
div_str = '''<div class="grid-container">\n''' 
for index, tal in tals.iterrows():
    div_str += '''<input class="sheet-training-ranks" type="hidden" name="attr_training_rank_''' + tal['tree'].lower() + '''" step="1" value="0" min="0" max="20" />\n<div class="sheet-training-talents">\n''' 
    div_str +='''<div class="grid-item">\n<input type="checkbox" /><label>''' + tal['name'] + '''<br><span style="font-size:10pt;">''' + tal['tree'] + '''</span></label>\n<div class="talent-rollbox">\n<p>''' + tal['effect'] + '''</p>\n'''
    if len(tal['str_pcard']) > 0:
        for p in tal['str_pcard']:
            div_str +='''<button class="skill-button" type="roll" value="''' + p +'''">\n</button>\n'''
    else:
        div_str +='''<button class="skill-button" type="roll" value="!power {{
    --name|@{Name} - ''' + tal['name'] + '''
    --Effect|''' + tal['effect'] + '''
    --format|''' + type.lower() + '''check
    }}">\n</button>\n'''
    div_str +='''</div>\n</div>\n</div>\n'''

div_str += '''\n</div>\n</div>'''
print(div_str)
# Out:
# <div class="grid-container">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_assassin" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Marked for Death<br><span style="font-size:10pt;">Assassin</span></label>
# <div class="talent-rollbox">
# <p>Use your Tactics to mark your target, giving them Aura X, where X is equal to Hits in your result set.  Your target is Vulnerable 1 to any Action you take against it while the Aura persists.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Marked for Death
#     --Effect|Use your Tactics to mark your target, giving them Aura X, where X is equal to Hits in your result set.  Your target is Vulnerable 1 to any Action you take against it while the Aura persists.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_tactics}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_conduit" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Attuning Conflux<br><span style="font-size:10pt;">Conduit</span></label>
# <div class="talent-rollbox">
# <p>Spend X Hits from the result set of the next Marvel you use this turn to increase your Attunement by X.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Attuning Conflux
#     --Effect|Spend X Hits from the result set of the next Marvel you use this turn to increase your Attunement by X.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_defender" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Stay Close to Me<br><span style="font-size:10pt;">Defender</span></label>
# <div class="talent-rollbox">
# <p>Use a Shift to protect 1 ally in your Current Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Stay Close to Me
#     --Effect|Use a Shift to protect 1 ally in your Current Zone.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_druid" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Nature's Wrath<br><span style="font-size:10pt;">Druid</span></label>
# <div class="talent-rollbox">
# <p>Spend X Attunement and spend an Action to use two Marvels.  You can add +X bonus Hits to either Marvel's result set.<br>Your Attunement decreases to 0.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Nature's Wrath
#     --Effect|Spend X Attunement and spend an Action to use two Marvels.  You can add +X bonus Hits to either Marvel's result set.<br>Your Attunement decreases to 0.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_elementalist" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Shape the elements<br><span style="font-size:10pt;">Elementalist</span></label>
# <div class="talent-rollbox">
# <p>Spend 2 Meomentum and gain +2 Current.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Shape the elements
#     --Effect|Spend 2 Meomentum and gain +2 Current.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_hunter" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Aim<br><span style="font-size:10pt;">Hunter</span></label>
# <div class="talent-rollbox">
# <p>Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Aim
#     --Effect|Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_shoot}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_hunter" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Predator’s Instinct<br><span style="font-size:10pt;">Hunter</span></label>
# <div class="talent-rollbox">
# <p>Focus to enter a heightened state of awareness, adding +1d4 Bonus Hits to your next Shoot attempt or Initiative Test.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Predator’s Instinct
#     --Effect|Focus to enter a heightened state of awareness, adding +1d4 Bonus Hits to your next Shoot attempt or Initiative Test.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_shoot}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Predator’s Instinct
#     --Effect|Focus to enter a heightened state of awareness, adding +1d4 Bonus Hits to your next Shoot attempt or Initiative Test.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_focus}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_knight" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Dedicated Exemplar<br><span style="font-size:10pt;">Knight</span></label>
# <div class="talent-rollbox">
# <p>Spend X Dedication to add X Hits to your next roll.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Dedicated Exemplar
#     --Effect|Spend X Dedication to add X Hits to your next roll.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_knight" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Momentous Act<br><span style="font-size:10pt;">Knight</span></label>
# <div class="talent-rollbox">
# <p>Spend 2 Momentum, then take an Action.  If there are no 1s in the result set, increase the Momentum by +5.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Momentous Act
#     --Effect|Spend 2 Momentum, then take an Action.  If there are no 1s in the result set, increase the Momentum by +5.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_marksman" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Aim<br><span style="font-size:10pt;">Marksman</span></label>
# <div class="talent-rollbox">
# <p>Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Aim
#     --Effect|Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_shoot}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_marksman" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Patient Shot<br><span style="font-size:10pt;">Marksman</span></label>
# <div class="talent-rollbox">
# <p>Use a Shift to Wait For It with the condition that an ally scores 1+ Hits against your target in melee combat.  When the the condition is met, Shoot your target dealing Hits directly to their Grit.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Patient Shot
#     --Effect|Use a Shift to Wait For It with the condition that an ally scores 1+ Hits against your target in melee combat.  When the the condition is met, Shoot your target dealing Hits directly to their Grit.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_shoot}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_martial artist" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Float like a butterfly. . .<br><span style="font-size:10pt;">Martial Artist</span></label>
# <div class="talent-rollbox">
# <p>Until the beginning of your next turn, use Reflexes +1d4 as as your Primary Defense.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Float like a butterfly. . .
#     --Effect|Until the beginning of your next turn, use Reflexes +1d4 as as your Primary Defense.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_templar" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Strike with Conviction<br><span style="font-size:10pt;">Templar</span></label>
# <div class="talent-rollbox">
# <p>Spend 2 Conviction.  The next time you Strike, Shoot, or use Martial Arts against a target this turn, automatically us one Effect Trigger from you Boon.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Strike with Conviction
#     --Effect|Spend 2 Conviction.  The next time you Strike, Shoot, or use Martial Arts against a target this turn, automatically us one Effect Trigger from you Boon.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_martial_arts}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Strike with Conviction
#     --Effect|Spend 2 Conviction.  The next time you Strike, Shoot, or use Martial Arts against a target this turn, automatically us one Effect Trigger from you Boon.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_shoot}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Strike with Conviction
#     --Effect|Spend 2 Conviction.  The next time you Strike, Shoot, or use Martial Arts against a target this turn, automatically us one Effect Trigger from you Boon.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_strike}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_templar" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Relentless Conviction<br><span style="font-size:10pt;">Templar</span></label>
# <div class="talent-rollbox">
# <p>Increase the Entropy by +2 to regain +3 Conviction</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Relentless Conviction
#     --Effect|Increase the Entropy by +2 to regain +3 Conviction
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_overseer" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Coordinated Strike<br><span style="font-size:10pt;">Overseer</span></label>
# <div class="talent-rollbox">
# <p>Lead your Minions to launch a coordinated melee against a single target in your Current or an Adjacent Zone, dealing X Hits to the target, where X is the sum of your Minions' Melee stat in the target's Current Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Coordinated Strike
#     --Effect|Lead your Minions to launch a coordinated melee against a single target in your Current or an Adjacent Zone, dealing X Hits to the target, where X is the sum of your Minions' Melee stat in the target's Current Zone.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_lead}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_overseer" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Coordinated Volley<br><span style="font-size:10pt;">Overseer</span></label>
# <div class="talent-rollbox">
# <p>Lead your Minions to launch a coordinated ranged attack against a single target in your Current or an Adjacent Zone, dealing X Hits the the target, where X is the sum of your Minons' Ranged stat in the target's Current Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Coordinated Volley
#     --Effect|Lead your Minions to launch a coordinated ranged attack against a single target in your Current or an Adjacent Zone, dealing X Hits the the target, where X is the sum of your Minons' Ranged stat in the target's Current Zone.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_lead}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_necromancer" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Rip and Tear!<br><span style="font-size:10pt;">Necromancer</span></label>
# <div class="talent-rollbox">
# <p>Lead your Minions to launch a coordinated melee against a single target in your Current or an Adjacent Zone, dealing X Hits to the target, where X is the + sum of your Minions' Melee stat in the target's Current Zone.<br>If the target dies, one other target in the same Zone becomes Afraid of your Minions.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Rip and Tear!
#     --Effect|Lead your Minions to launch a coordinated melee against a single target in your Current or an Adjacent Zone, dealing X Hits to the target, where X is the + sum of your Minions' Melee stat in the target's Current Zone.<br>If the target dies, one other target in the same Zone becomes Afraid of your Minions.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_lead}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_necromancer" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Death's Reach<br><span style="font-size:10pt;">Necromancer</span></label>
# <div class="talent-rollbox">
# <p>Lead your Haunts to launch a coordinated ranged attack against a single target in your Current or an Adjacent Zone, dealing X Hits the the target, where X is the Hits in the result set + sum of your Haunts Ranged stat in the target's Current Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Death's Reach
#     --Effect|Lead your Haunts to launch a coordinated ranged attack against a single target in your Current or an Adjacent Zone, dealing X Hits the the target, where X is the Hits in the result set + sum of your Haunts Ranged stat in the target's Current Zone.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_lead}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_beastmaster" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Pack Tactics<br><span style="font-size:10pt;">Beastmaster</span></label>
# <div class="talent-rollbox">
# <p>Lead your Minions to launch a coordinated melee against a single target in your Current or an Adjacent Zone, dealing X Hits to the target, where X is the sum of your Minions' Melee stat in the target's Current Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Pack Tactics
#     --Effect|Lead your Minions to launch a coordinated melee against a single target in your Current or an Adjacent Zone, dealing X Hits to the target, where X is the sum of your Minions' Melee stat in the target's Current Zone.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_lead}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_nexus" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Momentous Marvel<br><span style="font-size:10pt;">Nexus</span></label>
# <div class="talent-rollbox">
# <p>Spend 4 Momentum and immediately use one of your Marvels without spending an Action.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Momentous Marvel
#     --Effect|Spend 4 Momentum and immediately use one of your Marvels without spending an Action.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_pugilist" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Float like a butterfly. . .<br><span style="font-size:10pt;">Pugilist</span></label>
# <div class="talent-rollbox">
# <p>Until the beginning of your next turn, use Reflexes +1d4 as as your Primary Defense.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Float like a butterfly. . .
#     --Effect|Until the beginning of your next turn, use Reflexes +1d4 as as your Primary Defense.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_ranger" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Warden's Mark<br><span style="font-size:10pt;">Ranger</span></label>
# <div class="talent-rollbox">
# <p>Use your Tactics to mark your target, giving them Aura X, where X is equal to Hits in your result set.  Your target is Vulnerable 1 to any Action you take against it while the Aura persists.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Warden's Mark
#     --Effect|Use your Tactics to mark your target, giving them Aura X, where X is equal to Hits in your result set.  Your target is Vulnerable 1 to any Action you take against it while the Aura persists.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_tactics}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_scrapper" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Float like a butterfly. . .<br><span style="font-size:10pt;">Scrapper</span></label>
# <div class="talent-rollbox">
# <p>Until the beginning of your next turn, use Reflexes +1d4 as as your Primary Defense.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Float like a butterfly. . .
#     --Effect|Until the beginning of your next turn, use Reflexes +1d4 as as your Primary Defense.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_seer" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Dig Through Time<br><span style="font-size:10pt;">Seer</span></label>
# <div class="talent-rollbox">
# <p>Spend X Momentum to add X Bonus Hits to the next Portent you use this turn.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Dig Through Time
#     --Effect|Spend X Momentum to add X Bonus Hits to the next Portent you use this turn.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_shaman" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Humble Offering<br><span style="font-size:10pt;">Shaman</span></label>
# <div class="talent-rollbox">
# <p>Spend 2 Hits from the result set of the next Spirit you use this turn to increase your Rank in that Spirit by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Humble Offering
#     --Effect|Spend 2 Hits from the result set of the next Spirit you use this turn to increase your Rank in that Spirit by +1.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_shugenja" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Shugen-do<br><span style="font-size:10pt;">Shugenja</span></label>
# <div class="talent-rollbox">
# <p>Spend 2 Hits from the result set of the next Spirit you use this turn to increase your Rank in that Spirit by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Shugen-do
#     --Effect|Spend 2 Hits from the result set of the next Spirit you use this turn to increase your Rank in that Spirit by +1.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_soldier" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Aim<br><span style="font-size:10pt;">Soldier</span></label>
# <div class="talent-rollbox">
# <p>Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Aim
#     --Effect|Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_shoot}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_soldier" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Flanking<br><span style="font-size:10pt;">Soldier</span></label>
# <div class="talent-rollbox">
# <p>Use your Tactics to position yourself and an ally in your current Zone advantageously, choosing one target in your current Zone to gain a Vulnerable rating equal to Hits.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Flanking
#     --Effect|Use your Tactics to position yourself and an ally in your current Zone advantageously, choosing one target in your current Zone to gain a Vulnerable rating equal to Hits.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_tactics}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_tank" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Walk it off<br><span style="font-size:10pt;">Tank</span></label>
# <div class="talent-rollbox">
# <p>Use the Recover action.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{Name} - Walk it off
#     --Effect|Use the Recover action.
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_scout" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <div class="grid-item">
# <input type="checkbox" /><label>Pathfinder's Mark<br><span style="font-size:10pt;">Scout</span></label>
# <div class="talent-rollbox">
# <p>Use your Survival skill to Create an Advantage while scouting ahead of your allies, adding +1d4 Bonus Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{name} - Pathfinder's Mark
#     --Effect|Use your Survival skill to Create an Advantage while scouting ahead of your allies, adding +1d4 Bonus Hits to the result set.
#     --Result Set|[[ [$talent|XPND] @{BAMF|challenge}d@{skill_survival}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}">
# </button>
# </div>
# </div>
# </div>
#
# </div>
# </div>

# %%
tals
# Out:
#        tree           name   type rank requires  \
# 466  Ranger  Warden's Mark  Shift    2     None
#
#                                                                                                                                                                                              effect  \
# 466  Use your Tactics to mark your target, giving them Aura X, where X is equal to Hits in your result set.  Your target is Vulnerable 1 to any Action you take against it while the Aura persists.
#
#     replaces Exert Grapple Intimidate  ... Destroy Intuit  Luck Nihil Resist  \
# 466      NaN  None    None       None  ...    None   None  None  None   None
#
#     Tempor Vivus  \
# 466   None  None
#
#                                                                                                                                                                                                                                                         list_skills  \
# 466  [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, Tactics, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, N...
#
#         skills  \
# 466  [Tactics]
#
#                                                                                                                                                                                                                                                           str_pcard
# 466  [!power {{{{\n    --name|@{{name}} - Warden's Mark\n    --Effect|Use your Tactics to mark your target, giving them Aura X, where X is equal to Hits in your result set.  Your target is Vulnerable 1 to any Action you take against it while the Aura persi...
#
# [1 rows x 74 columns]

# %%
df_talents['tal_attr_nm'] = df_talents.name.str.replace(' ', '_')
df_talents['tal_attr_nm'] = df_talents['tal_attr_nm'].str.lower()
df_talents['path_attr_nm'] = df_talents['tree'].str.lower()
df_talents['div_id_nm'] = 'tal_' + df_talents['type'].str.lower() + '_' + df_talents['path_attr_nm'] + '_' + df_talents['tal_attr_nm']
df_talents['str_cbox'] = '''<label for="''' + df_talents['div_id_nm'] + '''">''' + df_talents['name'] + ''''</label><input type="checkbox" id="''' + df_talents['div_id_nm'] + '''">'''

# %%
df_talents.head()
# Out:
#       tree                   name     type rank         requires replaces  \
# 0  Acolyte  Commune with Divinity  Ability    1  Divine Doctrine     None
# 1  Acolyte  Commune with Divinity  Ability    1  Divine Doctrine     None
# 2  Acolyte  Commune with Divinity  Ability    1  Divine Doctrine     None
# 3  Acolyte        Divine Doctrine   Static    1             None     None
# 4  Acolyte        Divine Doctrine   Static    1             None     None
#
#                                                                                                                                                                                                                                                            effect  \
# 0                                                                                                                                   Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.
# 1                                                                                                                                                                                Your Concordance measures how closely you are aligned with your Divine Doctrine.
# 2                                                                                        You may use this Ability without using an Action at the beginning of each Waypoint.  If you use it during a Waypoint, it requires 8 - Steady Actions (minimum 1 Action).
# 3  You follow set of principles in your belief system or religious practice, referred to as your Divine Doctrine.  Each Divine Doctrine consists of <em>Virtues</em>, <em>Taboos</em>, and <em>Domains</em>.<br>When you act against your Virtues or engage in...
# 4                                   Select two items from the list below to be your Virtues and two items to be your Taboos:<br><em>Temperance, Indulgence, Avarice, Charity, Humility, Compassion, Wrath, Courage, Deceipt, Justice, Loyalty, Honesty . . .</em>
#
#   Exert Grapple Intimidate  ... Nihil Resist Tempor Vivus       skills  \
# 0  None    None       None  ...  None   None   None  None  [Composure]
# 1  None    None       None  ...  None   None   None  None           []
# 2  None    None       None  ...  None   None   None  None           []
# 3  None    None       None  ...  None   None   None  None           []
# 4  None    None       None  ...  None   None   None  None           []
#
#                                                                                                                                                                                                                                                         str_pcard  \
# 0  [!power {{{{\n    --name|@{{name}} - Commune with Divinity\n    --Effect|Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.\n    --Result Set|[[ [$talent|XPND] @{{BAMF|challeng...
# 1                                                                                                                                                                                                                                                             NaN
# 2                                                                                                                                                                                                                                                             NaN
# 3                                                                                                                                                                                                                                                             NaN
# 4                                                                                                                                                                                                                                                             NaN
#
#              tal_attr_nm path_attr_nm  \
# 0  commune_with_divinity      acolyte
# 1  commune_with_divinity      acolyte
# 2  commune_with_divinity      acolyte
# 3        divine_doctrine      acolyte
# 4        divine_doctrine      acolyte
#
#                                    div_id_nm  \
# 0  tal_ability_acolyte_commune_with_divinity
# 1  tal_ability_acolyte_commune_with_divinity
# 2  tal_ability_acolyte_commune_with_divinity
# 3         tal_static_acolyte_divine_doctrine
# 4         tal_static_acolyte_divine_doctrine
#
#                                                                                                                                                       str_cbox
# 0  <label for="tal_ability_acolyte_commune_with_divinity">Commune with Divinity'</label><input type="checkbox" id="tal_ability_acolyte_commune_with_divinity">
# 1  <label for="tal_ability_acolyte_commune_with_divinity">Commune with Divinity'</label><input type="checkbox" id="tal_ability_acolyte_commune_with_divinity">
# 2  <label for="tal_ability_acolyte_commune_with_divinity">Commune with Divinity'</label><input type="checkbox" id="tal_ability_acolyte_commune_with_divinity">
# 3                      <label for="tal_static_acolyte_divine_doctrine">Divine Doctrine'</label><input type="checkbox" id="tal_static_acolyte_divine_doctrine">
# 4                      <label for="tal_static_acolyte_divine_doctrine">Divine Doctrine'</label><input type="checkbox" id="tal_static_acolyte_divine_doctrine">
#
# [5 rows x 77 columns]

# %%
print('''<label for="tal_static_acolyte_divine_doctrine">Divine Doctrine'</label><input type="checkbox" id="tal_static_acolyte_divine_doctrine">''')
# Out:
# <label for="tal_static_acolyte_divine_doctrine">Divine Doctrine'</label><input type="checkbox" id="tal_static_acolyte_divine_doctrine">

# %%
# the HTML below works.  labesl and checkboxes need to be adjacent to the effect div.  current the CSS style has display: none for not(:checked) AND displat: Block for :checked
'''
<!DOCTYPE html>
<html>
<head>
<title>Page Title</title>
<style>
	input[type=checkbox]:checked~#tal_ability_reaver_rending_strike {
	display: block;
	}
    input[type=checkbox]:checked~#tal_trigger_reaver_blood_fury {
	display: block;
	}
    input[type=checkbox]:not(:checked)~#tal_ability_reaver_rending_strike {
	display: none;
	}
    input[type=checkbox]:not(:checked)~#tal_trigger_reaver_blood_fury {
	display: none;
	}
</style>
</head>
<body>
<div>
	<label for="tal_ability_reaver_rending_strike">Rending Strike</label>
	<input type="checkbox" id="tal_ability_reaver_rending_strike">
    <div id="tal_ability_reaver_rending_strike">
	Strike your target, delaing +1 Bonus Hits directly to their Grit.
</div>
</div>
<div>
	<label for="tal_trigger_reaver_blood_fury">Blood Fury</label>
	<input type="checkbox" id="tal_trigger_reaver_blood_fury">
    <div id="tal_trigger_reaver_blood_fury">
	When you are below your maximum Grit, add +1 Bonus Hits to any results set using Strike.
</div>
</div>



</body>
</html>
'''

# %%
print(str_div)
# Out:
# <div id="tal_ability_reaver_rending_strike">
# 	Strike your target, delaing +1 Bonus Hits directly to their Grit.
# </div>
# <div id="tal_trigger_reaver_blood_fury">
# 	When you are below your maximum Grit, add +1 Bonus Hits to any results set using Strike.
# </div>
# <div id="tal_trigger_reaver_strike_(3)">
# 	Increase your Strike Rank to 3 (d10).
# </div>
# <div id="tal_ability_reaver_whirlwind_strike">
# 	Strike at all hostile Targets in your Current Zone.  Deal 1 Hit to a number of targets equal to Hits in the result set.
# </div>
# <div id="tal_trigger_reaver_soul_reaver">
# 	When you Strike your target to death, immediately regain +2 points to your Grit.
# </div>
# <div id="tal_ability_reaver_vicious_whirlwind">
# 	Strike at all hostile Targets in your Current Zone.  Deal 2 Hits to a number of targets equal to Hits in the result set.
# </div>
# <div id="tal_ability_reaver_vicious_rending">
# 	Strike your target, delaing +2 Bonus Hits directly to their Grit.
# </div>
# <div id="tal_ability_reaver_">
#
# </div>
# <div id="tal_ability_reaver_">
#
# </div>
# <div id="tal_static_reaver_dangerous_trait_increase">
# 	Increase you Dangerous Trait rating by +1.
# </div>

# %%
print(str_cbox)
# Out:
# <label for="tal_ability_reaver_rending_strike">Rending Strike</label>
# <input type="checkbox" id="tal_ability_reaver_rending_strike">
# <label for="tal_trigger_reaver_blood_fury">Blood Fury</label>
# <input type="checkbox" id="tal_trigger_reaver_blood_fury">
# <label for="tal_trigger_reaver_strike_(3)">Strike (3)</label>
# <input type="checkbox" id="tal_trigger_reaver_strike_(3)">
# <label for="tal_ability_reaver_whirlwind_strike">Whirlwind Strike</label>
# <input type="checkbox" id="tal_ability_reaver_whirlwind_strike">
# <label for="tal_trigger_reaver_soul_reaver">Soul Reaver</label>
# <input type="checkbox" id="tal_trigger_reaver_soul_reaver">
# <label for="tal_ability_reaver_vicious_whirlwind">Vicious Whirlwind</label>
# <input type="checkbox" id="tal_ability_reaver_vicious_whirlwind">
# <label for="tal_ability_reaver_vicious_rending">Vicious Rending</label>
# <input type="checkbox" id="tal_ability_reaver_vicious_rending">
# <label for="tal_ability_reaver_"></label>
# <input type="checkbox" id="tal_ability_reaver_">
# <label for="tal_ability_reaver_"></label>
# <input type="checkbox" id="tal_ability_reaver_">
# <label for="tal_static_reaver_dangerous_trait_increase">Dangerous Trait Increase</label>
# <input type="checkbox" id="tal_static_reaver_dangerous_trait_increase">

# %%
str_div = ""
for i in rvr.index:
    str_div += f'''<div id="{rvr.iloc[i]['div_id_nm']}">\n\t{rvr.iloc[i]['effect']}\n</div>\n'''

# %%
print(str_div)
# Out:
# <div id="tal_ability_reaver_rending_strike">
# 	Strike your target, delaing +1 Bonus Hits directly to their Grit.
# </div>
# <div id="tal_trigger_reaver_blood_fury">
# 	When you are below your maximum Grit, add +1 Bonus Hits to any results set using Strike.
# </div>
# <div id="tal_trigger_reaver_strike_(3)">
# 	Increase your Strike Rank to 3 (d10).
# </div>
# <div id="tal_ability_reaver_whirlwind_strike">
# 	Strike at all hostile Targets in your Current Zone.  Deal 1 Hit to a number of targets equal to Hits in the result set.
# </div>
# <div id="tal_trigger_reaver_soul_reaver">
# 	When you Strike your target to death, immediately regain +2 points to your Grit.
# </div>
# <div id="tal_ability_reaver_vicious_whirlwind">
# 	Strike at all hostile Targets in your Current Zone.  Deal 2 Hits to a number of targets equal to Hits in the result set.
# </div>
# <div id="tal_ability_reaver_vicious_rending">
# 	Strike your target, delaing +2 Bonus Hits directly to their Grit.
# </div>
# <div id="tal_ability_reaver_">
#
# </div>
# <div id="tal_ability_reaver_">
#
# </div>
# <div id="tal_static_reaver_dangerous_trait_increase">
# 	Increase you Dangerous Trait rating by +1.
# </div>

# %%
str_css = "<style>\n"
for i in rvr.index:
    str_css += f'''\tinput:not(:checked)+#{rvr.iloc[i]['div_id_nm']} {{\n\tdisplay: none;\n}}\n'''
str_css += "<\style>\n"

# %%
print(str_css)
# Out:
# <style>
# 	input:not(:checked)+#tal_ability_reaver_rending_strike {
# 	display: none;
# }
# 	input:not(:checked)+#tal_trigger_reaver_blood_fury {
# 	display: none;
# }
# 	input:not(:checked)+#tal_trigger_reaver_strike_(3) {
# 	display: none;
# }
# 	input:not(:checked)+#tal_ability_reaver_whirlwind_strike {
# 	display: none;
# }
# 	input:not(:checked)+#tal_trigger_reaver_soul_reaver {
# 	display: none;
# }
# 	input:not(:checked)+#tal_ability_reaver_vicious_whirlwind {
# 	display: none;
# }
# 	input:not(:checked)+#tal_ability_reaver_vicious_rending {
# 	display: none;
# }
# 	input:not(:checked)+#tal_ability_reaver_ {
# 	display: none;
# }
# 	input:not(:checked)+#tal_ability_reaver_ {
# 	display: none;
# }
# 	input:not(:checked)+#tal_static_reaver_dangerous_trait_increase {
# 	display: none;
# }
# <\style>

# %%
print(str_cbox)
# Out:
# <label for="tal_ability_reaver_rending_strike">Rending Strike</label>
# <input type="checkbox" id="tal_ability_reaver_rending_strike">
# <label for="tal_trigger_reaver_blood_fury">Blood Fury</label>
# <input type="checkbox" id="tal_trigger_reaver_blood_fury">
# <label for="tal_trigger_reaver_strike_(3)">Strike (3)</label>
# <input type="checkbox" id="tal_trigger_reaver_strike_(3)">
# <label for="tal_ability_reaver_whirlwind_strike">Whirlwind Strike</label>
# <input type="checkbox" id="tal_ability_reaver_whirlwind_strike">
# <label for="tal_trigger_reaver_soul_reaver">Soul Reaver</label>
# <input type="checkbox" id="tal_trigger_reaver_soul_reaver">
# <label for="tal_ability_reaver_vicious_whirlwind">Vicious Whirlwind</label>
# <input type="checkbox" id="tal_ability_reaver_vicious_whirlwind">
# <label for="tal_ability_reaver_vicious_rending">Vicious Rending</label>
# <input type="checkbox" id="tal_ability_reaver_vicious_rending">
# <label for="tal_ability_reaver_"></label>
# <input type="checkbox" id="tal_ability_reaver_">
# <label for="tal_ability_reaver_"></label>
# <input type="checkbox" id="tal_ability_reaver_">
# <label for="tal_static_reaver_dangerous_trait_increase">Dangerous Trait Increase</label>
# <input type="checkbox" id="tal_static_reaver_dangerous_trait_increase">

# %%
print(str_cbox + '\n'+  str_div)
# Out:
# <label for="tal_ability_reaver_rending_strike">Rending Strike</label>
# <input type="checkbox" id="tal_ability_reaver_rending_strike">
# <label for="tal_trigger_reaver_blood_fury">Blood Fury</label>
# <input type="checkbox" id="tal_trigger_reaver_blood_fury">
# <label for="tal_trigger_reaver_strike_(3)">Strike (3)</label>
# <input type="checkbox" id="tal_trigger_reaver_strike_(3)">
# <label for="tal_ability_reaver_whirlwind_strike">Whirlwind Strike</label>
# <input type="checkbox" id="tal_ability_reaver_whirlwind_strike">
# <label for="tal_trigger_reaver_soul_reaver">Soul Reaver</label>
# <input type="checkbox" id="tal_trigger_reaver_soul_reaver">
# <label for="tal_ability_reaver_vicious_whirlwind">Vicious Whirlwind</label>
# <input type="checkbox" id="tal_ability_reaver_vicious_whirlwind">
# <label for="tal_ability_reaver_vicious_rending">Vicious Rending</label>
# <input type="checkbox" id="tal_ability_reaver_vicious_rending">
# <label for="tal_ability_reaver_"></label>
# <input type="checkbox" id="tal_ability_reaver_">
# <label for="tal_ability_reaver_"></label>
# <input type="checkbox" id="tal_ability_reaver_">
# <label for="tal_static_reaver_dangerous_trait_increase">Dangerous Trait Increase</label>
# <input type="checkbox" id="tal_static_reaver_dangerous_trait_increase">
#
# <div id="rvr_tal_rending_strike">
# 	Strike your target, delaing +1 Bonus Hits directly to their Grit.
# </div>
# <div id="rvr_tal_rending_strike">
# 	When you are below your maximum Grit, add +1 Bonus Hits to any results set using Strike.
# </div>
# <div id="rvr_tal_rending_strike">
# 	Increase your Strike Rank to 3 (d10).
# </div>
# <div id="rvr_tal_rending_strike">
# 	Strike at all hostile Targets in your Current Zone.  Deal 1 Hit to a number of targets equal to Hits in the result set.
# </div>
# <div id="rvr_tal_rending_strike">
# 	When you Strike your target to death, immediately regain +2 points to your Grit.
# </div>
# <div id="rvr_tal_rending_strike">
# 	Strike at all hostile Targets in your Current Zone.  Deal 2 Hits to a number of targets equal to Hits in the result set.
# </div>
# <div id="rvr_tal_rending_strike">
# 	Strike your target, delaing +2 Bonus Hits directly to their Grit.
# </div>
# <div id="rvr_tal_rending_strike">
#
# </div>
# <div id="rvr_tal_rending_strike">
#
# </div>
# <div id="rvr_tal_rending_strike">
# 	Increase you Dangerous Trait rating by +1.
# </div>
