# %%
import pandas as pd
# import htmlgenerator as hg
import os
import json
import numpy as np

while os.getcwd()[-10:] != 'no1_system':
    os.chdir('..')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\DonalHarrison\\Documents\\admin\\ach\\no1\\no1_system'

# %% [markdown]
# ## Training start

# %%
df_training = pd.read_csv('./docs/_data/training.csv')

# %%
pd.set_option('display.max_colwidth', 255)
df_training.head(5)
# Out:
#         Name   Type Prerequisites  \
# 0   Aberrant  Basic     Uncanny 2
# 1    Acolyte  Basic      Steady 2
# 2  Alchemist  Basic       Savvy 2
# 3      Brute  Basic   Dangerous 2
# 4  Channeler  Basic           NaN
#
#                                                                                                                             Description  \
# 0  You tap into mysterious and otherworldly power sources, harnessing enigmatic and often dangerous powers beyond mortal comprehension.
# 1                      You are a follower of a religion or spiritual practice, granting you kowledge of and powers from its principles.
# 2                                                You are adept at potion-making and transmutation, wielding transformative concoctions.
# 3                                                  You are a savage & resilient combatant, focusing on destroying one target at a time.
# 4                            You harness and manipulate fundamental energies of existence, acting as a conduit to the elemental forces.
#
#                                img_path  \
# 0   /no1_system/assets/img/aberrant.png
# 1    /no1_system/assets/img/acolyte.png
# 2  /no1_system/assets/img/alchemist.png
# 3      /no1_system/assets/img/brute.png
# 4  /no1_system/assets/img/channeler.png
#
#                                     page_path  \
# 0   /no1_system/characters/training/aberrant/
# 1    /no1_system/characters/training/acolyte/
# 2  /no1_system/characters/training/alchemist/
# 3      /no1_system/characters/training/brute/
# 4  /no1_system/characters/training/channeler/
#
#                                                                                              tag_img_src  \
# 0   https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/aberrant.png
# 1    https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/acolyte.png
# 2  https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/alchemist.png
# 3      https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/brute.png
# 4  https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/channeler.png
#
#           attr_training_rank_nm  \
# 0   attr_training_rank_aberrant
# 1    attr_training_rank_acolyte
# 2  attr_training_rank_alchemist
# 3      attr_training_rank_brute
# 4  attr_training_rank_channeler
#
#                                                                                                                                                                                                                                                           div_str
# 0  <div class="grid-character-training-item"><img src="https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/aberrant.png" alt="Aberrant Icon" width="80px" height="80px">Aberrant<input class="sheet-training-ranks" type="...
# 1  <div class="grid-character-training-item"><img src="https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/acolyte.png" alt="Acolyte Icon" width="80px" height="80px">Acolyte<input class="sheet-training-ranks" type="num...
# 2  <div class="grid-character-training-item"><img src="https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/alchemist.png" alt="Alchemist Icon" width="80px" height="80px">Alchemist<input class="sheet-training-ranks" typ...
# 3  <div class="grid-character-training-item"><img src="https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/brute.png" alt="Brute Icon" width="80px" height="80px">Brute<input class="sheet-training-ranks" type="number" n...
# 4  <div class="grid-character-training-item"><img src="https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/assets/img/channeler.png" alt="Channeler Icon" width="80px" height="80px">Channeler<input class="sheet-training-ranks" typ...

# %%
df_training['tag_img_src'] = df_training['img_path'].str.replace("/no1_system/", "https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/")
df_training['attr_training_rank_nm'] = "attr_training_rank_" + df_training['Name'].str.lower()

# %%
df_training['div_str'] = '<div class="grid-character-training-item"><img src="' + df_training['tag_img_src'] + '" alt="' + df_training['Name'] + ' Icon" width="50px" height="50px" style="vertical-align: middle;"><span style="vertical-align: middle;">' + df_training['Name'] + '    <input class="sheet-training-ranks" type="number" name="' + df_training['attr_training_rank_nm'] + '" step="1" value="0"min="0" max="20" /></span></div>'

# %%
training_divs = ''
for i in df_training.index:
    training_divs += df_training.iloc[i]['div_str']

# %%
f = open('./code/character_sheet/html_raw_training.html', 'w')
f.write(training_divs)
f.close()

# %% [markdown]
# ## Talents Start

# %%
f = open('./docs/_data/talents.json', 'r')
json.load(f)
f.close()

# %%
df_talents_raw = pd.read_json('./docs/_data/talents.json')

# %%
df_talents_raw.head()
# Out:
#                                                                                                                                                                                                                                                           talents
# 0  {'tree': 'Acolyte', 'name': 'Commune with Divinity', 'type': 'Ability', 'rank': '1', 'requires': 'Divine Doctrine', 'replaces': None, 'effect': ['Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concor...
# 1  {'tree': 'Acolyte', 'name': 'Divine Doctrine', 'type': 'Static', 'rank': '1', 'requires': None, 'replaces': None, 'effect': ['You follow set of principles in your belief system or religious practice, referred to as your Divine Doctrine.  Each Divine D...
# 2                                                                                          {'tree': 'Acolyte', 'name': 'Composure (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase your Composure Rank to 2 (d8).']}
# 3                                                                                        {'tree': 'Acolyte', 'name': 'Domain (2)', 'type': 'Static', 'rank': '2', 'requires': None, 'replaces': None, 'effect': ['Increase one of your Domain Ranks to 2 (d8).']}
# 4                                                                                        {'tree': 'Acolyte', 'name': 'Domain (2)', 'type': 'Static', 'rank': '3', 'requires': None, 'replaces': None, 'effect': ['Increase one of your Domain Ranks to 2 (d8).']}

# %%
t= pd.DataFrame(df_talents_raw.iloc[0, 0])
t.groupby(['tree','name','type','rank','requires'])['effect'].apply('<br>'.join).reset_index()
# Out:
#       tree                   name     type rank         requires  \
# 0  Acolyte  Commune with Divinity  Ability    1  Divine Doctrine
#
#                                                                                                                                                                                                                                                            effect
# 0  Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.<br>Your Concordance measures how closely you are aligned with your Divine Doctrine.<br>You may use this Ability without using...

# %%
df_talents[df_talents['replaces'] != None]
# Out:
#                tree                                                  name  \
# 0           Acolyte                                 Commune with Divinity
# 1           Acolyte                                 Commune with Divinity
# 2           Acolyte                                 Commune with Divinity
# 3           Acolyte                                       Divine Doctrine
# 4           Acolyte                                       Divine Doctrine
# 5           Acolyte                                       Divine Doctrine
# 6           Acolyte                                       Divine Doctrine
# 7           Acolyte                                         Composure (2)
# 8           Acolyte                                            Domain (2)
# 9           Acolyte                                            Domain (2)
# 10          Acolyte                                            Domain (3)
# 11         Aberrant                                            Aberration
# 12         Aberrant                                            Aberration
# 13         Aberrant                                        Aberration (2)
# 14         Aberrant                                        Break the Mold
# 15         Aberrant                                        Aberration (3)
# 16         Aberrant                                        Living Anomaly
# 17           Mystic                                        Seek Mysteries
# 18           Mystic                                        Seek Mysteries
# 19           Mystic                                        Seek Mysteries
# 20           Mystic                                 Strain Susceptibility
# 21           Mystic                                 Strain Susceptibility
# 22           Mystic                                 Strain Susceptibility
# 23           Mystic                                 Strain Susceptibility
# 24           Mystic                                         Manage Strain
# 25           Mystic                                           Insight (3)
# 26           Mystic                                          Affinity (2)
# 27           Mystic                                          Affinity (2)
# 28           Mystic                                          Affinity (3)
# 29        Alchemist                                   Prepare concoctions
# 30        Alchemist                                   Prepare concoctions
# 31        Alchemist                                             Craft (1)
# 32        Alchemist                                             Craft (2)
# 33        Alchemist                                             Craft (3)
# 34        Alchemist                                Dangerous Distillation
# 35        Alchemist                                Practiced Applications
# 36        Alchemist                                           Brew Broker
# 37        Alchemist                                      Premium Potables
# 38        Alchemist                                Accomplished Alchemist
# 39         Archmage                                     Master the arcane
# 40         Assassin                                         Coup de Grace
# 41         Assassin                                          Sneak Attack
# 42         Assassin                                         Poison Expert
# 43         Assassin                                           Unseen Shot
# 44         Assassin                                       Silent Takedown
# 45         Assassin                                Death from the Shadows
# 46         Assassin                                      Marked for Death
# 47         Assassin                                                Vanish
# 48         Assassin                                         Ambush Expert
# 49         Assassin                                        Never Unnarmed
# 50         Assassin                                At Home in the Shadows
# 51         Assassin                                           Assassinate
# 52         Assassin                                   Fearsome Reputation
# 53         Assassin                                       Contract Killer
# 54         Assassin                                    The Job's Not Done
# 55          Athlete                                           Powerlifter
# 56          Athlete                                              Sprinter
# 57          Athlete                                             Exert (2)
# 58          Athlete                                            Tumble (2)
# 59          Athlete                                             Exert (3)
# 60          Athlete                                            Tumble (3)
# 61          Athlete                                               Acrobat
# 62          Athlete                                            Freerunner
# 63          Athlete                                     Peak Conditioning
# 64          Heretic                                 Commune with Divinity
# 65          Heretic                                 Commune with Divinity
# 66          Heretic                                 Commune with Divinity
# 67        Tactician                                        Inspire Allies
# 68        Tactician                                            Reposition
# 69        Tactician                                  Seize the Initiative
# 70        Tactician                                   Battlefield Command
# 71        Tactician                                   Battlefield Command
# 72        Tactician                                   Tactical Assessment
# 73        Tactician                                    Coordinated Attack
# 74        Tactician                                    Defensive Maneuver
# 75        Tactician                                      Tactical Retreat
# 76        Tactician                                          Rallying Cry
# 77        Tactician                                     Flanking Maneuver
# 78        Tactician                                       Tactical Strike
# 79        Tactician                                           Tactics (2)
# 80        Tactician                                           Tactics (3)
# 81        Tactician                                           Tactics (4)
# 82        Tactician                                              Lead (2)
# 83        Tactician                                       Combat Reflexes
# 84        Tactician                                       Decisive Action
# 85        Tactician                                   Tactical Mastermind
# 86          Heretic                                       Divine Doctrine
# 87          Heretic                                       Divine Doctrine
# 88          Heretic                                       Divine Doctrine
# 89          Heretic                                       Divine Doctrine
# 90          Heretic                                   Unorthodox Doctrine
# 91          Heretic                                            Heterodoxy
# 92          Heretic                                         Profane Smite
# 93          Heretic                                         Divine Rebuke
# 94          Heretic                                   Heretical Knowledge
# 95          Heretic                                       Divine Defiance
# 96          Heretic                                          Profane Aura
# 97          Heretic                                      Heretic's Shield
# 98          Heretic                                       Dark Revelation
# 99          Heretic                                       Defiant Healing
# 100         Heretic                                     Sacred Disruption
# 101         Heretic                                       Divine Reversal
# 102         Heretic                                       Heretic's Wrath
# 103         Bastion
# 104       Berserker                                             Exert (2)
# 105       Berserker                                                  Rage
# 106       Berserker                                                  Rage
# 107       Berserker                                                  Rage
# 108       Berserker                                                  Rage
# 109       Berserker                                                Frenzy
# 110       Berserker                                          Undying Rage
# 111       Berserker                                     Berkserker's Fury
# 112       Berserker                                      Indomitable Rage
# 113       Berserker                                          Vicious Rage
# 114       Berserker                                             Exert (3)
# 115       Berserker                                             Bloodlust
# 116      Black Belt                                      Martial Arts (3)
# 117      Black Belt                                           Flying Kick
# 118      Black Belt                                           Cross Block
# 119      Black Belt                                         Kansetsu Geri
# 120      Black Belt                                          Renraku Waza
# 121      Black Belt                                          Renraku Waza
# 122      Black Belt                                      Martial Arts (4)
# 123      Black Belt                                Sound Mind, Sound Body
# 124    Blade Weaver
# 125   Bounty Hunter                                        Implements (1)
# 126   Bounty Hunter  I Can Bring You In Warm, Or I Can Bring You In Cold.
# 127   Bounty Hunter                                        Implements (2)
# 128   Bounty Hunter                                                 Bolas
# 129   Bounty Hunter                                              Manacles
# 130   Bounty Hunter                                          Survival (3)
# 131   Bounty Hunter                                           Insight (2)
# 132   Bounty Hunter                                        Streetwise (2)
# 133   Bounty Hunter                        . . .A Complicated Profession.
# 134   Bounty Hunter                                     Shrewd Contractor
# 135   Bounty Hunter                                    Word on the Street
# 136   Bounty Hunter                                        Intimidate (2)
# 137   Bounty Hunter                                 It's A Dirty Job. . .
# 138   Bounty Hunter                                    No Disintegrations
# 139   Bounty Hunter                                    No Disintegrations
# 140           Brute                                         Brutal Strike
# 141           Brute                                  Just Getting Started
# 142           Brute                                             Exert (2)
# 143           Brute                                        Intimidate (2)
# 144           Brute                                            Who's Next
# 145           Brute                                           You're Next
# 146           Brute                                      Grisly Slaughter
# 147       Channeler                                            Channeling
# 148       Channeler                                            Channeling
# 149       Channeler                                            Channeling
# 150       Channeler                                                Recoil
# 151       Channeler                                          Affinity (2)
# 152       Channeler                                         Composure (2)
# 153       Channeler                                            Endure (2)
# 154       Channeler                                             Focus (2)
# 155       Channeler                                          Affinity (2)
# 156       Channeler                                          Affinity (3)
# 157         Conduit                                   Attune with Essence
# 158         Conduit                                   Attune with Essence
# 159         Conduit                                   Attune with Essence
# 160         Conduit                                   Attune with Essence
# 161         Conduit                                   Attune with Essence
# 162         Conduit                                        Bonded Essence
# 163         Conduit                                        Bonded Essence
# 164         Conduit                                          Affinity (2)
# 165         Conduit                                             Focus (2)
# 166         Conduit                                           Insight (2)
# 167         Conduit                                          Affinity (3)
# 168         Conduit                                           Insight (3)
# 169         Conduit                                             Focus (3)
# 170         Conduit                                      Attuning Conflux
# 171       Confessor
# 172         Corsair                                              Sea Legs
# 173         Corsair                                        Pirate's Charm
# 174         Corsair                                    Nautical Navigator
# 175         Corsair                                     Sword of the Seas
# 176         Corsair                                              Sea Lore
# 177         Corsair                                   Fearsome Reputation
# 178         Corsair                                  Plunderer's Instinct
# 179         Corsair                                     Broadside Barrage
# 180         Corsair                                   Mariner's Endurance
# 181         Corsair                                             Operate 3
# 182         Corsair                                              Strike 3
# 183         Corsair                                        Grappling Hook
# 184         Corsair                                          Tidal Strike
# 185         Corsair                                     Weather the Storm
# 186         Corsair                                    Smuggler's Cunning
# 187         Corsair                                     Captain's Command
# 188        Courtier                                         Silver Tongue
# 189        Courtier                                  Diplomatic Immunity!
# 190        Courtier                                          Favor Broker
# 191        Courtier                                   Subtle Manipulation
# 192        Courtier                                      Secrets Unveiled
# 193        Courtier                                       Elegant Defense
# 194        Courtier                                      Intrigue Mastery
# 195        Courtier                                      Social Chameleon
# 196        Courtier                                            Rumor Mill
# 197        Courtier                                    Inspiring Presence
# 198        Courtier                              The Better Part of Valor
# 199        Courtier                                        Crisis Averted
# 200        Courtier                                        Shadow Network
# 201        Courtier                                         Regal Bearing
# 202        Courtier                                       Political Savvy
# 203        Courtier                                    Flawless Etiquette
# 204        Courtier                                     Whispered Secrets
# 205        Defender                                       Focused Defense
# 206        Defender                                      Stay Close to Me
# 207        Defender                                             Focus (2)
# 208        Defender                                            Harm's Way
# 209        Defender                                          Shake it off
# 210        Defender                                        Armor Training
# 211        Defender                                            Endure (2)
# 212        Guardian                                          Armor Expert
# 213        Guardian                                    Unshakable Defense
# 214        Guardian                                             Focus (3)
# 215        Guardian                                             Focus (4)
# 216        Guardian                                          Line of Fire
# 217        Guardian                                         I can take it
# 218        Guardian                                          Shake it off
# 219        Guardian                                          Armor Expert
# 220        Guardian                                            Endure (3)
# 221        Guardian                                            Endure (4)
# 222        Defender                                         Get Behind Me
# 223        Defender                                      Indomitable Will
# 224        Defender                                      Indomitable Will
# 225        Defender                                              Vigorous
# 226       Detective                                       Investigate (2)
# 227       Detective                                             Observant
# 228       Detective                                          Interrogator
# 229       Detective                                         Investigate 3
# 230       Detective                                   Deductive Reasoning
# 231       Detective                                       Shadow the Perp
# 232       Detective                                             Analyze 3
# 233       Detective                                     Intuitive Insight
# 234       Detective                                     Informant Network
# 235       Detective                                  Heightened Awareness
# 236       Detective                                    Logical Conclusion
# 237       Detective                                   Master Investigator
# 238       Diabolist                                     Dance With Devils
# 239       Diabolist                                     Dance With Devils
# 240       Diabolist                                     Dance With Devils
# 241       Diabolist                                     Dance With Devils
# 242       Diabolist                                        Diabolic Gifts
# 243       Diabolist                                        Diabolic Gifts
# 244       Diabolist                                  Touch the Hellplanes
# 245       Diabolist                                  Touch the Hellplanes
# 246       Diabolist                                  Touch the Hellplanes
# 247       Diabolist                                          Affinity (1)
# 248       Diabolist                                          Affinity (3)
# 249       Diabolist                                        Profane Allure
# 250       Diabolist                                        Profane Caress
# 251       Diabolist                                        Diabolic Voice
# 252       Diabolist                                          Affinity (3)
# 253        Diplomat                                          Persuade (2)
# 254        Diplomat                                         Nobody's Fool
# 255        Diplomat                                         Silver Tongue
# 256        Diplomat                                              Browbeat
# 257        Diplomat                                           Deceive (2)
# 258        Diplomat                                           Unflappable
# 259        Diplomat                                          Persuade (3)
# 260        Diplomat                                          Steel Nerves
# 261        Diplomat                                    Let's Be Civilized
# 262        Diplomat                                    Let's Be Civilized
# 263         Dragoon
# 264          Driver
# 265           Druid                                               Animism
# 266           Druid                                    Attune with Nature
# 267           Druid                                    Attune with Nature
# 268           Druid                                    Attune with Nature
# 269           Druid                                    Attune with Nature
# 270           Druid                                    Attune with Nature
# 271           Druid                                         Nature's Bond
# 272           Druid                                         Nature's Bond
# 273           Druid                                      Nourish the Bond
# 274           Druid                                       Temper the Bond
# 275           Druid                                          Affinity (2)
# 276           Druid                                           Wild Talker
# 277           Druid                                          Affinity (2)
# 278           Druid                                            Endure (2)
# 279           Druid                                           Insight (2)
# 280           Druid                                          Affinity (3)
# 281           Druid                                           Insight (3)
# 282           Druid                                            Endure (3)
# 283           Druid                                        Nature's Wrath
# 284           Druid                                        Nature's Wrath
# 285         Duelist                                            Quick Draw
# 286         Duelist                                            Strike (3)
# 287         Duelist                                 Journeyman Competitor
# 288         Duelist                                               Riposte
# 289         Duelist                                     Deadly Contestant
# 290         Duelist                                            Draw Steel
# 291         Duelist                                            Strike (4)
# 292         Duelist                                       Renowned Victor
# 293    Elementalist                                    Shape the elements
# 294    Elementalist                                    Elemental Recovery
# 295    Elementalist                                          Affinity (2)
# 296    Elementalist                                         Composure (3)
# 297    Elementalist                                            Endure (3)
# 298    Elementalist                                             Focus (3)
# 299    Elementalist                                          Affinity (3)
# 300    Elementalist                                          Affinity (3)
# 301    Elementalist                                          Affinity (4)
# 302    Elementalist                                Uncanny Trait Increase
# 303        Engineer                                             Tinkering
# 304        Engineer                                    Mechanical Mastery
# 305        Engineer                                             Gadgeteer
# 306        Engineer                                      Reinforced Armor
# 307        Engineer                                    Inventor's Insight
# 308        Engineer                                         Repair Expert
# 309        Engineer                                   Energy Manipulation
# 310        Engineer                                        Advanced Tools
# 311        Engineer                                      Explosive Expert
# 312        Engineer                                   Field Modifications
# 313        Engineer                                      Defensive Turret
# 314        Engineer                                         Energy Shield
# 315        Engineer                                       Analytical Mind
# 316        Engineer                                              Robotics
# 317        Engineer                                     Innovative Design
# 318        Engineer                                     Energy Conversion
# 319        Engineer                                   Structural Analysis
# 320        Engineer                                     Automated Systems
# 321        Engineer                                     Tactical Analysis
# 322        Engineer                                       Master Inventor
# 323            Fury
# 324     Grandmaster
# 325     Grandmaster                                               Dim Mak
# 326          Healer                                     Embrace the Cycle
# 327          Healer                                     Embrace the Cycle
# 328          Healer                                     The Cycle's Drain
# 329          Healer
# 330          Healer                                         Healing Hands
# 331          Hunter                                                   Aim
# 332          Hunter                                          Survival (3)
# 333          Hunter                                        Silent Stalker
# 334          Hunter                                    Natural Camoflauge
# 335          Hunter                                          Perceive (2)
# 336          Hunter                                             Shoot (2)
# 337          Hunter                                   Predator’s Instinct
# 338          Hunter                                          Keen Tracker
# 339     Infiltrator                                       Silent Movement
# 340     Infiltrator                                       Disguise Expert
# 341     Infiltrator                                           Stealth (3)
# 342     Infiltrator                                           Stealth (4)
# 343     Infiltrator                                           Deceive (2)
# 344     Infiltrator                                        Implements (2)
# 345     Infiltrator                                        Implements (3)
# 346     Infiltrator                                           Lock Master
# 347     Infiltrator                                               Evasion
# 348     Infiltrator                                                Vanish
# 349     Intiltrator                                              Blend In
# 350     Infiltrator                                           Spy Network
# 351     Infiltrator                                               Mimicry
# 352     Infiltrator                                  Counter-Surveillance
# 353     Infiltrator                                         Escape Artist
# 354     Infiltrator                                            Deep Cover
# 355     Infiltrator                                               Forgery
# 356     Infiltrator                                  Master of Subterfuge
# 357     Infiltrator                               Infiltrator's Instincts
# 358      Juggernaut
# 359          Knight                                  Chivalric Obligation
# 360          Knight                                  Chivalric Obligation
# 361          Knight                                  Chivalric Obligation
# 362          Knight                                  Chivalric Obligation
# 363          Knight                                            Strike (2)
# 364          Knight                                         Noble Bearing
# 365          Knight                                  Valorous Recognition
# 366          Knight                                        Armor Training
# 367          Knight                                    Dedicated Exemplar
# 368          Knight                                          Virtuous Act
# 369          Knight                                            Strike (3)
# 370          Knight                                         Noble Warrion
# 371          Knight                                           History (2)
# 372          Knight                                    Inspiring Vanquish
# 373          Knight                                      Renowned Warrior
# 374          Knight                                      Renowned Warrior
# 375          Knight                                           Atoning Act
# 376          Knight                                 Unwavering Dedication
# 377          Knight                                           A Noble End
# 378          Knight                                           A Noble End
# 379          Knight                                         Momentous Act
# 380            Lich
# 381            Mage                                      Grasp the arcane
# 382            Mage                                          Research (3)
# 383            Mage                                      Magical Affinity
# 384            Mage                                          Affinity (1)
# 385            Mage                                          Affinity (2)
# 386            Mage                                          Affinity (2)
# 387            Mage                                          Affinity (3)
# 388            Mage                                          Affinity (3)
# 389            Mage                                          Subtle Spell
# 390            Mage                                          Research (4)
# 391            Mage                                          Subtle Spell
# 392            Mage                                           Analyze (2)
# 393            Mage                                           Analyze (3)
# 394      Mageknight
# 395      Magic-User                                             Spellburn
# 396      Magic-User                                          Study Spells
# 397      Magic-User                                          Study Spells
# 398      Magic-User                                          Study Spells
# 399      Magic-User                                            Spellcraft
# 400      Magic-User                                          Research (2)
# 401      Magic-User                                      Magical Affinity
# 402      Magic-User                                          Affinity (1)
# 403      Magic-User                                          Affinity (2)
# 404      Magic-User                                      Magical Affinity
# 405      Magic-User                                          Subtle Spell
# 406      Magic-User
# 407        Marksman                                                   Aim
# 408        Marksman                                          Patient Shot
# 409        Marksman                                          Pinning Shot
# 410        Marksman                                        Piercing Shots
# 411        Marksman                                           Reflex Shot
# 412        Marksman                                      Suppressing Fire
# 413        Marksman                                      Suppressing Fire
# 414        Marksman                                        Crippling Shot
# 415        Marksman                                   Two Birds, One Shot
# 416        Marksman                                                 Ready
# 417        Marksman                                             Shoot (2)
# 418         Soldier                                             Shoot (2)
# 419        Marksman                                            Double Tap
# 420        Marksman                                             Shoot (3)
# 421        Marksman                                               Shooter
# 422        Marksman                                       Controlled Pair
# 423  Martial Artist                           Float like a butterfly. . .
# 424  Martial Artist                                           Back Stance
# 425  Martial Artist                                           Back Stance
# 426  Martial Artist                                          Front Stance
# 427  Martial Artist                                          Front Stance
# 428  Martial Artist                                      Martial Arts (2)
# 429  Martial Artist                                      Martial Arts (3)
# 430  Martial Artist                                           Knee Strike
# 431  Martial Artist                                     Ridge Hand Strike
# 432  Martial Artist                                            High Block
# 433  Martial Artist                                                 Parry
# 434  Martial Artist                                           Dual Strike
# 435  Martial Artist                                         Living Weapon
# 436  Martial Artist                                         Sweep the Leg
# 437  Martial Artist                                         Counterstrike
# 438           Medic                                             First Aid
# 439           Medic                                          Medicine (2)
# 440           Medic                                         Stop Whining!
# 441           Medic                                        Smelling Salts
# 442           Medic                                       Snap Out of It!
# 443           Medic                                     I'll Patch You Up
# 444           Medic                                    Stem the Bleeding
# 445           Medic                                          Medicine (3)
# 446           Medic                                          Medicine (4)
# 447           Medic                                    Emergency Medicine
# 448         Templar                                          Avowed Quest
# 449         Templar                                          Avowed Quest
# 450         Templar                                          Avowed Quest
# 451         Templar                                          Avowed Quest
# 452         Templar                                          Avowed Quest
# 453         Templar                                          Avowed Quest
# 454         Templar                                Strike with Conviction
# 455         Templar                                            Strike (2)
# 456         Templar                                              Boon (2)
# 457         Templar                                 Relentless Conviction
# 458         Templar                                   Wrathful Conviction
# 459         Templar                                    Eternal Conviction
# 460         Templar                                            Strike (3)
# 461         Templar                                              Boon (3)
# 462         Templar                                      I Am Inevitable.
# 463                                               Fortune Favors the Bold
# 464                                                     Double or Nothing
# 465                                                               Blooded
# 466                                                       Clever Solution
# 467                                                            Strong Arm
# 468       Scoundrel                                         Swift Offense
# 469       Scoundrel                                         Smooth Talker
# 470          Mesmer
# 471        Overseer                                      Recruit Henchmen
# 472        Overseer                                      Recruit Henchmen
# 473        Overseer                                      Recruit Henchmen
# 474        Overseer                                      Recruit Henchmen
# 475        Overseer                                      Recruit Henchmen
# 476        Overseer                                      Recruit Henchmen
# 477        Overseer                                      Recruit Henchmen
# 478        Overseer                                      Recruit Henchmen
# 479        Overseer                                      Promote Henchmen
# 480        Overseer                                      Promote Henchmen
# 481        Overseer                                     Skilled Recruiter
# 482        Overseer                                    Coordinated Strike
# 483        Overseer                                         Weapons Free!
# 484        Overseer                               Don't Just Stand There!
# 485        Overseer                                    Coordinated Volley
# 486        Overseer                                    At Ease, Soldiers!
# 487        Overseer                                      Rally the Troops
# 488        Overseer                                              Lead (2)
# 489        Overseer                                          Persuade (2)
# 490        Overseer                                              Lead (3)
# 491     Necromancer                                         Stir the Dead
# 492     Necromancer                                         Stir the Dead
# 493     Necromancer                                         Stir the Dead
# 494     Necromancer                                         Stir the Dead
# 495     Necromancer                                         Stir the Dead
# 496     Necromancer                                         Stir the Dead
# 497     Necromancer                                         Stir the Dead
# 498     Necromancer                                         Stir the Dead
# 499     Necromancer                                        Empower Haunts
# 500     Necromancer                                        Empower Haunts
# 501     Necromancer                                         Danse Macabre
# 502     Necromancer                                         Rip and Tear!
# 503     Necromancer                                         Rip and Tear!
# 504     Necromancer                                 Feast On Their Flesh!
# 505     Necromancer                                          Dread Siphon
# 506     Necromancer                                          Dread Siphon
# 507     Necromancer                                        Dread Presence
# 508     Necromancer                                       Swarm the Enemy
# 509     Necromancer                                       Swarm the Enemy
# 510     Necromancer                                         Death's Reach
# 511     Necromancer                                        Bone Splinters
# 512     Necromancer                                              Lead (2)
# 513     Necromancer                                        Intimidate (2)
# 514     Necromancer                                              Mori (3)
# 515     Necromancer                                              Mori (4)
# 516     Necromancer                                      Corpse Explosion
# 517     Beastmaster                                           Tame Beasts
# 518     Beastmaster                                           Tame Beasts
# 519     Beastmaster                                           Tame Beasts
# 520     Beastmaster                                           Tame Beasts
# 521     Beastmaster                                           Tame Beasts
# 522     Beastmaster                                           Tame Beasts
# 523     Beastmaster                                           Tame Beasts
# 524     Beastmaster                                           Tame Beasts
# 525     Beastmaster                                           Train Beast
# 526     Beastmaster                                           Train Beast
# 527     Beastmaster                                   Friend of the Wilds
# 528     Beastmaster                                          Pack Tactics
# 529     Beastmaster                                     Protect the Alpha
# 530     Beastmaster                                       One of the Pack
# 531     Beastmaster                                         Feed the Pack
# 532     Beastmaster                                       Gather the Pack
# 533     Beastmaster                                              Lead (3)
# 534     Beastmaster                                         Composure (3)
# 535         Paragon
# 536           Pilot
# 537          Priest                                 Commune with Divinity
# 538          Priest                                 Commune with Divinity
# 539          Priest                                 Commune with Divinity
# 540          Priest                                            Domain (2)
# 541          Priest                                       Divine Doctrine
# 542          Priest                                       Divine Doctrine
# 543          Priest                                       Divine Doctrine
# 544          Priest                                       Divine Doctrine
# 545          Priest                                     Invoke the Divine
# 546          Priest                                       Extended Domain
# 547          Priest
# 548          Priest                                            Domain (2)
# 549          Priest                                            Domain (3)
# 550     Probabilist                                         Derive Axioms
# 551           Psion                                         Hone the mind
# 552           Nexus                                   Attune with Essence
# 553           Nexus                                   Attune with Essence
# 554           Nexus                                   Attune with Essence
# 555           Nexus                                   Attune with Essence
# 556           Nexus                                   Attune with Essence
# 557           Nexus                                        Bonded Essence
# 558           Nexus                                        Bonded Essence
# 559           Nexus                                     Empowered Essence
# 560           Nexus                                          Affinity (2)
# 561           Nexus                                             Focus (2)
# 562           Nexus                                  Marvelous Attunement
# 563           Nexus                                          Affinity (3)
# 564           Nexus                                           Insight (3)
# 565           Nexus                                             Focus (3)
# 566           Nexus                                      Momentous Marvel
# 567           Nexus                                           Insight (4)
# 568           Nexus                                             Focus (4)
# 569        Pugilist                                              Haymaker
# 570        Pugilist                           Float like a butterfly. . .
# 571        Pugilist                                      Sting Like a Bee
# 572        Pugilist                                                   Jab
# 573        Pugilist                                                   Jab
# 574        Pugilist                                                 Cross
# 575        Pugilist                                                 Cross
# 576        Pugilist                                                  Hook
# 577        Pugilist                                                  Hook
# 578        Pugilist                                              Uppercut
# 579        Pugilist                                              Uppercut
# 580        Pugilist                                        Knockout Punch
# 581        Pugilist                                        Knockout Punch
# 582        Pugilist                                 Journeyman Competitor
# 583        Pugilist                                         Work the Body
# 584        Pugilist                                          Shake it off
# 585        Pugilist                                         Bob and Weave
# 586        Pugilist                                      Slip and Counter
# 587        Pugilist                                      Martial Arts (3)
# 588        Pugilist                                             Focus (2)
# 589        Pugilist                                             Focus (3)
# 590        Pugilist                                     Down, but Not Out
# 591      Raindancer
# 592          Ranger                                             Shoot (3)
# 593          Ranger                                            Skirmisher
# 594          Ranger                                             Weathered
# 595          Ranger                                           Survivalist
# 596          Ranger                                            Strike (3)
# 597          Ranger                                         Warden's Mark
# 598          Ranger                                      Solitary Warrior
# 599          Ranger                                         Quarry Master
# 600          Ranger                                           Unseen Shot
# 601          Reaver                                        Rending Strike
# 602          Reaver                                            Blood Fury
# 603          Reaver                                            Strike (3)
# 604          Reaver                                      Whirlwind Strike
# 605          Reaver                                           Soul Reaver
# 606          Reaver                                     Vicious Whirlwind
# 607          Reaver                                       Vicious Rending
# 608          Reaver
# 609          Reaver
# 610         Samurai
# 611         Scholar                                   Academic Dsicipline
# 612         Scholar                                   Academic Dsicipline
# 613         Scholar                                       Analytical Mind
# 614         Scholar                                       Analytical Mind
# 615         Scholar                                           Analyze (2)
# 616         Scholar                             Multidisciplinary Studies
# 617         Scholar                             Multidisciplinary Studies
# 618         Scholar                                    Knowledge is Power
# 619         Scholar                                           Analyze (3)
# 620         Scholar                                          Research (2)
# 621         Scholar                          Academic Discipline Increase
# ...
# 922                                                                                                  <label for="tal_static_brute_dangerous_trait_increase">Dangerous Trait Increase'</label><input type="checkbox" id="tal_static_brute_dangerous_trait_increase">
# 923                                                                                            <label for="tal_static_scrapper_dangerous_trait_increase">Dangerous Trait Increase'</label><input type="checkbox" id="tal_static_scrapper_dangerous_trait_increase">
# 924                                                                                          <label for="tal_static_berserker_dangerous_trait_increase">Dangerous Trait Increase'</label><input type="checkbox" id="tal_static_berserker_dangerous_trait_increase">
# 925                                                                                                <label for="tal_static_reaver_dangerous_trait_increase">Dangerous Trait Increase'</label><input type="checkbox" id="tal_static_reaver_dangerous_trait_increase">
# 926                                                                                                <label for="tal_static_sniper_dangerous_trait_increase">Dangerous Trait Increase'</label><input type="checkbox" id="tal_static_sniper_dangerous_trait_increase">
# 927                                                                                            <label for="tal_static_assassin_dangerous_trait_increase">Dangerous Trait Increase'</label><input type="checkbox" id="tal_static_assassin_dangerous_trait_increase">
# 928                                                                                        <label for="tal_static_black belt_dangerous_trait_increase">Dangerous Trait Increase'</label><input type="checkbox" id="tal_static_black belt_dangerous_trait_increase">
# 929                                                                                                <label for="tal_static_knight_dangerous_trait_increase">Dangerous Trait Increase'</label><input type="checkbox" id="tal_static_knight_dangerous_trait_increase">
# 930                                                                                  <label for="tal_static_weapon master_dangerous_trait_increase">Dangerous Trait Increase'</label><input type="checkbox" id="tal_static_weapon master_dangerous_trait_increase">
# 931                                                                                                <label for="tal_static_ranger_dangerous_trait_increase">Dangerous Trait Increase'</label><input type="checkbox" id="tal_static_ranger_dangerous_trait_increase">
# 932                                                                                                                 <label for="tal_static_thief_deft_trait_increase">Deft Trait Increase'</label><input type="checkbox" id="tal_static_thief_deft_trait_increase">
# 933                                                                                                                 <label for="tal_static_scout_deft_trait_increase">Deft Trait Increase'</label><input type="checkbox" id="tal_static_scout_deft_trait_increase">
# 934                                                                                                               <label for="tal_static_ranger_deft_trait_increase">Deft Trait Increase'</label><input type="checkbox" id="tal_static_ranger_deft_trait_increase">
# 935                                                                                                     <label for="tal_static_infiltrator_deft_trait_increase">Deft Trait Increase'</label><input type="checkbox" id="tal_static_infiltrator_deft_trait_increase">
# 936                                                                                                                     <label for="tal_static_spy_deft_trait_increase">Deft Trait Increase'</label><input type="checkbox" id="tal_static_spy_deft_trait_increase">
# 937                                                                                                   <label for="tal_static_swashbuckler_deft_trait_increase">Deft Trait Increase'</label><input type="checkbox" id="tal_static_swashbuckler_deft_trait_increase">
# 938                                                                                                             <label for="tal_static_athlete_deft_trait_increase">Deft Trait Increase'</label><input type="checkbox" id="tal_static_athlete_deft_trait_increase">
# 939                                                                                                         <label for="tal_static_tactician_deft_trait_increase">Deft Trait Increase'</label><input type="checkbox" id="tal_static_tactician_deft_trait_increase">
# 940                                                                                                           <label for="tal_static_operator_deft_trait_increase">Deft Trait Increase'</label><input type="checkbox" id="tal_static_operator_deft_trait_increase">
# 941                                                                                                        <label for="tal_static_diplomat_savvy_trait_increase">Savvy Trait Increase'</label><input type="checkbox" id="tal_static_diplomat_savvy_trait_increase">
# 942                                                                                                          <label for="tal_static_coutier_savvy_trait_increase">Savvy Trait Increase'</label><input type="checkbox" id="tal_static_coutier_savvy_trait_increase">
# 943                                                                                                      <label for="tal_static_scoundrel_savvy_trait_increase">Savvy Trait Increase'</label><input type="checkbox" id="tal_static_scoundrel_savvy_trait_increase">
# 944                                                                                                    <label for="tal_static_magic-user_savvy_trait_increase">Savvy Trait Increase'</label><input type="checkbox" id="tal_static_magic-user_savvy_trait_increase">
# 945                                                                                                                <label for="tal_static_mage_savvy_trait_increase">Savvy Trait Increase'</label><input type="checkbox" id="tal_static_mage_savvy_trait_increase">
# 946                                                                                                      <label for="tal_static_detective_savvy_trait_increase">Savvy Trait Increase'</label><input type="checkbox" id="tal_static_detective_savvy_trait_increase">
# 947                                                                                                                  <label for="tal_static_spy_savvy_trait_increase">Savvy Trait Increase'</label><input type="checkbox" id="tal_static_spy_savvy_trait_increase">
# 948                                                                                                               <label for="tal_static_balladeer_practiced_trouper">Practiced Trouper'</label><input type="checkbox" id="tal_static_balladeer_practiced_trouper">
# 949                                                                                                               <label for="tal_static_balladeer_practiced_trouper">Practiced Trouper'</label><input type="checkbox" id="tal_static_balladeer_practiced_trouper">
# 950                                                                                                      <label for="tal_static_balladeer_consummate_performer">Consummate Performer'</label><input type="checkbox" id="tal_static_balladeer_consummate_performer">
# 951                                                                                                      <label for="tal_static_balladeer_savvy_trait_increase">Savvy Trait Increase'</label><input type="checkbox" id="tal_static_balladeer_savvy_trait_increase">
# 952                                                                                                                                          <label for="tal_static_balladeer_lyricist">Lyricist'</label><input type="checkbox" id="tal_static_balladeer_lyricist">
# 953                                                                                                                                       <label for="tal_static_balladeer_craft_(2)">Craft (2)'</label><input type="checkbox" id="tal_static_balladeer_craft_(2)">
# 954                                                                                                                           <label for="tal_static_balladeer_composure_(2)">Composure (2)'</label><input type="checkbox" id="tal_static_balladeer_composure_(2)">
# 955                                                                                                                           <label for="tal_static_balladeer_composure_(3)">Composure (3)'</label><input type="checkbox" id="tal_static_balladeer_composure_(3)">
# 956                                                                                                                              <label for="tal_static_balladeer_persuade_(2)">Persuade (2)'</label><input type="checkbox" id="tal_static_balladeer_persuade_(2)">
# 957                                                                                                                           <label for="tal_static_balladeer_tavern_busker">Tavern Busker'</label><input type="checkbox" id="tal_static_balladeer_tavern_busker">
# 958                                                                                                                              <label for="tal_static_balladeer_paid_regular">Paid Regular'</label><input type="checkbox" id="tal_static_balladeer_paid_regular">
# 959                                                                                                                                       <label for="tal_static_balladeer_craft_(3)">Craft (3)'</label><input type="checkbox" id="tal_static_balladeer_craft_(3)">
# 960                                                                                                                                       <label for="tal_static_balladeer_craft_(4)">Craft (4)'</label><input type="checkbox" id="tal_static_balladeer_craft_(4)">
# 961                                                                                                   <label for="tal_static_balladeer_established_performer">Established Performer'</label><input type="checkbox" id="tal_static_balladeer_established_performer">
# 962                                                                                                    <label for="tal_static_rhapsodist_savvy_trait_increase">Savvy Trait Increase'</label><input type="checkbox" id="tal_static_rhapsodist_savvy_trait_increase">
# 963                                                                                                          <label for="tal_static_scholar_savvy_trait_increase">Savvy Trait Increase'</label><input type="checkbox" id="tal_static_scholar_savvy_trait_increase">
# 964                                                                                                          <label for="tal_static_scholar_savvy_trait_increase">Savvy Trait Increase'</label><input type="checkbox" id="tal_static_scholar_savvy_trait_increase">
# 965                                                                                                     <label for="tal_static_defender_steady_trait_increase">Steady Trait Increase'</label><input type="checkbox" id="tal_static_defender_steady_trait_increase">
# 966                                                                                                     <label for="tal_static_guardian_steady_trait_increase">Steady Trait Increase'</label><input type="checkbox" id="tal_static_guardian_steady_trait_increase">
# 967                                                                                                             <label for="tal_static_tank_steady_trait_increase">Steady Trait Increase'</label><input type="checkbox" id="tal_static_tank_steady_trait_increase">
# 968                                                                                                         <label for="tal_static_knight_steady_trait_increase">Steady Trait Increase'</label><input type="checkbox" id="tal_static_knight_steady_trait_increase">
# 969                                                                                                       <label for="tal_static_samurai_steady_trait_increase">Steady Trait Increase'</label><input type="checkbox" id="tal_static_samurai_steady_trait_increase">
# 970                                                                                                         <label for="tal_static_priest_steady_trait_increase">Steady Trait Increase'</label><input type="checkbox" id="tal_static_priest_steady_trait_increase">
# 971                                                                                                         <label for="tal_static_hunter_steady_trait_increase">Steady Trait Increase'</label><input type="checkbox" id="tal_static_hunter_steady_trait_increase">
# 972                                                                                                         <label for="tal_static_healer_steady_trait_increase">Steady Trait Increase'</label><input type="checkbox" id="tal_static_healer_steady_trait_increase">
# 973                                                                                                         <label for="tal_static_ranger_steady_trait_increase">Steady Trait Increase'</label><input type="checkbox" id="tal_static_ranger_steady_trait_increase">
# 974                                                                                                        <label for="tal_static_witch_uncanny_trait_increase">Uncanny Trait Increase'</label><input type="checkbox" id="tal_static_witch_uncanny_trait_increase">
# 975                                                                                                          <label for="tal_static_seer_uncanny_trait_increase">Uncanny Trait Increase'</label><input type="checkbox" id="tal_static_seer_uncanny_trait_increase">
# 976                                                                                                  <label for="tal_static_aberrant_uncanny_trait_increase">Uncanny Trait Increase'</label><input type="checkbox" id="tal_static_aberrant_uncanny_trait_increase">
# 977                                                                                                  <label for="tal_static_aberrant_uncanny_trait_increase">Uncanny Trait Increase'</label><input type="checkbox" id="tal_static_aberrant_uncanny_trait_increase">
# 978                                                                                              <label for="tal_static_petitioner_uncanny_trait_increase">Uncanny Trait Increase'</label><input type="checkbox" id="tal_static_petitioner_uncanny_trait_increase">
# 979                                                                                                      <label for="tal_static_thrall_uncanny_trait_increase">Uncanny Trait Increase'</label><input type="checkbox" id="tal_static_thrall_uncanny_trait_increase">
# 980                                                                                                      <label for="tal_static_mystic_uncanny_trait_increase">Uncanny Trait Increase'</label><input type="checkbox" id="tal_static_mystic_uncanny_trait_increase">
# 981                                                                                                        <label for="tal_static_adept_uncanny_trait_increase">Uncanny Trait Increase'</label><input type="checkbox" id="tal_static_adept_uncanny_trait_increase">
#
# [982 rows x 77 columns]

# %%
df_talents = pd.DataFrame()
for i in df_talents_raw.index:
    df_talents = pd.concat([df_talents, pd.DataFrame(df_talents_raw.iloc[i, 0])], axis=0)
df_talents.reset_index(drop=True, inplace=True)
df_talents['name'] = df_talents['name'].astype('str')

# %%
skills = ["Exert","Grapple","Intimidate","Martial Arts","Shoot","Strike","Throw","Bellor","Inferno","Sangui","Tempest","Implements","Insight","Legerdemain","Operate","Stealth","Tactics","Tumble","Mori","Nox","Plaga","Squall","Craft","Pilot","Analyze","Computers","Cosmology","Current Events","Deceive","History","Linguistics","Nature","Navigate","Persuade","Research","Skrimisiology","Streetwise","Survival","Theology","Arithm","Medicine","Mentis","Phylla","Rime","Torrent","Composure","Endure","Focus","Investigate","Lead","Perceive","Forma","Locus","Lux","Ordi","Tellus","Aether","Destroy","Intuit","Luck","Nihil","Resist","Tempor","Vivus"]

# %%
for s in skills:
    df_talents[s] = [s if s in eff else None for eff in df_talents['effect']]
    df_talents[s].dropna(inplace=True)

# %%
df_talents[skills].head()
# Out:
#   Exert Grapple Intimidate Martial Arts Shoot Strike Throw Bellor Inferno  \
# 0  None    None       None         None  None   None  None   None    None
# 1  None    None       None         None  None   None  None   None    None
# 2  None    None       None         None  None   None  None   None    None
# 3  None    None       None         None  None   None  None   None    None
# 4  None    None       None         None  None   None  None   None    None
#
#   Sangui  ...  Ordi Tellus Aether Destroy Intuit  Luck Nihil Resist Tempor  \
# 0   None  ...  None   None   None    None   None  None  None   None   None
# 1   None  ...  None   None   None    None   None  None  None   None   None
# 2   None  ...  None   None   None    None   None  None  None   None   None
# 3   None  ...  None   None   None    None   None  None  None   None   None
# 4   None  ...  None   None   None    None   None  None  None   None   None
#
#   Vivus
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
#
# [5 rows x 64 columns]

# %%
df_talents['skills'] = df_talents[skills].values.tolist()

# %%
for i in df_talents.index:
    sl = df_talents.iloc[i]['skills']
    x = [s for s in sl if s is not None]
    df_talents.iloc[i]['skills'] = x

# %%
x
# Out:
# []

# %%
df_talents['skills'].head()
# Out:
# 0    [Composure]
# 1             []
# 2             []
# 3             []
# 4             []
# Name: skills, dtype: object

# %%
def build_powercard(name, effect, skill, type):
    powercard = '''!power {{{{
    --name|@{{name}} - ''' + name + '''
    --Effect|''' + effect + '''
    --Result Set|[[ [$talent|XPND] @{{BAMF|challenge}}d@{{skill_''' + skill + '''}}>4]]
    --Hits|[^talent.ss]
    --1s|[^talent.ones]
    --format|''' + type.lower() + '''check
    }}}}'''
    return(powercard)

# %%
n['name']
# Out:
# 'Commune with Divinity'

# %%
df_talents['str_pcard'] = ''

# %%
i=0
n = df_talents.iloc[i][:]
if len(n.skills) > 0:
    pcs = []
    for s in n.skills:
        x = build_powercard(n['name'], n['effect'], s, n['type'])
        pcs.append(x)
    df_talents.loc[i, 'str_pcard'] = pcs

# %%
print(pcs[0])
# Out:
# !power {{{{
#     --name|@{{name}} - Commune with Divinity
#     --Effect|Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.
#     --Result Set|[[ [$talent|XPND] @{{BAMF|challenge}}d@{{skill_Composure}}>4]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}}}

# %%
for i in df_talents.index:
    n = df_talents.iloc[i][:]
    pcs = np.nan
    if n['type'] != 'Static':
        if len(n['skills']) > 0:
            pcs = []
            for s in n['skills']:
                x = build_powercard(n['name'], n['effect'], s, n['type'])
                pcs.append(x)
    df_talents.loc[i, 'str_pcard'] = pcs

# %%
df_talents.head(10)
# Out:
#       tree                   name     type rank         requires replaces  \
# 0  Acolyte  Commune with Divinity  Ability    1  Divine Doctrine     None
# 1  Acolyte  Commune with Divinity  Ability    1  Divine Doctrine     None
# 2  Acolyte  Commune with Divinity  Ability    1  Divine Doctrine     None
# 3  Acolyte        Divine Doctrine   Static    1             None     None
# 4  Acolyte        Divine Doctrine   Static    1             None     None
# 5  Acolyte        Divine Doctrine   Static    1             None     None
# 6  Acolyte        Divine Doctrine   Static    1             None     None
# 7  Acolyte          Composure (2)   Static    2             None     None
# 8  Acolyte             Domain (2)   Static    2             None     None
# 9  Acolyte             Domain (2)   Static    3             None     None
#
#                                                                                                                                                                                                                                                            effect  \
# 0                                                                                                                                   Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.
# 1                                                                                                                                                                                Your Concordance measures how closely you are aligned with your Divine Doctrine.
# 2                                                                                        You may use this Ability without using an Action at the beginning of each Waypoint.  If you use it during a Waypoint, it requires 8 - Steady Actions (minimum 1 Action).
# 3  You follow set of principles in your belief system or religious practice, referred to as your Divine Doctrine.  Each Divine Doctrine consists of <em>Virtues</em>, <em>Taboos</em>, and <em>Domains</em>.<br>When you act against your Virtues or engage in...
# 4                                   Select two items from the list below to be your Virtues and two items to be your Taboos:<br><em>Temperance, Indulgence, Avarice, Charity, Humility, Compassion, Wrath, Courage, Deceipt, Justice, Loyalty, Honesty . . .</em>
# 5                                                                                                                           Select 2 Effect Skills from the list below to be your Domain:<br><em>Bellor, Inferno, Lux, Mori, Nox, Ordi, Rime, Tempest, Vivus</em>
# 6  Commitment to your Divine Doctrine lets you access <a href='/no1_system/characters/powers#Rites'>Rites</a>.  If one your Rite's result set contains a 1, reduce your Concordance by 1.<br>If you attempt to use a Rite when you Concordance is below 0, add...
# 7                                                                                                                                                                                                                         Increase your Composure Rank to 2 (d8).
# 8                                                                                                                                                                                                                    Increase one of your Domain Ranks to 2 (d8).
# 9                                                                                                                                                                                                                    Increase one of your Domain Ranks to 2 (d8).
#
#   Exert Grapple Intimidate  ... Aether Destroy Intuit  Luck Nihil Resist  \
# 0  None    None       None  ...   None    None   None  None  None   None
# 1  None    None       None  ...   None    None   None  None  None   None
# 2  None    None       None  ...   None    None   None  None  None   None
# 3  None    None       None  ...   None    None   None  None  None   None
# 4  None    None       None  ...   None    None   None  None  None   None
# 5  None    None       None  ...   None    None   None  None  None   None
# 6  None    None       None  ...   None    None   None  None  None   None
# 7  None    None       None  ...   None    None   None  None  None   None
# 8  None    None       None  ...   None    None   None  None  None   None
# 9  None    None       None  ...   None    None   None  None  None   None
#
#   Tempor  Vivus  \
# 0   None   None
# 1   None   None
# 2   None   None
# 3   None   None
# 4   None   None
# 5   None  Vivus
# 6   None   None
# 7   None   None
# 8   None   None
# 9   None   None
#
#                                                           skills  \
# 0                                                    [Composure]
# 1                                                             []
# 2                                                             []
# 3                                                             []
# 4                                                             []
# 5  [Bellor, Inferno, Tempest, Mori, Nox, Rime, Lux, Ordi, Vivus]
# 6                                                             []
# 7                                                    [Composure]
# 8                                                             []
# 9                                                             []
#
#                                                                                                                                                                                                                                                         str_pcard
# 0  [!power {{{{\n    --name|@{{name}} - Commune with Divinity\n    --Effect|Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.\n    --Result Set|[[ [$talent|XPND] @{{BAMF|challeng...
# 1                                                                                                                                                                                                                                                             NaN
# 2                                                                                                                                                                                                                                                             NaN
# 3                                                                                                                                                                                                                                                             NaN
# 4                                                                                                                                                                                                                                                             NaN
# 5                                                                                                                                                                                                                                                             NaN
# 6                                                                                                                                                                                                                                                             NaN
# 7                                                                                                                                                                                                                                                             NaN
# 8                                                                                                                                                                                                                                                             NaN
# 9                                                                                                                                                                                                                                                             NaN
#
# [10 rows x 73 columns]

# %%
# df_talents.info()

# %%
df_talents['tal_attr_nm'] = df_talents.name.str.replace(' ', '_')
df_talents['tal_attr_nm'] = df_talents['tal_attr_nm'].str.lower()
df_talents['path_attr_nm'] = df_talents['tree'].str.lower()
df_talents['div_id_nm'] = 'tal_' + df_talents['type'].str.lower() + '_' + df_talents['path_attr_nm'] + '_' + df_talents['tal_attr_nm']
df_talents['str_cbox'] = '''<label for="''' + df_talents['div_id_nm'] + '''">''' + df_talents['name'] + ''''</label><input type="checkbox" id="''' + df_talents['div_id_nm'] + '''">'''

# %%
df_talents.head()
# Out:
#       tree                   name     type rank         requires replaces  \
# 0  Acolyte  Commune with Divinity  Ability    1  Divine Doctrine     None
# 1  Acolyte  Commune with Divinity  Ability    1  Divine Doctrine     None
# 2  Acolyte  Commune with Divinity  Ability    1  Divine Doctrine     None
# 3  Acolyte        Divine Doctrine   Static    1             None     None
# 4  Acolyte        Divine Doctrine   Static    1             None     None
#
#                                                                                                                                                                                                                                                            effect  \
# 0                                                                                                                                   Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.
# 1                                                                                                                                                                                Your Concordance measures how closely you are aligned with your Divine Doctrine.
# 2                                                                                        You may use this Ability without using an Action at the beginning of each Waypoint.  If you use it during a Waypoint, it requires 8 - Steady Actions (minimum 1 Action).
# 3  You follow set of principles in your belief system or religious practice, referred to as your Divine Doctrine.  Each Divine Doctrine consists of <em>Virtues</em>, <em>Taboos</em>, and <em>Domains</em>.<br>When you act against your Virtues or engage in...
# 4                                   Select two items from the list below to be your Virtues and two items to be your Taboos:<br><em>Temperance, Indulgence, Avarice, Charity, Humility, Compassion, Wrath, Courage, Deceipt, Justice, Loyalty, Honesty . . .</em>
#
#   Exert Grapple Intimidate  ... Nihil Resist Tempor Vivus       skills  \
# 0  None    None       None  ...  None   None   None  None  [Composure]
# 1  None    None       None  ...  None   None   None  None           []
# 2  None    None       None  ...  None   None   None  None           []
# 3  None    None       None  ...  None   None   None  None           []
# 4  None    None       None  ...  None   None   None  None           []
#
#                                                                                                                                                                                                                                                         str_pcard  \
# 0  [!power {{{{\n    --name|@{{name}} - Commune with Divinity\n    --Effect|Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.\n    --Result Set|[[ [$talent|XPND] @{{BAMF|challeng...
# 1                                                                                                                                                                                                                                                             NaN
# 2                                                                                                                                                                                                                                                             NaN
# 3                                                                                                                                                                                                                                                             NaN
# 4                                                                                                                                                                                                                                                             NaN
#
#              tal_attr_nm path_attr_nm  \
# 0  commune_with_divinity      acolyte
# 1  commune_with_divinity      acolyte
# 2  commune_with_divinity      acolyte
# 3        divine_doctrine      acolyte
# 4        divine_doctrine      acolyte
#
#                                    div_id_nm  \
# 0  tal_ability_acolyte_commune_with_divinity
# 1  tal_ability_acolyte_commune_with_divinity
# 2  tal_ability_acolyte_commune_with_divinity
# 3         tal_static_acolyte_divine_doctrine
# 4         tal_static_acolyte_divine_doctrine
#
#                                                                                                                                                       str_cbox
# 0  <label for="tal_ability_acolyte_commune_with_divinity">Commune with Divinity'</label><input type="checkbox" id="tal_ability_acolyte_commune_with_divinity">
# 1  <label for="tal_ability_acolyte_commune_with_divinity">Commune with Divinity'</label><input type="checkbox" id="tal_ability_acolyte_commune_with_divinity">
# 2  <label for="tal_ability_acolyte_commune_with_divinity">Commune with Divinity'</label><input type="checkbox" id="tal_ability_acolyte_commune_with_divinity">
# 3                      <label for="tal_static_acolyte_divine_doctrine">Divine Doctrine'</label><input type="checkbox" id="tal_static_acolyte_divine_doctrine">
# 4                      <label for="tal_static_acolyte_divine_doctrine">Divine Doctrine'</label><input type="checkbox" id="tal_static_acolyte_divine_doctrine">
#
# [5 rows x 77 columns]

# %%
print('''<label for="tal_static_acolyte_divine_doctrine">Divine Doctrine'</label><input type="checkbox" id="tal_static_acolyte_divine_doctrine">''')
# Out:
# <label for="tal_static_acolyte_divine_doctrine">Divine Doctrine'</label><input type="checkbox" id="tal_static_acolyte_divine_doctrine">

# %%
# the HTML below works.  labesl and checkboxes need to be adjacent to the effect div.  current the CSS style has display: none for not(:checked) AND displat: Block for :checked
'''
<!DOCTYPE html>
<html>
<head>
<title>Page Title</title>
<style>
	input[type=checkbox]:checked~#tal_ability_reaver_rending_strike {
	display: block;
	}
    input[type=checkbox]:checked~#tal_trigger_reaver_blood_fury {
	display: block;
	}
    input[type=checkbox]:not(:checked)~#tal_ability_reaver_rending_strike {
	display: none;
	}
    input[type=checkbox]:not(:checked)~#tal_trigger_reaver_blood_fury {
	display: none;
	}
</style>
</head>
<body>
<div>
	<label for="tal_ability_reaver_rending_strike">Rending Strike</label>
	<input type="checkbox" id="tal_ability_reaver_rending_strike">
    <div id="tal_ability_reaver_rending_strike">
	Strike your target, delaing +1 Bonus Hits directly to their Grit.
</div>
</div>
<div>
	<label for="tal_trigger_reaver_blood_fury">Blood Fury</label>
	<input type="checkbox" id="tal_trigger_reaver_blood_fury">
    <div id="tal_trigger_reaver_blood_fury">
	When you are below your maximum Grit, add +1 Bonus Hits to any results set using Strike.
</div>
</div>



</body>
</html>
'''

# %%
print(str_div)
# Out:
# <div id="tal_ability_reaver_rending_strike">
# 	Strike your target, delaing +1 Bonus Hits directly to their Grit.
# </div>
# <div id="tal_trigger_reaver_blood_fury">
# 	When you are below your maximum Grit, add +1 Bonus Hits to any results set using Strike.
# </div>
# <div id="tal_trigger_reaver_strike_(3)">
# 	Increase your Strike Rank to 3 (d10).
# </div>
# <div id="tal_ability_reaver_whirlwind_strike">
# 	Strike at all hostile Targets in your Current Zone.  Deal 1 Hit to a number of targets equal to Hits in the result set.
# </div>
# <div id="tal_trigger_reaver_soul_reaver">
# 	When you Strike your target to death, immediately regain +2 points to your Grit.
# </div>
# <div id="tal_ability_reaver_vicious_whirlwind">
# 	Strike at all hostile Targets in your Current Zone.  Deal 2 Hits to a number of targets equal to Hits in the result set.
# </div>
# <div id="tal_ability_reaver_vicious_rending">
# 	Strike your target, delaing +2 Bonus Hits directly to their Grit.
# </div>
# <div id="tal_ability_reaver_">
#
# </div>
# <div id="tal_ability_reaver_">
#
# </div>
# <div id="tal_static_reaver_dangerous_trait_increase">
# 	Increase you Dangerous Trait rating by +1.
# </div>

# %%
print(str_cbox)
# Out:
# <label for="tal_ability_reaver_rending_strike">Rending Strike</label>
# <input type="checkbox" id="tal_ability_reaver_rending_strike">
# <label for="tal_trigger_reaver_blood_fury">Blood Fury</label>
# <input type="checkbox" id="tal_trigger_reaver_blood_fury">
# <label for="tal_trigger_reaver_strike_(3)">Strike (3)</label>
# <input type="checkbox" id="tal_trigger_reaver_strike_(3)">
# <label for="tal_ability_reaver_whirlwind_strike">Whirlwind Strike</label>
# <input type="checkbox" id="tal_ability_reaver_whirlwind_strike">
# <label for="tal_trigger_reaver_soul_reaver">Soul Reaver</label>
# <input type="checkbox" id="tal_trigger_reaver_soul_reaver">
# <label for="tal_ability_reaver_vicious_whirlwind">Vicious Whirlwind</label>
# <input type="checkbox" id="tal_ability_reaver_vicious_whirlwind">
# <label for="tal_ability_reaver_vicious_rending">Vicious Rending</label>
# <input type="checkbox" id="tal_ability_reaver_vicious_rending">
# <label for="tal_ability_reaver_"></label>
# <input type="checkbox" id="tal_ability_reaver_">
# <label for="tal_ability_reaver_"></label>
# <input type="checkbox" id="tal_ability_reaver_">
# <label for="tal_static_reaver_dangerous_trait_increase">Dangerous Trait Increase</label>
# <input type="checkbox" id="tal_static_reaver_dangerous_trait_increase">

# %%
str_div = ""
for i in rvr.index:
    str_div += f'''<div id="{rvr.iloc[i]['div_id_nm']}">\n\t{rvr.iloc[i]['effect']}\n</div>\n'''

# %%
print(str_div)
# Out:
# <div id="tal_ability_reaver_rending_strike">
# 	Strike your target, delaing +1 Bonus Hits directly to their Grit.
# </div>
# <div id="tal_trigger_reaver_blood_fury">
# 	When you are below your maximum Grit, add +1 Bonus Hits to any results set using Strike.
# </div>
# <div id="tal_trigger_reaver_strike_(3)">
# 	Increase your Strike Rank to 3 (d10).
# </div>
# <div id="tal_ability_reaver_whirlwind_strike">
# 	Strike at all hostile Targets in your Current Zone.  Deal 1 Hit to a number of targets equal to Hits in the result set.
# </div>
# <div id="tal_trigger_reaver_soul_reaver">
# 	When you Strike your target to death, immediately regain +2 points to your Grit.
# </div>
# <div id="tal_ability_reaver_vicious_whirlwind">
# 	Strike at all hostile Targets in your Current Zone.  Deal 2 Hits to a number of targets equal to Hits in the result set.
# </div>
# <div id="tal_ability_reaver_vicious_rending">
# 	Strike your target, delaing +2 Bonus Hits directly to their Grit.
# </div>
# <div id="tal_ability_reaver_">
#
# </div>
# <div id="tal_ability_reaver_">
#
# </div>
# <div id="tal_static_reaver_dangerous_trait_increase">
# 	Increase you Dangerous Trait rating by +1.
# </div>

# %%
str_css = "<style>\n"
for i in rvr.index:
    str_css += f'''\tinput:not(:checked)+#{rvr.iloc[i]['div_id_nm']} {{\n\tdisplay: none;\n}}\n'''
str_css += "<\style>\n"

# %%
print(str_css)
# Out:
# <style>
# 	input:not(:checked)+#tal_ability_reaver_rending_strike {
# 	display: none;
# }
# 	input:not(:checked)+#tal_trigger_reaver_blood_fury {
# 	display: none;
# }
# 	input:not(:checked)+#tal_trigger_reaver_strike_(3) {
# 	display: none;
# }
# 	input:not(:checked)+#tal_ability_reaver_whirlwind_strike {
# 	display: none;
# }
# 	input:not(:checked)+#tal_trigger_reaver_soul_reaver {
# 	display: none;
# }
# 	input:not(:checked)+#tal_ability_reaver_vicious_whirlwind {
# 	display: none;
# }
# 	input:not(:checked)+#tal_ability_reaver_vicious_rending {
# 	display: none;
# }
# 	input:not(:checked)+#tal_ability_reaver_ {
# 	display: none;
# }
# 	input:not(:checked)+#tal_ability_reaver_ {
# 	display: none;
# }
# 	input:not(:checked)+#tal_static_reaver_dangerous_trait_increase {
# 	display: none;
# }
# <\style>

# %%
print(str_cbox)
# Out:
# <label for="tal_ability_reaver_rending_strike">Rending Strike</label>
# <input type="checkbox" id="tal_ability_reaver_rending_strike">
# <label for="tal_trigger_reaver_blood_fury">Blood Fury</label>
# <input type="checkbox" id="tal_trigger_reaver_blood_fury">
# <label for="tal_trigger_reaver_strike_(3)">Strike (3)</label>
# <input type="checkbox" id="tal_trigger_reaver_strike_(3)">
# <label for="tal_ability_reaver_whirlwind_strike">Whirlwind Strike</label>
# <input type="checkbox" id="tal_ability_reaver_whirlwind_strike">
# <label for="tal_trigger_reaver_soul_reaver">Soul Reaver</label>
# <input type="checkbox" id="tal_trigger_reaver_soul_reaver">
# <label for="tal_ability_reaver_vicious_whirlwind">Vicious Whirlwind</label>
# <input type="checkbox" id="tal_ability_reaver_vicious_whirlwind">
# <label for="tal_ability_reaver_vicious_rending">Vicious Rending</label>
# <input type="checkbox" id="tal_ability_reaver_vicious_rending">
# <label for="tal_ability_reaver_"></label>
# <input type="checkbox" id="tal_ability_reaver_">
# <label for="tal_ability_reaver_"></label>
# <input type="checkbox" id="tal_ability_reaver_">
# <label for="tal_static_reaver_dangerous_trait_increase">Dangerous Trait Increase</label>
# <input type="checkbox" id="tal_static_reaver_dangerous_trait_increase">

# %%
print(str_cbox + '\n'+  str_div)
# Out:
# <label for="tal_ability_reaver_rending_strike">Rending Strike</label>
# <input type="checkbox" id="tal_ability_reaver_rending_strike">
# <label for="tal_trigger_reaver_blood_fury">Blood Fury</label>
# <input type="checkbox" id="tal_trigger_reaver_blood_fury">
# <label for="tal_trigger_reaver_strike_(3)">Strike (3)</label>
# <input type="checkbox" id="tal_trigger_reaver_strike_(3)">
# <label for="tal_ability_reaver_whirlwind_strike">Whirlwind Strike</label>
# <input type="checkbox" id="tal_ability_reaver_whirlwind_strike">
# <label for="tal_trigger_reaver_soul_reaver">Soul Reaver</label>
# <input type="checkbox" id="tal_trigger_reaver_soul_reaver">
# <label for="tal_ability_reaver_vicious_whirlwind">Vicious Whirlwind</label>
# <input type="checkbox" id="tal_ability_reaver_vicious_whirlwind">
# <label for="tal_ability_reaver_vicious_rending">Vicious Rending</label>
# <input type="checkbox" id="tal_ability_reaver_vicious_rending">
# <label for="tal_ability_reaver_"></label>
# <input type="checkbox" id="tal_ability_reaver_">
# <label for="tal_ability_reaver_"></label>
# <input type="checkbox" id="tal_ability_reaver_">
# <label for="tal_static_reaver_dangerous_trait_increase">Dangerous Trait Increase</label>
# <input type="checkbox" id="tal_static_reaver_dangerous_trait_increase">
#
# <div id="rvr_tal_rending_strike">
# 	Strike your target, delaing +1 Bonus Hits directly to their Grit.
# </div>
# <div id="rvr_tal_rending_strike">
# 	When you are below your maximum Grit, add +1 Bonus Hits to any results set using Strike.
# </div>
# <div id="rvr_tal_rending_strike">
# 	Increase your Strike Rank to 3 (d10).
# </div>
# <div id="rvr_tal_rending_strike">
# 	Strike at all hostile Targets in your Current Zone.  Deal 1 Hit to a number of targets equal to Hits in the result set.
# </div>
# <div id="rvr_tal_rending_strike">
# 	When you Strike your target to death, immediately regain +2 points to your Grit.
# </div>
# <div id="rvr_tal_rending_strike">
# 	Strike at all hostile Targets in your Current Zone.  Deal 2 Hits to a number of targets equal to Hits in the result set.
# </div>
# <div id="rvr_tal_rending_strike">
# 	Strike your target, delaing +2 Bonus Hits directly to their Grit.
# </div>
# <div id="rvr_tal_rending_strike">
#
# </div>
# <div id="rvr_tal_rending_strike">
#
# </div>
# <div id="rvr_tal_rending_strike">
# 	Increase you Dangerous Trait rating by +1.
# </div>
