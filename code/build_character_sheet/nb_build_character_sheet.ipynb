# %%
import pandas as pd
# import htmlgenerator as hg
import os
import json
import numpy as np

while os.getcwd()[-10:] != 'no1_system':
    os.chdir('..')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\DonalHarrison\\Documents\\admin\\ach\\no1\\no1_system'

# %% [markdown]
# ## Training start

# %%
df_training = pd.read_csv('./docs/_data/training.csv')

# %%
pd.set_option('display.max_colwidth', 255)
df_training.head(5)
# Out:
#         Name   Type Prerequisites  \
# 0   Aberrant  Basic     Uncanny 2
# 1    Acolyte  Basic      Steady 2
# 2  Alchemist  Basic       Savvy 2
# 3      Brute  Basic   Dangerous 2
# 4  Channeler  Basic           NaN
#
#                                                                                                                             Description  \
# 0  You tap into mysterious and otherworldly power sources, harnessing enigmatic and often dangerous powers beyond mortal comprehension.
# 1                      You are a follower of a religion or spiritual practice, granting you kowledge of and powers from its principles.
# 2                                                You are adept at potion-making and transmutation, wielding transformative concoctions.
# 3                                                  You are a savage & resilient combatant, focusing on destroying one target at a time.
# 4                            You harness and manipulate fundamental energies of existence, acting as a conduit to the elemental forces.
#
#                                img_path  \
# 0   /no1_system/assets/img/aberrant.png
# 1    /no1_system/assets/img/acolyte.png
# 2  /no1_system/assets/img/alchemist.png
# 3      /no1_system/assets/img/brute.png
# 4  /no1_system/assets/img/channeler.png
#
#                                     page_path
# 0   /no1_system/characters/training/aberrant/
# 1    /no1_system/characters/training/acolyte/
# 2  /no1_system/characters/training/alchemist/
# 3      /no1_system/characters/training/brute/
# 4  /no1_system/characters/training/channeler/

# %%
df_training['tag_img_src'] = df_training['img_path'].str.replace("/no1_system/", "https://raw.githubusercontent.com/donalharrison/no1_system/site-testing/docs/")
df_training['attr_training_rank_nm'] = "attr_training_rank_" + df_training['Name'].str.lower()

# %%
df_training['div_str'] = '<div class="grid-character-training-item"><img src="' + df_training['tag_img_src'] + '" alt="' + df_training['Name'] + ' Icon" width="50px" height="50px" style="vertical-align: middle;"><span style="vertical-align: middle;">' + df_training['Name'] + '    <input class="sheet-training-ranks" type="number" name="' + df_training['attr_training_rank_nm'] + '" step="1" value="0"min="0" max="20" /></span></div>'

# %%
training_divs = ''
for i in df_training.index:
    training_divs += df_training.iloc[i]['div_str']

# %%
write_training = False

# %%
if write_training:
    f = open('./code/character_sheet/html_raw_training.html', 'w')
    f.write(training_divs)
    f.close()

# %% [markdown]
# ## Talents Start

# %%
f = open('./docs/_data/talents.json', 'r')
df_talents_raw = json.load(f)
f.close()

# %%
df_talents = pd.DataFrame(df_talents_raw['talents'])
df_talents['effect_raw'] = df_talents['effect'].copy()

# %%
df_talents[df_talents['tree']=='Seer']
# Out:
#      tree                    name     type rank          requires replaces  \
# 563  Seer     Peer Through Depths  Ability    1              None     None
# 564  Seer      Sift Through Sands  Ability    2              None     None
# 565  Seer     Reach Through Mists  Ability    2              None     None
# 566  Seer   Think the Unthinkable  Trigger    1              None     None
# 567  Seer     Know the Unknowable  Trigger    1              None     None
# 568  Seer          Read the Bones  Ability    1              None     None
# 569  Seer        Dig Through Time    Shift    3              None     None
# 570  Seer                  Ponder  Ability    2              None     None
# 571  Seer               Preordain  Ability    2              None     None
# 572  Seer        Glimpse the Cosm  Ability    2              None     None
# 573  Seer         Behold the Cosm  Trigger    3  Glimpse the Cosm     None
# 574  Seer                 Foresee  Ability    3              None     None
# 575  Seer      Unexplained Vision  Trigger    3              None     None
# 576  Seer              See Beyond  Ability    2              None     None
# 577  Seer  Uncanny Trait Increase  Ability                   None     None
# 883  Seer  Uncanny Trait Increase   Static    2              None     None
#
#                                                 effect  \
# 563  [<h4 style='margin: 3px';>Portent</h4>, Increa...
# 564  [<h4 style='margin: 3px';>Portent</h4>, Spend ...
# 565  [<h4 style='margin: 3px';>Portent</h4>, Spend ...
# 566  [<h4 style='margin: 3px';>Portent</h4>, When y...
# 567  [<h4 style='margin: 3px';>Portent</h4>, When y...
# 568  [<h4 style='margin: 3px';>Portent</h4>, Analyz...
# 569  [Spend X Momentum to add X Bonus Hits to the n...
# 570  [<h4 style='margin: 3px';>Portent</h4>, Spend ...
# 571  [<h4 style='margin: 3px';>Portent</h4>, Roll 2...
# 572  [<h4 style='margin: 3px';>Portent</h4>, Percie...
# 573  [When you Glimpse the Cosm and score 3+ Hits, ...
# 574  [<h4 style='margin: 3px';>Portent</h4>, Intuit...
# 575  [<h4 style='margin: 3px';>Portent</h4>, When y...
# 576  [Spend 1 Momentum and Perceive to reveal hiden...
# 577        [Increase your Uncanny Trait rating by +1.]
# 883         [Increase you Uncanny Trait rating by +1.]
#
#                                             effect_raw
# 563  [<h4 style='margin: 3px';>Portent</h4>, Increa...
# 564  [<h4 style='margin: 3px';>Portent</h4>, Spend ...
# 565  [<h4 style='margin: 3px';>Portent</h4>, Spend ...
# 566  [<h4 style='margin: 3px';>Portent</h4>, When y...
# 567  [<h4 style='margin: 3px';>Portent</h4>, When y...
# 568  [<h4 style='margin: 3px';>Portent</h4>, Analyz...
# 569  [Spend X Momentum to add X Bonus Hits to the n...
# 570  [<h4 style='margin: 3px';>Portent</h4>, Spend ...
# 571  [<h4 style='margin: 3px';>Portent</h4>, Roll 2...
# 572  [<h4 style='margin: 3px';>Portent</h4>, Percie...
# 573  [When you Glimpse the Cosm and score 3+ Hits, ...
# 574  [<h4 style='margin: 3px';>Portent</h4>, Intuit...
# 575  [<h4 style='margin: 3px';>Portent</h4>, When y...
# 576  [Spend 1 Momentum and Perceive to reveal hiden...
# 577        [Increase your Uncanny Trait rating by +1.]
# 883         [Increase you Uncanny Trait rating by +1.]

# %%
len(df_talents.iloc[2]['effect_raw'])
# Out:
# 1

# %%
skill_rank_tals, skill_rank_ranks = [], []
for i, row in df_talents.iterrows():
    for e in row['effect']:
        if 'Increase your' in e:
            skill_rank_tals.append(e[e.find('your')+5 : e.lower().find('rank')-1])
            skill_rank_ranks.append(e[e.lower().find('rank') : e.lower().find('rank') + 9])
# skill_rank_tals

# %%
skill_incs = []
for t in skill_rank_tals:
    skill_incs.append(t[t.find('your')+5 : t.lower().find('rank')-1])

# %%
df_tmp = pd.DataFrame({"skill":skill_rank_tals, "rank":skill_rank_ranks, "n":1})
# df_tmp.groupby(['skill', 'rank']).count()
pd.pivot_table(data=df_tmp, values='n', index='skill', columns='rank', aggfunc='sum').to_csv('skill_rank_talents.csv', index=True, na_rep=0)

# %%
clean_talent_effect = []
for i, f in df_talents.iterrows():
    # print(f['effect'])
    if len(f['effect_raw']) > 1:
        v = ''
        for e in f['effect_raw']:
            v += e + '<br>' #('<br>'.join).reset_index()
    else:
        v = f['effect_raw'][0]
    clean_talent_effect.append(v)
#clean_talent_effect
df_talents['effect'] = clean_talent_effect

# %%
clean_talent_effect
# Out:
# ['Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.<br>Your Concordance measures how closely you are aligned with your Divine Doctrine.<br>You may use this Ability without using an Action at the beginning of each Waypoint.  If you use it during a Waypoint, it requires 8 - Steady Actions (minimum 1 Action).<br>',
#  "You follow set of principles in your belief system or religious practice, referred to as your Divine Doctrine.  Each Divine Doctrine consists of <em>Virtues</em>, <em>Taboos</em>, and <em>Domains</em>.<br>When you act against your Virtues or engage in a Taboo, reduce your Concordance by 1.<br>Select two items from the list below to be your Virtues and two items to be your Taboos:<br><em>Temperance, Indulgence, Avarice, Charity, Humility, Compassion, Wrath, Courage, Deceipt, Justice, Loyalty, Honesty . . .</em><br>Select 2 Effect Skills from the list below to be your Domain:<br><em>Bellor, Inferno, Lux, Mori, Nox, Ordi, Rime, Tempest, Vivus</em><br>Commitment to your Divine Doctrine lets you access <a href='/no1_system/characters/powers#Rites'>Rites</a>.  If one your Rite's result set contains a 1, reduce your Concordance by 1.<br>If you attempt to use a Rite when you Concordance is below 0, add 1 Hazard die to the roll for each point your Concordance is below 0.<br>",
#  'Increase your Composure Rank to 2 (d8).',
#  'Increase one of your Domain Ranks to 2 (d8).',
#  'Increase one of your Domain Ranks to 2 (d8).',
#  'Increase one of your Domain Ranks to 3 (d10).',
#  'You have an innate ability that deviates from the normal.<br>When you gain this Talent, choose one of the following Effect Skill to be your Aberration:<br><em>Destroy, Intuit, Luck, Resist</em><br>',
#  'Increase your Abberation Rank to 2 (d8).',
#  "When you score 3+ Hits with your Aberration's Effect Triggers, increase the Momentum by +2.",
#  'Increase your Abberation Rank to 3 (d10).',
#  "When you score 5+ Hits with your Aberration's Effect Triggers, you may immediately use a different Effect Trigger from your Aberration.",
#  "You hold knowledge of the mysteries of the cosmos, bending secret powers to your will.  You gain access to <a href='/no1_system/characters/powers/arcana/'>Arcana</a>.<br>Intuit, Research, or use your Insight to unravel these mysteries further, gaining Hits in Arcana Ranks to invest in your Arcana.<br>You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 4 Actions.<br>",
#  "Your pursuit of Arcana expose you to <strong>Strain</strong>.<br>When you roll one of your Affinity to invoke and Arcana, you gain Strain according to the result as soon as the Arcana effects resolve.<br>Strain accumulates over the course of your adventures, only reducing by 1d6 at the conclusion of a Waypoint.<br>You suffer the effects of Strain according to the <em>Straing Effects Table</em> table below.  Strain Effects are cumulative:<br><table style='width: 50%;'><thead><th>Strain</th><th>Effect</th></thead><tr><td>0-4</td><td>No effect</td></tr><tr><td>5-9</td><td>Fatigued 1</td></tr><tr><td>10-14</td><td>Confused</td></tr><tr><td>15-19</td><td>Fatigued 2</td></tr><tr><td>20-24</td><td>Vulnerable 3</td></tr><tr><td>25-29</td><td>Stunned 4</td></tr><tr><td>30+</td><td>Dead</td></tr></table><br>",
#  'Use your Insight to reduce your current Strain by Hits.',
#  'Increase your Insight Rank to 3 (d10).',
#  'Increase one of your Affinity Ranks to 2 (d8).',
#  'Increase one of your Affinity Ranks to 2 (d8).',
#  'Increase one of your Affinity Ranks to 3 (d10).',
#  'Craft at Challenge 3 to gain Hits + Savvy in Concoction Ranks to prepare Concocions.<br>You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 7 - Craft Actions (minimum 1 Action).<br>',
#  'Increase your Craft Rank to 1 (d6).',
#  'Increase your Craft Rank to 2 (d8).',
#  'Increase your Craft Rank to 3 (d10).',
#  'When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.',
#  'Once per turn you can use or apply a Concoction that requires a Shift to Use Your Equipment wihtout using a Shift.',
#  'When you Persuade or Deceive a target to sell your Concoctions and score 2+ Hits, gain +1 Wealth from the transaction.',
#  'When you Persuade or Deceive a target to sell your Concoctions and score 3+ Hits, gain +1 Wealth from the transaction.',
#  'When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.',
#  '',
#  'Spend 3 Momentum and immediately Strike a target in your Current Zone that is Prone.  On 6+ Hits, the target dies.',
#  'When you score Hits against a target while Hidden, add +1d6 bonus Hits to the result set.',
#  "You are a master of using Poison, doubling the Poison's effects.",
#  'You do not lose your Hidden rating when you Shoot a target while Hidden.',
#  'Strike an opponent whil Hidden, attempting to subdue them quietly.  If you score 4+ Hits, the tareget suffers no damage to their Defenses or Grit, but gains Unconscious X, where X is equal to Hits in the result set.',
#  'When you Strike or Shoot your target to death, you may immediately use your Stealth without using a Shift.',
#  'Use your Tactics to mark your target, giving them Aura X, where X is equal to Hits in your result set.  Your target is Vulnerable 1 to any Action you take against it while the Aura persists.',
#  'Spend X Momentum to gain Hidden X, where X is the amount of Momentum spent.',
#  "When you make an Initiative Test in an Ambush, you may spend Momentum to increase Hits scored by X, where X is the number of Momentum spent.<br>If your team's total Initiative is 6+ greater than your enemy's, the Initiative does not shift to the enemy during the first round of the encounter (1s still increase Entropy).",
#  'When you are being searched by someone attempting to disarm you of your weapons and implements, you may use Legerdemain to hide a dagger on your person is you sore 1+ Hits.',
#  'When you Defy Danger to Hide! and score 2+ Hits, you can take an additional Shift this turn.',
#  'When you Sneak Attack a target you have Marked for Death, add +2d6 Bonus Hits to the result set.',
#  'Gain +3 Renown and +1 Enemies',
#  'Persuade one target in your Current Zone to negotiate terms of a contract, adding +2 Bonus Hits to the result set.',
#  "When a target you have Marked for Death escapes, immediately spend 1 Momentum to gain Favor 1.  You can only use this favor to learn about the escaped target's wherabouts.",
#  'Exert yourself to accomplish a feat of strength, adding +1d4 bonus hits to the result set.',
#  'When you Shift to move to an adjacent Zone, you may move an additional Zone.',
#  'Increase your Exert Rank to 2 (d8).',
#  'Increase your Tumble rank to 2 (d8).',
#  'Increase your Exert Rank to 3 (d10).',
#  'Increase your Tumble rank to 3 (d10).',
#  'You are adept in acrobatics, adding +2 Bonus Hits any result sets using Tumble.',
#  'When you Defy Danger using Parkour!, add +1d4 Bonus Hits to the result set.',
#  'When you Recover, regain +2 Defenses.',
#  'Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in <strong><em>Concordance</em></strong>.<br>Your Concordance measures how closely you are aligned with your Divine Doctrine.<br>You may use this Ability without using an Action at the beginning of each Waypoint.  If you use it during a Waypoint, it requires 8 - Steady Actions (minimum 1 Action).<br>',
#  'Lead all allies in your Current Zone, allowing a number of them equal to the Hits in the result set to immediately do 1 of the following:<ul><li>Recover</li><li>Reduce one Variable Status by -1</li><li>Add +1 Bonus Hits to their next result set</li></ul>',
#  'Use your Tactics allies in your current Zones, allowing X allies to immediately use a Shift, where X is equal to Hits in the result set.',
#  'When an enemy scores 1 or 0 Hits in their result set, your team regains the initiative.',
#  'Lead all allies in your Current Zone, granting X allies +2 Bonus Hits on their next roll, where X is the number of Hits in the result set.<br>If you score 4+ Hits, reduce the Entropy by -2.<br>',
#  'You are adept at planning battles and missions.  You add +1d4 Bonus Hits when you use your Tactics to plan a mission.',
#  'Lead the assault in combat designating one target in your Current Zone.  The target gains Vulnerable X, where X is equal to Hits -2 in the result set.',
#  'Spend X Momentum to grant all allies in your Current Zone to regain +X to their Primary Defenses, where X is equal to the Momentum spent.',
#  'Use your Tactics to guide allies in your current and all adjacent Zones in a tactical retreat, allowing a number of allies equal to Hits in the result set to immediately Shift away from hostile targets and reducing any Hazard by -1.',
#  'Lead allies in your Current Zone, adding Hits -1 to the Momentum and Creating 1 Advantage in your Current Zone.',
#  'Spend 3 Momentum and use your Tactics to outmanuever your enemies.  On 2+ Hits, you may designate up to 3 targets in your Current or Adjacent Zones to gain Vulnerable 1.',
#  'Use your Tactics instead of Strike to attack an enemy in yoru Current Zone.  The target suffers Hits -2 to their Defense and you Create 1 Advantage in your Current Zone.',
#  'Increase your Tactics Rank to 2 (d8).',
#  'Increase your Tactics Rank to 3 (d10).',
#  'Increase your Tactics Rank to 4 (d12).',
#  'Increase your Lead Rank to 2 (d8).',
#  'When a hostile target Shifts away from you in melee combat, they add an additional Hazard die to their next roll.',
#  'You are adept take swift and decisive action to turn the tide.  If you Lead or use your Tactics on the first turn of a Timer, increase the Momentum by +2.',
#  'When you use your Tactics, adding +1 Bonus Hits to the result set.',
#  "You follow set of principles in your belief system or religious practice, referred to as your Divine Doctrine.  Each Divine Doctrine consists of <em>Virtues</em>, <em>Taboos</em>, and <em>Domains</em>.<br>When you act against your Virtues or engage in a Taboo, reduce your Concordance by 1.<br>Select two items from the list below to be your Virtues and two items to be your Taboos:<br><em>Temperance, Indulgence, Avarice, Charity, Humility, Compassion, Wrath, Courage, Deceipt, Justice, Loyalty, Honesty . . .</em><br>Select 2 Effect Skills from the list below to be your Domain:<br><em>Bellor, Inferno, Lux, Mori, Nox, Ordi, Rime, Tempest, Vivus</em><br>Commitment to your Divine Doctrine lets you access <a href='/no1_system/characters/powers#Rites'>Rites</a>.  If one your Rite's result set contains a 1, reduce your Concordance by 1.<br>If you attempt to use a Rite when you Concordance is below 0, add 1 Hazard die to the roll for each point your Concordance is below 0.<br>",
#  'Select 1 additional Effect Skill from the list below to add to your Domain:<br>Bellor, Inferno, Lux, Mori, Nox, Ordi, Rime, Tempest, Vivus',
#  'Use a Shift to maintain your Composure, immediately gaining 1d4+1 Concordance.',
#  'Spend your Concordance to add Xd4 to your Strike, where X is equal to the amount of Concordance spent.',
#  'When you suffer Hits from an attack in your Current or and Adjacent Zone, you may spend 1 Concordance to deal +1d4 Bonus Hits to the attacking target.',
#  'Increase your Cosmology or Theology Ranks to 2 (d8).',
#  'When you suffer Hits from a Power effects, you may spend 1 Concordance to regain +1d6 to your Primary Defense.',
#  'Focus to gain an Aura X, where X is the number of Hits in the result set.<br>While the Aura persists, all Allies in your Current Zone regain Grit equal to your Heretic rank at the beginning of your turn.<br>All hostile targets in your Current Zone gain Fatigued 1.',
#  'When you suffer Hits from an attack you can see, you can spend 1 Concordance to reduce the Hits by -1d4.',
#  'Once per Waypoint, use your Insight to uncover an unwanted truth.  If you score 3+ Hits, ask the BAMF one question about the game fiction.  Answers will vary depending on the amount of infromation you and your allies have discovered about the game fiction in question.',
#  'You can spend 1 Concordance to call on the Vivus energy.  You and one ally in your Current Zone ragin Hits to your Grit or Primary Defenses.',
#  "When a target you can see uses a Power, you can spend 1 Concordance to use one Effect Skill in your Domain.  If you score more Hits than the hostile Power's Hits, the Power does not take effect.<br>Then, you and the hostile target are engaged in a Contest.",
#  'When you successfully use your Sacred Disruption, you deal Hits in your Domain Skill result set to the target.',
#  'When you use your Profane Smite and score 3+ Hits, your target gain Blind.',
#  '',
#  'Increase your Exert Rank to 2 (d8).',
#  'Exert yourself, entering a trance-like fury to crush your enemies, see them driven before you, and to hear the lamentations of their women. You gain a Rage Aura equal to Hits +1 in the result set.<br>While you are in a Rage, you may decrease your Rage Aura by -1 to add +2 Bonus Hits to any Action using Exert, Endure, Grapple, Intimidate, Martial Arts, Strike, or Throw.<br>If your Rage Aura equals 0 or you use a Shift to dismiss it, you gain Fatigued 2 and Confused 1, and the Entropy increases by +1.<br>If your Rage Aura is 8+, you gain Fatigued 2 and Confused, and the Entropy increases by +2.<br>',
#  'When you are in a Rage and score 4+ Hits in melee combat, increase your Rage Aura by +2.',
#  'When you are in a Rage and use the Recover Acation, you may regain +3 to your Grit and decrease your Dying rating by -1.',
#  "Decrease your Rage Aura by -2 and choose one (1):<ul><li>Strike or use your Martial Arts against one target in your Current Zone, adding +1d4 Bonus Hits to the restul set and your target gains Wounded 1.</li><li>Throw one target you have Grappled into an Adjacent Zone, ending the target's Grappled status.  The target and one other target in the Adjacent Zone take X Hits and become Prone, where X is equalt to Hits in the result set.</li><li>Intimidate hostile targets in your Current Zone.  Up to X targets gian Provoked and your recover X to your Primary Defense, where X is equal to Hits in the result set.</li></ul>",
#  'While you are in a Rage, you automatically regain +1 point to your Primary Defense at the beginning of your turn and you are immune to being Afraid.',
#  'When  you are in a Rage and score 5+ Hits using Grapple, Martial Arts, Strike, or Throw, you may reduce your Rage Aura by -1 and your target gian Vulnerable 1.',
#  'Increase your Exert Rank to 3 (d10).',
#  'When you are in a Rage and suffer 2+ Hits from a melee attack, increase you Rage Aura by +1.',
#  'Increase your Martial Arts Rank to 3 (d10).',
#  'When you Shift to Move into an Adjacent Zone and use your Martial Arts to attack your target, add +3 Hits to the result set.',
#  'When you are in a Defensive Stance and take 3+ Hits in melee combat from an attacker you can see, reduce the total hits by 1.',
#  'When you are in a Aggressive Stance and score 4+ Hits in melee combat, your target gains Vulnerable 2.',
#  'Use your Martial Arts against a target in your Current Zone.<br>If you score 3+ Hits, add +1d4 Bonus Hits to the results set.<br>',
#  'Increase your Martial Arts Rank to 4 (d12).',
#  'When you use an Action to Recover Defenses, you may regain up to +1 Grit.',
#  '',
#  'Increase your Implements Rank to 1 (d6).',
#  'Intimidate a target in yout Current Zone that you are trying to apprehend, adding +1d4 Bonus Hits to the result set.',
#  'Increase your Implements Rank to 2 (d8).',
#  'Use your Implements to ensnare one target in your Current or and Adjacent Zone.  The target gains Prone and Restrained X, where X is equal to Hits in the result set.',
#  'Use your Implements to bind the hands of one target in your Current Zone.  On 2+ Hits, the target gains Restrained X, where X is 8+Hits in the result set.',
#  'Increase your Survival Rank to 3 (d10).',
#  'Increase your Insight Rank to 2 (d8).',
#  'Increase your Streetwise Rank to 2 (d8).',
#  'Gain +2 Enemies and either +1 Renown or +3 Wealth.',
#  'Persuade, Intimidate, or use your Insight when discussing the terms of a bounty, addin +1d4 Bonus Hits to the result set.',
#  'Use your Streetwise to gain valuable information or find the right person to talk to about you target.  On 3+ Hits, you gain +1 Favor to use in your hunt.',
#  'Increase your Intimidate Rank to 2 (d8).',
#  'When you successfully apprehend a wanted target, gain +1 Renown or +2 Wealth.',
#  'Strike one target in your Current Zone or Shoot one target in your Current or an Adjacent Zone aiming to subdue them.<br>On 4+ Hits, your target gains Unconscious 1.  Otherwise target gains Stunned 4.<br>',
#  'Strike one target with unrelenting force, adding +1d4 Bonus Hits to the result set.',
#  'Use Martial Arts against one target with unrelenting force, adding +1d4 Bonus Hits to the result set.',
#  'Exert yourself when you are below your maximum Grit, then choose 1:<ul><li>Regain Hits to your Primary Defense.</li><li>Increase the current Timer by 1.</li></ul>',
#  'Increase your Exert Rank to 2 (d8).',
#  'Increase your Intimidate Rank to 2 (d8).',
#  "Intimidate all targets in your Current Zone.  If you score Hits greater than their current Nerve, they become <a href:'/no1_system/core/statuses#Afraid/'>Afraid</a> of you.",
#  'When you Strike your target to death, you can Initiate a Contest with one hostile target in your Current Zone wihtout using a Shift.',
#  'When you Strike your target to death, describe the gruesome end you delivered.  Then all hostile targets in your Current Zone with Nerve less than Hits become Afraid of you.',
#  "Your Affinity for these forces all you to use <a href='/no1_system/characters/powers/techniques/'>Techniques</a> that channel their power.<br>When you gain this Talent, select 2 Effect Skills from the list below to be your Affinities:<br><em>Inferno, Lux, Nox, Rime, Squall, Tellus, Tempest, Torrent</em><br>At the beginning of each Waypoint, your Current is 0.<br>",
#  "If a Technique you use has a 1 in the result set, all targets within your Current Zone sustain Hits from the Techniques's effect equal to its lowest Threshold.",
#  'Increase one of your Affinity Ranks to 2 (d8).',
#  'Increase your Composure Rank to 2 (d8).',
#  'Increase your Endure Rank to 2 (d8).',
#  'Increase your Focus Rank to 2 (d8).',
#  'Increase one of your Affinity Ranks to 2 (d8).',
#  'Increase one of your Affinity Ranks to 3 (d10).',
#  'Focus or use your Insight to connect with your power, gaining Hits in Attunement.<br>Attunment measures the strength of connection to your power, which determines the strength of the Marvels you can manifest.<br>If the result set of one of your Marvels contains a 1, reduce your Atttunement by X, where X is equal to Hits in the same result set.<br>If your Attunement equals 0 or less, you gain Stunned 3 and the Entropy increases by +3.<br>You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 8 - Steady Actions (minimum 1 Action).<br>',
#  'When you gain this Talent, select 1 Effect Skill from the list below to be an <em>Affinity</em> allowing you to further empower your Spells with Skill Talents:<br><em>Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus</em><br>Your Essence is innately bound to this Affinity, allowing you to manifest its effects into reality by using Marvels.<br>',
#  'Increase one of your Affinity Ranks to 2 (d8).',
#  'Increase your Focus Rank to 2 (d8).',
#  'Increase your Insight Rank to 2 (d8).',
#  'Increase one of your Affinity Ranks to 3 (d10).',
#  'Increase your Insight Rank to 3 (d10).',
#  'Increase your Focus Rank to 3 (d10).',
#  'Spend X Hits from the result set of the next Marvel you use this turn to increase your Attunement by X.',
#  'Select 2 additional Effect Skills from the list below to add to your Affinity:<br><em>Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus</em>',
#  '',
#  'You are adept at fighting on accustomed to the rolling decks of ships. While you are moving on board a shipYou add +1d4 Bonus Hits when you Strike or Shoot a target, and you reduce all Hazards by -1.',
#  'Persuade a sailor, pirate, or maritime merchant, adding +2 Bonus Hits to the result set.',
#  'Increase your Navigate Rank to 2 (d8).',
#  'Increase your Strike Rank to 3 (d10).',
#  'Increase your Cosmology or History rank to 2 (d8).',
#  'Gain +3 Renown and +1 Enemies',
#  'Perceive or Investigate to find hidden compartments, treaure, or valuable cargo, adding +1d4 Bonus Hits to the result set.',
#  'Lead the crew of a ship in unleashing a devastating broadside attack.  On 2+ Hits, the ballistae to deal double Hits on their next Shoot attempt.',
#  'When you Recover to reduce Fatigue, recover any remaining Hits to Vigor once your Fatigue rating is 0.',
#  'Increase your Operate Rank to 3 (d10).',
#  'Increase your Strike Rank to 3 (d10).',
#  'Use your Implements to throw a grappling hook, allowing you to use your Shift to Move to an Adjacent Zone that is vertical from your Current Zone.',
#  'Spend Momentum to Strike with the rage of the seas adding +X Bonus Hits to the result set, where X is the amount of Momentum spent.',
#  'Lead your crew through a severe storm or troubled waters.  On 2+ Hits, all crew Actions add +2 Bonus Hits to their Result Set.',
#  'Deceive a target that holds a position of authority, adding +1d4 Bonus Hits to the result set.',
#  'Lead all allies in your Current Zone allowing X allies to immediately use a Shoft or Trigger, where X is the number of Hits in the result set.',
#  'Persuade your target, adding +2 Hits to the result set.',
#  'Once per Waypoint, you may invoke your dipmoatic staus to avoid arrest or legal consequences for minor offenses.',
#  'You are an expert at arranging advantageous deals and alliances, leveraging your noble prowess to gain favors and resources.<br> At the beginning of a Waypoint when you are in a city, you may spend 2 Momentum to gain 1 Favor and 1 Wealth.',
#  'Deceive your target, adding +2 Bonus Hits to the result set.',
#  'When you use your Insight or Investigate a situation to uncover information that someone is trying to conceal, add +1d4 Hits to the result set.',
#  'When you suffer Hits from a target you can see and your Nerve is above 0, spend 1 Nerve to reduce the total Hits by +2.',
#  'Increase your History Rank to 3 (d10) and your Persuasion or Insight Rank to 3 (d10).',
#  'Deceive to adopt the mannerisms and speech of a different social class, adding +1d4 Bonus Hits to the result set.',
#  'You can utilize your Shadow Network to spread a rumor or piece of misinformation. While you are in a city, Spend 2 Wealth and Deceive to plant the seeds of gossip.',
#  'Lead all allies in your Current Zone, restoring Hits to their Primary Defenses.',
#  'You excel at forming discrete alliances ensuring mutual benefits without drawing unwanted attention, allowing you to add 1d+ Bonus Hits to any result set when you Persuade or use your Insight in a private meeting.',
#  'When you successfully diffuse a social situation in the benefit of you and your allies, gain +1 Renown.',
#  'You maintain a network of informants and are skilled at finding enterprising local to gather valuable intelligence.  You may spend Wealth while in a city and ask the BAMF X questions, where X is the amount of Wealth spent.  Then, Deceive your informants to cover your tracks.<br>The BAMF will provide your answers at a time that makes sense in the game fiction.',
#  'When you are engaged in a Contest and Persuade or Intimidate your opponent, add +2 Bonus Hits to the result set.',
#  'Increase your History Rank to 2 (d8) and your Persuasion or Insight Rank to 2 (d8).',
#  'When you are in a formal setting and Persuade a target, you may use a Savvy Trait reroll to reroll all dice instead of just 1s.',
#  'You are a master at communicating subtly and discreetly, exchanging critical information without arousing suspicion.  Deceive to communicate with an ally in your Current Zone when you are being observed by unwanted ears.  On 3+ Hits, you can speak freely without being overheard.',
#  'Focus to defend yourself in combat, assuming a Defensive Stance adding +Hits to your Primary Defense.',
#  'Use a Shift to protect 1 ally in your Current Zone.',
#  'Increase your Focus Rank to 2 (d8).',
#  'When you protect an ally in your Current Zone and they are Hit by an attack you can see, you may redirect a number of Hits against that ally to yourself equal to the Defender Rank.',
#  'When you Recover, regain +2 Defenses.',
#  'You gain an additional +2 rating from any Armor you equip.',
#  'Increase your Endure Rank to 2 (d8).',
#  'You gain an addition +4 rating from any Armor you equip.',
#  'When you Focus to defend yourself in combat, ad +1d4 Bonus Hits to your Primary Defense.',
#  'Increase your Focus Rank to 3 (d10).',
#  'Increase your Focus Rank to 4 (d12).',
#  'When you protect an ally in your Current Zone and they are Hit by an attack you can see, you may redirect a number of Hits against that ally to yourself equal to the Guardian Rank.',
#  'When you take more than 1 Hit from an effect, reduce the total Hits by -1.',
#  'When you Recover, regain +2 Defenses.',
#  'You gain an additional +4 rating from any Armor you equip.',
#  'Increase your Endure Rank to 3 (d10).',
#  'Increase your Endure Rank to 4 (d12).',
#  'When you use a Shift to protect 1 ally in your Current Zone, your protect 2 allies instead.',
#  'Maintain your Composure engaged in a Contest, causing your opponent to hesitate.<br>Add +2 to the current Timer and reduce the Momentum by -Hits.<br>',
#  'Increase your Vigor by 3.',
#  'Increase your Investigate Rank to 2 (d8).',
#  'You can use a Shift to Perceive or Investigate when gathering information or searching for clues.',
#  'Persuade or Intimidate a target you are questioning, adding +2 Bonus Hits to the result set.',
#  'Increase your Investigation Rank to 3 (d10).',
#  'Analyze the facts and data, adding +1d4 Hits to the result set.',
#  'Use Stealth to follow or observe a target without being noticed, adding +1d4 Hits to the result set.',
#  'Increase your Analyze Rank to 3 (d10).',
#  'Use your Insight to determine if your target is lying or to sense their intentions, adding +2 Bonus Hits to the result set.',
#  'You maintain a network of informants and are skilled at finding enterprising local to gather valuable intelligence.  You may spend Wealth while in a city and ask the BAMF X questions, where X is the amount of Wealth spent.  Then, Deceive your informants to cover your tracks.<br>The BAMF will provide your answers at a time that makes sense in the game fiction.',
#  'When you are the target of an Ambush and make an Initiative Test, add +1d4 Bonus Hits to the result set.',
#  'You can draw accurate conclusions from limited information.  Spend 3 Momentum to state yoru conclusion.  The BAMF will tell you if you are correct.',
#  'Use a Shift to Investigate, then Analyze your findings, summing the Hits in both result sets.',
#  'Persuade, Endure, or maintain your Composure to contact your the Patrons of the Hellplanes and gain Hits in Succor which determines the highest rank of Gifts you can use.<br>If a Gift you use has a 1 in the result set, reduce your Succor by -1.<br>If your Succor equals 0 or less, increase the Entropy by +4 and gain +1 Debts.<br>You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 7 - Savvy Actions (minimum 1 Action) and the Entropy increases by +1.<br>',
#  'You discover your Patron dwell in the Hellplanes.  Add +2 Bonus hits to the result sets of Actions using the Receive Gifts Ability.<br>Increase your Deceive or Persuade Rank to 1 (d6), 2 (d8), or 3 (d10).<br>',
#  'You gain the ability to cast Hexes on your enemies.<br>When you gain this Talent, select 2 Effect Skill from the list below to be an <em>Affinity</em> allowing you to further empower your Hexes with Skill Talents:<br><em>Aether, Inferno, Mori, Nox, Plaga, Rime, Sangui, Tempest</em><br>When you lose focus on your Ongoing Hexes, increase the Entropy by +3.<br>',
#  'Increase one of your Affinity Ranks to 1 (d6).',
#  'Increase one of your Affinity Ranks to 2 (d8).',
#  'Increase the Entropy by +1, then Deceive or Persuade on target in your Current Zone to give them Charmed X, where X is equal to Hits in the result set.',
#  "Increase the Entropy by +1, then touch one target in your Current Zone who is Charmed by you to regain X Grit, where X is the target's Charmed rating.  The target loses Charmed.",
#  'When you Deceive or Persuade a target, you may add +1d4 Bonus Hits to the result set.  Increase the Entropy by +1.',
#  'Increase one of your Affinity Ranks to 3 (d10).',
#  'Increase your Persuade Rank to 2 (d8).',
#  'Nothing slips by you while engaged in social Contests, scoring +2 Bonus Hits when using Insight or Persuade.',
#  'Persuade your target, adding +2 Hits to the result set.',
#  'Intimidate your opponent while engaged in a Contest, adding +2 Hits to the result set.',
#  'Increase your Deceive Rank to 2 (d8).',
#  'When you Recover to regain Nerve, regain and additional +2 Bonus Hits.',
#  'Increase your Persuade Rank to 3 (d10).',
#  'When you take 4+ Hits and Nerve is your Primary Defense, spend 4 Momentum to immediately regain 3 Nerve.',
#  'Once per Waypoint, you may attempt to avert a Combat encounter with sentient creatures by entering into negotiations.<br>On the turn of the first round of a Combat before the first attack is made, Persuade your enemies.<ul><li><strong>If Hits + Savvy > Challenge:</strong> Set the Momentum to 0 & your enemies pause to hear your offer.</li><li><strong>If Hits + Savvy <= Challenge:</strong> Your team loses the Intiative & a number of enemies equal to Hits are Provoked by you.</li></ul><br>',
#  '',
#  '',
#  '',
#  'Endure or use your Insight to connect with nature, gaining Hits in Attunement.<br>Attunment measures the strength of connection to nature, which determines the strength of the Marvels you can manifest.<br>If the result set of one of your Marvels contains a 1, reduce your Atttunement by X, where X is equal to Hits in the same result set.<br>If your Attunement equals 0 or less, you gain Fatigued 4 and the Momentum decreases by -2.<br>You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 7 - Steady Actions (minimum 1 Action).<br>',
#  'You possess an innate bond with nature and the natural world.<br>When you gain this Talent, you gain the following two Effect Skills as your <em>Affinity</em> allowing you to further empower your Marvels and Effect Triggers:<br><em>Phylla, Tellus</em><br>',
#  'Select 2 additional Effect Skills from the list below to add to your Afinity:<br><em>Plaga, Rime, Squall, Torrent</em>',
#  'Select 2 additional Effect Skills from the list below to add to your Afinity:<br><em>Inferno, Rime, Tempest, Torrent, Vivus</em>',
#  'Increase one of your Affinity Ranks to 2 (d8).',
#  'Use Linguistics to ask one natural animal in yoru Current Zone X questions, where X is equal to Hits in the result set.',
#  'Increase one of your Affinity Ranks to 2 (d8).',
#  'Increase your Endure Rank to 2 (d8).',
#  'Increase your Insight Rank to 2 (d8).',
#  'Increase one of your Affinity Ranks to 3 (d10).',
#  'Increase your Insight Rank to 3 (d10).',
#  'Increase your Endure Rank to 3 (d10).',
#  "Spend X Attunement and spend an Action to use two Marvels.  You can add +X bonus Hits to either Marvel's result set.<br>Your Attunement decreases to 0.<br>",
#  'You can draw or change weapons without using a Shift.',
#  'Increase your Stealth Rank to 3 (d10).',
#  'You can Initiate a Contest with one hostile target in your Current Zone without using a Shift.',
#  'Counterattack an enemy Strike that just scored 0 Hits.  Deal 1d4 bonus Hits.',
#  'When you Strike a target while engaged in a Contest, add +2 Bonus Hits to the results set.',
#  'When you Strike a target in the first round of a Contest, add +2 Bonus Hits to the results set.',
#  'Increase your Strike Rank to 4 (d12).',
#  'When you Strike your opponent to win a Contest, gain +1 Renown.',
#  'Spend 2 Momentum and gain +2 Current.',
#  'Spend X Current and choose one (1):<ul><li>Reduce one of your Statuses by -X.</li><li>Recover +X to your Primary Defense.</li></ul>',
#  'Increase one of your Affinity Ranks to 2 (d8).',
#  'Increase your Composure Rank to 3 (d10).',
#  'Increase your Endure Rank to 3 (d10).',
#  'Increase your Focus Rank to 3 (d10).',
#  'Increase one of your Affinity Ranks to 3 (d10).',
#  'Increase one of your Affinity Ranks to 3 (d10).',
#  'Increase one of your Affinity Ranks to 4 (d12).',
#  'Increase your Uncanny Trait rating by +1.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  "When you gain this Talent, increase you Vivus Rank to 2 (d8).<br>You can use <a href='/no1_system/characters/powers/techniques/'>Techniques</a> that call on the Vivus Skill.<br>",
#  "If one your Techniques's result set contains a 1, you suffer a number of Hits equal to the Technique's Threshold to your Grit.",
#  '',
#  '',
#  'Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.',
#  'Increase you Survival Rank to 3 (d10).',
#  'When you use Stealth in a wilderness environment, add +1d4 Bonus Hits to the result set.',
#  'Use Stealth to conceal yourself while in a natural environment.  Until you use a Shift or Action, you gain Hidden X, where X is equal to 8+Hits in the result set.',
#  'Increase your Perceive Rank to 2 (d8).',
#  'Increase your Shoot Rank to 2 (d8).',
#  'Focus to enter a heightened state of awareness, adding +1d4 Bonus Hits to your next Shoot attempt or Initiative Test.',
#  'When you use Survival to track and locate a target, add +2 Bonus Hits to the result set.',
#  'When you use Stealth to move through hostile or unfamiliar territory, add +1d4 Bonus Hits to the result set.',
#  'Deceive the world to gain Disguised X, where X is euqal to Hits in the result set.  You cannot use this ability if you are being observed by an enemy.',
#  'Increase your Stealth Rank to 3 (d10).',
#  'Increase your Stealth Rank to 4 (d12).',
#  'Increase your Deceive Rank to 2 (d8).',
#  'Increase your Implements Rank to 2 (d8).',
#  'Increase your Implements Rank to 3 (d10).',
#  'Use your Implements to disable a lock blocking your way, adding +1d4 Bonus Hits to the result set.',
#  'When you suffer Hits from an attack that includes targets other than your self and your Reflexes are above 0, reduce Hits by -2.',
#  'Spend Momentum to gain Hidden X, where X is the amount of Momentum spent.',
#  'When you Defy Danger to Hide! while in a Zone with a crowd, add +1d4 Bonus Hits to the result set.',
#  'You maintain a network of informants and are skilled at finding enterprising local to gather valuable intelligence.  You may spend Wealth while in a city and ask the BAMF X questions, where X is the amount of Wealth spent.  Then, Deceive your informants to cover your tracks.<br>The BAMF will provide your answers at a time that makes sense in the game fiction.',
#  'Deceive your opponents while Hidden, adding +2 Bonus Hits to the result set.',
#  'Perceive to detect hidden observers or surveillance devices, adding +1d4 Bonus Hits to the result set.',
#  'When you attempt to escape being Restrained, add +1d4 Bonus Hits to the result set.',
#  'You maintain false identities to use for subtly gathering information.  You have a number of these identities equal to your Infiltrator Rank.',
#  'Use your Craft, Implements, or Linguistics to forge documents or objects, adding +2 Bonus Hits to the result set.',
#  'When you Deceive or use Legerdemain to create a diversion, Create 2 Advantages in your Current Zone.',
#  'When you are the target of an Ambush and make an Initiative Test, add +1d4 Bonus Hits to the result set.',
#  '',
#  'Your elevated status requires that you show bravery, strength, and conviction in all your affairs.<br>Chivalric Obligations require three (3) Virtues, one of which is Courage &mdash; braving danger and facing fear or defeat without hesitation.<br>Select two other Virtues from the list below:<br><em>Temperance, Indulgence, Avarice, Charity, Humility, Compassion, Wrath, Deceipt, Justice, Loyalty, Honesty . . .</em><br>You gain Dedication which measures your commitment to yoru Chivalric Obligation.  When you gain this Talent, your Dedication equals 3.<br>Whenever you act against your Virtues, reduce your Dedication by -1. If your Dedication is 0 or less, increase the Entropy by +5.<br>',
#  'Increase your Strike Rank to 2 (d8).',
#  'When you Persuade a target in a formal setting, add +2 Hits to the result set.',
#  'Gain +1 Renown and +1 Wealth',
#  'You gain an additional +2 rating from any Armor you equip.',
#  'Spend X Dedication to add X Hits to your next roll.',
#  'When you act in concordance with one or more of your Virtues, increase your Dedication by +2.',
#  'Increase your Strike Rank to 3 (d10).',
#  'Increase your Tactics Rank to 2 (d8) and your Composure Rank to 2 (d8).',
#  'Increase your History Rank to 2 (d8).',
#  'When you score Hits and kill a targer, one ally you can see in your Currnet Zone may immediately use the Recover action.',
#  'When you gain this talent, Gain +2 Renown.<br>Once per Waypoint, you may invoke your Knightly status to gain audience with an important figure who recognizes valor.<br>',
#  'Spend 4 Momentum to increase your Dedication by +3.',
#  'When your Dedication goes below 1, you may spend 5 Grit to increase your Dedication by +1.',
#  'When you are Dying, you may increase your Dying rating to 4, accepting an honorable daeth.<br>If you do, all allies in the current Encounter can immediately use Recover without using an Action and the current Timer increases by +2.<br>',
#  'Spend 2 Momentum, then take an Action.  If there are no 1s in the result set, increase the Momentum by +5.',
#  '',
#  'Whe nyou Study Spells, add +2 Bonus Hits to the result set.',
#  'Increase your Research Rank to 3 (d10).',
#  'When you gain this Talent, select 1 Effect Skills from the list below to be an <em>Affinity</em> allowing you to further empower your Spells with Skill Talents:<br><em>Aether, Forma, Inferno, Lux, Mori, Nihil, Nox, Phylla, Plaga, Rime, Squall, Tellus, Tempest, Torrent, Vivus</em>',
#  'Increase your Affinity Rank to 1 (d6).',
#  'Increase your Affinity Rank to 2 (d8).',
#  'Increase your Affinity Rank to 2 (d8).',
#  'Increase your Affinity Rank to 3 (d10).',
#  'Increase your Affinity Rank to 3 (d10).',
#  'Choose one (1) Spell you have 2+ Ranks in.  The Spell gains the Subtle keyword.',
#  'Increase your Research Rank to 4 (d12).',
#  'Choose one (1) Spell you have 2+ Ranks in.  The Spell gains the Subtle keyword.',
#  'Increase your Analyze Rank to 2 (d8).',
#  'Increase your Analyze Rank to 3 (d10).',
#  '',
#  "If a Spell you use has a 1 in the result set, you suffer Hits equal to the Spell's lowest Threshold.",
#  'Research the magical secrets and recipes that empower your Spells.<br>You gain Hits in Spell Ranks to invest in your Spells.<br>You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 10 - Savvy Actions (minimum 1 Action).<br>',
#  'Analyze a magical effect you encounter to determine its type, source, and/or effects.',
#  'Increase your Research Rank to 2 (d8).',
#  'When you gain this Talent, select 1 Effect Skills from the list below to be an <em>Affinity</em> allowing you to further empower your Spells with Skill Talents:<br><em>Aether, Forma, Inferno, Lux, Mori, Nihil, Nox, Phylla, Plaga, Rime, Squall, Tellus, Tempest, Torrent, Vivus</em>',
#  'Increase your Affinity Rank to 1 (d6).',
#  'Increase your Affinity Rank to 2 (d8).',
#  'When you gain this Talent, select 1 Effect Skills from the list below to be an <em>Affinity</em> allowing you to further empower your Spells with Skill Talents:<br><em>Aether, Forma, Inferno, Lux, Mori, Nihil, Nox, Phylla, Plaga, Rime, Squall, Tellus, Tempest, Torrent, Vivus</em>',
#  'Choose one (1) Spell you have 2+ Ranks in.  The Spell gains the Subtle keyword.',
#  '',
#  'Use a Shift to aim carefully.  Add +1d4 Bonus Hits to your next Shoot result set this turn.',
#  'Use a Shift to Wait For It with the condition that an ally scores 1+ Hits against your target in melee combat.  When the the condition is met, Shoot your target dealing Hits directly to their Grit.',
#  'Shoot your target, reducing Hits in the result set by -2 but giving your target Restrained 2.',
#  "You know how punch through your targets' defenses, scoring +1 Bonus Hits to their Grit when you score 1+ Hits with Shoot.",
#  'When you are the target on Ambush, you immediately dela +1d4 Bonus Hits to one target.',
#  'Use your Tactics to fire a ranged weapon in your Current or an Adjacent Zone, protecting your allies by forcing your enemies to seek cover.<br>Allies can ignore a number of Hazards in the targetted Zone equal to Hits in the result set.<br>',
#  'Shoot your target, redicing Hits in the result set by -2 but giving your target Fatigued 1 and Wounded 1.',
#  'Shoot two targets in your Current or an Adjacent Zon, dividing Hits between the two.',
#  'You can use the <em>Use Your Equipment</em> Shift to reload, draw, or restring / unjam a ranged weapon once per turn without using your Shift.',
#  'Increase your Shoot Rank to 2 (d8).',
#  'Increase your Shoot Rank to 2 (d8).',
#  'Shoot your target at Hazard 1.  Add +1d4 Bonus Hits to the result set.',
#  'Increase your Shoot Rank to 3 (d10).',
#  'When you Shoot your target but earn 0 Hits, add +2 Hits to the result set.',
#  'When you Shoot a target with no 1s in the result set, you may immediately make a second Shoot attempt.',
#  'Until the beginning of your next turn, use Reflexes +1d4 as as your Primary Defense.',
#  'You assume a Defensive Stance, reducing all Hits from using your Martial Arts by -1.<br>You can maintain this stance until you use a different Shift as long as your Reflexes are above 0.<br>',
#  'You assume an Aggressive Stance, adding +1 Bonus Hits when using your Martial Arts.<br>You can maintain this stance until you use a different Shift and as long as your Reflexes are above 0.<br>',
#  'Increase your Martial Arts Rank to 2 (d8).',
#  'Increase your Martial Arts Rank to 3 (d10).',
#  'When you are in an Aggressive Stance and score 4+ Hits in melee combat, your target gains Fatigued 2.',
#  'When you are in an Aggressive Stance and score 4+ Hits in melee combat, your taget gains Dazed 1.',
#  'When you are in a Defensive Stance and take 4+ Hits in melee combat from an attacker you can see, reduce the total hits by 1.',
#  'When you are in a Defensive Stance and take Hits in melee combat from an attacker you can see, reduce your Reflexes by 1 and reduce the Hits by 3.',
#  'You can split Hits scored by your Martial Arts between 2 melee targets in your Current Zone.',
#  'When you use your Martial Arts against your target but earn 0 Hits, add +2 Hits to the result set.',
#  'Use your Martial Arts against your target and reduce the Hits by -2.  If 1+ Hits remain, your target becomes Prone.',
#  'When you Parry a melee attack, immediately use your Martial Arts against the attacker at scoring Hits -2.',
#  'Score 2+ Hits with your Medicine to have one target in your Current Zone regain +X Grit, where X is equal to Hits in the result set.',
#  'Increase your Medicine Rank to 2 (d8).',
#  'Use your Medicine to reduce the Wounded rating of one target in your Current Zone by X, where X is equal to Hits in the result set.',
#  'Use your Medicine to reduce the Unconscious rating of one target in your Current Zone by X, where X is equal to Hits in the result set.',
#  'Use your Medicine to reduce the Dazed or Stunned rating of one target in your Current Zone by X, where X is equal to Hits in the result set.',
#  'Use your Medicine to have one target in your Current Zone recover X to their Primary Defense, where X is euqal to Hits in the result set.',
#  'Use your Medicine to reduce the Dying Rating of one target in your current zone by X, where X is equal to Hits -1 in the result set.',
#  'Increase your Medicine Rank to 3 (d10).',
#  'Increase your Medicine Rank to 4 (d12).',
#  'You can use Abilities that use Medicine as Shifts instead of an Actions.',
#  'Your are on a Quest of great importance.  Write a new Target with the <em>Quest</em> keyword to represent this undertaking.  Work with the BAMF to structure this Target.  You may only have one Quest of this type active at a time.<br>Your Quest grants you Conviction, allowing you to access powers to be used in pursuit of your Quest.  When you gain this Talent, your Conviction equals 5.<br>As you set out on a Quest, select one Effect Skill from the list below to be your Boon, and gain +1 Skill Rank in the chosen Skill:<br><em>Bellor, Destroy, Inferno, Lux, Mori, Nox, Ordi, Vivus</em><br>Each time you gain 1+ Milestones from a part of your Quest, your Conviction increases by +5.<br>If you fail to complete your Quest, lose 1 Renown and increase the Entropy by +5.<br>If you have no Quest, your Conviction is 0.  You may write a new Target with the Quest keyword at the beginning of the each Waypoint.<br>',
#  'Spend 2 Conviction.  The next time you Strike, Shoot, or use Martial Arts against a target this turn, automatically us one Effect Trigger from you Boon.',
#  'Increase your Strike Rank to 2 (d8).',
#  'Increase your Boon Rank to 2 (d8).',
#  'Increase the Entropy by +2 to regain +3 Conviction',
#  'Spend 2 Conviction, then use your Boon to harm your foe scoring Hits against one target in your Current Zone.',
#  'When you are Dying, you may spend 2 Conviction and increase the Entropy by +4.  You recover from the Dying status, regain 3 Grit, and Recover without using an Action.',
#  'Increase your Strike Rank to 3 (d10).',
#  'Increase your Boon Rank to 3 (d10).',
#  'If you succesfully complete every part of a Quest, you may immediately spend 5 Momentum to roll 1d20:<ul><li>If you roll 12+, increase the Momentum by +3.  You and all allies gain +1 Milestone, and you gain +2 Renown.</li><li>If you roll 11 or less, increase the Entropy by +5 and gain +2 Enemies.</li></ul>',
#  '',
#  'When you take an Action that contains no 1s in the result set <em>without any re-rolls</em>, reduce your Nerve by Hits and roll 1d20.',
#  'You are Resistant to posion damage.',
#  '.',
#  'You can Throw weapons into Adjacent Zones.',
#  'When you attack a target that has not yet acted in this encounter, add +1d4 Bonus hits to the result set.',
#  'You can spend Momentum to add Hits to the results set of any Action taken to Deceive or Persuade.',
#  '',
#  "Persuade at Challenge 3 to gain Hits + Savvy Henchmen Ranks to recruit Henchmen from the Henchman Minions table.<br>Henchmen are a type of Minion you can command to do your bidding.<br>Each type of Henchman has it own Cost which specifies the number of Henchmen Ranks you mus invest to recruit them.<br>The different Henchmen have their own statistics that specify their Grit, Actions, and any Talents they have.<br>If one of your Henchman's Grit reaches 0, they die.  You may compose a letter of condolences to their next of kin if you see fit to stoop.<br>Your Henchmen wait for your instruction.  On each of your turns, your Henchmen use either a Shift or an Action unless you use a Talent to lead them.<br>You may use this Ability without spending an Action at the beginning of each Waypoint if you are in a city.  If you use it during a Waypoint while you are in a city, it requires 7 + Savvy Actions (minimum 1 Action).<br><em><strong>Advanced Henchmen:</strong> Each Henchman also has a Rating that determines how experienced they are.  All Henchmen have a rating of 1 when recruited.  You can increase a Henchman's rating by using the Promote Henchman talent.</em><br>",
# ...
#  'Use your Insight to detect lies and hidden motives, adding +1d4 Bonus Hits to the result set.',
#  'When you are being searched by someone attempting to disarm you of your weapons and implements, you may use Legerdemain to hide up to Gear X on your person, where X is equal to Hits in the result set.',
#  'When you use Stealth to avoid detection but get less than 3 Hits in the result set, you may spend 4 momentum to gain Hidden 5.',
#  'You reduce the Hazard rating of Zones you Move through with your Shifts by -2.',
#  'When you Perceive traces of your target(s) or clues about the best path to take but score 0 Hits, add +2 Hits to the result set.',
#  'When you use Stealth to move through hostile or unfamiliar territory, add +1d4 Bonus Hits to the result set.',
#  'Use Stealth to conceal yourself while in a natural environment.  Until you take use a Shift or Action, you gain Hidden X, where X is equal to 8+Hits in the result set.',
#  'Use your Stealth while scouting ahead of your allies.  On 4+ Hits, you gain 2 additional Shifts this turn.',
#  'Use your skills of Survival to track an enemy, adding +1d4 Bonus Hits and ignoring 1s in the result set.',
#  "When you make an Initiative Test in an Ambush, add +2d4 Bonus Hits to the result set.<br>If your team's total Initiative is 8+ greater than your enemy's, the Initiative does not shift to the enemy during the first round of the encounter (1s still increase Entropy).",
#  'When Perceive your enemy to Create an Advantage, add +1d4 Bonus Hits to the result set.',
#  'When you suffer Hits from an attack that includes targets other than your self and your Reflexes are above 0, reduce Hits by -2.',
#  'You can use a Shift to Perceive or Investigate when gathering information or searching for clues.',
#  'When you are the target of an Ambush, add Hits from your Initiative Test to your Reflexes until the beginning of your next turn.',
#  'When you use Stealth to avoid detection but get less than 3 Hits in the result set, you may spend 4 momentum to gain Hidden 5.',
#  'When you are the target of an Ambush and make an Initiative Test, add +1d4 Bonus Hits to the result set.',
#  'Use your Survival skill to Create an Advantage while scouting ahead of your allies, adding +1d4 Bonus Hits to the result set.',
#  'Increase your Operate Rank to 2 (d8).',
#  'You can mount or dismount a vehicle or creature without using a Shift.',
#  'When you Operate a mount (or vehicle) and Shift to Move, you may Strike or Shoot at an enemy as part of the Shift.',
#  'You are adept at maneuvering your mounts and vehicles in combat.  You and your mounts and vehicles share all Defenses.',
#  'When you Operate a mount or vehicle and Shift to Move, you may move an additional Zone.',
#  'Increase your Operate Rank to 3 (d10).',
#  'When you Operate a mount (or vehicle) and Shift to Move, you may Navigate your way as part of the Shift.',
#  'Operate a mount, adding +1d4 Bonus Hits to the result set.',
#  'Operate a watercraft, adding +1d4 Bonus Hits to the result set.',
#  'Operate a land vehicle, adding +1d4 Bonus Hits to the result set.',
#  'Mounts and vehicles you Operate reduce any Hits suffered by -1.',
#  'Persuade, Endure, or maintain your Composure to contact your Patron and gain Hits in Succor which determines the highest rank of Gifts you can use.<br>If a Gift you use has a 1 in the result set, reduce your Succor by -1.<br>If your Succor equals 0 or less, increase the Entropy by +4 and gain +1 Debts.<br>You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 10 - Uncanny Actions (minimum 1 Action).<br>',
#  'Choose one of the Effect Skills below to be an Affinity.<br><em>Aether, Bellor, Destroy, Inferno, Intuit, Mori, Nihil, Ordi, Rime, Vivus</em>',
#  'Spend 4 Momentum to convince your Patron to restore your Gifts.  Regain +2 Succor and increase the Entropy by +2.',
#  'Increase one of your Affinity Ranks to 1 (d6).',
#  'Increase one of your Affinity Ranks to 2 (d8).',
#  'Increase one of your Affinity Ranks to 3 (d10).',
#  'Increase your Persuade Rank to 2 (d8).',
#  'Increase your Composure Rank to 2 (d8).',
#  'Increase your Endure Rank to 2 (d8).',
#  'Increase your Composure Rank to 3 (d10).',
#  'Choose one of the Effect Skills below to be an Affinity.<br><em></em>',
#  'Your Patron grants you irresistable talents.  Add +2 Bonus hits to the result sets of Actions using the Receive Gifts Ability.<br>Increase your Isnight or Persuade Rank to 1 (d6), 2 (d8), or 3 (d10).<br>',
#  'Increase you Uncanny Trait rating by +1.',
#  'Increase you Uncanny Trait rating by +1.',
#  'Increase your Persuade Rank to 2 (d8).',
#  'Increase your Composure Rank to 2 (d8).',
#  'Increase your Endure Rank to 2 (d8).',
#  'Increase your Persuade Rank to 3 (d10).',
#  'Increase your Composure Rank to 3 (d10).',
#  'Increase your Focus Rank to 2 (d8).',
#  'Increase your Focus Rank to 3 (d10).',
#  'Increase one of your Affinity Ranks to 3 (d10).',
#  'Increase one of your Affinity Ranks to 4 (d12).',
#  '',
#  '',
#  'You can Craft to recite an Epic.<br>If you lose focus on an Ongoing Epic before completing its final verse, choose one:<ul><li>Lose 1 Renown</li><li>Decrease the Momentum by -2</li></ul><br>',
#  'You are unshakable in your performances, allowing you to use Focus or Composure to Maintain Focus on your Ongoing Epics.',
#  'Increase your Strike Rank to 1 (d6).',
#  'Increase your Craft Rank to 1 (d6).',
#  'Increase your Composure Rank to 2 (d8).',
#  'Increase your Strike Rank to 2 (d8).',
#  'Increase your Craft Rank to 2 (d8).',
#  'Gain +2 Renown.',
#  'You can Craft to recite an Epic.<br>If you lose focus on an Ongoing Epic before completing its final verse, choose one:<ul><li>Lose 1 Renown</li><li>Decrease the Momentum by -2</li></ul><br>',
#  'You are unshakable in your performances, allowing you to use Focus or Composure to Maintain Focus on your Ongoing Epics.',
#  'Increase you Savvy Trait rating by +1.',
#  'You have honed your craft in reciting Sagas.  You add +1 Bonus Hits to the result set when you Craft and Epic with the Saga keyword.',
#  'Increase your Craft Rank to 2 (d8).',
#  'Increase your Composure Rank to 2 (d8).',
#  'Increase your Composure Rank to 3 (d10).',
#  'Increase your History Rank to 2 (d8).',
#  'Increase your History Rank to 3 (d10) and your Insight or Linguistics Rank to 2 (d8).',
#  'Increase your History Rank to 4 (d12) and your Insight or Linguistics Rank to 3 (d10).',
#  'Increase your Craft Rank to 3 (d10).',
#  'Increase your Craft Rank to 4 (d12).',
#  'Gain +2 Renown.',
#  '',
#  '',
#  'You gain the ability to cast Hexes on your enemies.<br>When you gain this Talent, select 2 Effect Skill from the list below to be an <em>Affinity</em> allowing you to further empower your Spells with Skill Talents:<br><em>Aether, Forma, Inferno, Mori, Nox, Plaga, Phylla, Rime, Sangui, Tempest</em><br>When you lose focus on your Ongoing Hexes, increase the Entropy by +5.<br>',
#  'Craft at Challenge 3 to gain Hits + Savvy in Concoction Ranks to prepare Concocions.<br>You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 8 - Craft Actions (minimum 1 Action).<br>',
#  'When you Focus to Maintain Focus on your Ongoing effects, add +1d4 Bonus Hits to the result set.',
#  'Persuade the spirits of the world at Challenge 3 to send you a Beast Minion.  On 1+ Hits, you may recruit a Beast of cost 1 or less from the Beast Minions table.<br>You may use this Ability without spending an Action at the beginning of each Waypoint.  If you use it during a Waypoint, it requires 5 - Steady Actions (minimum 1 Action).<br>',
#  'Increase one of your Affinity Ranks to 3 (d10).',
#  'When you can see your Beast Minion and it dies, spend 3 Grit to return it to life.',
#  'Increase one of your Affinity Ranks to 3 (d10).',
#  'Increase your Craft Rank to 2 (d8).',
#  'When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.',
#  'When you Persuade the spirits of the world to send you a Beast Minon, you may recruit a of cost 2 or less.',
#  'When you Focus to Maintain Focus on your Ongoing effects, spend X Grit to add X Bonus Hits to the result set.',
#  'Grapple your target, adding +1d4 bonus Hits and making them Prone, but ending their Grappled Status.',
#  'When an opponet you can see tries to Grapple you, reduce Hits in their result set by -2.',
#  'Grapple one target in your Current Zone.  On 3+ Hits, your target becomes Prone and Dazed 2.',
#  'When you have an opponent Grappled, you may reduce their Grappled rating by -1 to give them Vulnerable 2 and Prone.',
#  'Increase your Grapple Rank to 2 (d8).',
#  'When you Shift to Move into an Adjacent Zone and Grapple your target, add +2 Hits to the result set.',
#  'Increase your Grapple Rank to 3 (d10).',
#  'Increase your Grapple Rank to 4 (d12).',
#  'Increase your Endure Rank to 2 (d8).',
#  'Increase your Endure Rank to 3 (d10).',
#  'Increase your Exert Rank to 2 (d8).',
#  'You can Initiate a Contest with one hostile target in your Current Zone without using a Shift.',
#  'You are used to getting back up after a hard blow.  If you gain the Unconscious Status, reduce the rating by -1.',
#  'When you have an target Grappled and use an Action to Recover, add +1d4 Bonus Hits to the result set.',
#  '',
#  '',
#  'Increase you Dangerous Trait rating by +1.',
#  'Increase you Dangerous Trait rating by +1.',
#  'Increase you Dangerous Trait rating by +1.',
#  'Increase you Dangerous Trait rating by +1.',
#  'Increase you Dangerous Trait rating by +1.',
#  'Increase you Dangerous Trait rating by +1.',
#  'Increase you Dangerous Trait rating by +1.',
#  'Increase you Dangerous Trait rating by +1.',
#  'Increase you Dangerous Trait rating by +1.',
#  'You can draw or change weapons without using a Shift.',
#  'Increase your Strike Rank to 3 (d10).',
#  'You are an expert Swordsman, granting you access to <em>Sworldplay</em> talents when using a gear with the <em>Sword</em> Keyword.',
#  'You are an expert with Axes, granting you access to <em>Hewer</em> talents when using a gear with the <em>Axe</em> Keyword..',
#  'You are an expert Maces, granting you access to <em>Crusher</em> talents when using a gear with the <em>Mace</em> Keyword.',
#  'You are an expert with Polearms, granting you access to <em>Poledance</em> talents when using Gear with the <em>Polearm</em> Keyword.',
#  'You are an expert at using two weapons at once, granting you access to <em>Niten</em> talents when using two Weapon Gear at the same time.',
#  'Increase your Strike Rank to 4 (d12).',
#  "<h4 style='margin: 3px'>Sworldplay</h4><br>Spend X Defenses and Strike one target in your Current Zone, add X Bonus Hits to the result set.<br>",
#  "<h4 style='margin: 3px'>Sworldplay</h4><br>Strike one target in your Current Zone.  You may spend 3 Hits from the result set to have the target gain Wounded 1.<br>",
#  "<h4 style='margin: 3px'>Sworldplay</h4><br>Deceive one target in your Current Zone.  One 2+ Hits, you may immediately Strike the target adding +1d4 Bonus Hits to the result set.<br>",
#  "<h4 style='margin: 3px'>Hewer</h4><br>Strike one target in your Current Zone.  You may spend 3 Hits in the result set to have the target gain Wounded 2.<br>",
#  "<h4 style='margin: 3px'>Hewer</h4><br>Strike one target in your Current Zone.  You may spend 2 Hits in the result set to have to reduce one of the target's Gear Ratings by X, where X is the total Hits in the result set.<br>",
#  "<h4 style='margin: 3px'>Hewer</h4><br>Strike one target in your Current Zone that is is Wounded, it gains Vulnerable 1 and Stunned 1.<br>",
#  "<h4 style='margin: 3px'>Crusher</h4><br>Strike one target in your Current Zone.  You may spend 2 Hits in the result set to make the target gain Vulnerable 1.<br>",
#  "<h4 style='margin: 3px'>Crusher</h4><br>When you Strike one target in your Current Zone that is Vulnerable, the target gains Fatigued 1.<br>",
#  "<h4 style='margin: 3px'>Crusher</h4><br>When you Strike one target in your Current Zone that is Vulnerable, the target gains Stunned 2.<br>",
#  "<h4 style='margin: 3px'>Crusher</h4><br>Strike one target in your Current Zone.  You may spend 2 Hits in the result set to move your target to an Adjacent Zone.<br>",
#  "<h4 style='margin: 3px'>Poledance</h4><br>Strike one target in your Current Zone.  You may spend 2 Hits in the result set to make the target become Prone.<br>",
#  "<h4 style='margin: 3px'>Poledance</h4><br>Strike one target in your Current Zone.  You may spend 2 Hits in the result set to make the target gain Restrained 2.<br>",
#  "<h4 style='margin: 3px'>Poledance</h4><br>Strike one target in your Current Zone and gain Aura 1.  While this Aura persists, all targets in your Current Zone add 1 Hazard to any Action targetting you.<br>",
#  "<h4 style='margin: 3px'>Niten</h4><br>Strike one target in your Current Zone.  You may spend 2 Hits from the result set to immediately Wait for it. . . , preparing an Action to Strike one target in your Current Zone if they use a Shift to Move or an Action to attack.<br>",
#  "<h4 style='margin: 3px'>Niten</h4><br>Strike one target in your Current Zone and use your second weapon to defend yourself to gain Armor Defense X, where X is equal to Hits in the result set.<br>",
#  "<h4 style='margin: 3px'>Niten</h4><br>When you Strike a target and score 3+ Hits, you may immediately use another Action to strike with your second weapon.<br>",
#  'Increase you Dangerous Trait rating by +1.',
#  'Increase you Dangerous Trait rating by +1.',
#  'Increase you Deft Trait rating by +1.',
#  'Increase you Deft Trait rating by +1.',
#  'Increase you Deft Trait rating by +1.',
#  'Increase you Deft Trait rating by +1.',
#  'Increase you Deft Trait rating by +1.',
#  'Increase you Deft Trait rating by +1.',
#  'Increase you Deft Trait rating by +1.',
#  'Increase you Deft Trait rating by +1.',
#  'Increase you Deft Trait rating by +1.',
#  'Increase you Savvy Trait rating by +1.',
#  'Increase you Savvy Trait rating by +1.',
#  'Increase you Savvy Trait rating by +1.',
#  'Increase you Savvy Trait rating by +1.',
#  'Increase you Savvy Trait rating by +1.',
#  'Increase you  Trait rating by +1.',
#  'Increase you Savvy Trait rating by +1.',
#  'You can Craft to recite an Epic.<br>If you lose focus on an Ongoing Epic before completing its final verse, choose one:<ul><li>Lose 1 Renown</li><li>Decrease the Momentum by -2</li></ul><br>',
#  'You are unshakable in your performances, allowing you to use Focus or Composure to Maintain Focus on your Ongoing Epics.',
#  'Increase you Savvy Trait rating by +1.',
#  'You have honed your craft in reciting Ballads.  You add +1 Bonus Hits to the result set when you Craft and Epic with the Ballad keyword.',
#  'Increase your Craft Rank to 2 (d8).',
#  'Increase your Composure Rank to 2 (d8).',
#  'Increase your Composure Rank to 3 (d10).',
#  'Increase your Persuade Rank to 2 (d8).',
#  'Increase your Streetwise Rank to 2 (d8) and your Persuasion Rank to 2 (d8).',
#  'Increase your Streetwise Rank to 3 (d10) and your Persuasion Rank to 3 (d10).',
#  'Increase your Craft Rank to 3 (d10).',
#  'Increase your Craft Rank to 4 (d12).',
#  'Gain +3 Wealth.',
#  'Increase you Savvy Trait rating by +1.',
#  'Increase you Savvy Trait rating by +1.',
#  'Increase you Savvy Trait rating by +1.',
#  'Increase you Savvy Trait rating by +1.',
#  'Increase you Steady Trait rating by +1.',
#  'Increase you Steady Trait rating by +1.',
#  'Increase you Steady Trait rating by +1.',
#  'Increase you Steady Trait rating by +1.',
#  'Increase you Steady Trait rating by +1.',
#  'Increase you Steady Trait rating by +1.',
#  'Increase you Steady Trait rating by +1.',
#  'Increase you Steady Trait rating by +1.',
#  'Increase you Uncanny Trait rating by +1.',
#  'Increase you Uncanny Trait rating by +1.',
#  'Increase you Uncanny Trait rating by +1.',
#  'Increase you Uncanny Trait rating by +1.',
#  'Increase you Uncanny Trait rating by +1.',
#  'Increase you Uncanny Trait rating by +1.',
#  'Increase you Uncanny Trait rating by +1.',
#  'Increase you Uncanny Trait rating by +1.']

# %%
df_talents
# Out:
#            tree                    name     type rank         requires  \
# 0       Acolyte   Commune with Divinity  Ability    1  Divine Doctrine
# 1       Acolyte         Divine Doctrine   Static    1             None
# 2       Acolyte           Composure (2)   Static    2             None
# 3       Acolyte              Domain (2)   Static    2             None
# 4       Acolyte              Domain (2)   Static    3             None
# ..          ...                     ...      ...  ...              ...
# 871    Aberrant  Uncanny Trait Increase   Static    3             None
# 872  Petitioner  Uncanny Trait Increase   Static    3             None
# 873      Thrall  Uncanny Trait Increase   Static    2             None
# 874      Mystic  Uncanny Trait Increase   Static    3             None
# 875       Adept  Uncanny Trait Increase   Static    2             None
#
#     replaces                                             effect  \
# 0       None  Maintain your Composure at Challenge 3 to alig...
# 1       None  You follow set of principles in your belief sy...
# 2       None            Increase your Composure Rank to 2 (d8).
# 3       None       Increase one of your Domain Ranks to 2 (d8).
# 4       None       Increase one of your Domain Ranks to 2 (d8).
# ..       ...                                                ...
# 871     None           Increase you Uncanny Trait rating by +1.
# 872     None           Increase you Uncanny Trait rating by +1.
# 873     None           Increase you Uncanny Trait rating by +1.
# 874     None           Increase you Uncanny Trait rating by +1.
# 875     None           Increase you Uncanny Trait rating by +1.
#
#                                             effect_raw
# 0    [Maintain your Composure at Challenge 3 to ali...
# 1    [You follow set of principles in your belief s...
# 2            [Increase your Composure Rank to 2 (d8).]
# 3       [Increase one of your Domain Ranks to 2 (d8).]
# 4       [Increase one of your Domain Ranks to 2 (d8).]
# ..                                                 ...
# 871         [Increase you Uncanny Trait rating by +1.]
# 872         [Increase you Uncanny Trait rating by +1.]
# 873         [Increase you Uncanny Trait rating by +1.]
# 874         [Increase you Uncanny Trait rating by +1.]
# 875         [Increase you Uncanny Trait rating by +1.]
#
# [876 rows x 8 columns]

# %%
# t= pd.DataFrame(df_talents_raw.iloc[0, 0])
# t.groupby(['tree','name','type','rank','requires'])['effect'].apply('<br>'.join).reset_index()

# %%
# df_talents = pd.DataFrame()
# for i, t in df_talents_raw.iterrows():
#     if len(t['effect']) > 1:
#         v = t.groupby(['tree','name','type','rank','requires'])['effect'].apply('<br>'.join).reset_index()
#     else:
#         v = t.copy()
#     df_talents = pd.concat([df_talents, v], axis=0)
# df_talents.reset_index(drop=True, inplace=True)
# df_talents['name'] = df_talents['name'].astype('str')
# df_talents.sort_values(by=['tree', 'type', 'rank', 'name'], inplace=True)
# df_talents.reset_index(inplace=True, drop=True)

# %%
df_talents[df_talents['tree']=='Seer'].groupby(['tree','type'])['name'].count()
# Out:
# tree  type
# Seer  Ability    10
#       Shift       1
#       Static      1
#       Trigger     4
# Name: name, dtype: int64

# %%
skills = ["Exert","Grapple","Intimidate","Martial Arts","Shoot","Strike","Throw","Bellor","Inferno","Sangui","Tempest","Implements","Insight","Legerdemain","Operate","Stealth","Tactics","Tumble","Mori","Nox","Plaga","Squall","Craft","Pilot","Analyze","Computers","Cosmology","Current Events","Deceive","History","Linguistics","Nature","Navigate","Persuade","Research","Skrimisiology","Streetwise","Survival","Theology","Arithm","Medicine","Mentis","Phylla","Rime","Torrent","Composure","Endure","Focus","Investigate","Lead","Perceive","Forma","Locus","Lux","Ordi","Tellus","Aether","Destroy","Intuit","Luck","Nihil","Resist","Tempor","Vivus"]

# %%
for s in skills:
    df_talents[s] = [s if s in eff else None for eff in df_talents['effect']]
    df_talents[s].dropna(inplace=True)

# %%
df_talents[skills].head()
# Out:
#   Exert Grapple Intimidate Martial Arts Shoot Strike Throw  Bellor  Inferno  \
# 0  None    None       None         None  None   None  None    None     None
# 1  None    None       None         None  None   None  None  Bellor  Inferno
# 2  None    None       None         None  None   None  None    None     None
# 3  None    None       None         None  None   None  None    None     None
# 4  None    None       None         None  None   None  None    None     None
#
#   Sangui  ...  Ordi Tellus Aether Destroy Intuit  Luck Nihil Resist Tempor  \
# 0   None  ...  None   None   None    None   None  None  None   None   None
# 1   None  ...  Ordi   None   None    None   None  None  None   None   None
# 2   None  ...  None   None   None    None   None  None  None   None   None
# 3   None  ...  None   None   None    None   None  None  None   None   None
# 4   None  ...  None   None   None    None   None  None  None   None   None
#
#    Vivus
# 0   None
# 1  Vivus
# 2   None
# 3   None
# 4   None
#
# [5 rows x 64 columns]

# %%
df_talents['list_skills'] = df_talents[skills].copy().values.tolist()

# %%
df_talents['list_skills'].head()
# Out:
# 0    [None, None, None, None, None, None, None, Non...
# 1    [None, None, None, None, None, None, None, Bel...
# 2    [None, None, None, None, None, None, None, Non...
# 3    [None, None, None, None, None, None, None, Non...
# 4    [None, None, None, None, None, None, None, Non...
# Name: list_skills, dtype: object

# %%
x=[]
for i in df_talents.index:
    sl = df_talents.iloc[i]['list_skills'].copy()
    x += [[s for s in sl if s is not None]]
    
df_talents['skills'] = x

# %%
df_talents.head()
# Out:
#       tree                   name     type rank         requires replaces  \
# 0  Acolyte  Commune with Divinity  Ability    1  Divine Doctrine     None
# 1  Acolyte        Divine Doctrine   Static    1             None     None
# 2  Acolyte          Composure (2)   Static    2             None     None
# 3  Acolyte             Domain (2)   Static    2             None     None
# 4  Acolyte             Domain (2)   Static    3             None     None
#
#                                               effect  \
# 0  Maintain your Composure at Challenge 3 to alig...
# 1  You follow set of principles in your belief sy...
# 2            Increase your Composure Rank to 2 (d8).
# 3       Increase one of your Domain Ranks to 2 (d8).
# 4       Increase one of your Domain Ranks to 2 (d8).
#
#                                           effect_raw Exert Grapple  ...  \
# 0  [Maintain your Composure at Challenge 3 to ali...  None    None  ...
# 1  [You follow set of principles in your belief s...  None    None  ...
# 2          [Increase your Composure Rank to 2 (d8).]  None    None  ...
# 3     [Increase one of your Domain Ranks to 2 (d8).]  None    None  ...
# 4     [Increase one of your Domain Ranks to 2 (d8).]  None    None  ...
#
#   Aether Destroy Intuit  Luck Nihil Resist Tempor  Vivus  \
# 0   None    None   None  None  None   None   None   None
# 1   None    None   None  None  None   None   None  Vivus
# 2   None    None   None  None  None   None   None   None
# 3   None    None   None  None  None   None   None   None
# 4   None    None   None  None  None   None   None   None
#
#                                          list_skills  \
# 0  [None, None, None, None, None, None, None, Non...
# 1  [None, None, None, None, None, None, None, Bel...
# 2  [None, None, None, None, None, None, None, Non...
# 3  [None, None, None, None, None, None, None, Non...
# 4  [None, None, None, None, None, None, None, Non...
#
#                                               skills
# 0                                        [Composure]
# 1  [Bellor, Inferno, Tempest, Mori, Nox, Rime, Lu...
# 2                                        [Composure]
# 3                                                 []
# 4                                                 []
#
# [5 rows x 74 columns]

# %%
def build_powercard(name, effect, skill, type):
    skill_clean = skill.lower()
    skill_clean = skill_clean.replace(' ', '_')
    effect_clean = effect.replace('choose', '**choose').replace(':<ul><li>', '**:^^^^**').replace('</li><li>', '^^^^').replace('</li></ul>', '**').replace('<strong>', '**').replace('</strong>', '**').replace('<em>', '//').replace('</em>', '//').replace('<br>', '^^').replace("<h4 style='margin: 3px;'><span style='background-color: #096491;border-radius: 8px'>", "**//").replace('</span></h4>', '//**^^')
    powercard = '''!power {{
    --name|@{character_name} - ''' + name + '''
    --Effect|''' + effect_clean + '''
    --Rank| d@{skill_''' + skill_clean + '''}
    --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_''' + skill_clean + '''}>@{Cosm|target}]]
    --Hits|[^talent.ss]
    --1s|[^talent.ones]
    --format|''' + type.lower() + '''check
    }}'''
    return(powercard)

# %%
t = df_talents[df_talents['name']=='Strike with Conviction']
t
# Out:
#         tree                    name   type rank      requires replaces  \
# 396  Templar  Strike with Conviction  Shift    1  Avowed Quest     None
#
#                                                 effect  \
# 396  Spend 2 Conviction.  The next time you Strike,...
#
#                                             effect_raw Exert Grapple  ...  \
# 396  [Spend 2 Conviction.  The next time you Strike...  None    None  ...
#
#     Aether Destroy Intuit  Luck Nihil Resist Tempor Vivus  \
# 396   None    None   None  None  None   None   None  None
#
#                                            list_skills  \
# 396  [None, None, None, Martial Arts, Shoot, Strike...
#
#                             skills
# 396  [Martial Arts, Shoot, Strike]
#
# [1 rows x 74 columns]

# %%
df_talents['str_pcard'] = ''

# %%
i=0
n = df_talents.iloc[i][:]
if len(n.skills) > 0:
    pcs = []
    for s in n.skills:
        x = build_powercard(n['name'], n['effect'], s, n['type'])
        pcs.append(x)
    df_talents.loc[i, 'str_pcard'] = pcs

# %%
df_talents[df_talents['effect'].str.contains('<ul>')].head()
# Out:
#              tree                  name     type rank requires replaces  \
# 53      Tactician        Inspire Allies  Ability    1  Leadd 2     None
# 90      Berserker     Berkserker's Fury  Ability    2     Rage     None
# 119         Brute  Just Getting Started  Ability    2     None     None
# 226      Diplomat    Let's Be Civilized  Ability    3     None     None
# 252  Elementalist    Elemental Recovery  Ability    1     None     None
#
#                                                 effect  \
# 53   Lead all allies in your Current Zone, allowing...
# 90   Decrease your Rage Aura by -2 and choose one (...
# 119  Exert yourself when you are below your maximum...
# 226  Once per Waypoint, you may attempt to avert a ...
# 252  Spend X Current and choose one (1):<ul><li>Red...
#
#                                             effect_raw  Exert  Grapple  ...  \
# 53   [Lead all allies in your Current Zone, allowin...   None     None  ...
# 90   [Decrease your Rage Aura by -2 and choose one ...   None  Grapple  ...
# 119  [Exert yourself when you are below your maximu...  Exert     None  ...
# 226  [Once per Waypoint, you may attempt to avert a...   None     None  ...
# 252  [Spend X Current and choose one (1):<ul><li>Re...   None     None  ...
#
#     Destroy Intuit  Luck Nihil Resist Tempor Vivus  \
# 53     None   None  None  None   None   None  None
# 90     None   None  None  None   None   None  None
# 119    None   None  None  None   None   None  None
# 226    None   None  None  None   None   None  None
# 252    None   None  None  None   None   None  None
#
#                                            list_skills  \
# 53   [None, None, None, None, None, None, None, Non...
# 90   [None, Grapple, Intimidate, Martial Arts, None...
# 119  [Exert, None, None, None, None, None, None, No...
# 226  [None, None, None, None, None, None, None, Non...
# 252  [None, None, None, None, None, None, None, Non...
#
#                                                 skills str_pcard
# 53                                              [Lead]
# 90   [Grapple, Intimidate, Martial Arts, Strike, Th...
# 119                                            [Exert]
# 226                                         [Persuade]
# 252                                                 []
#
# [5 rows x 75 columns]

# %%
pcs = []
for i in df_talents.index:
    n = df_talents.iloc[i][:]
    x = []
    if n['type'] != 'Static':
        if len(n['skills']) > 0:
            for s in n['skills']:
                x.append(build_powercard(n['name'], n['effect'], s, n['type']))
    pcs.append(x)
    
df_talents['str_pcard'] = pcs
    # print(i)

# %%
punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
df_talents['attr_tal_nm_raw'] = df_talents['name'].copy()
for m in punc:
    df_talents['attr_tal_nm_raw'] = df_talents['attr_tal_nm_raw'].str.replace("\\" + m, '')
df_talents['attr_tal_nm_raw'] = '''attr_talent_''' + df_talents['tree'].str.lower() + '_' + df_talents['attr_tal_nm_raw'].str.lower().str.replace(' ', '_').str.replace('__', '_') #.str.replace(punc, '')

# df_talents['attr_tal_nm'].str.replace(' ', '_')
# Out:
# C:\Users\DonalHarrison\AppData\Local\Temp\ipykernel_3448\3950107608.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_talents['attr_tal_nm_raw'] = df_talents['attr_tal_nm_raw'].str.replace("\\" + m, '')

# %%
df_talents.iloc[0]['attr_tal_nm_raw']
# Out:
# 'attr_talent_acolyte_commune_with_divinity'

# %%
attr_nms = []
for attr in df_talents['attr_tal_nm_raw'].unique():
    recs = df_talents[df_talents['attr_tal_nm'] == attr]['attr_tal_nm'].copy().reset_index()
    # print(len(recs))
    if len(recs) > 1:
        for nm in range(len(recs)):
            v = recs.iloc[nm]['attr_tal_nm'] + '_' + str(nm + 1)
            attr_nms.append(v)
    else:
        attr_nms.append(recs.iloc[0]['attr_tal_nm'])
df_talents['attr_tal_nm'] = attr_nms

# %%
df_talents
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_talents
#
# NameError: name 'df_talents' is not defined

# %%
df_talents['tree'].unique()
# Out:
# array(['Acolyte', 'Aberrant', 'Mystic', 'Alchemist', 'Archmage',
#        'Assassin', 'Athlete', 'Heretic', 'Tactician', 'Bastion',
#        'Berserker', 'Black Belt', 'Blade Weaver', 'Bounty Hunter',
#        'Brute', 'Channeler', 'Conduit', 'Confessor', 'Corsair',
#        'Courtier', 'Defender', 'Guardian', 'Detective', 'Diabolist',
#        'Diplomat', 'Dragoon', 'Driver', 'Druid', 'Duelist',
#        'Elementalist', 'Engineer', 'Fury', 'Grandmaster', 'Healer',
#        'Hunter', 'Infiltrator', 'Intiltrator', 'Juggernaut', 'Knight',
#        'Lich', 'Mage', 'Mageknight', 'Magic-User', 'Marksman', 'Soldier',
#        'Martial Artist', 'Medic', 'Templar', '', 'Scoundrel', 'Mesmer',
#        'Overseer', 'Necromancer', 'Beastmaster', 'Paragon', 'Pilot',
#        'Priest', 'Probabilist', 'Psion', 'Nexus', 'Pugilist',
#        'Raindancer', 'Ranger', 'Reaver', 'Samurai', 'Scholar', 'Scout',
#        'Scrapper', 'Seer', 'Shaman', 'Shifter', 'Shinobi',
#        'Shock Trooper', 'Shugenja', 'Skald', 'Sniper', 'Spellreaver',
#        'Spy', 'Summoner', 'Swashbuckler', 'Tank', 'Thief', 'Operator',
#        'Petitioner', 'Thrall', 'Transmuter', 'Traveler', 'Troubadour',
#        'Rhapsodist', 'Vanguard', 'Warlord', 'Witch', 'Wrestler', 'Zealot',
#        'Zenith', 'Weapon Master', 'Coutier', 'Balladeer', 'Adept'],
#       dtype=object)

# %%
df_talents[df_talents['name']=="Berkserker's Fury"]
# Out:
#          tree               name     type rank requires replaces  \
# 90  Berserker  Berkserker's Fury  Ability    2     Rage     None
#
#                                                effect  \
# 90  Decrease your Rage Aura by -2 and choose one (...
#
#                                            effect_raw Exert  Grapple  ...  \
# 90  [Decrease your Rage Aura by -2 and choose one ...  None  Grapple  ...
#
#    Intuit  Luck Nihil Resist Tempor Vivus  \
# 90   None  None  None   None   None  None
#
#                                           list_skills  \
# 90  [None, Grapple, Intimidate, Martial Arts, None...
#
#                                                skills  \
# 90  [Grapple, Intimidate, Martial Arts, Strike, Th...
#
#                                             str_pcard  \
# 90  [!power {{\n    --name|@{character_name} - Ber...
#
#                                attr_tal_nm
# 90  attr_talent_berserker_berkserkers_fury
#
# [1 rows x 76 columns]

# %%
for p in df_talents['str_pcard']:
    for i in p:
        print(i)
        print(i[i.find('skill_')+6:i.find('--Result Set')-6].capitalize())
# Out:
# !power {{
#     --name|@{character_name} - Commune with Divinity
#     --Effect|Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in **//Concordance//**.^^Your Concordance measures how closely you are aligned with your Divine Doctrine.^^You may use this Ability without using an Action at the beginning of each Waypoint.  If you use it during a Waypoint, it requires 8 - Steady Actions (minimum 1 Action).^^
#     --Rank| d@{skill_composure}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_composure}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Composure
# !power {{
#     --name|@{character_name} - Manage Strain
#     --Effect|Use your Insight to reduce your current Strain by Hits.
#     --Rank| d@{skill_insight}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_insight}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Insight
# !power {{
#     --name|@{character_name} - Prepare concoctions
#     --Effect|Craft at Challenge 3 to gain Hits + Savvy in Concoction Ranks to prepare Concocions.^^You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 7 - Craft Actions (minimum 1 Action).^^
#     --Rank| d@{skill_craft}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_craft}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Craft
# !power {{
#     --name|@{character_name} - Dangerous Distillation
#     --Effect|When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_craft}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_craft}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Craft
# !power {{
#     --name|@{character_name} - Brew Broker
#     --Effect|When you Persuade or Deceive a target to sell your Concoctions and score 2+ Hits, gain +1 Wealth from the transaction.
#     --Rank| d@{skill_deceive}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_deceive}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|check
#     }}
# Deceive
# !power {{
#     --name|@{character_name} - Brew Broker
#     --Effect|When you Persuade or Deceive a target to sell your Concoctions and score 2+ Hits, gain +1 Wealth from the transaction.
#     --Rank| d@{skill_persuade}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_persuade}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|check
#     }}
# Persuade
# !power {{
#     --name|@{character_name} - Premium Potables
#     --Effect|When you Persuade or Deceive a target to sell your Concoctions and score 3+ Hits, gain +1 Wealth from the transaction.
#     --Rank| d@{skill_deceive}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_deceive}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|check
#     }}
# Deceive
# !power {{
#     --name|@{character_name} - Premium Potables
#     --Effect|When you Persuade or Deceive a target to sell your Concoctions and score 3+ Hits, gain +1 Wealth from the transaction.
#     --Rank| d@{skill_persuade}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_persuade}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|check
#     }}
# Persuade
# !power {{
#     --name|@{character_name} - Accomplished Alchemist
#     --Effect|When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_craft}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_craft}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Craft
# !power {{
#     --name|@{character_name} - Coup de Grace
#     --Effect|Spend 3 Momentum and immediately Strike a target in your Current Zone that is Prone.  On 6+ Hits, the target dies.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Silent Takedown
#     --Effect|Strike an opponent whil Hidden, attempting to subdue them quietly.  If you score 4+ Hits, the tareget suffers no damage to their Defenses or Grit, but gains Unconscious X, where X is equal to Hits in the result set.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Death from the Shadows
#     --Effect|When you Strike or Shoot your target to death, you may immediately use your Stealth without using a Shift.
#     --Rank| d@{skill_shoot}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_shoot}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Shoot
# !power {{
#     --name|@{character_name} - Death from the Shadows
#     --Effect|When you Strike or Shoot your target to death, you may immediately use your Stealth without using a Shift.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Death from the Shadows
#     --Effect|When you Strike or Shoot your target to death, you may immediately use your Stealth without using a Shift.
#     --Rank| d@{skill_stealth}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_stealth}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Stealth
# !power {{
#     --name|@{character_name} - Marked for Death
#     --Effect|Use your Tactics to mark your target, giving them Aura X, where X is equal to Hits in your result set.  Your target is Vulnerable 1 to any Action you take against it while the Aura persists.
#     --Rank| d@{skill_tactics}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_tactics}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}
# Tactics
# !power {{
#     --name|@{character_name} - Never Unnarmed
#     --Effect|When you are being searched by someone attempting to disarm you of your weapons and implements, you may use Legerdemain to hide a dagger on your person is you sore 1+ Hits.
#     --Rank| d@{skill_legerdemain}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_legerdemain}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Legerdemain
# !power {{
#     --name|@{character_name} - Contract Killer
#     --Effect|Persuade one target in your Current Zone to negotiate terms of a contract, adding +2 Bonus Hits to the result set.
#     --Rank| d@{skill_persuade}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_persuade}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Persuade
# !power {{
#     --name|@{character_name} - Powerlifter
#     --Effect|Exert yourself to accomplish a feat of strength, adding +1d4 bonus hits to the result set.
#     --Rank| d@{skill_exert}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_exert}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Exert
# !power {{
#     --name|@{character_name} - Commune with Divinity
#     --Effect|Maintain your Composure at Challenge 3 to align yourself with the divine. Gain Hits in **//Concordance//**.^^Your Concordance measures how closely you are aligned with your Divine Doctrine.^^You may use this Ability without using an Action at the beginning of each Waypoint.  If you use it during a Waypoint, it requires 8 - Steady Actions (minimum 1 Action).^^
#     --Rank| d@{skill_composure}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_composure}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Composure
# !power {{
#     --name|@{character_name} - Inspire Allies
#     --Effect|Lead all allies in your Current Zone, allowing a number of them equal to the Hits in the result set to immediately do 1 of the following**:^^^^**Recover^^^^Reduce one Variable Status by -1^^^^Add +1 Bonus Hits to their next result set**
#     --Rank| d@{skill_lead}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_lead}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Lead
# !power {{
#     --name|@{character_name} - Reposition
#     --Effect|Use your Tactics allies in your current Zones, allowing X allies to immediately use a Shift, where X is equal to Hits in the result set.
#     --Rank| d@{skill_tactics}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_tactics}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Tactics
# !power {{
#     --name|@{character_name} - Battlefield Command
#     --Effect|Lead all allies in your Current Zone, granting X allies +2 Bonus Hits on their next roll, where X is the number of Hits in the result set.^^If you score 4+ Hits, reduce the Entropy by -2.^^
#     --Rank| d@{skill_lead}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_lead}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Lead
# !power {{
#     --name|@{character_name} - Coordinated Attack
#     --Effect|Lead the assault in combat designating one target in your Current Zone.  The target gains Vulnerable X, where X is equal to Hits -2 in the result set.
#     --Rank| d@{skill_lead}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_lead}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|check
#     }}
# Lead
# !power {{
#     --name|@{character_name} - Tactical Retreat
#     --Effect|Use your Tactics to guide allies in your current and all adjacent Zones in a tactical retreat, allowing a number of allies equal to Hits in the result set to immediately Shift away from hostile targets and reducing any Hazard by -1.
#     --Rank| d@{skill_tactics}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_tactics}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|2check
#     }}
# Tactics
# !power {{
#     --name|@{character_name} - Rallying Cry
#     --Effect|Lead allies in your Current Zone, adding Hits -1 to the Momentum and Creating 1 Advantage in your Current Zone.
#     --Rank| d@{skill_lead}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_lead}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|check
#     }}
# Lead
# !power {{
#     --name|@{character_name} - Flanking Maneuver
#     --Effect|Spend 3 Momentum and use your Tactics to outmanuever your enemies.  On 2+ Hits, you may designate up to 3 targets in your Current or Adjacent Zones to gain Vulnerable 1.
#     --Rank| d@{skill_tactics}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_tactics}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|check
#     }}
# Tactics
# !power {{
#     --name|@{character_name} - Tactical Strike
#     --Effect|Use your Tactics instead of Strike to attack an enemy in yoru Current Zone.  The target suffers Hits -2 to their Defense and you Create 1 Advantage in your Current Zone.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abiltiycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Tactical Strike
#     --Effect|Use your Tactics instead of Strike to attack an enemy in yoru Current Zone.  The target suffers Hits -2 to their Defense and you Create 1 Advantage in your Current Zone.
#     --Rank| d@{skill_tactics}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_tactics}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abiltiycheck
#     }}
# Tactics
# !power {{
#     --name|@{character_name} - Tactical Mastermind
#     --Effect|When you use your Tactics, adding +1 Bonus Hits to the result set.
#     --Rank| d@{skill_tactics}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_tactics}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Tactics
# !power {{
#     --name|@{character_name} - Heterodoxy
#     --Effect|Use a Shift to maintain your Composure, immediately gaining 1d4+1 Concordance.
#     --Rank| d@{skill_composure}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_composure}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}
# Composure
# !power {{
#     --name|@{character_name} - Profane Smite
#     --Effect|Spend your Concordance to add Xd4 to your Strike, where X is equal to the amount of Concordance spent.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Profane Aura
#     --Effect|Focus to gain an Aura X, where X is the number of Hits in the result set.^^While the Aura persists, all Allies in your Current Zone regain Grit equal to your Heretic rank at the beginning of your turn.^^All hostile targets in your Current Zone gain Fatigued 1.
#     --Rank| d@{skill_focus}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_focus}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Focus
# !power {{
#     --name|@{character_name} - Dark Revelation
#     --Effect|Once per Waypoint, use your Insight to uncover an unwanted truth.  If you score 3+ Hits, ask the BAMF one question about the game fiction.  Answers will vary depending on the amount of infromation you and your allies have discovered about the game fiction in question.
#     --Rank| d@{skill_insight}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_insight}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Insight
# !power {{
#     --name|@{character_name} - Defiant Healing
#     --Effect|You can spend 1 Concordance to call on the Vivus energy.  You and one ally in your Current Zone ragin Hits to your Grit or Primary Defenses.
#     --Rank| d@{skill_vivus}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_vivus}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Vivus
# !power {{
#     --name|@{character_name} - Rage
#     --Effect|Exert yourself, entering a trance-like fury to crush your enemies, see them driven before you, and to hear the lamentations of their women. You gain a Rage Aura equal to Hits +1 in the result set.^^While you are in a Rage, you may decrease your Rage Aura by -1 to add +2 Bonus Hits to any Action using Exert, Endure, Grapple, Intimidate, Martial Arts, Strike, or Throw.^^If your Rage Aura equals 0 or you use a Shift to dismiss it, you gain Fatigued 2 and Confused 1, and the Entropy increases by +1.^^If your Rage Aura is 8+, you gain Fatigued 2 and Confused, and the Entropy increases by +2.^^
#     --Rank| d@{skill_exert}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_exert}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}
# Exert
# !power {{
#     --name|@{character_name} - Rage
#     --Effect|Exert yourself, entering a trance-like fury to crush your enemies, see them driven before you, and to hear the lamentations of their women. You gain a Rage Aura equal to Hits +1 in the result set.^^While you are in a Rage, you may decrease your Rage Aura by -1 to add +2 Bonus Hits to any Action using Exert, Endure, Grapple, Intimidate, Martial Arts, Strike, or Throw.^^If your Rage Aura equals 0 or you use a Shift to dismiss it, you gain Fatigued 2 and Confused 1, and the Entropy increases by +1.^^If your Rage Aura is 8+, you gain Fatigued 2 and Confused, and the Entropy increases by +2.^^
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}
# Grapple
# !power {{
#     --name|@{character_name} - Rage
#     --Effect|Exert yourself, entering a trance-like fury to crush your enemies, see them driven before you, and to hear the lamentations of their women. You gain a Rage Aura equal to Hits +1 in the result set.^^While you are in a Rage, you may decrease your Rage Aura by -1 to add +2 Bonus Hits to any Action using Exert, Endure, Grapple, Intimidate, Martial Arts, Strike, or Throw.^^If your Rage Aura equals 0 or you use a Shift to dismiss it, you gain Fatigued 2 and Confused 1, and the Entropy increases by +1.^^If your Rage Aura is 8+, you gain Fatigued 2 and Confused, and the Entropy increases by +2.^^
#     --Rank| d@{skill_intimidate}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_intimidate}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}
# Intimidate
# !power {{
#     --name|@{character_name} - Rage
#     --Effect|Exert yourself, entering a trance-like fury to crush your enemies, see them driven before you, and to hear the lamentations of their women. You gain a Rage Aura equal to Hits +1 in the result set.^^While you are in a Rage, you may decrease your Rage Aura by -1 to add +2 Bonus Hits to any Action using Exert, Endure, Grapple, Intimidate, Martial Arts, Strike, or Throw.^^If your Rage Aura equals 0 or you use a Shift to dismiss it, you gain Fatigued 2 and Confused 1, and the Entropy increases by +1.^^If your Rage Aura is 8+, you gain Fatigued 2 and Confused, and the Entropy increases by +2.^^
#     --Rank| d@{skill_martial_arts}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_martial_arts}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}
# Martial_arts
# !power {{
#     --name|@{character_name} - Rage
#     --Effect|Exert yourself, entering a trance-like fury to crush your enemies, see them driven before you, and to hear the lamentations of their women. You gain a Rage Aura equal to Hits +1 in the result set.^^While you are in a Rage, you may decrease your Rage Aura by -1 to add +2 Bonus Hits to any Action using Exert, Endure, Grapple, Intimidate, Martial Arts, Strike, or Throw.^^If your Rage Aura equals 0 or you use a Shift to dismiss it, you gain Fatigued 2 and Confused 1, and the Entropy increases by +1.^^If your Rage Aura is 8+, you gain Fatigued 2 and Confused, and the Entropy increases by +2.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Rage
#     --Effect|Exert yourself, entering a trance-like fury to crush your enemies, see them driven before you, and to hear the lamentations of their women. You gain a Rage Aura equal to Hits +1 in the result set.^^While you are in a Rage, you may decrease your Rage Aura by -1 to add +2 Bonus Hits to any Action using Exert, Endure, Grapple, Intimidate, Martial Arts, Strike, or Throw.^^If your Rage Aura equals 0 or you use a Shift to dismiss it, you gain Fatigued 2 and Confused 1, and the Entropy increases by +1.^^If your Rage Aura is 8+, you gain Fatigued 2 and Confused, and the Entropy increases by +2.^^
#     --Rank| d@{skill_throw}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_throw}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}
# Throw
# !power {{
#     --name|@{character_name} - Rage
#     --Effect|Exert yourself, entering a trance-like fury to crush your enemies, see them driven before you, and to hear the lamentations of their women. You gain a Rage Aura equal to Hits +1 in the result set.^^While you are in a Rage, you may decrease your Rage Aura by -1 to add +2 Bonus Hits to any Action using Exert, Endure, Grapple, Intimidate, Martial Arts, Strike, or Throw.^^If your Rage Aura equals 0 or you use a Shift to dismiss it, you gain Fatigued 2 and Confused 1, and the Entropy increases by +1.^^If your Rage Aura is 8+, you gain Fatigued 2 and Confused, and the Entropy increases by +2.^^
#     --Rank| d@{skill_endure}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_endure}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|shiftcheck
#     }}
# Endure
# !power {{
#     --name|@{character_name} - Berkserker's Fury
#     --Effect|Decrease your Rage Aura by -2 and **choose one (1)**:^^^^**Strike or use your Martial Arts against one target in your Current Zone, adding +1d4 Bonus Hits to the restul set and your target gains Wounded 1.^^^^Throw one target you have Grappled into an Adjacent Zone, ending the target's Grappled status.  The target and one other target in the Adjacent Zone take X Hits and become Prone, where X is equalt to Hits in the result set.^^^^Intimidate hostile targets in your Current Zone.  Up to X targets gian Provoked and your recover X to your Primary Defense, where X is equal to Hits in the result set.**
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Grapple
# !power {{
#     --name|@{character_name} - Berkserker's Fury
#     --Effect|Decrease your Rage Aura by -2 and **choose one (1)**:^^^^**Strike or use your Martial Arts against one target in your Current Zone, adding +1d4 Bonus Hits to the restul set and your target gains Wounded 1.^^^^Throw one target you have Grappled into an Adjacent Zone, ending the target's Grappled status.  The target and one other target in the Adjacent Zone take X Hits and become Prone, where X is equalt to Hits in the result set.^^^^Intimidate hostile targets in your Current Zone.  Up to X targets gian Provoked and your recover X to your Primary Defense, where X is equal to Hits in the result set.**
#     --Rank| d@{skill_intimidate}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_intimidate}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Intimidate
# !power {{
#     --name|@{character_name} - Berkserker's Fury
#     --Effect|Decrease your Rage Aura by -2 and **choose one (1)**:^^^^**Strike or use your Martial Arts against one target in your Current Zone, adding +1d4 Bonus Hits to the restul set and your target gains Wounded 1.^^^^Throw one target you have Grappled into an Adjacent Zone, ending the target's Grappled status.  The target and one other target in the Adjacent Zone take X Hits and become Prone, where X is equalt to Hits in the result set.^^^^Intimidate hostile targets in your Current Zone.  Up to X targets gian Provoked and your recover X to your Primary Defense, where X is equal to Hits in the result set.**
#     --Rank| d@{skill_martial_arts}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_martial_arts}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Martial_arts
# !power {{
#     --name|@{character_name} - Berkserker's Fury
#     --Effect|Decrease your Rage Aura by -2 and **choose one (1)**:^^^^**Strike or use your Martial Arts against one target in your Current Zone, adding +1d4 Bonus Hits to the restul set and your target gains Wounded 1.^^^^Throw one target you have Grappled into an Adjacent Zone, ending the target's Grappled status.  The target and one other target in the Adjacent Zone take X Hits and become Prone, where X is equalt to Hits in the result set.^^^^Intimidate hostile targets in your Current Zone.  Up to X targets gian Provoked and your recover X to your Primary Defense, where X is equal to Hits in the result set.**
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Berkserker's Fury
#     --Effect|Decrease your Rage Aura by -2 and **choose one (1)**:^^^^**Strike or use your Martial Arts against one target in your Current Zone, adding +1d4 Bonus Hits to the restul set and your target gains Wounded 1.^^^^Throw one target you have Grappled into an Adjacent Zone, ending the target's Grappled status.  The target and one other target in the Adjacent Zone take X Hits and become Prone, where X is equalt to Hits in the result set.^^^^Intimidate hostile targets in your Current Zone.  Up to X targets gian Provoked and your recover X to your Primary Defense, where X is equal to Hits in the result set.**
#     --Rank| d@{skill_throw}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_throw}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Throw
# !power {{
#     --name|@{character_name} - Vicious Rage
#     --Effect|When  you are in a Rage and score 5+ Hits using Grapple, Martial Arts, Strike, or Throw, you may reduce your Rage Aura by -1 and your target gian Vulnerable 1.
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Grapple
# !power {{
#     --name|@{character_name} - Vicious Rage
#     --Effect|When  you are in a Rage and score 5+ Hits using Grapple, Martial Arts, Strike, or Throw, you may reduce your Rage Aura by -1 and your target gian Vulnerable 1.
#     --Rank| d@{skill_martial_arts}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_martial_arts}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Martial_arts
# !power {{
#     --name|@{character_name} - Vicious Rage
#     --Effect|When  you are in a Rage and score 5+ Hits using Grapple, Martial Arts, Strike, or Throw, you may reduce your Rage Aura by -1 and your target gian Vulnerable 1.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Vicious Rage
#     --Effect|When  you are in a Rage and score 5+ Hits using Grapple, Martial Arts, Strike, or Throw, you may reduce your Rage Aura by -1 and your target gian Vulnerable 1.
#     --Rank| d@{skill_throw}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_throw}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Throw
# !power {{
#     --name|@{character_name} - Flying Kick
#     --Effect|When you Shift to Move into an Adjacent Zone and use your Martial Arts to attack your target, add +3 Hits to the result set.
#     --Rank| d@{skill_martial_arts}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_martial_arts}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Martial_arts
# !power {{
#     --name|@{character_name} - Renraku Waza
#     --Effect|Use your Martial Arts against a target in your Current Zone.^^If you score 3+ Hits, add +1d4 Bonus Hits to the results set.^^
#     --Rank| d@{skill_martial_arts}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_martial_arts}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Martial_arts
# !power {{
#     --name|@{character_name} - I Can Bring You In Warm, Or I Can Bring You In Cold.
#     --Effect|Intimidate a target in yout Current Zone that you are trying to apprehend, adding +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_intimidate}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_intimidate}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Intimidate
# !power {{
#     --name|@{character_name} - Bolas
#     --Effect|Use your Implements to ensnare one target in your Current or and Adjacent Zone.  The target gains Prone and Restrained X, where X is equal to Hits in the result set.
#     --Rank| d@{skill_implements}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_implements}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Implements
# !power {{
#     --name|@{character_name} - Manacles
#     --Effect|Use your Implements to bind the hands of one target in your Current Zone.  On 2+ Hits, the target gains Restrained X, where X is 8+Hits in the result set.
#     --Rank| d@{skill_implements}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_implements}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Implements
# !power {{
#     --name|@{character_name} - Shrewd Contractor
#     --Effect|Persuade, Intimidate, or use your Insight when discussing the terms of a bounty, addin +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_intimidate}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_intimidate}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Intimidate
# !power {{
#     --name|@{character_name} - Shrewd Contractor
#     --Effect|Persuade, Intimidate, or use your Insight when discussing the terms of a bounty, addin +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_insight}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_insight}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Insight
# !power {{
#     --name|@{character_name} - Shrewd Contractor
#     --Effect|Persuade, Intimidate, or use your Insight when discussing the terms of a bounty, addin +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_persuade}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_persuade}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Persuade
# !power {{
#     --name|@{character_name} - Word on the Street
#     --Effect|Use your Streetwise to gain valuable information or find the right person to talk to about you target.  On 3+ Hits, you gain +1 Favor to use in your hunt.
#     --Rank| d@{skill_streetwise}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_streetwise}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Streetwise
# !power {{
#     --name|@{character_name} - No Disintegrations
#     --Effect|Strike one target in your Current Zone or Shoot one target in your Current or an Adjacent Zone aiming to subdue them.^^On 4+ Hits, your target gains Unconscious 1.  Otherwise target gains Stunned 4.^^
#     --Rank| d@{skill_shoot}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_shoot}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Shoot
# !power {{
#     --name|@{character_name} - No Disintegrations
#     --Effect|Strike one target in your Current Zone or Shoot one target in your Current or an Adjacent Zone aiming to subdue them.^^On 4+ Hits, your target gains Unconscious 1.  Otherwise target gains Stunned 4.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Brutal Strike
#     --Effect|Strike one target with unrelenting force, adding +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Brutal Blow
#     --Effect|Use Martial Arts against one target with unrelenting force, adding +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_martial_arts}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_martial_arts}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Martial_arts
# !power {{
#     --name|@{character_name} - Just Getting Started
#     --Effect|Exert yourself when you are below your maximum Grit, then **choose 1**:^^^^**Regain Hits to your Primary Defense.^^^^Increase the current Timer by 1.**
#     --Rank| d@{skill_exert}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_exert}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Exert
# !power {{
#     --name|@{character_name} - Who's Next
#     --Effect|Intimidate all targets in your Current Zone.  If you score Hits greater than their current Nerve, they become <a href:'/no1_system/core/statuses#Afraid/'>Afraid</a> of you.
#     --Rank| d@{skill_intimidate}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_intimidate}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Intimidate
# !power {{
#     --name|@{character_name} - You're Next
#     --Effect|When you Strike your target to death, you can Initiate a Contest with one hostile target in your Current Zone wihtout using a Shift.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Grisly Slaughter
#     --Effect|When you Strike your target to death, describe the gruesome end you delivered.  Then all hostile targets in your Current Zone with Nerve less than Hits become Afraid of you.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Channeling
#     --Effect|Your Affinity for these forces all you to use <a href='/no1_system/characters/powers/techniques/'>Techniques</a> that channel their power.^^When you gain this Talent, select 2 Effect Skills from the list below to be your Affinities:^^//Inferno, Lux, Nox, Rime, Squall, Tellus, Tempest, Torrent//^^At the beginning of each Waypoint, your Current is 0.^^
#     --Rank| d@{skill_inferno}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_inferno}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Inferno
# !power {{
#     --name|@{character_name} - Channeling
#     --Effect|Your Affinity for these forces all you to use <a href='/no1_system/characters/powers/techniques/'>Techniques</a> that channel their power.^^When you gain this Talent, select 2 Effect Skills from the list below to be your Affinities:^^//Inferno, Lux, Nox, Rime, Squall, Tellus, Tempest, Torrent//^^At the beginning of each Waypoint, your Current is 0.^^
#     --Rank| d@{skill_tempest}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_tempest}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Tempest
# !power {{
#     --name|@{character_name} - Channeling
#     --Effect|Your Affinity for these forces all you to use <a href='/no1_system/characters/powers/techniques/'>Techniques</a> that channel their power.^^When you gain this Talent, select 2 Effect Skills from the list below to be your Affinities:^^//Inferno, Lux, Nox, Rime, Squall, Tellus, Tempest, Torrent//^^At the beginning of each Waypoint, your Current is 0.^^
#     --Rank| d@{skill_nox}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_nox}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Nox
# !power {{
#     --name|@{character_name} - Channeling
#     --Effect|Your Affinity for these forces all you to use <a href='/no1_system/characters/powers/techniques/'>Techniques</a> that channel their power.^^When you gain this Talent, select 2 Effect Skills from the list below to be your Affinities:^^//Inferno, Lux, Nox, Rime, Squall, Tellus, Tempest, Torrent//^^At the beginning of each Waypoint, your Current is 0.^^
#     --Rank| d@{skill_squall}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_squall}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Squall
# !power {{
#     --name|@{character_name} - Channeling
#     --Effect|Your Affinity for these forces all you to use <a href='/no1_system/characters/powers/techniques/'>Techniques</a> that channel their power.^^When you gain this Talent, select 2 Effect Skills from the list below to be your Affinities:^^//Inferno, Lux, Nox, Rime, Squall, Tellus, Tempest, Torrent//^^At the beginning of each Waypoint, your Current is 0.^^
#     --Rank| d@{skill_rime}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_rime}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Rime
# !power {{
#     --name|@{character_name} - Channeling
#     --Effect|Your Affinity for these forces all you to use <a href='/no1_system/characters/powers/techniques/'>Techniques</a> that channel their power.^^When you gain this Talent, select 2 Effect Skills from the list below to be your Affinities:^^//Inferno, Lux, Nox, Rime, Squall, Tellus, Tempest, Torrent//^^At the beginning of each Waypoint, your Current is 0.^^
#     --Rank| d@{skill_torrent}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_torrent}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Torrent
# !power {{
#     --name|@{character_name} - Channeling
#     --Effect|Your Affinity for these forces all you to use <a href='/no1_system/characters/powers/techniques/'>Techniques</a> that channel their power.^^When you gain this Talent, select 2 Effect Skills from the list below to be your Affinities:^^//Inferno, Lux, Nox, Rime, Squall, Tellus, Tempest, Torrent//^^At the beginning of each Waypoint, your Current is 0.^^
#     --Rank| d@{skill_lux}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_lux}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Lux
# !power {{
#     --name|@{character_name} - Channeling
#     --Effect|Your Affinity for these forces all you to use <a href='/no1_system/characters/powers/techniques/'>Techniques</a> that channel their power.^^When you gain this Talent, select 2 Effect Skills from the list below to be your Affinities:^^//Inferno, Lux, Nox, Rime, Squall, Tellus, Tempest, Torrent//^^At the beginning of each Waypoint, your Current is 0.^^
#     --Rank| d@{skill_tellus}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_tellus}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Tellus
# !power {{
#     --name|@{character_name} - Attune with Essence
#     --Effect|Focus or use your Insight to connect with your power, gaining Hits in Attunement.^^Attunment measures the strength of connection to your power, which determines the strength of the Marvels you can manifest.^^If the result set of one of your Marvels contains a 1, reduce your Atttunement by X, where X is equal to Hits in the same result set.^^If your Attunement equals 0 or less, you gain Stunned 3 and the Entropy increases by +3.^^You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 8 - Steady Actions (minimum 1 Action).^^
#     --Rank| d@{skill_insight}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_insight}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Insight
# !power {{
#     --name|@{character_name} - Attune with Essence
#     --Effect|Focus or use your Insight to connect with your power, gaining Hits in Attunement.^^Attunment measures the strength of connection to your power, which determines the strength of the Marvels you can manifest.^^If the result set of one of your Marvels contains a 1, reduce your Atttunement by X, where X is equal to Hits in the same result set.^^If your Attunement equals 0 or less, you gain Stunned 3 and the Entropy increases by +3.^^You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 8 - Steady Actions (minimum 1 Action).^^
#     --Rank| d@{skill_focus}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_focus}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Focus
# !power {{
#     --name|@{character_name} - Augmented Bond
#     --Effect|Select 2 additional Effect Skills from the list below to add to your Affinity:^^//Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus//
#     --Rank| d@{skill_bellor}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_bellor}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Bellor
# !power {{
#     --name|@{character_name} - Augmented Bond
#     --Effect|Select 2 additional Effect Skills from the list below to add to your Affinity:^^//Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus//
#     --Rank| d@{skill_inferno}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_inferno}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Inferno
# !power {{
#     --name|@{character_name} - Augmented Bond
#     --Effect|Select 2 additional Effect Skills from the list below to add to your Affinity:^^//Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus//
#     --Rank| d@{skill_tempest}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_tempest}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Tempest
# !power {{
#     --name|@{character_name} - Augmented Bond
#     --Effect|Select 2 additional Effect Skills from the list below to add to your Affinity:^^//Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus//
#     --Rank| d@{skill_mori}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_mori}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Mori
# !power {{
#     --name|@{character_name} - Augmented Bond
#     --Effect|Select 2 additional Effect Skills from the list below to add to your Affinity:^^//Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus//
#     --Rank| d@{skill_nox}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_nox}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Nox
# !power {{
#     --name|@{character_name} - Augmented Bond
#     --Effect|Select 2 additional Effect Skills from the list below to add to your Affinity:^^//Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus//
#     --Rank| d@{skill_squall}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_squall}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Squall
# !power {{
#     --name|@{character_name} - Augmented Bond
#     --Effect|Select 2 additional Effect Skills from the list below to add to your Affinity:^^//Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus//
#     --Rank| d@{skill_rime}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_rime}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Rime
# !power {{
#     --name|@{character_name} - Augmented Bond
#     --Effect|Select 2 additional Effect Skills from the list below to add to your Affinity:^^//Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus//
#     --Rank| d@{skill_torrent}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_torrent}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Torrent
# !power {{
#     --name|@{character_name} - Augmented Bond
#     --Effect|Select 2 additional Effect Skills from the list below to add to your Affinity:^^//Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus//
#     --Rank| d@{skill_lux}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_lux}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Lux
# !power {{
#     --name|@{character_name} - Augmented Bond
#     --Effect|Select 2 additional Effect Skills from the list below to add to your Affinity:^^//Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus//
#     --Rank| d@{skill_ordi}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_ordi}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Ordi
# !power {{
#     --name|@{character_name} - Augmented Bond
#     --Effect|Select 2 additional Effect Skills from the list below to add to your Affinity:^^//Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus//
#     --Rank| d@{skill_aether}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_aether}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Aether
# !power {{
#     --name|@{character_name} - Augmented Bond
#     --Effect|Select 2 additional Effect Skills from the list below to add to your Affinity:^^//Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus//
#     --Rank| d@{skill_nihil}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_nihil}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Nihil
# !power {{
#     --name|@{character_name} - Augmented Bond
#     --Effect|Select 2 additional Effect Skills from the list below to add to your Affinity:^^//Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus//
#     --Rank| d@{skill_vivus}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_vivus}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Vivus
# !power {{
#     --name|@{character_name} - Pirate's Charm
#     --Effect|Persuade a sailor, pirate, or maritime merchant, adding +2 Bonus Hits to the result set.
#     --Rank| d@{skill_persuade}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_persuade}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Persuade
# !power {{
#     --name|@{character_name} - Sea Lore
#     --Effect|Increase your Cosmology or History rank to 2 (d8).
#     --Rank| d@{skill_cosmology}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_cosmology}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|2check
#     }}
# Cosmology
# !power {{
#     --name|@{character_name} - Sea Lore
#     --Effect|Increase your Cosmology or History rank to 2 (d8).
#     --Rank| d@{skill_history}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_history}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|2check
#     }}
# History
# !power {{
#     --name|@{character_name} - Plunderer's Instinct
#     --Effect|Perceive or Investigate to find hidden compartments, treaure, or valuable cargo, adding +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_investigate}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_investigate}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
# ...
#     --Effect|Choose one of the Effect Skills below to be an Affinity.^^//Aether, Bellor, Destroy, Inferno, Intuit, Mori, Nihil, Ordi, Rime, Vivus//
#     --Rank| d@{skill_bellor}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_bellor}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Bellor
# !power {{
#     --name|@{character_name} - Gifts Affinity
#     --Effect|Choose one of the Effect Skills below to be an Affinity.^^//Aether, Bellor, Destroy, Inferno, Intuit, Mori, Nihil, Ordi, Rime, Vivus//
#     --Rank| d@{skill_inferno}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_inferno}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Inferno
# !power {{
#     --name|@{character_name} - Gifts Affinity
#     --Effect|Choose one of the Effect Skills below to be an Affinity.^^//Aether, Bellor, Destroy, Inferno, Intuit, Mori, Nihil, Ordi, Rime, Vivus//
#     --Rank| d@{skill_mori}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_mori}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Mori
# !power {{
#     --name|@{character_name} - Gifts Affinity
#     --Effect|Choose one of the Effect Skills below to be an Affinity.^^//Aether, Bellor, Destroy, Inferno, Intuit, Mori, Nihil, Ordi, Rime, Vivus//
#     --Rank| d@{skill_rime}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_rime}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Rime
# !power {{
#     --name|@{character_name} - Gifts Affinity
#     --Effect|Choose one of the Effect Skills below to be an Affinity.^^//Aether, Bellor, Destroy, Inferno, Intuit, Mori, Nihil, Ordi, Rime, Vivus//
#     --Rank| d@{skill_ordi}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_ordi}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Ordi
# !power {{
#     --name|@{character_name} - Gifts Affinity
#     --Effect|Choose one of the Effect Skills below to be an Affinity.^^//Aether, Bellor, Destroy, Inferno, Intuit, Mori, Nihil, Ordi, Rime, Vivus//
#     --Rank| d@{skill_aether}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_aether}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Aether
# !power {{
#     --name|@{character_name} - Gifts Affinity
#     --Effect|Choose one of the Effect Skills below to be an Affinity.^^//Aether, Bellor, Destroy, Inferno, Intuit, Mori, Nihil, Ordi, Rime, Vivus//
#     --Rank| d@{skill_destroy}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_destroy}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Destroy
# !power {{
#     --name|@{character_name} - Gifts Affinity
#     --Effect|Choose one of the Effect Skills below to be an Affinity.^^//Aether, Bellor, Destroy, Inferno, Intuit, Mori, Nihil, Ordi, Rime, Vivus//
#     --Rank| d@{skill_intuit}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_intuit}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Intuit
# !power {{
#     --name|@{character_name} - Gifts Affinity
#     --Effect|Choose one of the Effect Skills below to be an Affinity.^^//Aether, Bellor, Destroy, Inferno, Intuit, Mori, Nihil, Ordi, Rime, Vivus//
#     --Rank| d@{skill_nihil}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_nihil}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Nihil
# !power {{
#     --name|@{character_name} - Gifts Affinity
#     --Effect|Choose one of the Effect Skills below to be an Affinity.^^//Aether, Bellor, Destroy, Inferno, Intuit, Mori, Nihil, Ordi, Rime, Vivus//
#     --Rank| d@{skill_vivus}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_vivus}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Vivus
# !power {{
#     --name|@{character_name} - Witch's Brew
#     --Effect|Craft at Challenge 3 to gain Hits + Savvy in Concoction Ranks to prepare Concocions.^^You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 8 - Craft Actions (minimum 1 Action).^^
#     --Rank| d@{skill_craft}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_craft}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Craft
# !power {{
#     --name|@{character_name} - Hexcrafter
#     --Effect|When you Focus to Maintain Focus on your Ongoing effects, add +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_focus}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_focus}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Focus
# !power {{
#     --name|@{character_name} - Witch's Familiar
#     --Effect|Persuade the spirits of the world at Challenge 3 to send you a Beast Minion.  On 1+ Hits, you may recruit a Beast of cost 1 or less from the Beast Minions table.^^You may use this Ability without spending an Action at the beginning of each Waypoint.  If you use it during a Waypoint, it requires 5 - Steady Actions (minimum 1 Action).^^
#     --Rank| d@{skill_persuade}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_persuade}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Persuade
# !power {{
#     --name|@{character_name} - Dangerous Distillation
#     --Effect|When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_craft}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_craft}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Craft
# !power {{
#     --name|@{character_name} - Greater Familiar
#     --Effect|When you Persuade the spirits of the world to send you a Beast Minon, you may recruit a of cost 2 or less.
#     --Rank| d@{skill_persuade}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_persuade}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Persuade
# !power {{
#     --name|@{character_name} - Blood for Power
#     --Effect|When you Focus to Maintain Focus on your Ongoing effects, spend X Grit to add X Bonus Hits to the result set.
#     --Rank| d@{skill_focus}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_focus}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Focus
# !power {{
#     --name|@{character_name} - Suplex
#     --Effect|Grapple your target, adding +1d4 bonus Hits and making them Prone, but ending their Grappled Status.
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Grapple
# !power {{
#     --name|@{character_name} - Sprawl
#     --Effect|When an opponet you can see tries to Grapple you, reduce Hits in their result set by -2.
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Grapple
# !power {{
#     --name|@{character_name} - Chokeslam
#     --Effect|Grapple one target in your Current Zone.  On 3+ Hits, your target becomes Prone and Dazed 2.
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Grapple
# !power {{
#     --name|@{character_name} - O Goshi
#     --Effect|When you have an opponent Grappled, you may reduce their Grappled rating by -1 to give them Vulnerable 2 and Prone.
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Grapple
# !power {{
#     --name|@{character_name} - Off the Top Rope!
#     --Effect|When you Shift to Move into an Adjacent Zone and Grapple your target, add +2 Hits to the result set.
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Grapple
# !power {{
#     --name|@{character_name} - At Home in the Clench
#     --Effect|When you have an target Grappled and use an Action to Recover, add +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Grapple
# !power {{
#     --name|@{character_name} - Lunge
#     --Effect|**//Sworldplay//**^^^^Spend X Defenses and Strike one target in your Current Zone, add X Bonus Hits to the result set.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Thrust
#     --Effect|**//Sworldplay//**^^^^Strike one target in your Current Zone.  You may spend 3 Hits from the result set to have the target gain Wounded 1.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Feint
#     --Effect|**//Sworldplay//**^^^^Deceive one target in your Current Zone.  One 2+ Hits, you may immediately Strike the target adding +1d4 Bonus Hits to the result set.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Feint
#     --Effect|**//Sworldplay//**^^^^Deceive one target in your Current Zone.  One 2+ Hits, you may immediately Strike the target adding +1d4 Bonus Hits to the result set.^^
#     --Rank| d@{skill_deceive}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_deceive}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Deceive
# !power {{
#     --name|@{character_name} - Hewer Flesh
#     --Effect|**//Hewer//**^^^^Strike one target in your Current Zone.  You may spend 3 Hits in the result set to have the target gain Wounded 2.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Sundering Chop
#     --Effect|**//Hewer//**^^^^Strike one target in your Current Zone.  You may spend 2 Hits in the result set to have to reduce one of the target's Gear Ratings by X, where X is the total Hits in the result set.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Feller's Hack
#     --Effect|**//Hewer//**^^^^Strike one target in your Current Zone that is is Wounded, it gains Vulnerable 1 and Stunned 1.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Crushing Blow
#     --Effect|**//Crusher//**^^^^Strike one target in your Current Zone.  You may spend 2 Hits in the result set to make the target gain Vulnerable 1.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Sapping Blow
#     --Effect|**//Crusher//**^^^^When you Strike one target in your Current Zone that is Vulnerable, the target gains Fatigued 1.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Jarring Blow
#     --Effect|**//Crusher//**^^^^When you Strike one target in your Current Zone that is Vulnerable, the target gains Stunned 2.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Forceful Blow
#     --Effect|**//Crusher//**^^^^Strike one target in your Current Zone.  You may spend 2 Hits in the result set to move your target to an Adjacent Zone.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Tripping Swipe
#     --Effect|**//Poledance//**^^^^Strike one target in your Current Zone.  You may spend 2 Hits in the result set to make the target become Prone.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Pinion Thrust
#     --Effect|**//Poledance//**^^^^Strike one target in your Current Zone.  You may spend 2 Hits in the result set to make the target gain Restrained 2.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Make Space
#     --Effect|**//Poledance//**^^^^Strike one target in your Current Zone and gain Aura 1.  While this Aura persists, all targets in your Current Zone add 1 Hazard to any Action targetting you.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Waki-gamae
#     --Effect|**//Niten//**^^^^Strike one target in your Current Zone.  You may spend 2 Hits from the result set to immediately Wait for it. . . , preparing an Action to Strike one target in your Current Zone if they use a Shift to Move or an Action to attack.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Off-hand Parry
#     --Effect|**//Niten//**^^^^Strike one target in your Current Zone and use your second weapon to defend yourself to gain Armor Defense X, where X is equal to Hits in the result set.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|abilitycheck
#     }}
# Strike
# !power {{
#     --name|@{character_name} - Sinawali
#     --Effect|**//Niten//**^^^^When you Strike a target and score 3+ Hits, you may immediately use another Action to strike with your second weapon.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}
# Strike

# %%
df_talents[df_talents['name']=='Marked for Death']
# Out:
#         tree              name   type rank requires replaces  \
# 34  Assassin  Marked for Death  Shift    2     None     None
#
#                                                effect  \
# 34  Use your Tactics to mark your target, giving t...
#
#                                            effect_raw Exert Grapple  ...  \
# 34  [Use your Tactics to mark your target, giving ...  None    None  ...
#
#     Luck Nihil Resist Tempor Vivus  \
# 34  None  None   None   None  None
#
#                                           list_skills     skills  \
# 34  [None, None, None, None, None, None, None, Non...  [Tactics]
#
#                                             str_pcard  \
# 34  [!power {{\n    --name|@{character_name} - Mar...
#
#                               attr_tal_nm  \
# 34  attr_talent_assassin_marked_for_death
#
#                           attr_tal_nm_raw
# 34  attr_talent_assassin_marked_for_death
#
# [1 rows x 77 columns]

# %%
# type='Shift'
# talents = df_talents[(df_talents['type']==type) & (df_talents['name'] != '') & (df_talents['tree'] != '')].copy()
# div_str = ''
# for p in talents['tree'].unique():
#     tals = talents[talents['tree']==p]
#     div_str += '''<div class="grid-container-talents">\n<input class="sheet-training-ranks" type="hidden" name="attr_training_rank_''' + p.lower() + '''" step="1" value="0" min="0" max="20" />\n<div class="sheet-training-talents">\n<h4 class="grid-talents-label" style="margin-bottom:4px;">''' + p + '''</h4>\n<div class="grid-container-talents">\n'''
#     # tals = t_type[t_type['tree']==p]
#     for index, tal in tals.iterrows():
#         div_str += '''<div class="grid-item-talents">\n''' 
#         div_str +='''<label style="font-size:12pt;">''' + tal['name'] + '''<br><span style="font-size:8pt;">Rank ''' + str(tal['rank']) + '''</span></label>\n<input type="checkbox" name="''' + tal['attr_tal_nm'] + '''" /><div class="talent-rollbox">\n<p>''' + tal['effect'] + '''</p>\n'''
#         if len(tal['str_pcard']) > 0:
#             for p in tal['str_pcard']:
#                 skill_button_nm = p[p.find('skill_')+6:p.find('--Result Set')-6].replace('_', ' ').title()
#                 div_str +='''<button class="skill-button" type="roll" value="''' + p +'''">\n''' + skill_button_nm + '''\n</button>\n'''
#         else:
#             div_str +='''<button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - ''' + tal['name'] + '''
#         --Effect|''' + tal['effect'] + '''
#         --format|''' + type.lower() + '''check
#         }}">\n</button>\n'''
#         div_str +='''</div>\n</div>\n'''
#     div_str += '''</div>\n</div>\n</div>\n'''

# # div_str += '''</div>\n'''
# print(div_str)

# %%
type='Shift'
talents = df_talents[(df_talents['type']==type) & (df_talents['name'] != '') & (df_talents['tree'] != '')].copy()
div_str = ''
for p in talents['tree'].unique():
    tals = talents[talents['tree']==p]
    div_str += '''<input class="sheet-training-ranks" type="hidden" name="attr_training_rank_''' + p.lower() + '''" step="1" value="0" min="0" max="20" />\n<div class="sheet-training-talents">\n<div class="grid-container-talents">\n<h4 class="grid-talents-label" style="margin-bottom:4px;">''' + p + '''</h4>\n<div class="grid-container-talents">\n'''
    for i, tal in tals.iterrows():
        div_str += '''<div class="grid-item-talents">\n'''
        div_str +='''<div>''' + tal['name'] + '''</div>\n<div>Rank ''' + str(tal['rank']) + '''</div>\n<div><details>\n<summary>&#10010;</summary>\n''' + tal['effect'] + '''\n</details>\n</div>\n<div>\n<input type="checkbox" name="''' + tal['attr_tal_nm'] + '''" />\n<div class="talent-rollbox">\n'''
        if len(tal['str_pcard']) > 0:
            for p in tal['str_pcard']:
                skill_button_nm = p[p.find('skill_')+6:p.find('--Result Set')-6].replace('_', ' ').title()
                div_str +='''<button class="txt-btn" type="roll" value="''' + p +'''">\n''' + skill_button_nm + '''\n</button>\n'''
        else:
            div_str +='''<button class="txt-btn" type="roll" value="!power {{
        --name|@{character_name} - ''' + tal['name'] + '''
        --Effect|''' + tal['effect'] + '''
        --format|''' + type.lower() + '''check
        }}">\nRoll\n</button>\n'''
        div_str +='''</div>\n</div>\n</div>\n'''
    div_str += '''</div>\n</div>\n</div>\n'''

# %%
f = open('shifts_training_talents.html', 'w')
f.write(div_str)
f.close()

# %%
# type='Ability'
# talents = df_talents[(df_talents['type']==type) & (df_talents['name'] != '') & (df_talents['tree'] != '')].copy()
# div_str = ''
# for p in talents['tree'].unique():
#     tals = talents[talents['tree']==p]
#     div_str += '''<div class="grid-container-talents">\n<input class="sheet-training-ranks" type="hidden" name="attr_training_rank_''' + p.lower() + '''" step="1" value="0" min="0" max="20" />\n<div class="sheet-training-talents">\n<h4 class="grid-talents-label" style="margin-bottom:4px;">''' + p + '''</h4>\n<div class="grid-container-talents">\n'''
#     # tals = t_type[t_type['tree']==p]
#     for index, tal in tals.iterrows():
#         div_str += '''<div class="grid-item-talents">\n''' 
#         div_str +='''<label style="font-size:12pt;">''' + tal['name'] + '''<br><span style="font-size:8pt;">Rank ''' + str(tal['rank']) + '''</span></label>\n<input type="checkbox" name="''' + tal['attr_tal_nm'] + '''" /><div class="talent-rollbox">\n<p>''' + tal['effect'] + '''</p>\n'''
#         if len(tal['str_pcard']) > 0:
#             for p in tal['str_pcard']:
#                 skill_button_nm = p[p.find('skill_')+6:p.find('--Result Set')-6].replace('_', ' ').title()
#                 div_str +='''<button class="skill-button" type="roll" value="''' + p +'''">\n''' + skill_button_nm + '''\n</button>\n'''
#         else:
#             div_str +='''<button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - ''' + tal['name'] + '''
#         --Effect|''' + tal['effect'] + '''
#         --format|''' + type.lower() + '''check
#         }}">\n</button>\n'''
#         div_str +='''</div>\n</div>\n'''
#     div_str += '''</div>\n</div>\n</div>\n'''

# # div_str += '''</div>\n'''
# print(div_str)

# %%
type='Ability'
talents = df_talents[(df_talents['type']==type) & (df_talents['name'] != '') & (df_talents['tree'] != '')].copy()
div_str = ''
for p in talents['tree'].unique():
    tals = talents[talents['tree']==p]
    div_str += '''<input class="sheet-training-ranks" type="hidden" name="attr_training_rank_''' + p.lower() + '''" step="1" value="0" min="0" max="20" />\n<div class="sheet-training-talents">\n<div class="grid-container-talents">\n<h4 class="grid-talents-label" style="margin-bottom:4px;">''' + p + '''</h4>\n<div class="grid-container-talents">\n'''
    for i, tal in tals.iterrows():
        div_str += '''<div class="grid-item-talents">\n'''
        div_str +='''<div>''' + tal['name'] + '''</div>\n<div>Rank ''' + str(tal['rank']) + '''</div>\n<div><details>\n<summary>&#10010;</summary>\n''' + tal['effect'] + '''\n</details>\n</div>\n<div>\n<input type="checkbox" name="''' + tal['attr_tal_nm'] + '''" />\n<div class="talent-rollbox">\n'''
        if len(tal['str_pcard']) > 0:
            for p in tal['str_pcard']:
                skill_button_nm = p[p.find('skill_')+6:p.find('--Result Set')-6].replace('_', ' ').title()
                div_str +='''<button class="txt-btn" type="roll" value="''' + p +'''">\n''' + skill_button_nm + '''\n</button>\n'''
        else:
            div_str +='''<button class="txt-btn" type="roll" value="!power {{
        --name|@{character_name} - ''' + tal['name'] + '''
        --Effect|''' + tal['effect'] + '''
        --format|''' + type.lower() + '''check
        }}">\nRoll\n</button>\n'''
        div_str +='''</div>\n</div>\n</div>\n'''
    div_str += '''</div>\n</div>\n</div>\n'''

# %%
f = open('abilities_training_talents.html', 'w')
f.write(div_str)
f.close()

# %%
# type='Static'
# talents = df_talents[(df_talents['type']==type) & (df_talents['name'] != '') & (df_talents['tree'] != '')].copy()
# div_str = ''
# for p in talents['tree'].unique():
#     tals = talents[talents['tree']==p]
#     div_str += '''<div class="grid-container-talents">\n<input class="sheet-training-ranks" type="hidden" name="attr_training_rank_''' + p.lower() + '''" step="1" value="0" min="0" max="20" />\n<div class="sheet-training-talents">\n<h4 class="grid-talents-label" style="margin-bottom:4px;">''' + p + '''</h4>\n<div class="grid-container-talents">\n'''
#     # tals = t_type[t_type['tree']==p]
#     for index, tal in tals.iterrows():
#         div_str += '''<div class="grid-item-talents">\n''' 
#         div_str +='''<label style="font-size:12pt;">''' + tal['name'] + '''<br><span style="font-size:8pt;">Rank ''' + str(tal['rank']) + '''</span></label>\n<input type="checkbox" name="''' + tal['attr_tal_nm'] + '''" /><div class="talent-rollbox">\n<p>''' + tal['effect'] + '''</p>\n'''
#         if len(tal['str_pcard']) > 0:
#             for p in tal['str_pcard']:
#                 skill_button_nm = p[p.find('skill_')+6:p.find('--Result Set')-6].replace('_', ' ').title()
#                 div_str +='''<button class="skill-button" type="roll" value="''' + p +'''">\n''' + skill_button_nm + '''\n</button>\n'''
#         else:
#             div_str +='''<button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - ''' + tal['name'] + '''
#         --Effect|''' + tal['effect'] + '''
#         --format|''' + type.lower() + '''check
#         }}">\n</button>\n'''
#         div_str +='''</div>\n</div>\n'''
#     div_str += '''</div>\n</div>\n</div>\n'''

# # div_str += '''</div>\n'''
# print(div_str)
# Out:
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_acolyte" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Acolyte</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Divine Doctrine<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_acolyte_divine_doctrine" /><div class="talent-rollbox">
# <p>You follow set of principles in your belief system or religious practice, referred to as your Divine Doctrine.  Each Divine Doctrine consists of <em>Virtues</em>, <em>Taboos</em>, and <em>Domains</em>.<br>When you act against your Virtues or engage in a Taboo, reduce your Concordance by 1.<br>Select two items from the list below to be your Virtues and two items to be your Taboos:<br><em>Temperance, Indulgence, Avarice, Charity, Humility, Compassion, Wrath, Courage, Deceipt, Justice, Loyalty, Honesty . . .</em><br>Select 2 Effect Skills from the list below to be your Domain:<br><em>Bellor, Inferno, Lux, Mori, Nox, Ordi, Rime, Tempest, Vivus</em><br>Commitment to your Divine Doctrine lets you access <a href='/no1_system/characters/powers#Rites'>Rites</a>.  If one your Rite's result set contains a 1, reduce your Concordance by 1.<br>If you attempt to use a Rite when you Concordance is below 0, add 1 Hazard die to the roll for each point your Concordance is below 0.<br></p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Divine Doctrine
#         --Effect|You follow set of principles in your belief system or religious practice, referred to as your Divine Doctrine.  Each Divine Doctrine consists of <em>Virtues</em>, <em>Taboos</em>, and <em>Domains</em>.<br>When you act against your Virtues or engage in a Taboo, reduce your Concordance by 1.<br>Select two items from the list below to be your Virtues and two items to be your Taboos:<br><em>Temperance, Indulgence, Avarice, Charity, Humility, Compassion, Wrath, Courage, Deceipt, Justice, Loyalty, Honesty . . .</em><br>Select 2 Effect Skills from the list below to be your Domain:<br><em>Bellor, Inferno, Lux, Mori, Nox, Ordi, Rime, Tempest, Vivus</em><br>Commitment to your Divine Doctrine lets you access <a href='/no1_system/characters/powers#Rites'>Rites</a>.  If one your Rite's result set contains a 1, reduce your Concordance by 1.<br>If you attempt to use a Rite when you Concordance is below 0, add 1 Hazard die to the roll for each point your Concordance is below 0.<br>
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Composure (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_acolyte_composure_2" /><div class="talent-rollbox">
# <p>Increase your Composure Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Composure (2)
#         --Effect|Increase your Composure Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Domain (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_acolyte_domain_2_1" /><div class="talent-rollbox">
# <p>Increase one of your Domain Ranks to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Domain (2)
#         --Effect|Increase one of your Domain Ranks to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Domain (2)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_acolyte_domain_2_2" /><div class="talent-rollbox">
# <p>Increase one of your Domain Ranks to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Domain (2)
#         --Effect|Increase one of your Domain Ranks to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Domain (3)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_acolyte_domain_3" /><div class="talent-rollbox">
# <p>Increase one of your Domain Ranks to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Domain (3)
#         --Effect|Increase one of your Domain Ranks to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_aberrant" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Aberrant</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Aberration<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_aberrant_aberration" /><div class="talent-rollbox">
# <p>You have an innate ability that deviates from the normal.<br>When you gain this Talent, choose one of the following Effect Skill to be your Aberration:<br><em>Destroy, Intuit, Luck, Resist</em><br></p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Aberration
#         --Effect|You have an innate ability that deviates from the normal.<br>When you gain this Talent, choose one of the following Effect Skill to be your Aberration:<br><em>Destroy, Intuit, Luck, Resist</em><br>
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Aberration (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_aberrant_aberration_2" /><div class="talent-rollbox">
# <p>Increase your Abberation Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Aberration (2)
#         --Effect|Increase your Abberation Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Aberration (3)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_aberrant_aberration_3" /><div class="talent-rollbox">
# <p>Increase your Abberation Rank to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Aberration (3)
#         --Effect|Increase your Abberation Rank to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Uncanny Trait Increase<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_witch_uncanny_trait_increase" /><div class="talent-rollbox">
# <p>Increase you Uncanny Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Uncanny Trait Increase
#         --Effect|Increase you Uncanny Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Uncanny Trait Increase<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_aberrant_uncanny_trait_increase_1" /><div class="talent-rollbox">
# <p>Increase you Uncanny Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Uncanny Trait Increase
#         --Effect|Increase you Uncanny Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_mystic" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Mystic</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Seek Mysteries<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_mystic_seek_mysteries" /><div class="talent-rollbox">
# <p>You hold knowledge of the mysteries of the cosmos, bending secret powers to your will.  You gain access to <a href='/no1_system/characters/powers/arcana/'>Arcana</a>.<br>Intuit, Research, or use your Insight to unravel these mysteries further, gaining Hits in Arcana Ranks to invest in your Arcana.<br>You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 4 Actions.<br></p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Seek Mysteries
#         --Effect|You hold knowledge of the mysteries of the cosmos, bending secret powers to your will.  You gain access to <a href='/no1_system/characters/powers/arcana/'>Arcana</a>.<br>Intuit, Research, or use your Insight to unravel these mysteries further, gaining Hits in Arcana Ranks to invest in your Arcana.<br>You may use this Ability without spending an Action at the beginning of each Waypoint. If you use it during a Waypoint, it requires 4 Actions.<br>
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Strain Susceptibility<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_mystic_strain_susceptibility" /><div class="talent-rollbox">
# <p>Your pursuit of Arcana expose you to <strong>Strain</strong>.<br>When you roll one of your Affinity to invoke and Arcana, you gain Strain according to the result as soon as the Arcana effects resolve.<br>Strain accumulates over the course of your adventures, only reducing by 1d6 at the conclusion of a Waypoint.<br>You suffer the effects of Strain according to the <em>Straing Effects Table</em> table below.  Strain Effects are cumulative:<br><table style='width: 50%;'><thead><th>Strain</th><th>Effect</th></thead><tr><td>0-4</td><td>No effect</td></tr><tr><td>5-9</td><td>Fatigued 1</td></tr><tr><td>10-14</td><td>Confused</td></tr><tr><td>15-19</td><td>Fatigued 2</td></tr><tr><td>20-24</td><td>Vulnerable 3</td></tr><tr><td>25-29</td><td>Stunned 4</td></tr><tr><td>30+</td><td>Dead</td></tr></table><br></p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Strain Susceptibility
#         --Effect|Your pursuit of Arcana expose you to <strong>Strain</strong>.<br>When you roll one of your Affinity to invoke and Arcana, you gain Strain according to the result as soon as the Arcana effects resolve.<br>Strain accumulates over the course of your adventures, only reducing by 1d6 at the conclusion of a Waypoint.<br>You suffer the effects of Strain according to the <em>Straing Effects Table</em> table below.  Strain Effects are cumulative:<br><table style='width: 50%;'><thead><th>Strain</th><th>Effect</th></thead><tr><td>0-4</td><td>No effect</td></tr><tr><td>5-9</td><td>Fatigued 1</td></tr><tr><td>10-14</td><td>Confused</td></tr><tr><td>15-19</td><td>Fatigued 2</td></tr><tr><td>20-24</td><td>Vulnerable 3</td></tr><tr><td>25-29</td><td>Stunned 4</td></tr><tr><td>30+</td><td>Dead</td></tr></table><br>
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Insight (3)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_mystic_insight_3" /><div class="talent-rollbox">
# <p>Increase your Insight Rank to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Insight (3)
#         --Effect|Increase your Insight Rank to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Affinity (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_mystic_affinity_2_1" /><div class="talent-rollbox">
# <p>Increase one of your Affinity Ranks to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Affinity (2)
#         --Effect|Increase one of your Affinity Ranks to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Affinity (2)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_mystic_affinity_2_2" /><div class="talent-rollbox">
# <p>Increase one of your Affinity Ranks to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Affinity (2)
#         --Effect|Increase one of your Affinity Ranks to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Affinity (3)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_mystic_affinity_3" /><div class="talent-rollbox">
# <p>Increase one of your Affinity Ranks to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Affinity (3)
#         --Effect|Increase one of your Affinity Ranks to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Uncanny Trait Increase<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_mystic_uncanny_trait_increase" /><div class="talent-rollbox">
# <p>Increase you Uncanny Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Uncanny Trait Increase
#         --Effect|Increase you Uncanny Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_alchemist" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Alchemist</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Craft (1)<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_alchemist_craft_1" /><div class="talent-rollbox">
# <p>Increase your Craft Rank to 1 (d6).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Craft (1)
#         --Effect|Increase your Craft Rank to 1 (d6).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Craft (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_alchemist_craft_2" /><div class="talent-rollbox">
# <p>Increase your Craft Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Craft (2)
#         --Effect|Increase your Craft Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Craft (3)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_alchemist_craft_3" /><div class="talent-rollbox">
# <p>Increase your Craft Rank to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Craft (3)
#         --Effect|Increase your Craft Rank to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Practiced Applications<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_alchemist_practiced_applications" /><div class="talent-rollbox">
# <p>Once per turn you can use or apply a Concoction that requires a Shift to Use Your Equipment wihtout using a Shift.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Practiced Applications
#         --Effect|Once per turn you can use or apply a Concoction that requires a Shift to Use Your Equipment wihtout using a Shift.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_assassin" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Assassin</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Poison Expert<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_assassin_poison_expert" /><div class="talent-rollbox">
# <p>You are a master of using Poison, doubling the Poison's effects.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Poison Expert
#         --Effect|You are a master of using Poison, doubling the Poison's effects.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Unseen Shot<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_assassin_unseen_shot" /><div class="talent-rollbox">
# <p>You do not lose your Hidden rating when you Shoot a target while Hidden.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Unseen Shot
#         --Effect|You do not lose your Hidden rating when you Shoot a target while Hidden.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Fearsome Reputation<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_assassin_fearsome_reputation" /><div class="talent-rollbox">
# <p>Gain +3 Renown and +1 Enemies</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Fearsome Reputation
#         --Effect|Gain +3 Renown and +1 Enemies
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Dangerous Trait Increase<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_berserker_dangerous_trait_increase" /><div class="talent-rollbox">
# <p>Increase you Dangerous Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Dangerous Trait Increase
#         --Effect|Increase you Dangerous Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_athlete" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Athlete</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Sprinter<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_athlete_sprinter" /><div class="talent-rollbox">
# <p>When you Shift to move to an adjacent Zone, you may move an additional Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Sprinter
#         --Effect|When you Shift to move to an adjacent Zone, you may move an additional Zone.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Exert (2)<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_athlete_exert_2" /><div class="talent-rollbox">
# <p>Increase your Exert Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Exert (2)
#         --Effect|Increase your Exert Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Tumble (2)<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_athlete_tumble_2" /><div class="talent-rollbox">
# <p>Increase your Tumble rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Tumble (2)
#         --Effect|Increase your Tumble rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Exert (3)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_athlete_exert_3" /><div class="talent-rollbox">
# <p>Increase your Exert Rank to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Exert (3)
#         --Effect|Increase your Exert Rank to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Tumble (3)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_athlete_tumble_3" /><div class="talent-rollbox">
# <p>Increase your Tumble rank to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Tumble (3)
#         --Effect|Increase your Tumble rank to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Acrobat<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_athlete_acrobat" /><div class="talent-rollbox">
# <p>You are adept in acrobatics, adding +2 Bonus Hits any result sets using Tumble.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Acrobat
#         --Effect|You are adept in acrobatics, adding +2 Bonus Hits any result sets using Tumble.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Peak Conditioning<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_athlete_peak_conditioning" /><div class="talent-rollbox">
# <p>When you Recover, regain +2 Defenses.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Peak Conditioning
#         --Effect|When you Recover, regain +2 Defenses.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Deft Trait Increase<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_infiltrator_deft_trait_increase" /><div class="talent-rollbox">
# <p>Increase you Deft Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Deft Trait Increase
#         --Effect|Increase you Deft Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_tactician" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Tactician</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Tactical Assessment<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_tactician_tactical_assessment" /><div class="talent-rollbox">
# <p>You are adept at planning battles and missions.  You add +1d4 Bonus Hits when you use your Tactics to plan a mission.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Tactical Assessment
#         --Effect|You are adept at planning battles and missions.  You add +1d4 Bonus Hits when you use your Tactics to plan a mission.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Tactics (2)<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_tactician_tactics_2" /><div class="talent-rollbox">
# <p>Increase your Tactics Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Tactics (2)
#         --Effect|Increase your Tactics Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Tactics (3)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_tactician_tactics_3" /><div class="talent-rollbox">
# <p>Increase your Tactics Rank to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Tactics (3)
#         --Effect|Increase your Tactics Rank to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Tactics (4)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_tactician_tactics_4" /><div class="talent-rollbox">
# <p>Increase your Tactics Rank to 4 (d12).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Tactics (4)
#         --Effect|Increase your Tactics Rank to 4 (d12).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Lead (2)<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_tactician_lead_2" /><div class="talent-rollbox">
# <p>Increase your Lead Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Lead (2)
#         --Effect|Increase your Lead Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Decisive Action<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_tactician_decisive_action" /><div class="talent-rollbox">
# <p>You are adept take swift and decisive action to turn the tide.  If you Lead or use your Tactics on the first turn of a Timer, increase the Momentum by +2.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Decisive Action
#         --Effect|You are adept take swift and decisive action to turn the tide.  If you Lead or use your Tactics on the first turn of a Timer, increase the Momentum by +2.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Deft Trait Increase<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_spy_deft_trait_increase" /><div class="talent-rollbox">
# <p>Increase you Deft Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Deft Trait Increase
#         --Effect|Increase you Deft Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_heretic" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Heretic</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Divine Doctrine<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_heretic_divine_doctrine" /><div class="talent-rollbox">
# <p>You follow set of principles in your belief system or religious practice, referred to as your Divine Doctrine.  Each Divine Doctrine consists of <em>Virtues</em>, <em>Taboos</em>, and <em>Domains</em>.<br>When you act against your Virtues or engage in a Taboo, reduce your Concordance by 1.<br>Select two items from the list below to be your Virtues and two items to be your Taboos:<br><em>Temperance, Indulgence, Avarice, Charity, Humility, Compassion, Wrath, Courage, Deceipt, Justice, Loyalty, Honesty . . .</em><br>Select 2 Effect Skills from the list below to be your Domain:<br><em>Bellor, Inferno, Lux, Mori, Nox, Ordi, Rime, Tempest, Vivus</em><br>Commitment to your Divine Doctrine lets you access <a href='/no1_system/characters/powers#Rites'>Rites</a>.  If one your Rite's result set contains a 1, reduce your Concordance by 1.<br>If you attempt to use a Rite when you Concordance is below 0, add 1 Hazard die to the roll for each point your Concordance is below 0.<br></p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Divine Doctrine
#         --Effect|You follow set of principles in your belief system or religious practice, referred to as your Divine Doctrine.  Each Divine Doctrine consists of <em>Virtues</em>, <em>Taboos</em>, and <em>Domains</em>.<br>When you act against your Virtues or engage in a Taboo, reduce your Concordance by 1.<br>Select two items from the list below to be your Virtues and two items to be your Taboos:<br><em>Temperance, Indulgence, Avarice, Charity, Humility, Compassion, Wrath, Courage, Deceipt, Justice, Loyalty, Honesty . . .</em><br>Select 2 Effect Skills from the list below to be your Domain:<br><em>Bellor, Inferno, Lux, Mori, Nox, Ordi, Rime, Tempest, Vivus</em><br>Commitment to your Divine Doctrine lets you access <a href='/no1_system/characters/powers#Rites'>Rites</a>.  If one your Rite's result set contains a 1, reduce your Concordance by 1.<br>If you attempt to use a Rite when you Concordance is below 0, add 1 Hazard die to the roll for each point your Concordance is below 0.<br>
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Unorthodox Doctrine<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_heretic_unorthodox_doctrine" /><div class="talent-rollbox">
# <p>Select 1 additional Effect Skill from the list below to add to your Domain:<br>Bellor, Inferno, Lux, Mori, Nox, Ordi, Rime, Tempest, Vivus</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Unorthodox Doctrine
#         --Effect|Select 1 additional Effect Skill from the list below to add to your Domain:<br>Bellor, Inferno, Lux, Mori, Nox, Ordi, Rime, Tempest, Vivus
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Heretical Knowledge<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_heretic_heretical_knowledge" /><div class="talent-rollbox">
# <p>Increase your Cosmology or Theology Ranks to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Heretical Knowledge
#         --Effect|Increase your Cosmology or Theology Ranks to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_berserker" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Berserker</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Exert (2)<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_berserker_exert_2" /><div class="talent-rollbox">
# <p>Increase your Exert Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Exert (2)
#         --Effect|Increase your Exert Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Indomitable Rage<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_berserker_indomitable_rage" /><div class="talent-rollbox">
# <p>While you are in a Rage, you automatically regain +1 point to your Primary Defense at the beginning of your turn and you are immune to being Afraid.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Indomitable Rage
#         --Effect|While you are in a Rage, you automatically regain +1 point to your Primary Defense at the beginning of your turn and you are immune to being Afraid.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Exert (3)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_berserker_exert_3" /><div class="talent-rollbox">
# <p>Increase your Exert Rank to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Exert (3)
#         --Effect|Increase your Exert Rank to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Dangerous Trait Increase<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_soldier_dangerous_trait_increase" /><div class="talent-rollbox">
# <p>Increase you Dangerous Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Dangerous Trait Increase
#         --Effect|Increase you Dangerous Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_black belt" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Black Belt</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Martial Arts (3)<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_black belt_martial_arts_3" /><div class="talent-rollbox">
# <p>Increase your Martial Arts Rank to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Martial Arts (3)
#         --Effect|Increase your Martial Arts Rank to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Martial Arts (4)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_black belt_martial_arts_4" /><div class="talent-rollbox">
# <p>Increase your Martial Arts Rank to 4 (d12).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Martial Arts (4)
#         --Effect|Increase your Martial Arts Rank to 4 (d12).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Dangerous Trait Increase<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_reaver_dangerous_trait_increase" /><div class="talent-rollbox">
# <p>Increase you Dangerous Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Dangerous Trait Increase
#         --Effect|Increase you Dangerous Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_bounty hunter" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Bounty Hunter</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Implements (1)<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_bounty hunter_implements_1" /><div class="talent-rollbox">
# <p>Increase your Implements Rank to 1 (d6).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Implements (1)
#         --Effect|Increase your Implements Rank to 1 (d6).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Implements (2)<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_bounty hunter_implements_2" /><div class="talent-rollbox">
# <p>Increase your Implements Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Implements (2)
#         --Effect|Increase your Implements Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Survival (3)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_bounty hunter_survival_3" /><div class="talent-rollbox">
# <p>Increase your Survival Rank to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Survival (3)
#         --Effect|Increase your Survival Rank to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Insight (2)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_bounty hunter_insight_2" /><div class="talent-rollbox">
# <p>Increase your Insight Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Insight (2)
#         --Effect|Increase your Insight Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Streetwise (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_bounty hunter_streetwise_2" /><div class="talent-rollbox">
# <p>Increase your Streetwise Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Streetwise (2)
#         --Effect|Increase your Streetwise Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">. . .A Complicated Profession.<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_bounty hunter__a_complicated_profession" /><div class="talent-rollbox">
# <p>Gain +2 Enemies and either +1 Renown or +3 Wealth.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - . . .A Complicated Profession.
#         --Effect|Gain +2 Enemies and either +1 Renown or +3 Wealth.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Intimidate (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_bounty hunter_intimidate_2" /><div class="talent-rollbox">
# <p>Increase your Intimidate Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Intimidate (2)
#         --Effect|Increase your Intimidate Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_brute" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Brute</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Exert (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_brute_exert_2" /><div class="talent-rollbox">
# <p>Increase your Exert Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Exert (2)
#         --Effect|Increase your Exert Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Intimidate (2)<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_brute_intimidate_2" /><div class="talent-rollbox">
# <p>Increase your Intimidate Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Intimidate (2)
#         --Effect|Increase your Intimidate Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Strike (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_brute_strike_2" /><div class="talent-rollbox">
# <p>Increase your Strike Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Strike (2)
#         --Effect|Increase your Strike Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Dangerous Trait Increase<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_zealot_" /><div class="talent-rollbox">
# <p>Increase you Dangerous Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Dangerous Trait Increase
#         --Effect|Increase you Dangerous Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_channeler" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Channeler</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Affinity (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_channeler_affinity_2_1" /><div class="talent-rollbox">
# <p>Increase one of your Affinity Ranks to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Affinity (2)
#         --Effect|Increase one of your Affinity Ranks to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Composure (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_channeler_affinity_2_2" /><div class="talent-rollbox">
# <p>Increase your Composure Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Composure (2)
#         --Effect|Increase your Composure Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Endure (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_channeler_composure_2" /><div class="talent-rollbox">
# <p>Increase your Endure Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Endure (2)
#         --Effect|Increase your Endure Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Focus (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_channeler_endure_2" /><div class="talent-rollbox">
# <p>Increase your Focus Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Focus (2)
#         --Effect|Increase your Focus Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Affinity (2)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_channeler_focus_2" /><div class="talent-rollbox">
# <p>Increase one of your Affinity Ranks to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Affinity (2)
#         --Effect|Increase one of your Affinity Ranks to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Affinity (3)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_channeler_affinity_3" /><div class="talent-rollbox">
# <p>Increase one of your Affinity Ranks to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Affinity (3)
#         --Effect|Increase one of your Affinity Ranks to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_conduit" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Conduit</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Bonded Essence<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_conduit_bonded_essence" /><div class="talent-rollbox">
# <p>When you gain this Talent, select 1 Effect Skill from the list below to be an <em>Affinity</em> allowing you to further empower your Spells with Skill Talents:<br><em>Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus</em><br>Your Essence is innately bound to this Affinity, allowing you to manifest its effects into reality by using Marvels.<br></p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Bonded Essence
#         --Effect|When you gain this Talent, select 1 Effect Skill from the list below to be an <em>Affinity</em> allowing you to further empower your Spells with Skill Talents:<br><em>Aether, Bellor, Inferno, Lux, Mori, Nihil, Nox, Ordi, Rime, Squall, Tempest, Torrent, Vivus</em><br>Your Essence is innately bound to this Affinity, allowing you to manifest its effects into reality by using Marvels.<br>
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Affinity (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_conduit_affinity_2" /><div class="talent-rollbox">
# <p>Increase one of your Affinity Ranks to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Affinity (2)
#         --Effect|Increase one of your Affinity Ranks to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# ...
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Swordsman
#         --Effect|You are an expert Swordsman, granting you access to <em>Sworldplay</em> talents when using a gear with the <em>Sword</em> Keyword.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Axeman<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_weapon master_quick_draw" /><div class="talent-rollbox">
# <p>You are an expert with Axes, granting you access to <em>Hewer</em> talents when using a gear with the <em>Axe</em> Keyword..</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Axeman
#         --Effect|You are an expert with Axes, granting you access to <em>Hewer</em> talents when using a gear with the <em>Axe</em> Keyword..
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Cudgeler<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_weapon master_strike_3" /><div class="talent-rollbox">
# <p>You are an expert Maces, granting you access to <em>Crusher</em> talents when using a gear with the <em>Mace</em> Keyword.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Cudgeler
#         --Effect|You are an expert Maces, granting you access to <em>Crusher</em> talents when using a gear with the <em>Mace</em> Keyword.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Polearm Expert<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_weapon master_swordsman" /><div class="talent-rollbox">
# <p>You are an expert with Polearms, granting you access to <em>Poledance</em> talents when using Gear with the <em>Polearm</em> Keyword.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Polearm Expert
#         --Effect|You are an expert with Polearms, granting you access to <em>Poledance</em> talents when using Gear with the <em>Polearm</em> Keyword.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Dual Wielder<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_weapon master_axeman" /><div class="talent-rollbox">
# <p>You are an expert at using two weapons at once, granting you access to <em>Niten</em> talents when using two Weapon Gear at the same time.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Dual Wielder
#         --Effect|You are an expert at using two weapons at once, granting you access to <em>Niten</em> talents when using two Weapon Gear at the same time.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Strike (4)<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_weapon master_cudgeler" /><div class="talent-rollbox">
# <p>Increase your Strike Rank to 4 (d12).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Strike (4)
#         --Effect|Increase your Strike Rank to 4 (d12).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Dangerous Trait Increase<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_weapon master_wakigamae" /><div class="talent-rollbox">
# <p>Increase you Dangerous Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Dangerous Trait Increase
#         --Effect|Increase you Dangerous Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_coutier" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Coutier</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Savvy Trait Increase<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_tactician_deft_trait_increase" /><div class="talent-rollbox">
# <p>Increase you Savvy Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Savvy Trait Increase
#         --Effect|Increase you Savvy Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_balladeer" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Balladeer</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Practiced Trouper<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_mage_savvy_trait_increase" /><div class="talent-rollbox">
# <p>You can Craft to recite an Epic.<br>If you lose focus on an Ongoing Epic before completing its final verse, choose one:<ul><li>Lose 1 Renown</li><li>Decrease the Momentum by -2</li></ul><br></p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Practiced Trouper
#         --Effect|You can Craft to recite an Epic.<br>If you lose focus on an Ongoing Epic before completing its final verse, choose one:<ul><li>Lose 1 Renown</li><li>Decrease the Momentum by -2</li></ul><br>
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Consummate Performer<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_detective_savvy_trait_increase" /><div class="talent-rollbox">
# <p>You are unshakable in your performances, allowing you to use Focus or Composure to Maintain Focus on your Ongoing Epics.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Consummate Performer
#         --Effect|You are unshakable in your performances, allowing you to use Focus or Composure to Maintain Focus on your Ongoing Epics.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Savvy Trait Increase<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_spy_savvy_trait_increase" /><div class="talent-rollbox">
# <p>Increase you Savvy Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Savvy Trait Increase
#         --Effect|Increase you Savvy Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Lyricist<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_balladeer_practiced_trouper" /><div class="talent-rollbox">
# <p>You have honed your craft in reciting Ballads.  You add +1 Bonus Hits to the result set when you Craft and Epic with the Ballad keyword.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Lyricist
#         --Effect|You have honed your craft in reciting Ballads.  You add +1 Bonus Hits to the result set when you Craft and Epic with the Ballad keyword.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Craft (2)<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_balladeer_consummate_performer" /><div class="talent-rollbox">
# <p>Increase your Craft Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Craft (2)
#         --Effect|Increase your Craft Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Composure (2)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_balladeer_savvy_trait_increase" /><div class="talent-rollbox">
# <p>Increase your Composure Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Composure (2)
#         --Effect|Increase your Composure Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Composure (3)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_balladeer_lyricist" /><div class="talent-rollbox">
# <p>Increase your Composure Rank to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Composure (3)
#         --Effect|Increase your Composure Rank to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Persuade (2)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_balladeer_craft_2" /><div class="talent-rollbox">
# <p>Increase your Persuade Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Persuade (2)
#         --Effect|Increase your Persuade Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Tavern Busker<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_balladeer_composure_2" /><div class="talent-rollbox">
# <p>Increase your Streetwise Rank to 2 (d8) and your Persuasion Rank to 2 (d8).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Tavern Busker
#         --Effect|Increase your Streetwise Rank to 2 (d8) and your Persuasion Rank to 2 (d8).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Paid Regular<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_balladeer_composure_3" /><div class="talent-rollbox">
# <p>Increase your Streetwise Rank to 3 (d10) and your Persuasion Rank to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Paid Regular
#         --Effect|Increase your Streetwise Rank to 3 (d10) and your Persuasion Rank to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Craft (3)<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_balladeer_persuade_2" /><div class="talent-rollbox">
# <p>Increase your Craft Rank to 3 (d10).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Craft (3)
#         --Effect|Increase your Craft Rank to 3 (d10).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Craft (4)<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_balladeer_tavern_busker" /><div class="talent-rollbox">
# <p>Increase your Craft Rank to 4 (d12).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Craft (4)
#         --Effect|Increase your Craft Rank to 4 (d12).
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Established Performer<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_balladeer_paid_regular" /><div class="talent-rollbox">
# <p>Gain +3 Wealth.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Established Performer
#         --Effect|Gain +3 Wealth.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_samurai" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Samurai</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Steady Trait Increase<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_tank_steady_trait_increase" /><div class="talent-rollbox">
# <p>Increase you Steady Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Steady Trait Increase
#         --Effect|Increase you Steady Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_healer" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Healer</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Steady Trait Increase<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_priest_steady_trait_increase" /><div class="talent-rollbox">
# <p>Increase you Steady Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Steady Trait Increase
#         --Effect|Increase you Steady Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_seer" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Seer</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Uncanny Trait Increase<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_ranger_steady_trait_increase" /><div class="talent-rollbox">
# <p>Increase you Uncanny Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Uncanny Trait Increase
#         --Effect|Increase you Uncanny Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_adept" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Adept</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Uncanny Trait Increase<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_adept_uncanny_trait_increase" /><div class="talent-rollbox">
# <p>Increase you Uncanny Trait rating by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Uncanny Trait Increase
#         --Effect|Increase you Uncanny Trait rating by +1.
#         --format|staticcheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
type='Static'
talents = df_talents[(df_talents['type']==type) & (df_talents['name'] != '') & (df_talents['tree'] != '')].copy()
div_str = ''
for p in talents['tree'].unique():
    tals = talents[talents['tree']==p]
    div_str += '''<input class="sheet-training-ranks" type="hidden" name="attr_training_rank_''' + p.lower() + '''" step="1" value="0" min="0" max="20" />\n<div class="sheet-training-talents">\n<div class="grid-container-talents">\n<h4 class="grid-talents-label" style="margin-bottom:4px;">''' + p + '''</h4>\n<div class="grid-container-talents">\n'''
    for i, tal in tals.iterrows():
        div_str += '''<div class="grid-item-talents">\n'''
        div_str +='''<div>''' + tal['name'] + '''</div>\n<div>Rank ''' + str(tal['rank']) + '''</div>\n<div><details>\n<summary>&#10010;</summary>\n''' + tal['effect'] + '''\n</details>\n</div>\n<div>\n<input type="checkbox" name="''' + tal['attr_tal_nm'] + '''" />\n<div class="talent-rollbox">\n'''
        if len(tal['str_pcard']) > 0:
            for p in tal['str_pcard']:
                skill_button_nm = 'Show' #p[p.find('skill_')+6:p.find('--Result Set')-6].replace('_', ' ').title()
                div_str +='''<button class="txt-btn" type="roll" value="''' + p +'''">\n''' + skill_button_nm + '''\n</button>\n'''
        else:
            div_str +='''<button class="txt-btn" type="roll" value="!power {{
        --name|@{character_name} - ''' + tal['name'] + '''
        --Effect|''' + tal['effect'] + '''
        --format|staticcheck
        }}">\nShow\n</button>\n'''
        div_str +='''</div>\n</div>\n</div>\n'''
    div_str += '''</div>\n</div>\n</div>\n'''

# %%
f = open('static_training_talents.html', 'w')
f.write(div_str)
f.close()

# %%
tals = df_talents[(df_talents['type']=='Ability') & (df_talents['name'] != '') & (df_talents['tree'] != '')].copy()
tals.groupby(['tree'])['name'].count()
# Out:
# tree
# Acolyte            1
# Alchemist          1
# Archmage           1
# Assassin           4
# Athlete            1
# Beastmaster        4
# Berserker          1
# Black Belt         1
# Bounty Hunter      5
# Brute              4
# Channeler          1
# Conduit            2
# Corsair            7
# Courtier           7
# Defender           2
# Detective          4
# Diabolist          3
# Diplomat           4
# Druid              3
# Elementalist       2
# Grandmaster        1
# Healer             1
# Heretic            5
# Hunter             1
# Infiltrator        3
# Knight             2
# Mage               1
# Magic-User         2
# Marksman           5
# Martial Artist     1
# Medic              6
# Mystic             1
# Necromancer        4
# Nexus              1
# Overseer           3
# Petitioner         4
# Priest             1
# Probabilist        5
# Psion              1
# Pugilist           8
# Reaver             2
# Scholar            3
# Scoundrel          2
# Scout              3
# Seer              10
# Shaman             1
# Shifter            1
# Shinobi            8
# Shugenja           1
# Skald              1
# Soldier            2
# Spy                6
# Tactician          3
# Tank               1
# Templar            1
# Thief              1
# Transmuter         1
# Weapon Master     13
# Witch              2
# Wrestler           2
# Name: name, dtype: int64

# %%
# type='Trigger'
# talents = df_talents[(df_talents['type']==type) & (df_talents['name'] != '') & (df_talents['tree'] != '')].copy()
# div_str = ''
# for p in talents['tree'].unique():
#     tals = talents[talents['tree']==p]
#     div_str += '''<div class="grid-container-talents">\n<input class="sheet-training-ranks" type="hidden" name="attr_training_rank_''' + p.lower() + '''" step="1" value="0" min="0" max="20" />\n<div class="sheet-training-talents">\n<h4 class="grid-talents-label" style="margin-bottom:4px;">''' + p + '''</h4>\n<div="grid-container-talents">\n'''
#     # tals = t_type[t_type['tree']==p]
#     for index, tal in tals.iterrows():
#         div_str += '''<div class="grid-item-talents">\n''' 
#         div_str +='''<label style="font-size:12pt;">''' + tal['name'] + '''<br><span style="font-size:8pt;">Rank ''' + str(tal['rank']) + '''</span></label>\n<input type="checkbox" name="''' + tal['attr_tal_nm'] + '''" /><div class="talent-rollbox">\n<p>''' + tal['effect'] + '''</p>\n'''
#         if len(tal['str_pcard']) > 0:
#             for p in tal['str_pcard']:
#                 skill_button_nm = p[p.find('skill_')+6:p.find('--Result Set')-6].replace('_', ' ').title()
#                 div_str +='''<button class="skill-button" type="roll" value="''' + p +'''">\n''' + skill_button_nm + '''\n</button>\n'''
#         else:
#             div_str +='''<button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - ''' + tal['name'] + '''
#         --Effect|''' + tal['effect'] + '''
#         --format|''' + type.lower() + '''check
#         }}">\n</button>\n'''
#         div_str +='''</div>\n</div>\n'''
#     div_str += '''</div>\n</div>\n</div>\n'''

# # div_str += '''</div>\n'''
# print(div_str)
# Out:
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_aberrant" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Aberrant</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Break the Mold<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_aberrant_break_the_mold" /><div class="talent-rollbox">
# <p>When you score 3+ Hits with your Aberration's Effect Triggers, increase the Momentum by +2.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Break the Mold
#         --Effect|When you score 3+ Hits with your Aberration's Effect Triggers, increase the Momentum by +2.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Living Anomaly<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_aberrant_living_anomaly" /><div class="talent-rollbox">
# <p>When you score 5+ Hits with your Aberration's Effect Triggers, you may immediately use a different Effect Trigger from your Aberration.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Living Anomaly
#         --Effect|When you score 5+ Hits with your Aberration's Effect Triggers, you may immediately use a different Effect Trigger from your Aberration.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_alchemist" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Alchemist</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Dangerous Distillation<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_alchemist_dangerous_distillation" /><div class="talent-rollbox">
# <p>When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Dangerous Distillation
#     --Effect|When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_craft}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_craft}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Craft
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Accomplished Alchemist<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_alchemist_accomplished_alchemist" /><div class="talent-rollbox">
# <p>When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Accomplished Alchemist
#     --Effect|When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_craft}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_craft}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Craft
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_assassin" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Assassin</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Sneak Attack<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_assassin_sneak_attack" /><div class="talent-rollbox">
# <p>When you score Hits against a target while Hidden, add +1d6 bonus Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Sneak Attack
#         --Effect|When you score Hits against a target while Hidden, add +1d6 bonus Hits to the result set.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Death from the Shadows<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_assassin_death_from_the_shadows" /><div class="talent-rollbox">
# <p>When you Strike or Shoot your target to death, you may immediately use your Stealth without using a Shift.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Death from the Shadows
#     --Effect|When you Strike or Shoot your target to death, you may immediately use your Stealth without using a Shift.
#     --Rank| d@{skill_shoot}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_shoot}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Shoot
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Death from the Shadows
#     --Effect|When you Strike or Shoot your target to death, you may immediately use your Stealth without using a Shift.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Strike
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Death from the Shadows
#     --Effect|When you Strike or Shoot your target to death, you may immediately use your Stealth without using a Shift.
#     --Rank| d@{skill_stealth}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_stealth}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Stealth
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Ambush Expert<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_assassin_ambush_expert" /><div class="talent-rollbox">
# <p>When you make an Initiative Test in an Ambush, you may spend Momentum to increase Hits scored by X, where X is the number of Momentum spent.<br>If your team's total Initiative is 6+ greater than your enemy's, the Initiative does not shift to the enemy during the first round of the encounter (1s still increase Entropy).</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Ambush Expert
#         --Effect|When you make an Initiative Test in an Ambush, you may spend Momentum to increase Hits scored by X, where X is the number of Momentum spent.<br>If your team's total Initiative is 6+ greater than your enemy's, the Initiative does not shift to the enemy during the first round of the encounter (1s still increase Entropy).
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Never Unnarmed<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_assassin_never_unnarmed" /><div class="talent-rollbox">
# <p>When you are being searched by someone attempting to disarm you of your weapons and implements, you may use Legerdemain to hide a dagger on your person is you sore 1+ Hits.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Never Unnarmed
#     --Effect|When you are being searched by someone attempting to disarm you of your weapons and implements, you may use Legerdemain to hide a dagger on your person is you sore 1+ Hits.
#     --Rank| d@{skill_legerdemain}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_legerdemain}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Legerdemain
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">At Home in the Shadows<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_assassin_at_home_in_the_shadows" /><div class="talent-rollbox">
# <p>When you Defy Danger to Hide! and score 2+ Hits, you can take an additional Shift this turn.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - At Home in the Shadows
#         --Effect|When you Defy Danger to Hide! and score 2+ Hits, you can take an additional Shift this turn.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">The Job's Not Done<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_assassin_the_jobs_not_done" /><div class="talent-rollbox">
# <p>When a target you have Marked for Death escapes, immediately spend 1 Momentum to gain Favor 1.  You can only use this favor to learn about the escaped target's wherabouts.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - The Job's Not Done
#         --Effect|When a target you have Marked for Death escapes, immediately spend 1 Momentum to gain Favor 1.  You can only use this favor to learn about the escaped target's wherabouts.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_athlete" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Athlete</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Freerunner<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_athlete_freerunner" /><div class="talent-rollbox">
# <p>When you Defy Danger using Parkour!, add +1d4 Bonus Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Freerunner
#         --Effect|When you Defy Danger using Parkour!, add +1d4 Bonus Hits to the result set.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_tactician" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Tactician</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Seize the Initiative<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_tactician_seize_the_initiative" /><div class="talent-rollbox">
# <p>When an enemy scores 1 or 0 Hits in their result set, your team regains the initiative.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Seize the Initiative
#         --Effect|When an enemy scores 1 or 0 Hits in their result set, your team regains the initiative.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Combat Reflexes<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_tactician_combat_reflexes" /><div class="talent-rollbox">
# <p>When a hostile target Shifts away from you in melee combat, they add an additional Hazard die to their next roll.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Combat Reflexes
#         --Effect|When a hostile target Shifts away from you in melee combat, they add an additional Hazard die to their next roll.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Tactical Mastermind<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_tactician_tactical_mastermind" /><div class="talent-rollbox">
# <p>When you use your Tactics, adding +1 Bonus Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Tactical Mastermind
#     --Effect|When you use your Tactics, adding +1 Bonus Hits to the result set.
#     --Rank| d@{skill_tactics}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_tactics}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Tactics
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_heretic" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Heretic</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Divine Rebuke<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_heretic_divine_rebuke" /><div class="talent-rollbox">
# <p>When you suffer Hits from an attack in your Current or and Adjacent Zone, you may spend 1 Concordance to deal +1d4 Bonus Hits to the attacking target.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Divine Rebuke
#         --Effect|When you suffer Hits from an attack in your Current or and Adjacent Zone, you may spend 1 Concordance to deal +1d4 Bonus Hits to the attacking target.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Divine Defiance<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_heretic_divine_defiance" /><div class="talent-rollbox">
# <p>When you suffer Hits from a Power effects, you may spend 1 Concordance to regain +1d6 to your Primary Defense.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Divine Defiance
#         --Effect|When you suffer Hits from a Power effects, you may spend 1 Concordance to regain +1d6 to your Primary Defense.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Heretic's Shield<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_heretic_heretics_shield" /><div class="talent-rollbox">
# <p>When you suffer Hits from an attack you can see, you can spend 1 Concordance to reduce the Hits by -1d4.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Heretic's Shield
#         --Effect|When you suffer Hits from an attack you can see, you can spend 1 Concordance to reduce the Hits by -1d4.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Sacred Disruption<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_heretic_sacred_disruption" /><div class="talent-rollbox">
# <p>When a target you can see uses a Power, you can spend 1 Concordance to use one Effect Skill in your Domain.  If you score more Hits than the hostile Power's Hits, the Power does not take effect.<br>Then, you and the hostile target are engaged in a Contest.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Sacred Disruption
#         --Effect|When a target you can see uses a Power, you can spend 1 Concordance to use one Effect Skill in your Domain.  If you score more Hits than the hostile Power's Hits, the Power does not take effect.<br>Then, you and the hostile target are engaged in a Contest.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Divine Reversal<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_heretic_divine_reversal" /><div class="talent-rollbox">
# <p>When you successfully use your Sacred Disruption, you deal Hits in your Domain Skill result set to the target.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Divine Reversal
#         --Effect|When you successfully use your Sacred Disruption, you deal Hits in your Domain Skill result set to the target.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Heretic's Wrath<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_heretic_heretics_wrath" /><div class="talent-rollbox">
# <p>When you use your Profane Smite and score 3+ Hits, your target gain Blind.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Heretic's Wrath
#         --Effect|When you use your Profane Smite and score 3+ Hits, your target gain Blind.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_berserker" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Berserker</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Frenzy<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_berserker_frenzy" /><div class="talent-rollbox">
# <p>When you are in a Rage and score 4+ Hits in melee combat, increase your Rage Aura by +2.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Frenzy
#         --Effect|When you are in a Rage and score 4+ Hits in melee combat, increase your Rage Aura by +2.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Undying Rage<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_berserker_undying_rage" /><div class="talent-rollbox">
# <p>When you are in a Rage and use the Recover Acation, you may regain +3 to your Grit and decrease your Dying rating by -1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Undying Rage
#         --Effect|When you are in a Rage and use the Recover Acation, you may regain +3 to your Grit and decrease your Dying rating by -1.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Vicious Rage<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_berserker_vicious_rage" /><div class="talent-rollbox">
# <p>When  you are in a Rage and score 5+ Hits using Grapple, Martial Arts, Strike, or Throw, you may reduce your Rage Aura by -1 and your target gian Vulnerable 1.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Vicious Rage
#     --Effect|When  you are in a Rage and score 5+ Hits using Grapple, Martial Arts, Strike, or Throw, you may reduce your Rage Aura by -1 and your target gian Vulnerable 1.
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Grapple
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Vicious Rage
#     --Effect|When  you are in a Rage and score 5+ Hits using Grapple, Martial Arts, Strike, or Throw, you may reduce your Rage Aura by -1 and your target gian Vulnerable 1.
#     --Rank| d@{skill_martial_arts}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_martial_arts}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Martial Arts
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Vicious Rage
#     --Effect|When  you are in a Rage and score 5+ Hits using Grapple, Martial Arts, Strike, or Throw, you may reduce your Rage Aura by -1 and your target gian Vulnerable 1.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Strike
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Vicious Rage
#     --Effect|When  you are in a Rage and score 5+ Hits using Grapple, Martial Arts, Strike, or Throw, you may reduce your Rage Aura by -1 and your target gian Vulnerable 1.
#     --Rank| d@{skill_throw}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_throw}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Throw
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Bloodlust<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_berserker_bloodlust" /><div class="talent-rollbox">
# <p>When you are in a Rage and suffer 2+ Hits from a melee attack, increase you Rage Aura by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Bloodlust
#         --Effect|When you are in a Rage and suffer 2+ Hits from a melee attack, increase you Rage Aura by +1.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_black belt" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Black Belt</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Flying Kick<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_black belt_flying_kick" /><div class="talent-rollbox">
# <p>When you Shift to Move into an Adjacent Zone and use your Martial Arts to attack your target, add +3 Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Flying Kick
#     --Effect|When you Shift to Move into an Adjacent Zone and use your Martial Arts to attack your target, add +3 Hits to the result set.
#     --Rank| d@{skill_martial_arts}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_martial_arts}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Martial Arts
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Cross Block<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_black belt_cross_block" /><div class="talent-rollbox">
# <p>When you are in a Defensive Stance and take 3+ Hits in melee combat from an attacker you can see, reduce the total hits by 1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Cross Block
#         --Effect|When you are in a Defensive Stance and take 3+ Hits in melee combat from an attacker you can see, reduce the total hits by 1.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Kansetsu Geri<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_black belt_kansetsu_geri" /><div class="talent-rollbox">
# <p>When you are in a Aggressive Stance and score 4+ Hits in melee combat, your target gains Vulnerable 2.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Kansetsu Geri
#         --Effect|When you are in a Aggressive Stance and score 4+ Hits in melee combat, your target gains Vulnerable 2.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Sound Mind, Sound Body<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_black belt_sound_mind_sound_body" /><div class="talent-rollbox">
# <p>When you use an Action to Recover Defenses, you may regain up to +1 Grit.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Sound Mind, Sound Body
#         --Effect|When you use an Action to Recover Defenses, you may regain up to +1 Grit.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_bounty hunter" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Bounty Hunter</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">It's A Dirty Job. . .<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_bounty hunter_its_a_dirty_job_" /><div class="talent-rollbox">
# <p>When you successfully apprehend a wanted target, gain +1 Renown or +2 Wealth.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - It's A Dirty Job. . .
#         --Effect|When you successfully apprehend a wanted target, gain +1 Renown or +2 Wealth.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">No Disintegrations<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_bounty hunter_no_disintegrations" /><div class="talent-rollbox">
# <p>Strike one target in your Current Zone or Shoot one target in your Current or an Adjacent Zone aiming to subdue them.<br>On 4+ Hits, your target gains Unconscious 1.  Otherwise target gains Stunned 4.<br></p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - No Disintegrations
#     --Effect|Strike one target in your Current Zone or Shoot one target in your Current or an Adjacent Zone aiming to subdue them.^^On 4+ Hits, your target gains Unconscious 1.  Otherwise target gains Stunned 4.^^
#     --Rank| d@{skill_shoot}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_shoot}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Shoot
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - No Disintegrations
#     --Effect|Strike one target in your Current Zone or Shoot one target in your Current or an Adjacent Zone aiming to subdue them.^^On 4+ Hits, your target gains Unconscious 1.  Otherwise target gains Stunned 4.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Strike
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_brute" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Brute</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">You're Next<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_brute_youre_next" /><div class="talent-rollbox">
# <p>When you Strike your target to death, you can Initiate a Contest with one hostile target in your Current Zone wihtout using a Shift.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - You're Next
#     --Effect|When you Strike your target to death, you can Initiate a Contest with one hostile target in your Current Zone wihtout using a Shift.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Strike
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Grisly Slaughter<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_brute_grisly_slaughter" /><div class="talent-rollbox">
# <p>When you Strike your target to death, describe the gruesome end you delivered.  Then all hostile targets in your Current Zone with Nerve less than Hits become Afraid of you.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Grisly Slaughter
#     --Effect|When you Strike your target to death, describe the gruesome end you delivered.  Then all hostile targets in your Current Zone with Nerve less than Hits become Afraid of you.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Strike
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_channeler" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Channeler</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Recoil<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_channeler_recoil" /><div class="talent-rollbox">
# <p>If a Technique you use has a 1 in the result set, all targets within your Current Zone sustain Hits from the Techniques's effect equal to its lowest Threshold.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Recoil
#         --Effect|If a Technique you use has a 1 in the result set, all targets within your Current Zone sustain Hits from the Techniques's effect equal to its lowest Threshold.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_corsair" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Corsair</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Mariner's Endurance<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_corsair_mariners_endurance" /><div class="talent-rollbox">
# <p>When you Recover to reduce Fatigue, recover any remaining Hits to Vigor once your Fatigue rating is 0.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Mariner's Endurance
#         --Effect|When you Recover to reduce Fatigue, recover any remaining Hits to Vigor once your Fatigue rating is 0.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_courtier" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Courtier</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Secrets Unveiled<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_courtier_secrets_unveiled" /><div class="talent-rollbox">
# <p>When you use your Insight or Investigate a situation to uncover information that someone is trying to conceal, add +1d4 Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Secrets Unveiled
#     --Effect|When you use your Insight or Investigate a situation to uncover information that someone is trying to conceal, add +1d4 Hits to the result set.
#     --Rank| d@{skill_insight}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_insight}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Insight
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Secrets Unveiled
#     --Effect|When you use your Insight or Investigate a situation to uncover information that someone is trying to conceal, add +1d4 Hits to the result set.
#     --Rank| d@{skill_investigate}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_investigate}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Investigate
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Elegant Defense<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_courtier_elegant_defense" /><div class="talent-rollbox">
# <p>When you suffer Hits from a target you can see and your Nerve is above 0, spend 1 Nerve to reduce the total Hits by +2.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Elegant Defense
#         --Effect|When you suffer Hits from a target you can see and your Nerve is above 0, spend 1 Nerve to reduce the total Hits by +2.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Crisis Averted<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_courtier_crisis_averted" /><div class="talent-rollbox">
# <p>When you successfully diffuse a social situation in the benefit of you and your allies, gain +1 Renown.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Crisis Averted
#         --Effect|When you successfully diffuse a social situation in the benefit of you and your allies, gain +1 Renown.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Regal Bearing<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_courtier_regal_bearing" /><div class="talent-rollbox">
# <p>When you are engaged in a Contest and Persuade or Intimidate your opponent, add +2 Bonus Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Regal Bearing
#     --Effect|When you are engaged in a Contest and Persuade or Intimidate your opponent, add +2 Bonus Hits to the result set.
#     --Rank| d@{skill_intimidate}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_intimidate}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Intimidate
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Regal Bearing
#     --Effect|When you are engaged in a Contest and Persuade or Intimidate your opponent, add +2 Bonus Hits to the result set.
#     --Rank| d@{skill_persuade}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_persuade}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Persuade
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Flawless Etiquette<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_courtier_flawless_etiquette" /><div class="talent-rollbox">
# <p>When you are in a formal setting and Persuade a target, you may use a Savvy Trait reroll to reroll all dice instead of just 1s.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Flawless Etiquette
#     --Effect|When you are in a formal setting and Persuade a target, you may use a Savvy Trait reroll to reroll all dice instead of just 1s.
#     --Rank| d@{skill_persuade}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_persuade}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Persuade
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_defender" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Defender</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Harm's Way<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_defender_harms_way" /><div class="talent-rollbox">
# <p>When you protect an ally in your Current Zone and they are Hit by an attack you can see, you may redirect a number of Hits against that ally to yourself equal to the Defender Rank.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Harm's Way
#         --Effect|When you protect an ally in your Current Zone and they are Hit by an attack you can see, you may redirect a number of Hits against that ally to yourself equal to the Defender Rank.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Shake it off<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_defender_shake_it_off" /><div class="talent-rollbox">
# <p>When you Recover, regain +2 Defenses.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Shake it off
#         --Effect|When you Recover, regain +2 Defenses.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Get Behind Me<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_defender_get_behind_me" /><div class="talent-rollbox">
# <p>When you use a Shift to protect 1 ally in your Current Zone, your protect 2 allies instead.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Get Behind Me
#         --Effect|When you use a Shift to protect 1 ally in your Current Zone, your protect 2 allies instead.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_guardian" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Guardian</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Unshakable Defense<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_guardian_armor_expert_2" /><div class="talent-rollbox">
# <p>When you Focus to defend yourself in combat, ad +1d4 Bonus Hits to your Primary Defense.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Unshakable Defense
#     --Effect|When you Focus to defend yourself in combat, ad +1d4 Bonus Hits to your Primary Defense.
#     --Rank| d@{skill_focus}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_focus}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Focus
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Line of Fire<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_guardian_focus_4" /><div class="talent-rollbox">
# <p>When you protect an ally in your Current Zone and they are Hit by an attack you can see, you may redirect a number of Hits against that ally to yourself equal to the Guardian Rank.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Line of Fire
#         --Effect|When you protect an ally in your Current Zone and they are Hit by an attack you can see, you may redirect a number of Hits against that ally to yourself equal to the Guardian Rank.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">I can take it<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_guardian_line_of_fire" /><div class="talent-rollbox">
# <p>When you take more than 1 Hit from an effect, reduce the total Hits by -1.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - I can take it
#         --Effect|When you take more than 1 Hit from an effect, reduce the total Hits by -1.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Shake it off<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_guardian_i_can_take_it" /><div class="talent-rollbox">
# <p>When you Recover, regain +2 Defenses.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Shake it off
#         --Effect|When you Recover, regain +2 Defenses.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_detective" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Detective</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Heightened Awareness<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_detective_heightened_awareness" /><div class="talent-rollbox">
# <p>When you are the target of an Ambush and make an Initiative Test, add +1d4 Bonus Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Heightened Awareness
#         --Effect|When you are the target of an Ambush and make an Initiative Test, add +1d4 Bonus Hits to the result set.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_diplomat" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Diplomat</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Unflappable<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_diplomat_unflappable" /><div class="talent-rollbox">
# <p>When you Recover to regain Nerve, regain and additional +2 Bonus Hits.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Unflappable
#         --Effect|When you Recover to regain Nerve, regain and additional +2 Bonus Hits.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Steel Nerves<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_diplomat_steel_nerves" /><div class="talent-rollbox">
# <p>When you take 4+ Hits and Nerve is your Primary Defense, spend 4 Momentum to immediately regain 3 Nerve.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Steel Nerves
#         --Effect|When you take 4+ Hits and Nerve is your Primary Defense, spend 4 Momentum to immediately regain 3 Nerve.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_duelist" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Duelist</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Riposte<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_duelist_riposte" /><div class="talent-rollbox">
# <p>Counterattack an enemy Strike that just scored 0 Hits.  Deal 1d4 bonus Hits.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Riposte
#     --Effect|Counterattack an enemy Strike that just scored 0 Hits.  Deal 1d4 bonus Hits.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Strike
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Deadly Contestant<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_duelist_deadly_contestant" /><div class="talent-rollbox">
# <p>When you Strike a target while engaged in a Contest, add +2 Bonus Hits to the results set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Deadly Contestant
#     --Effect|When you Strike a target while engaged in a Contest, add +2 Bonus Hits to the results set.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Strike
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Draw Steel<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_duelist_draw_steel" /><div class="talent-rollbox">
# <p>When you Strike a target in the first round of a Contest, add +2 Bonus Hits to the results set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Draw Steel
#     --Effect|When you Strike a target in the first round of a Contest, add +2 Bonus Hits to the results set.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Strike
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Renowned Victor<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_duelist_renowned_victor" /><div class="talent-rollbox">
# <p>When you Strike your opponent to win a Contest, gain +1 Renown.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Renowned Victor
#     --Effect|When you Strike your opponent to win a Contest, gain +1 Renown.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Strike
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_healer" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Healer</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# ...
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Hide in Plain Sight<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_scout_swift_reflexes" /><div class="talent-rollbox">
# <p>When you use Stealth to avoid detection but get less than 3 Hits in the result set, you may spend 4 momentum to gain Hidden 5.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Hide in Plain Sight
#     --Effect|When you use Stealth to avoid detection but get less than 3 Hits in the result set, you may spend 4 momentum to gain Hidden 5.
#     --Rank| d@{skill_stealth}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_stealth}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Stealth
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Scout's Alertness<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_scout_hide_in_plain_sight" /><div class="talent-rollbox">
# <p>When you are the target of an Ambush and make an Initiative Test, add +1d4 Bonus Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Scout's Alertness
#         --Effect|When you are the target of an Ambush and make an Initiative Test, add +1d4 Bonus Hits to the result set.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_operator" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Operator</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Mounted Combatant<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_operator_quick_mount" /><div class="talent-rollbox">
# <p>When you Operate a mount (or vehicle) and Shift to Move, you may Strike or Shoot at an enemy as part of the Shift.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Mounted Combatant
#     --Effect|When you Operate a mount (or vehicle) and Shift to Move, you may Strike or Shoot at an enemy as part of the Shift.
#     --Rank| d@{skill_shoot}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_shoot}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Shoot
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Mounted Combatant
#     --Effect|When you Operate a mount (or vehicle) and Shift to Move, you may Strike or Shoot at an enemy as part of the Shift.
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Strike
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Mounted Combatant
#     --Effect|When you Operate a mount (or vehicle) and Shift to Move, you may Strike or Shoot at an enemy as part of the Shift.
#     --Rank| d@{skill_operate}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_operate}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Operate
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Outrider<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_operator_battleready" /><div class="talent-rollbox">
# <p>When you Operate a mount or vehicle and Shift to Move, you may move an additional Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Outrider
#     --Effect|When you Operate a mount or vehicle and Shift to Move, you may move an additional Zone.
#     --Rank| d@{skill_operate}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_operate}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Operate
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Mounted Navigator<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_operator_operate_3" /><div class="talent-rollbox">
# <p>When you Operate a mount (or vehicle) and Shift to Move, you may Navigate your way as part of the Shift.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Mounted Navigator
#     --Effect|When you Operate a mount (or vehicle) and Shift to Move, you may Navigate your way as part of the Shift.
#     --Rank| d@{skill_operate}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_operate}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Operate
# </button>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Mounted Navigator
#     --Effect|When you Operate a mount (or vehicle) and Shift to Move, you may Navigate your way as part of the Shift.
#     --Rank| d@{skill_navigate}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_navigate}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Navigate
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_witch" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Witch</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Hexcrafter<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_warlord_" /><div class="talent-rollbox">
# <p>When you Focus to Maintain Focus on your Ongoing effects, add +1d4 Bonus Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Hexcrafter
#     --Effect|When you Focus to Maintain Focus on your Ongoing effects, add +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_focus}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_focus}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Focus
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Not Just Yet, My Pet<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_witch_hexcrafter" /><div class="talent-rollbox">
# <p>When you can see your Beast Minion and it dies, spend 3 Grit to return it to life.</p>
# <button class="skill-button" type="roll" value="!power {{
#         --name|@{character_name} - Not Just Yet, My Pet
#         --Effect|When you can see your Beast Minion and it dies, spend 3 Grit to return it to life.
#         --format|triggercheck
#         }}">
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Dangerous Distillation<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_witch_not_just_yet_my_pet" /><div class="talent-rollbox">
# <p>When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Dangerous Distillation
#     --Effect|When you Craft to prepare Concoctions, add +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_craft}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_craft}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Craft
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Greater Familiar<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_witch_affinity_3" /><div class="talent-rollbox">
# <p>When you Persuade the spirits of the world to send you a Beast Minon, you may recruit a of cost 2 or less.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Greater Familiar
#     --Effect|When you Persuade the spirits of the world to send you a Beast Minon, you may recruit a of cost 2 or less.
#     --Rank| d@{skill_persuade}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_persuade}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Persuade
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Blood for Power<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_witch_craft_2" /><div class="talent-rollbox">
# <p>When you Focus to Maintain Focus on your Ongoing effects, spend X Grit to add X Bonus Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Blood for Power
#     --Effect|When you Focus to Maintain Focus on your Ongoing effects, spend X Grit to add X Bonus Hits to the result set.
#     --Rank| d@{skill_focus}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_focus}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Focus
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_wrestler" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Wrestler</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Sprawl<br><span style="font-size:8pt;">Rank 1</span></label>
# <input type="checkbox" name="attr_talent_witch_greater_familiar" /><div class="talent-rollbox">
# <p>When an opponet you can see tries to Grapple you, reduce Hits in their result set by -2.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Sprawl
#     --Effect|When an opponet you can see tries to Grapple you, reduce Hits in their result set by -2.
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Grapple
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">O Goshi<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_wrestler_suplex" /><div class="talent-rollbox">
# <p>When you have an opponent Grappled, you may reduce their Grappled rating by -1 to give them Vulnerable 2 and Prone.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - O Goshi
#     --Effect|When you have an opponent Grappled, you may reduce their Grappled rating by -1 to give them Vulnerable 2 and Prone.
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Grapple
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Off the Top Rope!<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_wrestler_chokeslam" /><div class="talent-rollbox">
# <p>When you Shift to Move into an Adjacent Zone and Grapple your target, add +2 Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Off the Top Rope!
#     --Effect|When you Shift to Move into an Adjacent Zone and Grapple your target, add +2 Hits to the result set.
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Grapple
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">At Home in the Clench<br><span style="font-size:8pt;">Rank 3</span></label>
# <input type="checkbox" name="attr_talent_wrestler_exert_2" /><div class="talent-rollbox">
# <p>When you have an target Grappled and use an Action to Recover, add +1d4 Bonus Hits to the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - At Home in the Clench
#     --Effect|When you have an target Grappled and use an Action to Recover, add +1d4 Bonus Hits to the result set.
#     --Rank| d@{skill_grapple}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_grapple}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Grapple
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_training_rank_weapon master" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Weapon Master</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Sapping Blow<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_weapon master_sundering_chop" /><div class="talent-rollbox">
# <p><h4 style='margin: 3px'>Crusher</h4><br>When you Strike one target in your Current Zone that is Vulnerable, the target gains Fatigued 1.<br></p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Sapping Blow
#     --Effect|**//Crusher//**^^^^When you Strike one target in your Current Zone that is Vulnerable, the target gains Fatigued 1.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Strike
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Jarring Blow<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_weapon master_fellers_hack" /><div class="talent-rollbox">
# <p><h4 style='margin: 3px'>Crusher</h4><br>When you Strike one target in your Current Zone that is Vulnerable, the target gains Stunned 2.<br></p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Jarring Blow
#     --Effect|**//Crusher//**^^^^When you Strike one target in your Current Zone that is Vulnerable, the target gains Stunned 2.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Strike
# </button>
# </div>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt;">Sinawali<br><span style="font-size:8pt;">Rank 2</span></label>
# <input type="checkbox" name="attr_talent_weapon master_make_space" /><div class="talent-rollbox">
# <p><h4 style='margin: 3px'>Niten</h4><br>When you Strike a target and score 3+ Hits, you may immediately use another Action to strike with your second weapon.<br></p>
# <button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - Sinawali
#     --Effect|**//Niten//**^^^^When you Strike a target and score 3+ Hits, you may immediately use another Action to strike with your second weapon.^^
#     --Rank| d@{skill_strike}
#     --Result Set|[[ [$talent|XPND] @{Cosm|challenge}d@{skill_strike}>@{Cosm|target}]]
#     --Hits|[^talent.ss]
#     --1s|[^talent.ones]
#     --format|triggercheck
#     }}">
# Strike
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
type='Trigger'
talents = df_talents[(df_talents['type']==type) & (df_talents['name'] != '') & (df_talents['tree'] != '')].copy()
div_str = ''
for p in talents['tree'].unique():
    tals = talents[talents['tree']==p]
    div_str += '''<input class="sheet-training-ranks" type="hidden" name="attr_training_rank_''' + p.lower() + '''" step="1" value="0" min="0" max="20" />\n<div class="sheet-training-talents">\n<div class="grid-container-talents">\n<h4 class="grid-talents-label" style="margin-bottom:4px;">''' + p + '''</h4>\n<div class="grid-container-talents">\n'''
    for i, tal in tals.iterrows():
        div_str += '''<div class="grid-item-talents">\n'''
        div_str +='''<div>''' + tal['name'] + '''</div>\n<div>Rank ''' + str(tal['rank']) + '''</div>\n<div><details>\n<summary>&#10010;</summary>\n''' + tal['effect'] + '''\n</details>\n</div>\n<div>\n<input type="checkbox" name="''' + tal['attr_tal_nm'] + '''" />\n<div class="talent-rollbox">\n'''
        if len(tal['str_pcard']) > 0:
            for p in tal['str_pcard']:
                skill_button_nm = 'Trigger' #p[p.find('skill_')+6:p.find('--Result Set')-6].replace('_', ' ').title()
                div_str +='''<button class="txt-btn" type="roll" value="''' + p +'''">\n''' + skill_button_nm + '''\n</button>\n'''
        else:
            div_str +='''<button class="txt-btn" type="roll" value="!power {{
        --name|@{character_name} - ''' + tal['name'] + '''
        --Effect|''' + tal['effect'] + '''
        --format|triggercheck
        }}">\Trigger\n</button>\n'''
        div_str +='''</div>\n</div>\n</div>\n'''
    div_str += '''</div>\n</div>\n</div>\n'''

# %%
f = open('triggers_training_talents.html', 'w')
f.write(div_str)
f.close()

# %%
# the HTML below works.  labesl and checkboxes need to be adjacent to the effect div.  current the CSS style has display: none for not(:checked) AND displat: Block for :checked
'''
<!DOCTYPE html>
<html>
<head>
<title>Page Title</title>
<style>
	input[type=checkbox]:checked~#tal_ability_reaver_rending_strike {
	display: block;
	}
    input[type=checkbox]:checked~#tal_trigger_reaver_blood_fury {
	display: block;
	}
    input[type=checkbox]:not(:checked)~#tal_ability_reaver_rending_strike {
	display: none;
	}
    input[type=checkbox]:not(:checked)~#tal_trigger_reaver_blood_fury {
	display: none;
	}
</style>
</head>
<body>
<div>
	<label for="tal_ability_reaver_rending_strike">Rending Strike</label>
	<input type="checkbox" id="tal_ability_reaver_rending_strike">
    <div id="tal_ability_reaver_rending_strike">
	Strike your target, delaing +1 Bonus Hits directly to their Grit.
</div>
</div>
<div>
	<label for="tal_trigger_reaver_blood_fury">Blood Fury</label>
	<input type="checkbox" id="tal_trigger_reaver_blood_fury">
    <div id="tal_trigger_reaver_blood_fury">
	When you are below your maximum Grit, add +1 Bonus Hits to any results set using Strike.
</div>
</div>



</body>
</html>
'''
# Out:
# '\n<!DOCTYPE html>\n<html>\n<head>\n<title>Page Title</title>\n<style>\n\tinput[type=checkbox]:checked~#tal_ability_reaver_rending_strike {\n\tdisplay: block;\n\t}\n    input[type=checkbox]:checked~#tal_trigger_reaver_blood_fury {\n\tdisplay: block;\n\t}\n    input[type=checkbox]:not(:checked)~#tal_ability_reaver_rending_strike {\n\tdisplay: none;\n\t}\n    input[type=checkbox]:not(:checked)~#tal_trigger_reaver_blood_fury {\n\tdisplay: none;\n\t}\n</style>\n</head>\n<body>\n<div>\n\t<label for="tal_ability_reaver_rending_strike">Rending Strike</label>\n\t<input type="checkbox" id="tal_ability_reaver_rending_strike">\n    <div id="tal_ability_reaver_rending_strike">\n\tStrike your target, delaing +1 Bonus Hits directly to their Grit.\n</div>\n</div>\n<div>\n\t<label for="tal_trigger_reaver_blood_fury">Blood Fury</label>\n\t<input type="checkbox" id="tal_trigger_reaver_blood_fury">\n    <div id="tal_trigger_reaver_blood_fury">\n\tWhen you are below your maximum Grit, add +1 Bonus Hits to any results set using Strike.\n</div>\n</div>\n\n\n\n</body>\n</html>\n'

# %% [markdown]
# ### Skill Triggers Start

# %%
f = open('./docs/_data/skill_triggers.json', 'r')
skill_triggers_data = json.load(f)
f.close()

# %%
df_st = pd.DataFrame(skill_triggers_data['skill_triggers'])
df_st['rank'] = df_st['rank'].fillna(1).astype('int')
df_st['row_num'] = np.arange(len(df_st)) +1

# %%
df_st['name'] = np.where(df_st['name']=='', df_st['skill'] + ' ' +  df_st['type'] + ' ' + df_st['row_num'].astype('str'), df_st['name'])
df_st['attr_strig_nm'] = df_st['name'].str.replace(' ', '_').str.lower()
df_st['effect'] = df_st['effect'].replace({None: 'Under Development'})

# %%
df_st['pcard'] = '''!power {{
--name|@{character_name} - ''' + df_st['name'] + '''
--Effect|''' + df_st['effect'] + '''
}}'''

# %%
df_st.head()
# Out:
#                name   skill     type  rank  \
# 0  Aether Trigger 1  Aether  Trigger     2
# 1  Aether Trigger 2  Aether  Trigger     4
# 2  Aether Trigger 3  Aether  Trigger     1
# 3  Aether Trigger 4  Aether  Trigger     1
# 4  Aether Trigger 5  Aether  Trigger     1
#
#                                               effect  row_num  \
# 0  When you use an Aether effect and score 0 Hits...        1
# 1  When you use an Aether effect, score +1 Bonus ...        2
# 2  When you score 3+ Hits with an Aether effect, ...        3
# 3  When you score 4+ Hits with an Aether effect, ...        4
# 4  When you use the Recover Action and score 4+ H...        5
#
#                                                pcard     attr_strig_nm
# 0  !power {{\n--name|@{character_name} - Aether T...  aether_trigger_1
# 1  !power {{\n--name|@{character_name} - Aether T...  aether_trigger_2
# 2  !power {{\n--name|@{character_name} - Aether T...  aether_trigger_3
# 3  !power {{\n--name|@{character_name} - Aether T...  aether_trigger_4
# 4  !power {{\n--name|@{character_name} - Aether T...  aether_trigger_5

# %%
st
# Out:
# name              Aether Trigger 8
# skill                       Aether
# type                       Trigger
# rank                             1
# effect           Under Development
# row_num                          8
# pcard                          NaN
# attr_strig_nm     aether_trigger_8
# Name: 7, dtype: object

# %%
div_str = ''
for s in df_st['skill'].unique():
    strigs = df_st[df_st['skill'] == s]
    div_str += '''<div class="grid-container-talents">\n<input class="sheet-training-ranks" type="hidden" name="attr_skill_''' + s.lower() + '''" step="1" value="0" min="0" max="20" />\n<div class="sheet-training-talents">\n<h4 class="grid-talents-label" style="margin-bottom:4px;">''' + s + '''</h4>\n<div class="grid-container-talents">\n'''
    for i, st in strigs.iterrows():
        div_str += '''<div class="grid-item-talents">\n'''
        div_str +='''<div>''' + st['name'] + '''</div>\n<div>Rank ''' + str(st['rank']) + '''</div>\n<div><details>\n<summary>&#10010;</summary>\n''' + st['effect'] + '''\n</details>\n</div>\n<div>\n<input type="checkbox" name="''' + st['attr_strig_nm'] + '''" />\n<div class="talent-rollbox">\n'''
        if st['pcard'] != '':
            # skill_button_nm = p[p.find('skill_')+6:p.find('--Result Set')-6].replace('_', ' ').title()
            div_str +='''<button class="txt-btn" type="roll" value="''' + st['pcard'] +'''">\n''' + st['skill'] + '''\n</button>\n'''
        else:
            div_str +='''<button class="txt-btn" type="roll" value="!power {{
        --name|@{character_name} - ''' + st['name'] + '''
        --Effect|''' + st['effect'] + '''
        --format|triggercheck
        }}">\n''' + st['skill'] + '''</button>\n'''
        div_str +='''</div>\n</div>\n</div>\n'''
    div_str += '''</div>\n</div>\n</div>\n'''

# %%
print(div_str)
# Out:
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_skill_aether" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Aether</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <div>Aether Trigger 1</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Aether effect and score 0 Hits, add +2 Hits to the result.
# </details>
# </div>
# <div>
# <input type="checkbox" name="aether_trigger_1" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Aether Trigger 1
# --Effect|When you use an Aether effect and score 0 Hits, add +2 Hits to the result.
# }}">
# Aether
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Aether Trigger 2</div>
# <div>Rank 4</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Aether effect, score +1 Bonus Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="aether_trigger_2" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Aether Trigger 2
# --Effect|When you use an Aether effect, score +1 Bonus Hits.
# }}">
# Aether
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Aether Trigger 3</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 3+ Hits with an Aether effect, you may have the target gain Dazed 1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="aether_trigger_3" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Aether Trigger 3
# --Effect|When you score 3+ Hits with an Aether effect, you may have the target gain Dazed 1.
# }}">
# Aether
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Aether Trigger 4</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 4+ Hits with an Aether effect, you may remove 1 Hazard in the effect's Zone.
# </details>
# </div>
# <div>
# <input type="checkbox" name="aether_trigger_4" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Aether Trigger 4
# --Effect|When you score 4+ Hits with an Aether effect, you may remove 1 Hazard in the effect's Zone.
# }}">
# Aether
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Aether Trigger 5</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use the Recover Action and score 4+ Hits, you may reduce one Status by -1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="aether_trigger_5" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Aether Trigger 5
# --Effect|When you use the Recover Action and score 4+ Hits, you may reduce one Status by -1.
# }}">
# Aether
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Aether Trigger 6</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 3+ Hits with a Aether effect, you may have the effect's Zone lose Darkened until your next turn.
# </details>
# </div>
# <div>
# <input type="checkbox" name="aether_trigger_6" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Aether Trigger 6
# --Effect|When you score 3+ Hits with a Aether effect, you may have the effect's Zone lose Darkened until your next turn.
# }}">
# Aether
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Aether Trigger 7</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 3+ Hits with an Inferno effect, you may have the target gain Charmed 1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="aether_trigger_7" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Aether Trigger 7
# --Effect|When you score 3+ Hits with an Inferno effect, you may have the target gain Charmed 1.
# }}">
# Aether
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Aether Trigger 8</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="aether_trigger_8" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Aether Trigger 8
# --Effect|Under Development
# }}">
# Aether
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_skill_arithm" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Arithm</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <div>Scalar</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Arithm effect and score 0 Hits, add +2 Hits to the result.
# </details>
# </div>
# <div>
# <input type="checkbox" name="scalar" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Scalar
# --Effect|When you use an Arithm effect and score 0 Hits, add +2 Hits to the result.
# }}">
# Arithm
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>x+1</div>
# <div>Rank 4</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Arithm effect, score +1 Bonus Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="x+1" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - x+1
# --Effect|When you use an Arithm effect, score +1 Bonus Hits.
# }}">
# Arithm
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Arithm Trigger 11</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 4+ Hits with an Arithm effect, you may regain +1 Axiom.
# </details>
# </div>
# <div>
# <input type="checkbox" name="arithm_trigger_11" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Arithm Trigger 11
# --Effect|When you score 4+ Hits with an Arithm effect, you may regain +1 Axiom.
# }}">
# Arithm
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Arithm Trigger 12</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Perceive and score 3+ Hits, you may use 1 other Arithm Skill Trigger.
# </details>
# </div>
# <div>
# <input type="checkbox" name="arithm_trigger_12" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Arithm Trigger 12
# --Effect|When you Perceive and score 3+ Hits, you may use 1 other Arithm Skill Trigger.
# }}">
# Arithm
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Arithm Trigger 13</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Analyze and score 3+ Hits, you may use 1 other Arithm Skill Trigger.
# </details>
# </div>
# <div>
# <input type="checkbox" name="arithm_trigger_13" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Arithm Trigger 13
# --Effect|When you Analyze and score 3+ Hits, you may use 1 other Arithm Skill Trigger.
# }}">
# Arithm
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Arithm Trigger 14</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use your Insight and score 3+ Hits, you may use 1 other Arithm Skill Trigger.
# </details>
# </div>
# <div>
# <input type="checkbox" name="arithm_trigger_14" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Arithm Trigger 14
# --Effect|When you use your Insight and score 3+ Hits, you may use 1 other Arithm Skill Trigger.
# }}">
# Arithm
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Arithm Trigger 15</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 3+ Hits with an Arithm effect, you may increase the Challenge by +1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="arithm_trigger_15" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Arithm Trigger 15
# --Effect|When you score 3+ Hits with an Arithm effect, you may increase the Challenge by +1.
# }}">
# Arithm
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Arithm Trigger 16</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 3+ Hits with an Arithm effect, you may decrease the Challenge by -1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="arithm_trigger_16" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Arithm Trigger 16
# --Effect|When you score 3+ Hits with an Arithm effect, you may decrease the Challenge by -1.
# }}">
# Arithm
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Arithm Trigger 17</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Research and score 3+ Hits, you may use 1 other Arithm Skill Trigger.
# </details>
# </div>
# <div>
# <input type="checkbox" name="arithm_trigger_17" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Arithm Trigger 17
# --Effect|When you Research and score 3+ Hits, you may use 1 other Arithm Skill Trigger.
# }}">
# Arithm
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Arithm Trigger 18</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="arithm_trigger_18" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Arithm Trigger 18
# --Effect|Under Development
# }}">
# Arithm
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_skill_bellor" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Bellor</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <div>Bellor Trigger 19</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 0 Hits with a Bellor effect, add +2 Hits to the result.
# </details>
# </div>
# <div>
# <input type="checkbox" name="bellor_trigger_19" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Bellor Trigger 19
# --Effect|When you score 0 Hits with a Bellor effect, add +2 Hits to the result.
# }}">
# Bellor
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Bellor Trigger 20</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 4+ Hits with a Bellor effect while the Entropy is 10+, add +1d4 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="bellor_trigger_20" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Bellor Trigger 20
# --Effect|When you score 4+ Hits with a Bellor effect while the Entropy is 10+, add +1d4 Bonus Hits to the result set.
# }}">
# Bellor
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Bellor Trigger 21</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use Martial Arts or Strike and score 3+ Hits, you may increase the Entropy by +2 to add +2 Bonus Hits to your result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="bellor_trigger_21" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Bellor Trigger 21
# --Effect|When you use Martial Arts or Strike and score 3+ Hits, you may increase the Entropy by +2 to add +2 Bonus Hits to your result set.
# }}">
# Bellor
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Bellor Trigger 22</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Intimidate a target and score 3+ Hits, you may increase the Entropy by +1 to regain +2 Grit.
# </details>
# </div>
# <div>
# <input type="checkbox" name="bellor_trigger_22" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Bellor Trigger 22
# --Effect|When you Intimidate a target and score 3+ Hits, you may increase the Entropy by +1 to regain +2 Grit.
# }}">
# Bellor
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Bellor Trigger 23</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use Martial Arts, Strike, or Grapple a target and score 2+ Hits, you may spend 3 Momentum and 1 Entropy to have the target gain Confused 1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="bellor_trigger_23" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Bellor Trigger 23
# --Effect|When you use Martial Arts, Strike, or Grapple a target and score 2+ Hits, you may spend 3 Momentum and 1 Entropy to have the target gain Confused 1.
# }}">
# Bellor
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Bellor Trigger 24</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="bellor_trigger_24" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Bellor Trigger 24
# --Effect|Under Development
# }}">
# Bellor
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_skill_craft" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Craft</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <div>Craft Trigger 25</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Craft an Epic and score 0 Hits, add +2 Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="craft_trigger_25" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Craft Trigger 25
# --Effect|When you Craft an Epic and score 0 Hits, add +2 Hits to the result set.
# }}">
# Craft
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Craft Trigger 26</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Craft an Epic and score 5+ Hits, you may use your Shift this turn to activate the next Verse of the Epic as a Trigger.
# </details>
# </div>
# <div>
# <input type="checkbox" name="craft_trigger_26" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Craft Trigger 26
# --Effect|When you Craft an Epic and score 5+ Hits, you may use your Shift this turn to activate the next Verse of the Epic as a Trigger.
# }}">
# Craft
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Craft Trigger 27</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Craft to restore Gear Ratings and score 0 Hits, add +2 Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="craft_trigger_27" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Craft Trigger 27
# --Effect|When you Craft to restore Gear Ratings and score 0 Hits, add +2 Hits to the result set.
# }}">
# Craft
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Craft Trigger 28</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Craft an Epic with the Ballad keyword, add +1 Bonus Hit to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="craft_trigger_28" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Craft Trigger 28
# --Effect|When you Craft an Epic with the Ballad keyword, add +1 Bonus Hit to the result set.
# }}">
# Craft
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Craft Trigger 29</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Craft an Epic with the Saga keyword, add +1 Bonus Hit to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="craft_trigger_29" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Craft Trigger 29
# --Effect|When you Craft an Epic with the Saga keyword, add +1 Bonus Hit to the result set.
# }}">
# Craft
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Craft Trigger 30</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Craft to restore Gear ratings, score +1 Bonus Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="craft_trigger_30" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Craft Trigger 30
# --Effect|When you Craft to restore Gear ratings, score +1 Bonus Hits.
# }}">
# Craft
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Craft  31</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Craft to create Concoctions and score 0 Hits, add +2 Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="craft__31" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Craft  31
# --Effect|When you Craft to create Concoctions and score 0 Hits, add +2 Hits to the result set.
# }}">
# Craft
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Craft Trigger 32</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Craft to create Concoctions, score +1 Bonus Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="craft_trigger_32" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Craft Trigger 32
# --Effect|When you Craft to create Concoctions, score +1 Bonus Hits.
# }}">
# Craft
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Craft Trigger 33</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Craft to create Concoctions and score 3+, reduce the number of turns required by -2.
# </details>
# </div>
# <div>
# <input type="checkbox" name="craft_trigger_33" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Craft Trigger 33
# --Effect|When you Craft to create Concoctions and score 3+, reduce the number of turns required by -2.
# }}">
# Craft
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Craft Trigger 34</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When Strike a target and score 3+ Hits, you may restore +1 Gear Rating to your equipped weapon.
# </details>
# </div>
# <div>
# <input type="checkbox" name="craft_trigger_34" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Craft Trigger 34
# --Effect|When Strike a target and score 3+ Hits, you may restore +1 Gear Rating to your equipped weapon.
# }}">
# Craft
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Craft Trigger 35</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Craft, add +1 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="craft_trigger_35" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Craft Trigger 35
# --Effect|When you Craft, add +1 Bonus Hits to the result set.
# }}">
# Craft
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Craft Trigger 36</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="craft_trigger_36" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Craft Trigger 36
# --Effect|Under Development
# }}">
# Craft
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_skill_destroy" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Destroy</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <div>Destroy Trigger 37</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Destroy effect and score 0 Hits, add +2 Hits to the result.
# </details>
# </div>
# <div>
# <input type="checkbox" name="destroy_trigger_37" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Destroy Trigger 37
# --Effect|When you use a Destroy effect and score 0 Hits, add +2 Hits to the result.
# }}">
# Destroy
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Destroy Trigger 38</div>
# <div>Rank 4</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Destroy effect, score +1 Bonus Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="destroy_trigger_38" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Destroy Trigger 38
# --Effect|When you use a Destroy effect, score +1 Bonus Hits.
# }}">
# Destroy
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Destroy Trigger 39</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 4+ Hits with a Destroy effect, your target gains Vulnerable 1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="destroy_trigger_39" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Destroy Trigger 39
# --Effect|When you score 4+ Hits with a Destroy effect, your target gains Vulnerable 1.
# }}">
# Destroy
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Destroy Trigger 40</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 4+ Hits with a Destroy effect, your target gains Wounded 1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="destroy_trigger_40" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Destroy Trigger 40
# --Effect|When you score 4+ Hits with a Destroy effect, your target gains Wounded 1.
# }}">
# Destroy
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Destroy Trigger 41</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 4+ Hits with a Destroy effect that has a single target, you may score +1 Bonus Hits against a different target in the effect's Zone.
# </details>
# </div>
# <div>
# <input type="checkbox" name="destroy_trigger_41" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Destroy Trigger 41
# --Effect|When you score 4+ Hits with a Destroy effect that has a single target, you may score +1 Bonus Hits against a different target in the effect's Zone.
# }}">
# Destroy
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Destroy Trigger 42</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use Martial Arts, Strike, or Grapple a target and score 3+ Hits, you may spend 1 Momentum and add +1d4 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="destroy_trigger_42" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Destroy Trigger 42
# --Effect|When you use Martial Arts, Strike, or Grapple a target and score 3+ Hits, you may spend 1 Momentum and add +1d4 Bonus Hits to the result set.
# }}">
# Destroy
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Destroy Trigger 43</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Shoot or Thow at a target and score 3+ Hits, you may spend 1 Momentum and add +1d4 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="destroy_trigger_43" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Destroy Trigger 43
# --Effect|When you Shoot or Thow at a target and score 3+ Hits, you may spend 1 Momentum and add +1d4 Bonus Hits to the result set.
# }}">
# Destroy
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Destroy Trigger 44</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Destroy effect and score 3+ Hits, you may regain +1 Succor.
# </details>
# </div>
# <div>
# <input type="checkbox" name="destroy_trigger_44" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Destroy Trigger 44
# --Effect|When you use a Destroy effect and score 3+ Hits, you may regain +1 Succor.
# }}">
# Destroy
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Destroy Trigger 45</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Destroy effect and score 3+ Hits, you may regain +1 Concordance.
# </details>
# </div>
# <div>
# <input type="checkbox" name="destroy_trigger_45" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Destroy Trigger 45
# --Effect|When you use a Destroy effect and score 3+ Hits, you may regain +1 Concordance.
# }}">
# Destroy
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Destroy Trigger 46</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Destroy effect and score 3+ Hits, you may reduce your Strain by -3.
# </details>
# </div>
# <div>
# <input type="checkbox" name="destroy_trigger_46" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Destroy Trigger 46
# --Effect|When you use a Destroy effect and score 3+ Hits, you may reduce your Strain by -3.
# }}">
# Destroy
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_skill_forma" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Forma</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <div>Forma Trigger 47</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="forma_trigger_47" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Forma Trigger 47
# --Effect|Under Development
# }}">
# Forma
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Forma Trigger 48</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="forma_trigger_48" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Forma Trigger 48
# --Effect|Under Development
# }}">
# Forma
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Forma Trigger 49</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="forma_trigger_49" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Forma Trigger 49
# --Effect|Under Development
# }}">
# Forma
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Forma Trigger 50</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="forma_trigger_50" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Forma Trigger 50
# --Effect|Under Development
# }}">
# Forma
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Forma Trigger 51</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="forma_trigger_51" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Forma Trigger 51
# --Effect|Under Development
# }}">
# Forma
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Forma Trigger 52</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="forma_trigger_52" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Forma Trigger 52
# --Effect|Under Development
# }}">
# Forma
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_skill_inferno" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Inferno</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <div>Igniting</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 4+ Hits with an Inferno effect, you create a Fire Hazard 1 in the targetted Zone until the flames are extinguished.
# </details>
# </div>
# <div>
# <input type="checkbox" name="igniting" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Igniting
# --Effect|When you score 4+ Hits with an Inferno effect, you create a Fire Hazard 1 in the targetted Zone until the flames are extinguished.
# }}">
# Inferno
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Alluring</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 3+ Hits with an Inferno effect, you may have the target gain Charmed 1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="alluring" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Alluring
# --Effect|When you score 3+ Hits with an Inferno effect, you may have the target gain Charmed 1.
# }}">
# Inferno
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Inextinguishable</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Inferno effect and score 0 Hits, add +2 Hits to the result.
# </details>
# </div>
# <div>
# <input type="checkbox" name="inextinguishable" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Inextinguishable
# --Effect|When you use an Inferno effect and score 0 Hits, add +2 Hits to the result.
# }}">
# Inferno
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Cleansing</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 4+ Hits with an Inferno effect, you may have reduce one Status of a target in the same zone as the effect by -1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="cleansing" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Cleansing
# --Effect|When you score 4+ Hits with an Inferno effect, you may have reduce one Status of a target in the same zone as the effect by -1.
# }}">
# Inferno
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Parching</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 4+ Hits with an Inferno effect, your target gains Fatigued 1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="parching" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Parching
# --Effect|When you score 4+ Hits with an Inferno effect, your target gains Fatigued 1.
# }}">
# Inferno
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Unbridled</div>
# <div>Rank 3</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 4+ Hits with an Inferno effect, all targets in the targetted Zone suffer the Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="unbridled" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Unbridled
# --Effect|When you score 4+ Hits with an Inferno effect, all targets in the targetted Zone suffer the Hits.
# }}">
# Inferno
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Scorching</div>
# <div>Rank 3</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 4+ Hits with an Inferno effect, your target gains Vulnerable 1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="scorching" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Scorching
# --Effect|When you score 4+ Hits with an Inferno effect, your target gains Vulnerable 1.
# }}">
# Inferno
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Raging</div>
# <div>Rank 4</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Inferno effect, score +1 Bonus Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="raging" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Raging
# --Effect|When you use an Inferno effect, score +1 Bonus Hits.
# }}">
# Inferno
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_skill_intuit" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Intuit</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <div>Intuit Trigger 61</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Intuit effect and score 0 Hits, add +2 Hits to the result.
# </details>
# </div>
# <div>
# <input type="checkbox" name="intuit_trigger_61" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Intuit Trigger 61
# --Effect|When you use an Intuit effect and score 0 Hits, add +2 Hits to the result.
# }}">
# Intuit
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Intuit Trigger 62</div>
# <div>Rank 4</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Intuit effect, score +1 Bonus Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="intuit_trigger_62" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Intuit Trigger 62
# --Effect|When you use an Intuit effect, score +1 Bonus Hits.
# }}">
# Intuit
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Intuit Trigger 63</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Perceive and score 0 Hits, add +1d4 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="intuit_trigger_63" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Intuit Trigger 63
# --Effect|When you Perceive and score 0 Hits, add +1d4 Bonus Hits to the result set.
# }}">
# Intuit
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Intuit Trigger 64</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="intuit_trigger_64" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Intuit Trigger 64
# --Effect|Under Development
# }}">
# Intuit
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Intuit Trigger 65</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use your Insight and score 0 Hits, add +1d4 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="intuit_trigger_65" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Intuit Trigger 65
# --Effect|When you use your Insight and score 0 Hits, add +1d4 Bonus Hits to the result set.
# }}">
# Intuit
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Intuit Trigger 66</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Analyze and score 0 Hits, add +1d4 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="intuit_trigger_66" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Intuit Trigger 66
# --Effect|When you Analyze and score 0 Hits, add +1d4 Bonus Hits to the result set.
# }}">
# Intuit
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Intuit Trigger 67</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Investigate and score 0 Hits, add +1d4 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="intuit_trigger_67" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Intuit Trigger 67
# --Effect|When you Investigate and score 0 Hits, add +1d4 Bonus Hits to the result set.
# }}">
# Intuit
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Intuit Trigger 68</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Persuade and score 0 Hits, add +1d4 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="intuit_trigger_68" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Intuit Trigger 68
# --Effect|When you Persuade and score 0 Hits, add +1d4 Bonus Hits to the result set.
# }}">
# Intuit
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Intuit Trigger 69</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Persuade a target and score 2+ Hits, you may spend 1 Momentum and add +1d4 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="intuit_trigger_69" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Intuit Trigger 69
# --Effect|When you Persuade a target and score 2+ Hits, you may spend 1 Momentum and add +1d4 Bonus Hits to the result set.
# }}">
# Intuit
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Intuit Trigger 70</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Pererceive and score 2+ Hits, you may spend 1 Momentum and add +1d4 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="intuit_trigger_70" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Intuit Trigger 70
# --Effect|When you Pererceive and score 2+ Hits, you may spend 1 Momentum and add +1d4 Bonus Hits to the result set.
# }}">
# Intuit
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_skill_locus" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Locus</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <div>Locus Trigger 71</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Locus effect and score 0 Hits, add +2 Hits to the result.
# </details>
# </div>
# <div>
# <input type="checkbox" name="locus_trigger_71" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Locus Trigger 71
# --Effect|When you use an Locus effect and score 0 Hits, add +2 Hits to the result.
# }}">
# Locus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Locus Trigger 72</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Locus effect, score +1 Bonus Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="locus_trigger_72" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Locus Trigger 72
# --Effect|When you use an Locus effect, score +1 Bonus Hits.
# }}">
# Locus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Locus Trigger 73</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Shift to Defy Danger, add +1d4 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="locus_trigger_73" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Locus Trigger 73
# --Effect|When you use a Shift to Defy Danger, add +1d4 Bonus Hits to the result set.
# }}">
# Locus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Locus Trigger 74</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you take an Action that targets something in an Adjacent Zone, you may spen 2 Momentum to target any Zone up to 2 Adjacencies from your Current Zone.
# </details>
# </div>
# <div>
# <input type="checkbox" name="locus_trigger_74" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Locus Trigger 74
# --Effect|When you take an Action that targets something in an Adjacent Zone, you may spen 2 Momentum to target any Zone up to 2 Adjacencies from your Current Zone.
# }}">
# Locus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Locus Trigger 75</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you take an Action that targets something in an Adjacent Zone, you may spend 2 Momentum to add +1d4 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="locus_trigger_75" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Locus Trigger 75
# --Effect|When you take an Action that targets something in an Adjacent Zone, you may spend 2 Momentum to add +1d4 Bonus Hits to the result set.
# }}">
# Locus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Locus Trigger 76</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you Shift to Move to an Adjacent Zone, you may spend 3 Momentum to immediately use another Shift.
# </details>
# </div>
# <div>
# <input type="checkbox" name="locus_trigger_76" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Locus Trigger 76
# --Effect|When you Shift to Move to an Adjacent Zone, you may spend 3 Momentum to immediately use another Shift.
# }}">
# Locus
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_skill_luck" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Luck</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <div>Luck Trigger 77</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Luck effect and score 0 Hits, add +2 Hits to the result.
# </details>
# </div>
# <div>
# <input type="checkbox" name="luck_trigger_77" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Luck Trigger 77
# --Effect|When you use a Luck effect and score 0 Hits, add +2 Hits to the result.
# }}">
# Luck
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Luck Trigger 78</div>
# <div>Rank 4</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Luck effect, score +1 Bonus Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="luck_trigger_78" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Luck Trigger 78
# --Effect|When you use a Luck effect, score +1 Bonus Hits.
# }}">
# Luck
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Luck Trigger 79</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Action and score 0 Hits, you may spend 4 Momentum and reroll the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="luck_trigger_79" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Luck Trigger 79
# --Effect|When you use an Action and score 0 Hits, you may spend 4 Momentum and reroll the result set.
# }}">
# Luck
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Luck Trigger 80</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you roll a 1 on a Hazard die, you may reroll that Hazard, keeping the new result.
# </details>
# </div>
# <div>
# <input type="checkbox" name="luck_trigger_80" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Luck Trigger 80
# --Effect|When you roll a 1 on a Hazard die, you may reroll that Hazard, keeping the new result.
# }}">
# Luck
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Luck Trigger 81</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Savvy skill and score 0 Hits, you may spend 1 Momentum and add +2 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="luck_trigger_81" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Luck Trigger 81
# --Effect|When you use a Savvy skill and score 0 Hits, you may spend 1 Momentum and add +2 Bonus Hits to the result set.
# }}">
# Luck
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Luck Trigger 82</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Deft skill and score 0 Hits, you may spend 1 Momentum and add +2 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="luck_trigger_82" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Luck Trigger 82
# --Effect|When you use a Deft skill and score 0 Hits, you may spend 1 Momentum and add +2 Bonus Hits to the result set.
# }}">
# Luck
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Luck Trigger 83</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Maneuver and fail, you may reroll the Maneuver, keeping the second result.
# </details>
# </div>
# <div>
# <input type="checkbox" name="luck_trigger_83" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Luck Trigger 83
# --Effect|When you use a Maneuver and fail, you may reroll the Maneuver, keeping the second result.
# }}">
# Luck
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Luck Trigger 84</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an action and roll a 1 in the result set, you may spend a Trait Point to reroll the entire result set instead of only the 1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="luck_trigger_84" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Luck Trigger 84
# --Effect|When you use an action and roll a 1 in the result set, you may spend a Trait Point to reroll the entire result set instead of only the 1.
# }}">
# Luck
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Luck Trigger 85</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Shift to Defy Danger, add +1d4 Bonus Hits to the result set.
# </details>
# </div>
# <div>
# <input type="checkbox" name="luck_trigger_85" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# ...
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Unyielding
# --Effect|When you use an Tellus effect and score 0 Hits, add +2 Hits to the result.
# }}">
# Tellus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Overwhelming</div>
# <div>Rank 4</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Tellus effect, score +1 Bonus Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="overwhelming" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Overwhelming
# --Effect|When you use an Tellus effect, score +1 Bonus Hits.
# }}">
# Tellus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Metamorphic</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Tellus effect and score 3+ Hits, you may have the effect's target gain Slowed 1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="metamorphic" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Metamorphic
# --Effect|When you use a Tellus effect and score 3+ Hits, you may have the effect's target gain Slowed 1.
# }}">
# Tellus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Pummeling</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Tellus effect and score 4+ Hits, you may have the effect's target become Prone.
# </details>
# </div>
# <div>
# <input type="checkbox" name="pummeling" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Pummeling
# --Effect|When you use a Tellus effect and score 4+ Hits, you may have the effect's target become Prone.
# }}">
# Tellus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Grounding</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Tellus effect and score 3+ Hits, you may reduce one Status rating of one ally in the effect's Zone by -1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="grounding" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Grounding
# --Effect|When you use a Tellus effect and score 3+ Hits, you may reduce one Status rating of one ally in the effect's Zone by -1.
# }}">
# Tellus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Hardening</div>
# <div>Rank 3</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Tellus effect and score 3+ Hits, you gain Armor Defense +1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="hardening" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Hardening
# --Effect|When you use a Tellus effect and score 3+ Hits, you gain Armor Defense +1.
# }}">
# Tellus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Refining</div>
# <div>Rank 3</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 3+ Hits with an Tellus effect, you may remove 1 Hazard in the effect's Zone.
# </details>
# </div>
# <div>
# <input type="checkbox" name="refining" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Refining
# --Effect|When you score 3+ Hits with an Tellus effect, you may remove 1 Hazard in the effect's Zone.
# }}">
# Tellus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Obstructive</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you score 4+ Hits with an Tellus effect, you may create +1 Hazard in the effect's Zone.
# </details>
# </div>
# <div>
# <input type="checkbox" name="obstructive" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Obstructive
# --Effect|When you score 4+ Hits with an Tellus effect, you may create +1 Hazard in the effect's Zone.
# }}">
# Tellus
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_skill_tempest" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Tempest</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <div>Inescapable</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Tempest effect and score 0 Hits, add +2 Hits to the result.
# </details>
# </div>
# <div>
# <input type="checkbox" name="inescapable" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Inescapable
# --Effect|When you use an Tempest effect and score 0 Hits, add +2 Hits to the result.
# }}">
# Tempest
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Raging</div>
# <div>Rank 4</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Tempest effect, score +1 Bonus Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="raging" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Raging
# --Effect|When you use an Tempest effect, score +1 Bonus Hits.
# }}">
# Tempest
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Startling</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Tempest effect and score 3+ Hits, you may have the target gain Dazed 1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="startling" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Startling
# --Effect|When you use a Tempest effect and score 3+ Hits, you may have the target gain Dazed 1.
# }}">
# Tempest
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Staggering</div>
# <div>Rank 3</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Tempest effect and score 4+ Hits, you may have the target gain Stunned 3.
# </details>
# </div>
# <div>
# <input type="checkbox" name="staggering" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Staggering
# --Effect|When you use a Tempest effect and score 4+ Hits, you may have the target gain Stunned 3.
# }}">
# Tempest
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Shocking</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Tempest effect and score 4+ Hits, you may have the target gain Stunned 1.
# </details>
# </div>
# <div>
# <input type="checkbox" name="shocking" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Shocking
# --Effect|When you use a Tempest effect and score 4+ Hits, you may have the target gain Stunned 1.
# }}">
# Tempest
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Energizing</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Tempest effect and score 4+ Hits, you gain +2 Current.
# </details>
# </div>
# <div>
# <input type="checkbox" name="energizing" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Energizing
# --Effect|When you use a Tempest effect and score 4+ Hits, you gain +2 Current.
# }}">
# Tempest
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Ritualistic</div>
# <div>Rank 3</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Tempest effect and score 3+ Hits, you gain +1 Concordance.
# </details>
# </div>
# <div>
# <input type="checkbox" name="ritualistic" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Ritualistic
# --Effect|When you use a Tempest effect and score 3+ Hits, you gain +1 Concordance.
# }}">
# Tempest
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Surging</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use a Tempest effect and score 3+ Hits, you gain +1 Current.
# </details>
# </div>
# <div>
# <input type="checkbox" name="surging" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Surging
# --Effect|When you use a Tempest effect and score 3+ Hits, you gain +1 Current.
# }}">
# Tempest
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Tempest Trigger 179</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="tempest_trigger_179" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Tempest Trigger 179
# --Effect|Under Development
# }}">
# Tempest
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_skill_torrent" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Torrent</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <div>Torrent Trigger 180</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Torrent effect and score 0 Hits, add +2 Hits to the result.
# </details>
# </div>
# <div>
# <input type="checkbox" name="torrent_trigger_180" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Torrent Trigger 180
# --Effect|When you use an Torrent effect and score 0 Hits, add +2 Hits to the result.
# }}">
# Torrent
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Torrent Trigger 181</div>
# <div>Rank 4</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Torrent effect, score +1 Bonus Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="torrent_trigger_181" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Torrent Trigger 181
# --Effect|When you use an Torrent effect, score +1 Bonus Hits.
# }}">
# Torrent
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Torrent Trigger 182</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="torrent_trigger_182" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Torrent Trigger 182
# --Effect|Under Development
# }}">
# Torrent
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Torrent Trigger 183</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="torrent_trigger_183" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Torrent Trigger 183
# --Effect|Under Development
# }}">
# Torrent
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Torrent Trigger 184</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="torrent_trigger_184" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Torrent Trigger 184
# --Effect|Under Development
# }}">
# Torrent
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Torrent Trigger 185</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="torrent_trigger_185" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Torrent Trigger 185
# --Effect|Under Development
# }}">
# Torrent
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Torrent Trigger 186</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="torrent_trigger_186" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Torrent Trigger 186
# --Effect|Under Development
# }}">
# Torrent
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-training-ranks" type="hidden" name="attr_skill_vivus" step="1" value="0" min="0" max="20" />
# <div class="sheet-training-talents">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Vivus</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <div>Vivus Trigger 187</div>
# <div>Rank 2</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Vivus effect and score 0 Hits, add +2 Hits to the result.
# </details>
# </div>
# <div>
# <input type="checkbox" name="vivus_trigger_187" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Vivus Trigger 187
# --Effect|When you use an Vivus effect and score 0 Hits, add +2 Hits to the result.
# }}">
# Vivus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Vivus Trigger 188</div>
# <div>Rank 4</div>
# <div><details>
# <summary>&#10010;</summary>
# When you use an Vivus effect, score +1 Bonus Hits.
# </details>
# </div>
# <div>
# <input type="checkbox" name="vivus_trigger_188" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Vivus Trigger 188
# --Effect|When you use an Vivus effect, score +1 Bonus Hits.
# }}">
# Vivus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Vivus Trigger 189</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="vivus_trigger_189" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Vivus Trigger 189
# --Effect|Under Development
# }}">
# Vivus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Vivus Trigger 190</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="vivus_trigger_190" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Vivus Trigger 190
# --Effect|Under Development
# }}">
# Vivus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Vivus Trigger 191</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="vivus_trigger_191" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Vivus Trigger 191
# --Effect|Under Development
# }}">
# Vivus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Vivus Trigger 192</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="vivus_trigger_192" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Vivus Trigger 192
# --Effect|Under Development
# }}">
# Vivus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Vivus Trigger 193</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="vivus_trigger_193" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Vivus Trigger 193
# --Effect|Under Development
# }}">
# Vivus
# </button>
# </div>
# </div>
# </div>
# <div class="grid-item-talents">
# <div>Vivus Trigger 194</div>
# <div>Rank 1</div>
# <div><details>
# <summary>&#10010;</summary>
# Under Development
# </details>
# </div>
# <div>
# <input type="checkbox" name="vivus_trigger_194" />
# <div class="talent-rollbox">
# <button class="txt-btn" type="roll" value="!power {{
# --name|@{character_name} - Vivus Trigger 194
# --Effect|Under Development
# }}">
# Vivus
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
f = open('skill_triggers.html', 'w')
f.write(div_str)
f.close()

# %% [markdown]
# ## Powers Start

# %%
os.getcwd()
# Out:
# 'c:\\Users\\DonalHarrison\\Documents\\admin\\ach\\no1\\no1_system'

# %%
f = open('./docs/_data/powers.json', 'r')
powers_data = json.load(f)
f.close()

# %% [markdown]
# ### Arcana Start

# %%
df_arcana = pd.DataFrame.from_records(powers_data['arcana'])

# %%
df_arcana['attr_arcana_nm'] = '''attr_arc_rank_''' + df_arcana['name'].str.lower().str.replace(' ', '_')

# %%
arc_pcard = []
arcs = df_arcana[df_arcana['name']=='The Fractured Mirror'].copy()
for i, arc in df_arcana.iterrows():
    if ~(np.isnan(arc['threshold'])):
        pc=[]
        for asp in arc['aspects']:
            card = '''!power {{
    --name|@{character_name} - ''' + arc['name'] + '''
    --Aspect|''' + asp['skill'] + '''
    --Type|''' + asp['type'] + '''
    --Cost|''' + str(asp['strain']) + '''
    --api_modattr|_name @{character_name} _strain|''' + str(asp['strain']) + '''
    --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_''' + asp['skill'].lower() + '''}>@{Cosm|target}]]
    --Hits|[^arcana.ss]
    --1s|[^arcana.ones]
    --format|powercheck\n'''
            for e in asp['effects']:
                clean_effect = e['effect'].replace('choose', '**choose').replace(':<ul><li>', '**:^^^^**').replace('</li><li>', '^^^^').replace('</li></ul>', '**')
                card += '''--?? $arcana.ss >= ''' + str(round(arc['threshold'])) + ''' AND @{''' + arc['attr_arcana_nm'].replace('attr_', '') + '''} >= ''' +str(e['ranks']) + ''' ?? Effect:|**//Rank - ''' + str(e['ranks']) + '''//**^^''' + clean_effect + '\n'
            card += '''}}'''
            # print(pc)
            pc.append(card)
        arc_pcard.append(pc)
    else:
        arc_pcard.append(np.nan)
df_arcana['arc_pcard'] = arc_pcard

# %%
for a, p in zip(df_arcana['aspects'][0], df_arcana['arc_pcard'][0]):
    print(a, p)
# Out:
# {'skill': 'Inferno', 'type': 'Ability', 'strain': 5, 'effects': [{'ranks': 0, 'effect': 'Deal Hits to 1 target in your Current or an Adjacent Zone.'}, {'ranks': 1, 'effect': 'Deal Hits to 1 target in your Current or an Adjacent Zone.  Reduce your Strain by 1.'}, {'ranks': 4, 'effect': 'Deal Hits to 2 targets in your Current or an Adjacent Zone.  Reduce your Strain by 2.'}]} !power {{
#     --name|@{character_name} - The Prime Conflagration
#     --Aspect|Inferno
#     --Type|Ability
#     --Cost|5
#     --api_modattr|_name @{character_name} _strain|5
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_inferno}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_prime_conflagration} >= 0 ?? Effect:|**//Rank - 0//**^^Deal Hits to 1 target in your Current or an Adjacent Zone.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_prime_conflagration} >= 1 ?? Effect:|**//Rank - 1//**^^Deal Hits to 1 target in your Current or an Adjacent Zone.  Reduce your Strain by 1.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_prime_conflagration} >= 4 ?? Effect:|**//Rank - 4//**^^Deal Hits to 2 targets in your Current or an Adjacent Zone.  Reduce your Strain by 2.
# }}
# {'skill': 'Aether', 'type': 'Shift', 'strain': 5, 'effects': [{'ranks': 0, 'effect': 'Score 2+ Hits to have 1 target in your Current Zone gains Dazed.'}, {'ranks': 1, 'effect': 'Score 2+ Hits to have up to 2 targets in your Current Zone gain Dazed.'}, {'ranks': 4, 'effect': 'Score 2+ Hits to have up to Hits targets in your Current Zone gain Dazed.'}]} !power {{
#     --name|@{character_name} - The Prime Conflagration
#     --Aspect|Aether
#     --Type|Shift
#     --Cost|5
#     --api_modattr|_name @{character_name} _strain|5
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_aether}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_prime_conflagration} >= 0 ?? Effect:|**//Rank - 0//**^^Score 2+ Hits to have 1 target in your Current Zone gains Dazed.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_prime_conflagration} >= 1 ?? Effect:|**//Rank - 1//**^^Score 2+ Hits to have up to 2 targets in your Current Zone gain Dazed.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_prime_conflagration} >= 4 ?? Effect:|**//Rank - 4//**^^Score 2+ Hits to have up to Hits targets in your Current Zone gain Dazed.
# }}

# %%
div_str = ''
for i, arc in df_arcana.iterrows():
  if ~(np.isnan(arc['threshold'])):
    div_str += '''<div class="grid-container-arcana">\n<div class="grid-talents-label"><h3 style="margin:3px;">''' + arc['name'] + '''</h3>\n<label>Arcana Rank: <input name="''' + arc['attr_arcana_nm'] + '''" type="number" value="0" step="1" max="''' + str(arc['max_ranks']) + '''" /> of ''' + str(arc['max_ranks']) + '''</label>\n<h4 style="margin:3px;">Threshold &mdash; ''' + str(round(arc['threshold'])) + '''</h4>\n</div>'''
    for asp, pc in zip(arc['aspects'], arc['arc_pcard']):
      div_str += '''<div class="grid-arcana-item"><button class="skill-button" type="roll" value="''' + pc + '''">''' + asp['skill'] + '''</button>\n<br><em>''' + asp['type'] + '''</em><br><strong>Strain &mdash; '''+ str(asp['strain']) + '''</strong>\n<div class="grid-arcana-table">\n<div class="arcana-data">Rank</div>\n<div class="arcana-data">Effect</div>\n'''
      for e in asp['effects']:
        div_str += '''<div class="arcana-data">''' + str(e['ranks']) + '''</div>\n<div class="arcana-data">''' + e['effect'] + '''</div>'''
      div_str += '''</div>\n</div>'''
    div_str += '''</div>\n'''
print(div_str)
# Out:
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Prime Conflagration</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_prime_conflagration" type="number" value="0" step="1" max="4" /> of 4</label>
# <h4 style="margin:3px;">Threshold &mdash; 2</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Prime Conflagration
#     --Aspect|Inferno
#     --Type|Ability
#     --Cost|5
#     --api_modattr|_name @{character_name} _strain|5
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_inferno}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_prime_conflagration} >= 0 ?? Effect:|**//Rank - 0//**^^Deal Hits to 1 target in your Current or an Adjacent Zone.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_prime_conflagration} >= 1 ?? Effect:|**//Rank - 1//**^^Deal Hits to 1 target in your Current or an Adjacent Zone.  Reduce your Strain by 1.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_prime_conflagration} >= 4 ?? Effect:|**//Rank - 4//**^^Deal Hits to 2 targets in your Current or an Adjacent Zone.  Reduce your Strain by 2.
# }}">Inferno</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 5</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">0</div>
# <div class="arcana-data">Deal Hits to 1 target in your Current or an Adjacent Zone.</div><div class="arcana-data">1</div>
# <div class="arcana-data">Deal Hits to 1 target in your Current or an Adjacent Zone.  Reduce your Strain by 1.</div><div class="arcana-data">4</div>
# <div class="arcana-data">Deal Hits to 2 targets in your Current or an Adjacent Zone.  Reduce your Strain by 2.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Prime Conflagration
#     --Aspect|Aether
#     --Type|Shift
#     --Cost|5
#     --api_modattr|_name @{character_name} _strain|5
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_aether}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_prime_conflagration} >= 0 ?? Effect:|**//Rank - 0//**^^Score 2+ Hits to have 1 target in your Current Zone gains Dazed.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_prime_conflagration} >= 1 ?? Effect:|**//Rank - 1//**^^Score 2+ Hits to have up to 2 targets in your Current Zone gain Dazed.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_prime_conflagration} >= 4 ?? Effect:|**//Rank - 4//**^^Score 2+ Hits to have up to Hits targets in your Current Zone gain Dazed.
# }}">Aether</button>
# <br><em>Shift</em><br><strong>Strain &mdash; 5</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">0</div>
# <div class="arcana-data">Score 2+ Hits to have 1 target in your Current Zone gains Dazed.</div><div class="arcana-data">1</div>
# <div class="arcana-data">Score 2+ Hits to have up to 2 targets in your Current Zone gain Dazed.</div><div class="arcana-data">4</div>
# <div class="arcana-data">Score 2+ Hits to have up to Hits targets in your Current Zone gain Dazed.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Flame of Affliction</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_flame_of_affliction" type="number" value="0" step="1" max="7" /> of 7</label>
# <h4 style="margin:3px;">Threshold &mdash; 3</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Flame of Affliction
#     --Aspect|Inferno
#     --Type|Ability
#     --Cost|3
#     --api_modattr|_name @{character_name} _strain|3
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_inferno}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_flame_of_affliction} >= 3 ?? Effect:|**//Rank - 3//**^^Deal Hits to 1 target's Grit, ignoring all Defenses.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_flame_of_affliction} >= 7 ?? Effect:|**//Rank - 7//**^^Deal Hits to all target's Grit, ignoring all Defenses.
# }}">Inferno</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 3</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">3</div>
# <div class="arcana-data">Deal Hits to 1 target's Grit, ignoring all Defenses.</div><div class="arcana-data">7</div>
# <div class="arcana-data">Deal Hits to all target's Grit, ignoring all Defenses.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Flame of Affliction
#     --Aspect|Mori
#     --Type|Trigger
#     --Cost|5
#     --api_modattr|_name @{character_name} _strain|5
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_mori}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_flame_of_affliction} >= 5 ?? Effect:|**//Rank - 5//**^^When a target you can see in your Current Zone dies, restore Hits to your Grit.
# }}">Mori</button>
# <br><em>Trigger</em><br><strong>Strain &mdash; 5</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">5</div>
# <div class="arcana-data">When a target you can see in your Current Zone dies, restore Hits to your Grit.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Flame of Affliction
#     --Aspect|Plaga
#     --Type|Ability
#     --Cost|1
#     --api_modattr|_name @{character_name} _strain|1
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_plaga}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_flame_of_affliction} >= 3 ?? Effect:|**//Rank - 3//**^^One target in your Current or an Adjacent Zone gains Fatigued 1.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_flame_of_affliction} >= 5 ?? Effect:|**//Rank - 5//**^^One target in your Current or an Adjacent Zone gains Fatigued 2.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_flame_of_affliction} >= 7 ?? Effect:|**//Rank - 7//**^^All targets in your Current or an Adjacent Zone gains Fatigued 2.
# }}">Plaga</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 1</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">3</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone gains Fatigued 1.</div><div class="arcana-data">5</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone gains Fatigued 2.</div><div class="arcana-data">7</div>
# <div class="arcana-data">All targets in your Current or an Adjacent Zone gains Fatigued 2.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Eternal Cycle</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_eternal_cycle" type="number" value="0" step="1" max="5" /> of 5</label>
# <h4 style="margin:3px;">Threshold &mdash; 2</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Eternal Cycle
#     --Aspect|Mori
#     --Type|Ability
#     --Cost|1
#     --api_modattr|_name @{character_name} _strain|1
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_mori}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_eternal_cycle} >= 2 ?? Effect:|**//Rank - 2//**^^One target in your Current or an Adjacent Zone loses 2 Grit and one target in your Current Zone reduces their Dying rating by -1.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_eternal_cycle} >= 5 ?? Effect:|**//Rank - 5//**^^One target in your Current or an Adjacent Zone loses X Grit and one target in your Current Zone reduces their Dying rating by -1, where X is equal to Hits in the result set.
# }}">Mori</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 1</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">2</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone loses 2 Grit and one target in your Current Zone reduces their Dying rating by -1.</div><div class="arcana-data">5</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone loses X Grit and one target in your Current Zone reduces their Dying rating by -1, where X is equal to Hits in the result set.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Eternal Cycle
#     --Aspect|Vivus
#     --Type|Ability
#     --Cost|1
#     --api_modattr|_name @{character_name} _strain|1
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_vivus}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_eternal_cycle} >= 1 ?? Effect:|**//Rank - 1//**^^One target in your Current or an Adjacent Zone regains X Grit, where X is equal to Hits in the result set.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_eternal_cycle} >= 5 ?? Effect:|**//Rank - 5//**^^One target in your Current or an Adjacent Zone regains X Grit and one other target in your Current or an Adjacent Zone gains Wounded 1, where X is equal to Hits in the result set.
# }}">Vivus</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 1</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone regains X Grit, where X is equal to Hits in the result set.</div><div class="arcana-data">5</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone regains X Grit and one other target in your Current or an Adjacent Zone gains Wounded 1, where X is equal to Hits in the result set.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Silent War</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_silent_war" type="number" value="0" step="1" max="4" /> of 4</label>
# <h4 style="margin:3px;">Threshold &mdash; 1</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Silent War
#     --Aspect|Bellor
#     --Type|Trigger
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_bellor}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 1 AND @{arc_rank_the_silent_war} >= 1 ?? Effect:|**//Rank - 1//**^^When you make an Initiative Test using Tactics, add +1d4 Bonus Hits to the result set
# }}">Bellor</button>
# <br><em>Trigger</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">When you make an Initiative Test using Tactics, add +1d4 Bonus Hits to the result set</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Silent War
#     --Aspect|Destroy
#     --Type|Shift
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_destroy}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 1 AND @{arc_rank_the_silent_war} >= 2 ?? Effect:|**//Rank - 2//**^^You gain Aura X to add +1d4 Bonus Hits to any Action using Shoot or Strike, where X is equal to Hits in the result set.
# --?? $arcana.ss >= 1 AND @{arc_rank_the_silent_war} >= 4 ?? Effect:|**//Rank - 4//**^^You gain Aura X. Add +2d4 Bonus Hits to any Action using Shoot or Strike while the Aura persists., where X is equal to Hits in the result set.
# }}">Destroy</button>
# <br><em>Shift</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">2</div>
# <div class="arcana-data">You gain Aura X to add +1d4 Bonus Hits to any Action using Shoot or Strike, where X is equal to Hits in the result set.</div><div class="arcana-data">4</div>
# <div class="arcana-data">You gain Aura X. Add +2d4 Bonus Hits to any Action using Shoot or Strike while the Aura persists., where X is equal to Hits in the result set.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Silent War
#     --Aspect|Nox
#     --Type|Shift
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_nox}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 1 AND @{arc_rank_the_silent_war} >= 1 ?? Effect:|**//Rank - 1//**^^Target your Current and an Adjacent Zone.  The targeted Zone gains the Silent keyword until the beginning of your next turn.
# --?? $arcana.ss >= 1 AND @{arc_rank_the_silent_war} >= 1 ?? Effect:|**//Rank - 1//**^^Your Current and all Adjacent Zones gain the Silent keyword until the beginning of your next turn.
# }}">Nox</button>
# <br><em>Shift</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">Target your Current and an Adjacent Zone.  The targeted Zone gains the Silent keyword until the beginning of your next turn.</div><div class="arcana-data">1</div>
# <div class="arcana-data">Your Current and all Adjacent Zones gain the Silent keyword until the beginning of your next turn.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Fractured Mirror</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_fractured_mirror" type="number" value="0" step="1" max="3" /> of 3</label>
# <h4 style="margin:3px;">Threshold &mdash; 3</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Fractured Mirror
#     --Aspect|Tempor
#     --Type|Ability
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_tempor}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_fractured_mirror} >= 1 ?? Effect:|**//Rank - 1//**^^Increase the current Timer by +1.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_fractured_mirror} >= 3 ?? Effect:|**//Rank - 3//**^^Increase the current Timer by +1.
# }}">Tempor</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">Increase the current Timer by +1.</div><div class="arcana-data">3</div>
# <div class="arcana-data">Increase the current Timer by +1.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Fractured Mirror
#     --Aspect|Locus
#     --Type|Shift
#     --Cost|1
#     --api_modattr|_name @{character_name} _strain|1
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_locus}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_fractured_mirror} >= 1 ?? Effect:|**//Rank - 1//**^^You move to any Adjacent Zone ignoring Hazards.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_fractured_mirror} >= 3 ?? Effect:|**//Rank - 3//**^^You and up to X targets move to any Adjacent Zone ignoring Hazards, where X is equal to Hits in the result set.
# }}">Locus</button>
# <br><em>Shift</em><br><strong>Strain &mdash; 1</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">You move to any Adjacent Zone ignoring Hazards.</div><div class="arcana-data">3</div>
# <div class="arcana-data">You and up to X targets move to any Adjacent Zone ignoring Hazards, where X is equal to Hits in the result set.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Fractured Mirror
#     --Aspect|Luck
#     --Type|Shift
#     --Cost|3
#     --api_modattr|_name @{character_name} _strain|3
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_luck}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_fractured_mirror} >= 1 ?? Effect:|**//Rank - 1//**^^Increase the Momentum by +2.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_fractured_mirror} >= 3 ?? Effect:|**//Rank - 3//**^^Decrease the Entropy by -2 and increase the Momentum by +2.
# }}">Luck</button>
# <br><em>Shift</em><br><strong>Strain &mdash; 3</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">Increase the Momentum by +2.</div><div class="arcana-data">3</div>
# <div class="arcana-data">Decrease the Entropy by -2 and increase the Momentum by +2.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Fractured Mirror
#     --Aspect|Mentis
#     --Type|Ability
#     --Cost|1
#     --api_modattr|_name @{character_name} _strain|1
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_mentis}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_fractured_mirror} >= 1 ?? Effect:|**//Rank - 1//**^^One target in your Current or an Adjacent Zone gains Stunned 1.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_fractured_mirror} >= 3 ?? Effect:|**//Rank - 3//**^^Up to X targets in your Current or an Adjacent Zone gain Stunned 1.
# }}">Mentis</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 1</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone gains Stunned 1.</div><div class="arcana-data">3</div>
# <div class="arcana-data">Up to X targets in your Current or an Adjacent Zone gain Stunned 1.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Iron Moon</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_iron_moon" type="number" value="0" step="1" max="5" /> of 5</label>
# <h4 style="margin:3px;">Threshold &mdash; 2</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Iron Moon
#     --Aspect|Bellor
#     --Type|Shift
#     --Cost|1
#     --api_modattr|_name @{character_name} _strain|1
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_bellor}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_iron_moon} >= 1 ?? Effect:|**//Rank - 1//**^^Increase the Entrpy by +2.  Up to X targets in your Current Zone gain Afraid 2, where X is equal to Hits in the result set.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_iron_moon} >= 3 ?? Effect:|**//Rank - 3//**^^Increase the Entrpy by +1.  Up to X targets in your Current Zone gain Afraid 2, where X is equal to Hits in the result set.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_iron_moon} >= 5 ?? Effect:|**//Rank - 5//**^^Up to X targets in your Current Zone gain Afraid 2, where X is equal to Hits in the result set.
# }}">Bellor</button>
# <br><em>Shift</em><br><strong>Strain &mdash; 1</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">Increase the Entrpy by +2.  Up to X targets in your Current Zone gain Afraid 2, where X is equal to Hits in the result set.</div><div class="arcana-data">3</div>
# <div class="arcana-data">Increase the Entrpy by +1.  Up to X targets in your Current Zone gain Afraid 2, where X is equal to Hits in the result set.</div><div class="arcana-data">5</div>
# <div class="arcana-data">Up to X targets in your Current Zone gain Afraid 2, where X is equal to Hits in the result set.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Iron Moon
#     --Aspect|Destroy
#     --Type|Shift
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_destroy}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_iron_moon} >= 1 ?? Effect:|**//Rank - 1//**^^Add +1d4 Bonus Hits to your next Action using Shoot or Strike.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_iron_moon} >= 5 ?? Effect:|**//Rank - 5//**^^You gain Aura X, where X is equal to Hits in the result set.  While this Aura persists, add +1d4 Bonus Hits to any Action using Shoot or Strike.
# }}">Destroy</button>
# <br><em>Shift</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">Add +1d4 Bonus Hits to your next Action using Shoot or Strike.</div><div class="arcana-data">5</div>
# <div class="arcana-data">You gain Aura X, where X is equal to Hits in the result set.  While this Aura persists, add +1d4 Bonus Hits to any Action using Shoot or Strike.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Iron Moon
#     --Aspect|Mori
#     --Type|Ability
#     --Cost|1
#     --api_modattr|_name @{character_name} _strain|1
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_mori}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_iron_moon} >= 1 ?? Effect:|**//Rank - 1//**^^One target in your Current or an Adjacent Zone loses X Grit, where X is equal to Hits in the result set.  If the target is Afraid, reduce your Strain by -1.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_iron_moon} >= 5 ?? Effect:|**//Rank - 5//**^^One target in your Current or an Adjacent Zone loses X Grit and gains Wounded 1, where X is equal to Hits in the result set.  If the target is Afraid, reduce your Strain by -1.
# }}">Mori</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 1</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone loses X Grit, where X is equal to Hits in the result set.  If the target is Afraid, reduce your Strain by -1.</div><div class="arcana-data">5</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone loses X Grit and gains Wounded 1, where X is equal to Hits in the result set.  If the target is Afraid, reduce your Strain by -1.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Crimson Sun</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_crimson_sun" type="number" value="0" step="1" max="5" /> of 5</label>
# <h4 style="margin:3px;">Threshold &mdash; 2</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Crimson Sun
#     --Aspect|Bellor
#     --Type|Shift
#     --Cost|1
#     --api_modattr|_name @{character_name} _strain|1
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_bellor}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_crimson_sun} >= 1 ?? Effect:|**//Rank - 1//**^^Up to X targets in your Current Zone become Provoked, where X is equal to Hits in the result set.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_crimson_sun} >= 5 ?? Effect:|**//Rank - 5//**^^All targets in your Current Zone become Provoked.
# }}">Bellor</button>
# <br><em>Shift</em><br><strong>Strain &mdash; 1</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">Up to X targets in your Current Zone become Provoked, where X is equal to Hits in the result set.</div><div class="arcana-data">5</div>
# <div class="arcana-data">All targets in your Current Zone become Provoked.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Crimson Sun
#     --Aspect|Lux
#     --Type|Ability
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_lux}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_crimson_sun} >= 1 ?? Effect:|**//Rank - 1//**^^One target in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set.  If the target is Provoked, add +1d4 Bonus Hits to the result set.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_crimson_sun} >= 3 ?? Effect:|**//Rank - 3//**^^Up to X targets in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set.  If a target is Provoked, add +1d4 Bonus Hits to the result set.
# }}">Lux</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set.  If the target is Provoked, add +1d4 Bonus Hits to the result set.</div><div class="arcana-data">3</div>
# <div class="arcana-data">Up to X targets in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set.  If a target is Provoked, add +1d4 Bonus Hits to the result set.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Crimson Sun
#     --Aspect|Resist
#     --Type|Shift
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_resist}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_crimson_sun} >= 3 ?? Effect:|**//Rank - 3//**^^Spend 2 Momentum.  You regain 3 Grit and gain Armor Bonus X, where X is equal to Hits in the result set.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_crimson_sun} >= 5 ?? Effect:|**//Rank - 5//**^^Spend 2 Momentum.  You and up to X target in your Current or an Adjacent Zone regain 3 Grit and gain Armor Bonus X, where X is equal to Hits in the result set.
# }}">Resist</button>
# <br><em>Shift</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">3</div>
# <div class="arcana-data">Spend 2 Momentum.  You regain 3 Grit and gain Armor Bonus X, where X is equal to Hits in the result set.</div><div class="arcana-data">5</div>
# <div class="arcana-data">Spend 2 Momentum.  You and up to X target in your Current or an Adjacent Zone regain 3 Grit and gain Armor Bonus X, where X is equal to Hits in the result set.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Long Night</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_long_night" type="number" value="0" step="1" max="3" /> of 3</label>
# <h4 style="margin:3px;">Threshold &mdash; 1</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Long Night
#     --Aspect|Tempor
#     --Type|Ability
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_tempor}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 1 AND @{arc_rank_the_long_night} >= 1 ?? Effect:|**//Rank - 1//**^^Increase the current Timer by +1.
# --?? $arcana.ss >= 1 AND @{arc_rank_the_long_night} >= 3 ?? Effect:|**//Rank - 3//**^^Increase the current Timer by +X, where X is equal to Hits in the result set.
# }}">Tempor</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">Increase the current Timer by +1.</div><div class="arcana-data">3</div>
# <div class="arcana-data">Increase the current Timer by +X, where X is equal to Hits in the result set.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Long Night
#     --Aspect|Nox
#     --Type|Shift
#     --Cost|None
#     --api_modattr|_name @{character_name} _strain|None
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_nox}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 1 AND @{arc_rank_the_long_night} >= 1 ?? Effect:|**//Rank - 1//**^^One target in your Current or an Adjacent Zone gains Blind 1.
# --?? $arcana.ss >= 1 AND @{arc_rank_the_long_night} >= 3 ?? Effect:|**//Rank - 3//**^^Up to X target in your Current or an Adjacent Zone gains Blind 1, where X is equal to Hits in the result set.
# }}">Nox</button>
# <br><em>Shift</em><br><strong>Strain &mdash; None</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone gains Blind 1.</div><div class="arcana-data">3</div>
# <div class="arcana-data">Up to X target in your Current or an Adjacent Zone gains Blind 1, where X is equal to Hits in the result set.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Growing Dawn</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_growing_dawn" type="number" value="0" step="1" max="4" /> of 4</label>
# <h4 style="margin:3px;">Threshold &mdash; 2</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Growing Dawn
#     --Aspect|Lux
#     --Type|Ability
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_lux}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_growing_dawn} >= 2 ?? Effect:|**//Rank - 2//**^^Up to X targets in your Current or an Adjacent Zone gain Dazed 1.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_growing_dawn} >= 4 ?? Effect:|**//Rank - 4//**^^Up to X targets in your Current or an Adjacent Zone gain Dazed 3.
# }}">Lux</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">2</div>
# <div class="arcana-data">Up to X targets in your Current or an Adjacent Zone gain Dazed 1.</div><div class="arcana-data">4</div>
# <div class="arcana-data">Up to X targets in your Current or an Adjacent Zone gain Dazed 3.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Growing Dawn
#     --Aspect|Ordi
#     --Type|Ability
#     --Cost|1
#     --api_modattr|_name @{character_name} _strain|1
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_ordi}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_growing_dawn} >= 1 ?? Effect:|**//Rank - 1//**^^Score 1 Hit to up to 3 targets in your Current Zone. Reduce your Strain by -1 for each target you score Hits against that is Dazed.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_growing_dawn} >= 4 ?? Effect:|**//Rank - 4//**^^Score X Hit to up to 3 targets in your Current or an Adjacent Zone, X . . . Reduce your Strain by -1 for each target you score Hits against that is Dazed.
# }}">Ordi</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 1</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">Score 1 Hit to up to 3 targets in your Current Zone. Reduce your Strain by -1 for each target you score Hits against that is Dazed.</div><div class="arcana-data">4</div>
# <div class="arcana-data">Score X Hit to up to 3 targets in your Current or an Adjacent Zone, X . . . Reduce your Strain by -1 for each target you score Hits against that is Dazed.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Coming War</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_coming_war" type="number" value="0" step="1" max="4" /> of 4</label>
# <h4 style="margin:3px;">Threshold &mdash; 1</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Coming War
#     --Aspect|Bellor
#     --Type|Ability
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_bellor}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 1 AND @{arc_rank_the_coming_war} >= 1 ?? Effect:|**//Rank - 1//**^^Increase the Entropy by X to have X targets gain Fatigued 1, where X is equal to Hits in the result set.
# --?? $arcana.ss >= 1 AND @{arc_rank_the_coming_war} >= 4 ?? Effect:|**//Rank - 4//**^^Increase the Entropy by X to have X targets gain Fatigued 3, where X is equal to Hits in the result set.
# }}">Bellor</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">Increase the Entropy by X to have X targets gain Fatigued 1, where X is equal to Hits in the result set.</div><div class="arcana-data">4</div>
# <div class="arcana-data">Increase the Entropy by X to have X targets gain Fatigued 3, where X is equal to Hits in the result set.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Coming War
#     --Aspect|Ordi
#     --Type|Ability
#     --Cost|None
#     --api_modattr|_name @{character_name} _strain|None
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_ordi}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 1 AND @{arc_rank_the_coming_war} >= 1 ?? Effect:|**//Rank - 1//**^^Spend 2 Momentum.  Divide 5 Hits among up to X targets in your Current or an Adjacent Zone, where X is equal to Hits in the result set.  Reduce your Strain by -1 for each each target you score Hits against that is Fatigued.
# --?? $arcana.ss >= 1 AND @{arc_rank_the_coming_war} >= 4 ?? Effect:|**//Rank - 4//**^^Spend 2 Momentum.  Divide 10 Hits among up to X targets in your Current or an Adjacent Zone, where X is equal to Hits in the result set.  Reduce your Strain by -1 for each each target you score Hits against that is Fatigued.
# }}">Ordi</button>
# <br><em>Ability</em><br><strong>Strain &mdash; None</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">Spend 2 Momentum.  Divide 5 Hits among up to X targets in your Current or an Adjacent Zone, where X is equal to Hits in the result set.  Reduce your Strain by -1 for each each target you score Hits against that is Fatigued.</div><div class="arcana-data">4</div>
# <div class="arcana-data">Spend 2 Momentum.  Divide 10 Hits among up to X targets in your Current or an Adjacent Zone, where X is equal to Hits in the result set.  Reduce your Strain by -1 for each each target you score Hits against that is Fatigued.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Heart of Cruelty</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_heart_of_cruelty" type="number" value="0" step="1" max="6" /> of 6</label>
# <h4 style="margin:3px;">Threshold &mdash; 3</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Heart of Cruelty
#     --Aspect|Destroy
#     --Type|Ability
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_destroy}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_heart_of_cruelty} >= 2 ?? Effect:|**//Rank - 2//**^^One target in your Current or an Adjacent Zone gains Wounded 1.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_heart_of_cruelty} >= 4 ?? Effect:|**//Rank - 4//**^^One target in your Current or an Adjacent Zone gains Wounded 2.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_heart_of_cruelty} >= 6 ?? Effect:|**//Rank - 6//**^^One target in your Current or an Adjacent Zone gains Wounded 3.
# }}">Destroy</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">2</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone gains Wounded 1.</div><div class="arcana-data">4</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone gains Wounded 2.</div><div class="arcana-data">6</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone gains Wounded 3.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Heart of Cruelty
#     --Aspect|Mori
#     --Type|
#     --Cost|1
#     --api_modattr|_name @{character_name} _strain|1
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_mori}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_heart_of_cruelty} >= 2 ?? Effect:|**//Rank - 2//**^^One target in your Current or an Adjacent Zone loses 1 Grit.  If the target is wounded, they lose 2 Grit instead.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_heart_of_cruelty} >= 4 ?? Effect:|**//Rank - 4//**^^One target in your Current or an Adjacent Zone loses 1 Grit.  If the target is wounded, they lose 3 Grit instead.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_heart_of_cruelty} >= 6 ?? Effect:|**//Rank - 6//**^^One target in your Current or an Adjacent Zone loses 1 Grit.  If the target is wounded, they lose 4 Grit instead.
# }}">Mori</button>
# <br><em></em><br><strong>Strain &mdash; 1</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">2</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone loses 1 Grit.  If the target is wounded, they lose 2 Grit instead.</div><div class="arcana-data">4</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone loses 1 Grit.  If the target is wounded, they lose 3 Grit instead.</div><div class="arcana-data">6</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone loses 1 Grit.  If the target is wounded, they lose 4 Grit instead.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Heart of Cruelty
#     --Aspect|Plaga
#     --Type|Ability
#     --Cost|1
#     --api_modattr|_name @{character_name} _strain|1
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_plaga}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_heart_of_cruelty} >= 2 ?? Effect:|**//Rank - 2//**^^One target in your Current or an Adjacent Zone gains Vulnerable 2.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_heart_of_cruelty} >= 4 ?? Effect:|**//Rank - 4//**^^One target in your Current or an Adjacent Zone gains Vulnerable X, where X is equal to Hits in the result set.
# }}">Plaga</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 1</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">2</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone gains Vulnerable 2.</div><div class="arcana-data">4</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone gains Vulnerable X, where X is equal to Hits in the result set.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Shattered Peace</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_shattered_peace" type="number" value="0" step="1" max="4" /> of 4</label>
# <h4 style="margin:3px;">Threshold &mdash; 2</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Shattered Peace
#     --Aspect|Bellor
#     --Type|Trigger
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_bellor}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_shattered_peace} >= 2 ?? Effect:|**//Rank - 2//**^^When you make an Initiative Test, add +1d4 Bonus Hits to the result set
# --?? $arcana.ss >= 2 AND @{arc_rank_the_shattered_peace} >= 4 ?? Effect:|**//Rank - 4//**^^When you and up to X allies in your Current Zone make an Initiative Test, add +1d4 Bonus Hits to the result set
# }}">Bellor</button>
# <br><em>Trigger</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">2</div>
# <div class="arcana-data">When you make an Initiative Test, add +1d4 Bonus Hits to the result set</div><div class="arcana-data">4</div>
# <div class="arcana-data">When you and up to X allies in your Current Zone make an Initiative Test, add +1d4 Bonus Hits to the result set</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Shattered Peace
#     --Aspect|Ordi
#     --Type|Shift
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_ordi}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_shattered_peace} >= 1 ?? Effect:|**//Rank - 1//**^^Until the end of your next turn, if you or your allies would increase the Momentum, increase the Momentum an additional +1.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_shattered_peace} >= 3 ?? Effect:|**//Rank - 3//**^^Until the end of your next turn, if you or your allies would increase the Momentum, increase the Momentum an additional +1.  If the Momenumt reachesh 10+, you gain +1 Renonwn.
# }}">Ordi</button>
# <br><em>Shift</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">Until the end of your next turn, if you or your allies would increase the Momentum, increase the Momentum an additional +1.</div><div class="arcana-data">3</div>
# <div class="arcana-data">Until the end of your next turn, if you or your allies would increase the Momentum, increase the Momentum an additional +1.  If the Momenumt reachesh 10+, you gain +1 Renonwn.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Quiet</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_quiet" type="number" value="0" step="1" max="5" /> of 5</label>
# <h4 style="margin:3px;">Threshold &mdash; 2</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Quiet
#     --Aspect|Nihil
#     --Type|Ability
#     --Cost|5
#     --api_modattr|_name @{character_name} _strain|5
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_nihil}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_quiet} >= 2 ?? Effect:|**//Rank - 2//**^^You Current Zone gains the Silent keyword ongoing.  All targets in your Current Zone gain Blind 1 Ongoing.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_quiet} >= 5 ?? Effect:|**//Rank - 5//**^^You Current and all Adjacent Zones gains the Silent keyword ongoing.  All targets in the effected Zones gain Blind 1 Ongoing.
# }}">Nihil</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 5</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">2</div>
# <div class="arcana-data">You Current Zone gains the Silent keyword ongoing.  All targets in your Current Zone gain Blind 1 Ongoing.</div><div class="arcana-data">5</div>
# <div class="arcana-data">You Current and all Adjacent Zones gains the Silent keyword ongoing.  All targets in the effected Zones gain Blind 1 Ongoing.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Forgotten Cold</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_forgotten_cold" type="number" value="0" step="1" max="5" /> of 5</label>
# <h4 style="margin:3px;">Threshold &mdash; 3</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Forgotten Cold
#     --Aspect|Intuit
#     --Type|Ability
#     --Cost|1
#     --api_modattr|_name @{character_name} _strain|1
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_intuit}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_forgotten_cold} >= 1 ?? Effect:|**//Rank - 1//**^^You gain Aura X, where X is equal to Hits in the result set.  While the Aura persists, you ignore Hazards when you Shift to Move.
# ...
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Vihreän Astri</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_vihreän_astri" type="number" value="0" step="1" max="4" /> of 4</label>
# <h4 style="margin:3px;">Threshold &mdash; 2</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Vihreän Astri
#     --Aspect|Lux
#     --Type|Ability
#     --Cost|2
#     --api_modattr|_name @{character_name} _strain|2
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_lux}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_vihreän_astri} >= 1 ?? Effect:|**//Rank - 1//**^^One target in your Current or an Adjacent Zone takes 1 Hits and gains Fatigued 1, where X is equal to Hits in the result set.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_vihreän_astri} >= 2 ?? Effect:|**//Rank - 2//**^^One target in your Current or an Adjacent Zone takes X Hits and gains Fatigued 1, where X is equal to Hits in the result set.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_vihreän_astri} >= 4 ?? Effect:|**//Rank - 4//**^^One target in your Current or an Adjacent Zone takes X Hits and gains Fatigued X, where X is equal to Hits in the result set.
# }}">Lux</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 2</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone takes 1 Hits and gains Fatigued 1, where X is equal to Hits in the result set.</div><div class="arcana-data">2</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone takes X Hits and gains Fatigued 1, where X is equal to Hits in the result set.</div><div class="arcana-data">4</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone takes X Hits and gains Fatigued X, where X is equal to Hits in the result set.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Vihreän Astri
#     --Aspect|Ordi
#     --Type|Shift
#     --Cost|1
#     --api_modattr|_name @{character_name} _strain|1
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_ordi}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_vihreän_astri} >= 2 ?? Effect:|**//Rank - 2//**^^Reduce your Strain by -1 for each target in your Zone that is Fatigued.<br>Reduce your Strain by -1 for each target in your Zone that is Charmed.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_vihreän_astri} >= 4 ?? Effect:|**//Rank - 4//**^^Reduce your Strain by -1 for each target in your Zone that is Fatigued.<br>Reduce your Strain by -1 for each target in your Zone that is Charmed.<br>Move to an Adjacent Zone ignoring Hazards.
# }}">Ordi</button>
# <br><em>Shift</em><br><strong>Strain &mdash; 1</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">2</div>
# <div class="arcana-data">Reduce your Strain by -1 for each target in your Zone that is Fatigued.<br>Reduce your Strain by -1 for each target in your Zone that is Charmed.</div><div class="arcana-data">4</div>
# <div class="arcana-data">Reduce your Strain by -1 for each target in your Zone that is Fatigued.<br>Reduce your Strain by -1 for each target in your Zone that is Charmed.<br>Move to an Adjacent Zone ignoring Hazards.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Vihreän Astri
#     --Aspect|Plaga
#     --Type|Ability
#     --Cost|None
#     --api_modattr|_name @{character_name} _strain|None
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_plaga}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 2 AND @{arc_rank_the_vihreän_astri} >= 1 ?? Effect:|**//Rank - 1//**^^One target in your Current or an Adjacent Zone loses 1 Grit and gains Charmed 2.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_vihreän_astri} >= 3 ?? Effect:|**//Rank - 3//**^^One target in your Current or an Adjacent Zone loses 3 Grit and gains Charmed 2.
# --?? $arcana.ss >= 2 AND @{arc_rank_the_vihreän_astri} >= 4 ?? Effect:|**//Rank - 4//**^^One target in your Current or an Adjacent Zone loses 3 Grit and gains Charmed X.
# }}">Plaga</button>
# <br><em>Ability</em><br><strong>Strain &mdash; None</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone loses 1 Grit and gains Charmed 2.</div><div class="arcana-data">3</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone loses 3 Grit and gains Charmed 2.</div><div class="arcana-data">4</div>
# <div class="arcana-data">One target in your Current or an Adjacent Zone loses 3 Grit and gains Charmed X.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Sequence</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_sequence" type="number" value="0" step="1" max="8" /> of 8</label>
# <h4 style="margin:3px;">Threshold &mdash; 3</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Sequence
#     --Aspect|Tempor
#     --Type|Ability
#     --Cost|3
#     --api_modattr|_name @{character_name} _strain|3
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_tempor}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_sequence} >= 3 ?? Effect:|**//Rank - 3//**^^Increase the current Timer by +1.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_sequence} >= 5 ?? Effect:|**//Rank - 5//**^^Increase the current Timer by +1.  If the Momentum is 10 or greater, immediately take another Action.  Otherwise, Increase the Momentum by +1.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_sequence} >= 8 ?? Effect:|**//Rank - 8//**^^Increase the current Timer by +1.  If the Momentum is 10 or greater, immediately take another Action.  Otherwise, Increase the Momentum by +X, where X is equal to Hits in the result set.
# }}">Tempor</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 3</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">3</div>
# <div class="arcana-data">Increase the current Timer by +1.</div><div class="arcana-data">5</div>
# <div class="arcana-data">Increase the current Timer by +1.  If the Momentum is 10 or greater, immediately take another Action.  Otherwise, Increase the Momentum by +1.</div><div class="arcana-data">8</div>
# <div class="arcana-data">Increase the current Timer by +1.  If the Momentum is 10 or greater, immediately take another Action.  Otherwise, Increase the Momentum by +X, where X is equal to Hits in the result set.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Sequence
#     --Aspect|Locus
#     --Type|Shift
#     --Cost|3
#     --api_modattr|_name @{character_name} _strain|3
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_locus}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_sequence} >= 3 ?? Effect:|**//Rank - 3//**^^Move one target in your Current or an Adjacent Zone to your Current Zone.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_sequence} >= 5 ?? Effect:|**//Rank - 5//**^^Move one target in your Current or an Adjacent Zone to any Zone Adjacent to your Current Zone.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_sequence} >= 8 ?? Effect:|**//Rank - 8//**^^Move X targets in your Current or an Adjacent Zone to any Zone Adjacent to your Current Zone.
# }}">Locus</button>
# <br><em>Shift</em><br><strong>Strain &mdash; 3</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">3</div>
# <div class="arcana-data">Move one target in your Current or an Adjacent Zone to your Current Zone.</div><div class="arcana-data">5</div>
# <div class="arcana-data">Move one target in your Current or an Adjacent Zone to any Zone Adjacent to your Current Zone.</div><div class="arcana-data">8</div>
# <div class="arcana-data">Move X targets in your Current or an Adjacent Zone to any Zone Adjacent to your Current Zone.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Sequence
#     --Aspect|Arithm
#     --Type|Ability
#     --Cost|6
#     --api_modattr|_name @{character_name} _strain|6
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_arithm}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 3 AND @{arc_rank_the_sequence} >= 3 ?? Effect:|**//Rank - 3//**^^Roll 1d20 + Hits as X.  If X is greater than 17, you gain +1 Milestone.  Otherwise, increase the Entropy by +10.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_sequence} >= 5 ?? Effect:|**//Rank - 5//**^^Roll 1d20 + Hits as X.  If X is greater than 16, you gain +1 Milestone.  Otherwise, increase the Entropy by +10.
# --?? $arcana.ss >= 3 AND @{arc_rank_the_sequence} >= 8 ?? Effect:|**//Rank - 8//**^^Roll 1d20 + Hits as X.  If X is greater than 15, you gain +1 Milestone.  Otherwise, increase the Entropy by +10.
# }}">Arithm</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 6</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">3</div>
# <div class="arcana-data">Roll 1d20 + Hits as X.  If X is greater than 17, you gain +1 Milestone.  Otherwise, increase the Entropy by +10.</div><div class="arcana-data">5</div>
# <div class="arcana-data">Roll 1d20 + Hits as X.  If X is greater than 16, you gain +1 Milestone.  Otherwise, increase the Entropy by +10.</div><div class="arcana-data">8</div>
# <div class="arcana-data">Roll 1d20 + Hits as X.  If X is greater than 15, you gain +1 Milestone.  Otherwise, increase the Entropy by +10.</div></div>
# </div></div>
# <div class="grid-container-arcana">
# <div class="grid-talents-label"><h3 style="margin:3px;">The Recursion</h3>
# <label>Arcana Rank: <input name="attr_arc_rank_the_recursion" type="number" value="0" step="1" max="8" /> of 8</label>
# <h4 style="margin:3px;">Threshold &mdash; 4</h4>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Recursion
#     --Aspect|Tempor
#     --Type|Ability
#     --Cost|5
#     --api_modattr|_name @{character_name} _strain|5
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_tempor}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 4 AND @{arc_rank_the_recursion} >= 2 ?? Effect:|**//Rank - 2//**^^The current Timer ends.
# --?? $arcana.ss >= 4 AND @{arc_rank_the_recursion} >= 5 ?? Effect:|**//Rank - 5//**^^The current Timer ends.  If the Momentum is greater than the Entropy, reduce your Strain by -3.
# --?? $arcana.ss >= 4 AND @{arc_rank_the_recursion} >= 8 ?? Effect:|**//Rank - 8//**^^The current Timer ends.  If the Momentum is greater than the Entropy, reduce your Strain by -X, where X is equal to Hits in the result set.
# }}">Tempor</button>
# <br><em>Ability</em><br><strong>Strain &mdash; 5</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">2</div>
# <div class="arcana-data">The current Timer ends.</div><div class="arcana-data">5</div>
# <div class="arcana-data">The current Timer ends.  If the Momentum is greater than the Entropy, reduce your Strain by -3.</div><div class="arcana-data">8</div>
# <div class="arcana-data">The current Timer ends.  If the Momentum is greater than the Entropy, reduce your Strain by -X, where X is equal to Hits in the result set.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Recursion
#     --Aspect|Vivus
#     --Type|Trigger
#     --Cost|5
#     --api_modattr|_name @{character_name} _strain|5
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_vivus}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 4 AND @{arc_rank_the_recursion} >= 3 ?? Effect:|**//Rank - 3//**^^When the current Timer ends while its value is above 1, you regain +3 Grit.
# --?? $arcana.ss >= 4 AND @{arc_rank_the_recursion} >= 5 ?? Effect:|**//Rank - 5//**^^When the current Timer ends while its value is above 1, you and up to X target in your Current Zone regain +3 Grit.
# --?? $arcana.ss >= 4 AND @{arc_rank_the_recursion} >= 7 ?? Effect:|**//Rank - 7//**^^When the current Timer ends while its value is above 1, you and up to X target in your Current Zone regain +5 Grit.
# }}">Vivus</button>
# <br><em>Trigger</em><br><strong>Strain &mdash; 5</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">3</div>
# <div class="arcana-data">When the current Timer ends while its value is above 1, you regain +3 Grit.</div><div class="arcana-data">5</div>
# <div class="arcana-data">When the current Timer ends while its value is above 1, you and up to X target in your Current Zone regain +3 Grit.</div><div class="arcana-data">7</div>
# <div class="arcana-data">When the current Timer ends while its value is above 1, you and up to X target in your Current Zone regain +5 Grit.</div></div>
# </div><div class="grid-arcana-item"><button class="skill-button" type="roll" value="!power {{
#     --name|@{character_name} - The Recursion
#     --Aspect|Destroy
#     --Type|Trigger
#     --Cost|0
#     --api_modattr|_name @{character_name} _strain|0
#     --Result Set|[[ [$arcana|XPND] @{Cosm|challenge}d@{skill_destroy}>@{Cosm|target}]]
#     --Hits|[^arcana.ss]
#     --1s|[^arcana.ones]
#     --format|powercheck
# --?? $arcana.ss >= 4 AND @{arc_rank_the_recursion} >= 1 ?? Effect:|**//Rank - 1//**^^When the current Timer ends while its value is above 1, all targets in your Current Zone lose -3 Grit.
# --?? $arcana.ss >= 4 AND @{arc_rank_the_recursion} >= 4 ?? Effect:|**//Rank - 4//**^^When the current Timer ends while its value is above 1, all targets in your Current Zone except for you lose -3 Grit.
# --?? $arcana.ss >= 4 AND @{arc_rank_the_recursion} >= 8 ?? Effect:|**//Rank - 8//**^^When the current Timer ends while its value is above 1, all targets in your Current Zone except for you lose -5 Grit.  If a target dies from this effect, set a new Timer to 2 and immediately take an Action.
# }}">Destroy</button>
# <br><em>Trigger</em><br><strong>Strain &mdash; 0</strong>
# <div class="grid-arcana-table">
# <div class="arcana-data">Rank</div>
# <div class="arcana-data">Effect</div>
# <div class="arcana-data">1</div>
# <div class="arcana-data">When the current Timer ends while its value is above 1, all targets in your Current Zone lose -3 Grit.</div><div class="arcana-data">4</div>
# <div class="arcana-data">When the current Timer ends while its value is above 1, all targets in your Current Zone except for you lose -3 Grit.</div><div class="arcana-data">8</div>
# <div class="arcana-data">When the current Timer ends while its value is above 1, all targets in your Current Zone except for you lose -5 Grit.  If a target dies from this effect, set a new Timer to 2 and immediately take an Action.</div></div>
# </div></div>

# %%
for index, arc in df_arcana.iterrows():
    # arc = df_arcana[df_arcana.index == i].copy()
    print(f'''{arc['name']}''')
    print('Max Ranks &mdash; ' +str(arc['max_ranks']))
    print('Threshold: ' + str(arc['threshold']))
    if arc['requires'] is not None:
        print(arc['requires'])
    for a in arc['aspects']:
        # for a in l:
        if a['skill'] is not None:
            print(a['skill'])
        if a['type'] is not None:
            print(a['type'])
        if a['strain'] is not None:
            print(a['strain'])
        for e in a['effects']:
            if e['ranks'] is not None:
                print('--- Rank:  ' + str(e['ranks']))
            if e['effect'] is not None:
                print('--- Effect:  ' + e['effect'])
# Out:
# The Prime Conflagration
# Max Ranks &mdash; 4
# Threshold: 2.0
# Inferno
# Ability
# 5
# --- Rank:  0
# --- Effect:  Deal Hits to 1 target in your Current or an Adjacent Zone.
# --- Rank:  1
# --- Effect:  Deal Hits to 1 target in your Current or an Adjacent Zone.  Reduce your Strain by 1.
# --- Rank:  4
# --- Effect:  Deal Hits to 2 targets in your Current or an Adjacent Zone.  Reduce your Strain by 2.
# Aether
# Shift
# 5
# --- Rank:  0
# --- Effect:  Score 2+ Hits to have 1 target in your Current Zone gains Dazed.
# --- Rank:  1
# --- Effect:  Score 2+ Hits to have up to 2 targets in your Current Zone gain Dazed.
# --- Rank:  4
# --- Effect:  Score 2+ Hits to have up to Hits targets in your Current Zone gain Dazed.
# The Flame of Affliction
# Max Ranks &mdash; 7
# Threshold: nan
# Inferno
# Ability
# 3
# --- Rank:  3
# --- Effect:  Deal Hits to 1 target's Grit, ignoring all Defenses.
# --- Rank:  7
# --- Effect:  Deal Hits to all target's Grit, ignoring all Defenses.
# Mori
# Trigger
# 5
# --- Rank:  5
# --- Effect:  When a target you can see in your Current Zone dies, restore Hits to your Grit.
# Plaga
# Ability
# 1
# --- Rank:  3
# --- Effect:  One target in your Current or an Adjacent Zone gains Fatigued 1.
# --- Rank:  5
# --- Effect:  One target in your Current or an Adjacent Zone gains Fatigued 2.
# --- Rank:  7
# --- Effect:  All targets in your Current or an Adjacent Zone gains Fatigued 2.
# The Eternal Cycle
# Max Ranks &mdash; 5
# Threshold: 2.0
# Mori
# Ability
# 1
# --- Rank:  2
# --- Effect:  One target in your Current or an Adjacent Zone loses 2 Grit and one target in your Current Zone reduces their Dying rating by -1.
# --- Rank:  5
# --- Effect:  One target in your Current or an Adjacent Zone loses X Grit and one target in your Current Zone reduces their Dying rating by -1, where X is equal to Hits in the result set.
# Vivus
# Ability
# 1
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone regains X Grit, where X is equal to Hits in the result set.
# --- Rank:  5
# --- Effect:  One target in your Current or an Adjacent Zone regains X Grit and one other target in your Current or an Adjacent Zone gains Wounded 1, where X is equal to Hits in the result set.
# The Great Tapestry
# Max Ranks &mdash; 8
# Threshold: nan
# Aether
#
# Tempor
#
# Locus
#
# Lux
#
# Mori
#
# Nox
#
# Vivus
#
# The Silent War
# Max Ranks &mdash; 4
# Threshold: 1.0
# Bellor
# Trigger
# 2
# --- Rank:  1
# --- Effect:  When you make an Initiative Test using Tactics, add +1d4 Bonus Hits to the result set
# Destroy
# Shift
# 2
# --- Rank:  2
# --- Effect:  You gain Aura X to add +1d4 Bonus Hits to any Action using Shoot or Strike, where X is equal to Hits in the result set.
# --- Rank:  4
# --- Effect:  You gain Aura X. Add +2d4 Bonus Hits to any Action using Shoot or Strike while the Aura persists., where X is equal to Hits in the result set.
# Nox
# Shift
# 2
# --- Rank:  1
# --- Effect:  Target your Current and an Adjacent Zone.  The targeted Zone gains the Silent keyword until the beginning of your next turn.
# --- Rank:  1
# --- Effect:  Your Current and all Adjacent Zones gain the Silent keyword until the beginning of your next turn.
# The Fractured Mirror
# Max Ranks &mdash; 3
# Threshold: 3.0
# Tempor
# Ability
# 2
# --- Rank:  1
# --- Effect:  Increase the current Timer by +1.
# --- Rank:  3
# --- Effect:  Increase the current Timer by +1.
# Locus
# Shift
# 1
# --- Rank:  1
# --- Effect:  You move to any Adjacent Zone ignoring Hazards.
# --- Rank:  3
# --- Effect:  You and up to X targets move to any Adjacent Zone ignoring Hazards, where X is equal to Hits in the result set.
# Luck
# Shift
# 3
# --- Rank:  1
# --- Effect:  Increase the Momentum by +2.
# --- Rank:  3
# --- Effect:  Decrease the Entropy by -2 and increase the Momentum by +2.
# Mentis
# Ability
# 1
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone gains Stunned 1.
# --- Rank:  3
# --- Effect:  Up to X targets in your Current or an Adjacent Zone gain Stunned 1.
# The Iron Moon
# Max Ranks &mdash; 5
# Threshold: 2.0
# Bellor
# Shift
# 1
# --- Rank:  1
# --- Effect:  Increase the Entrpy by +2.  Up to X targets in your Current Zone gain Afraid 2, where X is equal to Hits in the result set.
# --- Rank:  3
# --- Effect:  Increase the Entrpy by +1.  Up to X targets in your Current Zone gain Afraid 2, where X is equal to Hits in the result set.
# --- Rank:  5
# --- Effect:  Up to X targets in your Current Zone gain Afraid 2, where X is equal to Hits in the result set.
# Destroy
# Shift
# 2
# --- Rank:  1
# --- Effect:  Add +1d4 Bonus Hits to your next Action using Shoot or Strike.
# --- Rank:  5
# --- Effect:  You gain Aura X, where X is equal to Hits in the result set.  While this Aura persists, add +1d4 Bonus Hits to any Action using Shoot or Strike.
# Mori
# Ability
# 1
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone loses X Grit, where X is equal to Hits in the result set.  If the target is Afraid, reduce your Strain by -1.
# --- Rank:  5
# --- Effect:  One target in your Current or an Adjacent Zone loses X Grit and gains Wounded 1, where X is equal to Hits in the result set.  If the target is Afraid, reduce your Strain by -1.
# The Crimson Sun
# Max Ranks &mdash; 5
# Threshold: 2.0
# Bellor
# Shift
# 1
# --- Rank:  1
# --- Effect:  Up to X targets in your Current Zone become Provoked, where X is equal to Hits in the result set.
# --- Rank:  5
# --- Effect:  All targets in your Current Zone become Provoked.
# Lux
# Ability
# 2
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set.  If the target is Provoked, add +1d4 Bonus Hits to the result set.
# --- Rank:  3
# --- Effect:  Up to X targets in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set.  If a target is Provoked, add +1d4 Bonus Hits to the result set.
# Resist
# Shift
# 2
# --- Rank:  3
# --- Effect:  Spend 2 Momentum.  You regain 3 Grit and gain Armor Bonus X, where X is equal to Hits in the result set.
# --- Rank:  5
# --- Effect:  Spend 2 Momentum.  You and up to X target in your Current or an Adjacent Zone regain 3 Grit and gain Armor Bonus X, where X is equal to Hits in the result set.
# The Long Night
# Max Ranks &mdash; 3
# Threshold: 1.0
# Tempor
# Ability
# 2
# --- Rank:  1
# --- Effect:  Increase the current Timer by +1.
# --- Rank:  3
# --- Effect:  Increase the current Timer by +X, where X is equal to Hits in the result set.
# Nox
# Shift
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone gains Blind 1.
# --- Rank:  3
# --- Effect:  Up to X target in your Current or an Adjacent Zone gains Blind 1, where X is equal to Hits in the result set.
# The Growing Dawn
# Max Ranks &mdash; 4
# Threshold: 2.0
# Lux
# Ability
# 2
# --- Rank:  2
# --- Effect:  Up to X targets in your Current or an Adjacent Zone gain Dazed 1.
# --- Rank:  4
# --- Effect:  Up to X targets in your Current or an Adjacent Zone gain Dazed 3.
# Ordi
# Ability
# 1
# --- Rank:  1
# --- Effect:  Score 1 Hit to up to 3 targets in your Current Zone. Reduce your Strain by -1 for each target you score Hits against that is Dazed.
# --- Rank:  4
# --- Effect:  Score X Hit to up to 3 targets in your Current or an Adjacent Zone, X . . . Reduce your Strain by -1 for each target you score Hits against that is Dazed.
# The Coming War
# Max Ranks &mdash; 4
# Threshold: 1.0
# Bellor
# Ability
# 2
# --- Rank:  1
# --- Effect:  Increase the Entropy by X to have X targets gain Fatigued 1, where X is equal to Hits in the result set.
# --- Rank:  4
# --- Effect:  Increase the Entropy by X to have X targets gain Fatigued 3, where X is equal to Hits in the result set.
# Ordi
# Ability
# --- Rank:  1
# --- Effect:  Spend 2 Momentum.  Divide 5 Hits among up to X targets in your Current or an Adjacent Zone, where X is equal to Hits in the result set.  Reduce your Strain by -1 for each each target you score Hits against that is Fatigued.
# --- Rank:  4
# --- Effect:  Spend 2 Momentum.  Divide 10 Hits among up to X targets in your Current or an Adjacent Zone, where X is equal to Hits in the result set.  Reduce your Strain by -1 for each each target you score Hits against that is Fatigued.
# The Heart of Cruelty
# Max Ranks &mdash; 6
# Threshold: 3.0
# Destroy
# Ability
# 2
# --- Rank:  2
# --- Effect:  One target in your Current or an Adjacent Zone gains Wounded 1.
# --- Rank:  4
# --- Effect:  One target in your Current or an Adjacent Zone gains Wounded 2.
# --- Rank:  6
# --- Effect:  One target in your Current or an Adjacent Zone gains Wounded 3.
# Mori
#
# 1
# --- Rank:  2
# --- Effect:  One target in your Current or an Adjacent Zone loses 1 Grit.  If the target is wounded, they lose 2 Grit instead.
# --- Rank:  4
# --- Effect:  One target in your Current or an Adjacent Zone loses 1 Grit.  If the target is wounded, they lose 3 Grit instead.
# --- Rank:  6
# --- Effect:  One target in your Current or an Adjacent Zone loses 1 Grit.  If the target is wounded, they lose 4 Grit instead.
# Plaga
# Ability
# 1
# --- Rank:  2
# --- Effect:  One target in your Current or an Adjacent Zone gains Vulnerable 2.
# --- Rank:  4
# --- Effect:  One target in your Current or an Adjacent Zone gains Vulnerable X, where X is equal to Hits in the result set.
# The Shattered Peace
# Max Ranks &mdash; 4
# Threshold: 2.0
# Bellor
# Trigger
# 2
# --- Rank:  2
# --- Effect:  When you make an Initiative Test, add +1d4 Bonus Hits to the result set
# --- Rank:  4
# --- Effect:  When you and up to X allies in your Current Zone make an Initiative Test, add +1d4 Bonus Hits to the result set
# Ordi
# Shift
# 2
# --- Rank:  1
# --- Effect:  Until the end of your next turn, if you or your allies would increase the Momentum, increase the Momentum an additional +1.
# --- Rank:  3
# --- Effect:  Until the end of your next turn, if you or your allies would increase the Momentum, increase the Momentum an additional +1.  If the Momenumt reachesh 10+, you gain +1 Renonwn.
# The Quiet
# Max Ranks &mdash; 5
# Threshold: 2.0
# Nihil
# Ability
# 5
# --- Rank:  2
# --- Effect:  You Current Zone gains the Silent keyword ongoing.  All targets in your Current Zone gain Blind 1 Ongoing.
# --- Rank:  5
# --- Effect:  You Current and all Adjacent Zones gains the Silent keyword ongoing.  All targets in the effected Zones gain Blind 1 Ongoing.
# The Forgotten Cold
# Max Ranks &mdash; 5
# Threshold: 3.0
# Intuit
# Ability
# 1
# --- Rank:  1
# --- Effect:  You gain Aura X, where X is equal to Hits in the result set.  While the Aura persists, you ignore Hazards when you Shift to Move.
# --- Rank:  5
# --- Effect:  You and up to X targets in your Current Zone gain Aura X, where X is equal to Hits in the result set.  While the Aura persists, all effected targets ignore Hazards when they Shift to Move.
# Mentis
# Ability
# 2
# --- Rank:  1
# --- Effect:  One target in your Current Zone gains Confused 2.
# --- Rank:  5
# --- Effect:  Up to X targets in your Current Zone gains Confused 2.
# Rime
# Ability
# 1
# --- Rank:  1
# --- Effect:  Target your Current or an Adjacent Zone to gain Hazard 3.  All targets in the targeted Zone gain Frozen 1 and take 1 Hit.  Reduce your Strain by -1 for each target that takes Hits from this effect that is Confused.
# --- Rank:  5
# --- Effect:  Target your Current and all Adjacent Zones to gain Hazard 3.  All targets in the targeted Zone gain Frozen 1 and take 1 Hit.  Reduce your Strain by -1 for each target that takes Hits from this effect that is Confused.
# The Lost Winds
# Max Ranks &mdash; 4
# Threshold: 1.0
# Luck
# Shift
# 2
# --- Rank:  1
# --- Effect:  If you score 3+ Hits on your next Action, choose one (1):<ul><li>Increase the Momentum by +3.</li><li>You gain +1 Renown.</li><li>You gain +3 Wealth.</li></ul>
# --- Rank:  4
# --- Effect:  If you score 3+ Hits on your next Action, choose up to two (2):<ul><li>Increase the Momentum by +3.</li><li>You gain +1 Renown.</li><li>You gain +3 Wealth.</li></ul>
# Squall
# Shift
# 1
# --- Rank:  1
# --- Effect:  Add +X Bonus Hits to your next Action using Operate, Shoot, or Tumble, where X is equal to Hits in the result set.
# --- Rank:  4
# --- Effect:  Add +Xd4 Bonus Hits to your next Action using Operate, Shoot, or Tumble, where X is equal to Hits in the result set.
# The Black Sun
# Max Ranks &mdash; 8
# Threshold: 3.0
# Destroy
# Ability
# 5
# --- Rank:  4
# --- Effect:  All targets in your Current or an Adjacent Zone lose 2 Grit.  Reduce your Strain by 2.
# --- Rank:  8
# --- Effect:  All targets in your Current or an Adjacent Zone take Lose X Grit, where X is equal to Hits in the result set.  Reduce your Strain by the total Grit lost from the effect.  Increase the Entropy by +5.
# Lux
# Ability
# 5
# --- Rank:  4
# --- Effect:  X targets in your Current Zone gain Charmed 2.
# --- Rank:  6
# --- Effect:  X targets in your Current Zone gain Charmed 5.
# Nox
# Ability
# 5
# --- Rank:  2
# --- Effect:  Up to X Targets in your Current or an Adjacent Zone gain Stunned 2, where X is equal to Hits in the result set.
# --- Rank:  4
# --- Effect:  Up to X Targets in your Current or an Adjacent Zone gain Stunned 4, where X is equal to Hits in the result set.
# Ordi
# Shift
# 5
# --- Rank:  2
# --- Effect:  You recover +1 to your Primary Defense for each target in your Current Zone that are Charmed or Stunned.
# --- Rank:  6
# --- Effect:  You recover +X to your Primary Defense, where X is equal to the number of target in your Current Zone that are Charmed or Stunned.
# The Ebon Field
# Max Ranks &mdash; 5
# Threshold: 2.0
# Locus
# Shift
# 1
# --- Rank:  1
# --- Effect:  You may Shift to Move up to 2 Adjacent Zones ignoring Hazards.  You gain Fatigued 1.  Increase the Entropy by +1.
# --- Rank:  3
# --- Effect:  One target in your Current Zone Shifts to Move up to 2 Adjacent Zones ignoring Hazards.  The target gain Fatigued 1.  Increase the Entropy by +3.
# --- Rank:  5
# --- Effect:  Up to X targets in your Current Zone may Shift to Move up to 2 Adjacent Zones ignoring Hazards.  All targets gain Fatigued 1.  Increase the Entropy by +3.
# Nihil
# Ability
# 3
# --- Rank:  1
# --- Effect:  You reduce one Status by X.  Increase the Entropy by +1.
# --- Rank:  3
# --- Effect:  You and one target in your Current Zone reduce one Status by X.  Increase the Entropy by +2.
# --- Rank:  5
# --- Effect:  You reduce all Statuses of allies in your Current Zone by X.  Increase the Entropy by +5.
# Nox
# Ability
# 2
# --- Rank:  1
# --- Effect:  One target in your Current Zone gains Blind 1.  Increase the Entropy by +1.
# --- Rank:  3
# --- Effect:  One target in your Current Zone gains Blind 3.  Increase the Entropy by +4.
# --- Rank:  1
# --- Effect:  Up to X targets in your Current Zone gain Blind 3, where X is equal to Hits in the result set.  Increase the Entropy by +5.
# The Eternal Bloom
# Max Ranks &mdash; 4
# Threshold: nan
# Phylla
# Ability
# 1
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone gains Restrained X, where X is equal to Hits in the result set.
# --- Rank:  2
# --- Effect:  All targets in your Current or an Adjacent Zone gain Restrained 2.
# --- Rank:  4
# --- Effect:  All targets except you in your Current or an Adjacent Zone gain Restrained X.
# Tellus
# Ability
# 1
# --- Rank:  1
# --- Effect:  Target your Current or an Adjacent Zone.  The targeted Zone gains Hazard 2 and all targets in the Zone take 1 Hit and lose the Flying keyword until the beginning of your next turn.
# --- Rank:  2
# --- Effect:  Target your Current or an Adjacent Zone.  The targeted Zone gains Hazard 2 and all targets in the Zone take 2 Hits and lose the Flying keyword until the beginning of your next turn.
# --- Rank:  4
# --- Effect:  Target your Current and all Adjacent Zones.  The targeted Zones gain Hazard 2 and all targets in the Zones take 2 Hits and lose the Flying keyword until the beginning of your next turn.
# Vivus
# Shift
# 1
# --- Rank:  1
# --- Effect:  Reduce your Strain by 3.  You gain Aura 2.  While the Aura persists, any target that uses an Action to Recover in your Current Zone regains +1 Grit.
# --- Rank:  2
# --- Effect:  Reduce your Strain by 3.  You gain Aura X.  While the Aura persists, any target that uses an Action to Recover in your Current Zone regains +1 Grit.
# --- Rank:  1
# --- Effect:  Reduce your Strain by 3.  You gain Aura X, where X is equal to Hits in the result set.  While the Aura persists, any target that uses an Action to Recover in your Current Zone regains +X Grit.
# The Void's Embrace
# Max Ranks &mdash; 4
# Threshold: nan
# Forma
#
# Nihil
#
# The Whispering Stars
# Max Ranks &mdash; 4
# Threshold: nan
# Aether
# Ability
# 1
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone gains Charmed 2 and Dazed 1, where X is equal to Hits in the result set.
# --- Rank:  2
# --- Effect:  One target in your Current or an Adjacent Zone gains Charmed X and Dazed 1, where X is equal to Hits in the result set.
# --- Rank:  4
# --- Effect:  One target in your Current or an Adjacent Zone gains Charmed X and Dazed x, where X is equal to Hits in the result set.
# Locus
# Shift
# 1
# --- Rank:  1
# --- Effect:  Select one target in an Adjacent from your Current Zone.  You switch places with the target, both ignoring Hazards from the movement.
# --- Rank:  2
# --- Effect:  Select one target up to two Zones Adjacent from your Current Zone.  You switch places with the target, both ignoring Hazards from the movement.
# --- Rank:  4
# --- Effect:  Select one target upt to two Zones Adjacent from your Current Zone.  You switch places with the target, both ignoring Hazards from the movement.  The target gains Dazed 1.
# Lux
# Ability
# 2
# --- Rank:  1
# --- Effect:  One target in yoru Current Zone gains Blind 1 and Provoked 1.
# --- Rank:  2
# --- Effect:  One target in yoru Current Zone gains Blind 1 and Provoked X, where X is equal to Hits in the result set.
# --- Rank:  4
# --- Effect:  One target in yoru Current Zone gains Blind 2 and Provoked X, where X is equal to Hits in the result set.
# Nox
# Ability
# 1
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone gains Confused 2 and Silenced 1.
# --- Rank:  2
# --- Effect:  One target in your Current or an Adjacent Zone gains Confused X and Silenced 2.
# --- Rank:  4
# --- Effect:  One target in your Current or an Adjacent Zone gains Confused X, Silenced X, and Vulnerable 1.
# The Celestial Conflux
# Max Ranks &mdash; 5
# Threshold: 2.0
# Aether
# Shift
# 2
# --- Rank:  2
# --- Effect:  Up to X targets in your Current Zone gain Vulnerable 2, where X is equal to Hits in the result set.
# --- Rank:  5
# --- Effect:  All targets in your Current Zone gain Vulnerable 2.
# Lux
# Ability
# 1
# --- Rank:  2
# --- Effect:  Up to X targets in your Current Zone take 1 Hit, where X is equal to Hits in the result set.  Redduce your Strain by -2.
# --- Rank:  2
# --- Effect:  Up to X targets in your Current Zone take 1 Hit, where X is equal to Hits in the result set.  Reduce your Strain by the number of targets with Vulnerable that suffered Hits from this effect.
# The Dreamer's Well
# Max Ranks &mdash; 4
# Threshold: 2.0
# Aether
# Ability
# 3
# --- Rank:  1
# --- Effect:  Increase the Entropy by +1 and gain a vision of one target of your choice, learning the target's current location.
# --- Rank:  4
# --- Effect:  Increase the Entropy by +1 and gain a vision of one target of your choice, learning the target's current location.  Reduce your Straing by X, where X is equal to Hits in the result set.
# Mentis
# Ability
# --- Rank:  1
# --- Effect:  Increase the Entropy by +2 and you may ask the BAMF one <em>'Yes or No'</em> question about the game fiction.
# --- Rank:  4
# --- Effect:  You gain Fatigued 2 and the BAMF reveals one secret to you about the game fiction.
# The Tempest Core
# Max Ranks &mdash; 5
# Threshold: 3.0
# Squall
# Ability
# 2
# --- Rank:  2
# --- Effect:  Move one target in your Current Zone away from you one Adjacent Zone.
# --- Rank:  5
# --- Effect:  Move up to X targets in your Current Zone away from you one Adjacent Zone, where X is equal to Hits in the result set.
# Tempest
# Ability
# 2
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone takes 2 Hits.
# --- Rank:  3
# --- Effect:  One target in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set.
# Torrent
# Ability
# 1
# --- Rank:  1
# --- Effect:  Target your Current or an Adjacent Zone to gain Hazard 3.  All targets in the targeted Zone gain Fatigued 1 and take 1 Hit.
# --- Rank:  4
# --- Effect:  Target your Current and all Adjacent Zones to gain Hazard 3.  All targets in the targeted Zones gain Fatigued 1 and take 1 Hit.  Reduce your Strain by -1 for each target that takes Hits from this effect that is Fatigued.
# The Luminous Shard
# Max Ranks &mdash; 3
# Threshold: nan
# Lux
# Ability
# 2
# --- Rank:  1
# --- Effect:  Up to X targets in your Current or an Adjacent Zone gain Blind 1.
# --- Rank:  3
# --- Effect:  Up to X targets in your Current or an Adjacent Zone gain Blind 1 and take X Hits, where X is equal to Hits in the result set.
# Tellus
# Ability
# 2
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone gains Restrained 2.  Reduce your strain by X if the target is Blind, where X is equal to Hits in the result set.
# --- Rank:  3
# --- Effect:  Up to X targets in your Current or an Adjacent Zone gain Restrained 2.  Reduce your strain by -1 for each target who gains Restrained if they are Blind.
# The Endless Ruin
# Max Ranks &mdash; 6
# Threshold: nan
# Bellor
# Ability
# 2
# --- Rank:  2
# --- Effect:  Increase the Entropy by +1.  You gain Aura 1.  While this Aura persists, you can ignore Hazards when the use a Shift to Move.
# --- Rank:  4
# --- Effect:  Increase the Entropy by +1.  You and up to X targets gain Aura 2, where X is equal to Hits in the result set.  While this Aura persists, affected targets ignore Hazards when the use a Shift to Move.
# --- Rank:  6
# --- Effect:  Increase the Entropy by +1.  You and up to X targets gain Aura X, where X is equal to Hits in the result set.  While this Aura persists, affected targets can ignore Hazards when the use a Shift to Move.
# Destroy
# Ability
# 2
# --- Rank:  2
# --- Effect:  Your Current or an Adjacent Zone to gains Hazard 2.
# --- Rank:  4
# --- Effect:  Your Current and all Adjacent Zones to gain Hazard 2.
# --- Rank:  4
# --- Effect:  Your Current and all Adjacent Zones to gain Hazard 4.
# Mori
# Ability
# 2
# --- Rank:  2
# --- Effect:  One target in your Current or an Adjacent Zone loses -X Grit, where X is euqal to the number of Hazards in the target's Current Zone.  Reduce your Strain by -1.
# --- Rank:  4
# --- Effect:  All targets in your Current or an Adjacent Zone lose -X Grit, where X is euqal to the number of Hazards in the target's Current Zone.  Reduce your Strain by -X.
# --- Rank:  6
# --- Effect:  All targets in your Current or an Adjacent Zone loses -X Grit, where X is euqal to the number of Hazards in the target's Current Zone.  Reduce your Strain by -Y, where Y is equal to the total Grit the targets of this effect lose.
# The Blood Hand
# Max Ranks &mdash; 3
# Threshold: 3.0
# Inferno
# Ability
# 2
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set.  If the target is Wounded, reduce your Strain by -2.
# --- Rank:  3
# --- Effect:  One target in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set.  If the target is Wounded, reduce your Strain by -X.
# Sangui
# Ability
# 1
# --- Rank:  1
# --- Effect:  One target in your Current Zone gains Fatigued 1.
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone gains Fatigued 1 and Wounded 1.
# The Bleeding Tome
# Max Ranks &mdash; 4
# Threshold: 3.0
# Mori
# Ability
# 3
# --- Rank:  1
# --- Effect:  One target in your Current Zone gains Fatigued 1 and loses 1 Grit.  Reduce your Strain by -1 if the target is Vulnerable.
# --- Rank:  3
# --- Effect:  One target in your Current Zone gains Fatigued 1 and loses 3 Grit.  Reduce your Strain by -1 if the target is Vulnerable.
# --- Rank:  4
# --- Effect:  One target in your Current Zone gains Fatigued 1 and loses X Grit, where X is equal to Hits in the result set.  Reduce your Strain by -3 if the target is Vulnerable.
# Plaga
# Ability
# 1
# --- Rank:  1
# --- Effect:  One target in your Current Zone gains Vulnerable 1.
# --- Rank:  2
# --- Effect:  One target in your Current Zone gains Vulnerable 2.
# --- Rank:  3
# --- Effect:  One target in your Current Zone gains Vulnerable 2.  Reduce the Entropy by -2.
# Sangui
# Ability
# --- Rank:  1
# --- Effect:  One target in your Current Zone takes 2 Hits.  You regain 2 Grit if the target is Fatigued.
# --- Rank:  2
# --- Effect:  One target in your Current Zone takes X Hits, where X is equal to Hits in the result set.  You regain 2 Grit if the target is Fatigued.
# --- Rank:  4
# --- Effect:  One target in your Current Zone takes X Hits, where X is equal to Hits in the result set.  You regain X Grit if the target is Fatigued.
# The Hungering Tide
# Max Ranks &mdash; 5
# Threshold: 3.0
# Destroy
# Ability
# 2
# --- Rank:  2
# --- Effect:  One target in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set.  If the target is Dazed, your recover 2 to your Primary Defense.
# --- Rank:  4
# --- Effect:  One target in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set.  If the target is Dazed, your recover X to your Primary Defense.
# --- Rank:  5
# --- Effect:  All targets in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set.  If a target is Dazed, your recover X to your Primary Defense.
# Tellus
#
# --- Rank:  2
# --- Effect:  All targets in your Current Zone become Prone.
# --- Rank:  3
# --- Effect:  All targets in your Current Zone take become Prone and gain Dazed 1.
# --- Rank:  5
# --- Effect:  All targets in your Current Zone take become Prone and gain Dazed X, where X is equal to Hits in the result set.
# Torrent
#
# --- Rank:  2
# --- Effect:  Move one target in your Curent Zone away from you to an Adjacent Zone.  If the target is Prone, it loses X Grit, where X is equal to Hits in the result set.
# --- Rank:  3
# --- Effect:  Move all targets in your Current or an Adjacent Zone up to one Adjacent Zone from their Current Zone.  If a target is Prone, it loses X Grit, where X is equal to Hits in the result set.
# --- Rank:  5
# --- Effect:  Move up to X targets in your Current or an Adjacent Zone up to one Adjacent Zone from their Current Zone.  If the target is Prone, it loses X Grit, where X is equal to Hits in the result set.  If a target is Dazed, reduce your Strain by X.
# The Vihreän Astri
# Max Ranks &mdash; 4
# Threshold: 2.0
# Lux
# Ability
# 2
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone takes 1 Hits and gains Fatigued 1, where X is equal to Hits in the result set.
# --- Rank:  2
# --- Effect:  One target in your Current or an Adjacent Zone takes X Hits and gains Fatigued 1, where X is equal to Hits in the result set.
# --- Rank:  4
# --- Effect:  One target in your Current or an Adjacent Zone takes X Hits and gains Fatigued X, where X is equal to Hits in the result set.
# Ordi
# Shift
# 1
# --- Rank:  2
# --- Effect:  Reduce your Strain by -1 for each target in your Zone that is Fatigued.<br>Reduce your Strain by -1 for each target in your Zone that is Charmed.
# --- Rank:  4
# --- Effect:  Reduce your Strain by -1 for each target in your Zone that is Fatigued.<br>Reduce your Strain by -1 for each target in your Zone that is Charmed.<br>Move to an Adjacent Zone ignoring Hazards.
# Plaga
# Ability
# --- Rank:  1
# --- Effect:  One target in your Current or an Adjacent Zone loses 1 Grit and gains Charmed 2.
# --- Rank:  3
# --- Effect:  One target in your Current or an Adjacent Zone loses 3 Grit and gains Charmed 2.
# --- Rank:  4
# --- Effect:  One target in your Current or an Adjacent Zone loses 3 Grit and gains Charmed X.
# The Sequence
# Max Ranks &mdash; 8
# Threshold: 3.0
# Tempor
# Ability
# 3
# --- Rank:  3
# --- Effect:  Increase the current Timer by +1.
# --- Rank:  5
# --- Effect:  Increase the current Timer by +1.  If the Momentum is 10 or greater, immediately take another Action.  Otherwise, Increase the Momentum by +1.
# --- Rank:  8
# --- Effect:  Increase the current Timer by +1.  If the Momentum is 10 or greater, immediately take another Action.  Otherwise, Increase the Momentum by +X, where X is equal to Hits in the result set.
# Locus
# Shift
# 3
# --- Rank:  3
# --- Effect:  Move one target in your Current or an Adjacent Zone to your Current Zone.
# --- Rank:  5
# --- Effect:  Move one target in your Current or an Adjacent Zone to any Zone Adjacent to your Current Zone.
# --- Rank:  8
# --- Effect:  Move X targets in your Current or an Adjacent Zone to any Zone Adjacent to your Current Zone.
# Arithm
# Ability
# 6
# --- Rank:  3
# --- Effect:  Roll 1d20 + Hits as X.  If X is greater than 17, you gain +1 Milestone.  Otherwise, increase the Entropy by +10.
# --- Rank:  5
# --- Effect:  Roll 1d20 + Hits as X.  If X is greater than 16, you gain +1 Milestone.  Otherwise, increase the Entropy by +10.
# --- Rank:  8
# --- Effect:  Roll 1d20 + Hits as X.  If X is greater than 15, you gain +1 Milestone.  Otherwise, increase the Entropy by +10.
# The Recursion
# Max Ranks &mdash; 8
# Threshold: 4.0
# Tempor
# Ability
# 5
# --- Rank:  2
# --- Effect:  The current Timer ends.
# --- Rank:  5
# --- Effect:  The current Timer ends.  If the Momentum is greater than the Entropy, reduce your Strain by -3.
# --- Rank:  8
# --- Effect:  The current Timer ends.  If the Momentum is greater than the Entropy, reduce your Strain by -X, where X is equal to Hits in the result set.
# Vivus
# Trigger
# 5
# --- Rank:  3
# --- Effect:  When the current Timer ends while its value is above 1, you regain +3 Grit.
# --- Rank:  5
# --- Effect:  When the current Timer ends while its value is above 1, you and up to X target in your Current Zone regain +3 Grit.
# --- Rank:  7
# --- Effect:  When the current Timer ends while its value is above 1, you and up to X target in your Current Zone regain +5 Grit.
# Destroy
# Trigger
# 0
# --- Rank:  1
# --- Effect:  When the current Timer ends while its value is above 1, all targets in your Current Zone lose -3 Grit.
# --- Rank:  4
# --- Effect:  When the current Timer ends while its value is above 1, all targets in your Current Zone except for you lose -3 Grit.
# --- Rank:  8
# --- Effect:  When the current Timer ends while its value is above 1, all targets in your Current Zone except for you lose -5 Grit.  If a target dies from this effect, set a new Timer to 2 and immediately take an Action.

# %% [markdown]
# ### Concoctions Start

# %%
df_concoctions = pd.DataFrame.from_records(powers_data['concoctions'])

# %%
df_concoctions.head()
# Out:
#         name    type ranks                                       effect doses  \
# 0       Bear  Elixir     1             Gain +1d6 to your Vigor Defense.     2
# 1       Bear  Elixir     2           Gain +1d6+2 to your Vigor Defense.     2
# 2       Bear  Elixir     3             Gain +2d6 to your Vigor Defense.     2
# 3  Crocodile  Elixir     1  Recover 1d4+1 Hits to your Primary Defense.     3
# 4  Crocodile  Elixir     2  Recover 1d4+2 Hits to your Primary Defense.     3
#
#    dice_spec  \
# 0    [[1d6]]
# 1  [[1d6+2]]
# 2    [[2d6]]
# 3  [[1d4+1]]
# 4  [[1d4+2]]
#
#                                                                                                                                                                      pcard  \
# 0                  !power {{\n--Name|@{character_name} - BearElixir\n--Rank|1\n--Result Set|[[ [$conc|XPND][[1d6]]\n--Effect|Gain +$conc.total  to your Vigor Defense.\n}}
# 1                !power {{\n--Name|@{character_name} - BearElixir\n--Rank|2\n--Result Set|[[ [$conc|XPND][[1d6+2]]\n--Effect|Gain +$conc.total  to your Vigor Defense.\n}}
# 2                  !power {{\n--Name|@{character_name} - BearElixir\n--Rank|3\n--Result Set|[[ [$conc|XPND][[2d6]]\n--Effect|Gain +$conc.total  to your Vigor Defense.\n}}
# 3  !power {{\n--Name|@{character_name} - CrocodileElixir\n--Rank|1\n--Result Set|[[ [$conc|XPND][[1d4+1]]\n--Effect|Recover $conc.total  Hits to your Primary Defense.\n}}
# 4  !power {{\n--Name|@{character_name} - CrocodileElixir\n--Rank|2\n--Result Set|[[ [$conc|XPND][[1d4+2]]\n--Effect|Recover $conc.total  Hits to your Primary Defense.\n}}
#
#                                     pcard_effect
# 0           Gain +"print" to your Vigor Defense.
# 1           Gain +"print" to your Vigor Defense.
# 2           Gain +"print" to your Vigor Defense.
# 3  Recover "print" Hits to your Primary Defense.
# 4  Recover "print" Hits to your Primary Defense.

# %%
df_concoctions['dice_spec'] = df_concoctions['effect'].str.extract(r'(\dd\d*[^\s.]+)')
df_concoctions['pcard_effect'] = df_concoctions['effect'].str.replace(r'(\dd\d*[^\s.]+)', '"print"')
df_concoctions['attr_conc_type_nm'] = '''attr_conc_has_''' + df_concoctions['name'].str.lower()
df_concoctions['attr_conc_rank_nm'] = '''attr_conc_''' + df_concoctions['name'].str.lower() + '''_r''' + df_concoctions['ranks'].astype('str')
# Out:
# C:\Users\DonalHarrison\AppData\Local\Temp\ipykernel_21208\961142440.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_concoctions['pcard_effect'] = df_concoctions['effect'].str.replace(r'(\dd\d*[^\s.]+)', '"print"')

# %%
df_concoctions['pcard'] = '''!power {{
--name|@{character_name} - ''' + df_concoctions['name'] + ''' ''' + df_concoctions['type'] + '''
--Rank|''' + df_concoctions['ranks'] + '''
--Result Set|[[ [$conc|XPND] ''' + df_concoctions['dice_spec'] + ''']]
--Effect|''' + df_concoctions['pcard_effect'].str.replace('"print"', '[^conc.total] ') + '''
--format|shiftcheck
}}'''

df_concoctions['pcard_default'] = '''!power {{
--name|@{character_name} - ''' + df_concoctions['name'] + ''' ''' + df_concoctions['type'] + '''
--Rank|''' + df_concoctions['ranks'] + '''

--Effect|''' + df_concoctions['effect'] + '''
--format|shiftcheck
}}'''

df_concoctions['pcard'].fillna(df_concoctions['pcard_default'], inplace=True)

# %%
df_concoctions.head()
# Out:
#         name    type ranks                                       effect doses  \
# 0       Bear  Elixir     1             Gain +1d6 to your Vigor Defense.     2
# 1       Bear  Elixir     2           Gain +1d6+2 to your Vigor Defense.     2
# 2       Bear  Elixir     3             Gain +2d6 to your Vigor Defense.     2
# 3  Crocodile  Elixir     1  Recover 1d4+1 Hits to your Primary Defense.     3
# 4  Crocodile  Elixir     2  Recover 1d4+2 Hits to your Primary Defense.     3
#
#   dice_spec  \
# 0       1d6
# 1     1d6+2
# 2       2d6
# 3     1d4+1
# 4     1d4+2
#
#                                                                                                                                                                                             pcard  \
# 0                  !power {{\n--name|@{character_name} - Bear Elixir\n--Rank|1\n--Result Set|[[ [$conc|XPND] 1d6]]\n--Effect|Gain +[^conc.total]  to your Vigor Defense.\n--format|shiftcheck\n}}
# 1                !power {{\n--name|@{character_name} - Bear Elixir\n--Rank|2\n--Result Set|[[ [$conc|XPND] 1d6+2]]\n--Effect|Gain +[^conc.total]  to your Vigor Defense.\n--format|shiftcheck\n}}
# 2                  !power {{\n--name|@{character_name} - Bear Elixir\n--Rank|3\n--Result Set|[[ [$conc|XPND] 2d6]]\n--Effect|Gain +[^conc.total]  to your Vigor Defense.\n--format|shiftcheck\n}}
# 3  !power {{\n--name|@{character_name} - Crocodile Elixir\n--Rank|1\n--Result Set|[[ [$conc|XPND] 1d4+1]]\n--Effect|Recover [^conc.total]  Hits to your Primary Defense.\n--format|shiftcheck\n}}
# 4  !power {{\n--name|@{character_name} - Crocodile Elixir\n--Rank|2\n--Result Set|[[ [$conc|XPND] 1d4+2]]\n--Effect|Recover [^conc.total]  Hits to your Primary Defense.\n--format|shiftcheck\n}}
#
#                                     pcard_effect        attr_conc_type_nm  \
# 0           Gain +"print" to your Vigor Defense.       attr_conc_has_bear
# 1           Gain +"print" to your Vigor Defense.       attr_conc_has_bear
# 2           Gain +"print" to your Vigor Defense.       attr_conc_has_bear
# 3  Recover "print" Hits to your Primary Defense.  attr_conc_has_crocodile
# 4  Recover "print" Hits to your Primary Defense.  attr_conc_has_crocodile
#
#         attr_conc_rank_nm
# 0       attr_conc_bear_r1
# 1       attr_conc_bear_r2
# 2       attr_conc_bear_r3
# 3  attr_conc_crocodile_r1
# 4  attr_conc_crocodile_r2

# %%
print(df_concoctions.iloc[0]['pcard'])
# Out:
# !power {{
# --name|@{character_name} - Bear Elixir
# --Rank|1
# --Result Set|[[ [$conc|XPND] 1d6]]
# --Effect|Gain +[^conc.total]  to your Vigor Defense.
# --format|shiftcheck
# }}

# %%
ctype[ctype['name'] == n]['attr_conc_type_nm'].unique()
# Out:
# array(['attr_conc_has_bear'], dtype=object)

# %%
conc = df_concoctions.copy()
div_str = '<div class="grid-container">'
for t in conc['type'].unique():
    div_str += '''<div class="grid-item grid-concoction">''' + t + ''''s</div>\n<div class="grid-container">\n'''
    ctype = conc[conc['type'] == t]
    for n in ctype['name'].unique():
        div_str +='''<div class="grid-item grid-concoction">\n<input type="checkbox" name="''' + ctype[ctype['name'] == n]['attr_conc_type_nm'].unique() + '''" />    ''' + n + '''\n<div class="grid-container-concoction">\n'''
        for j, c in ctype[ctype['name'] == n].iterrows():
            div_str += '''<div class="grid-item">Rank ''' + str(c['ranks']) + '''\n<div class="grid-container grid-concoction">\n''' + c['effect'] + '''<label>Doses<input type="number" name="''' + c['attr_conc_rank_nm'] + '''" value="0" min="0" step="1" /></label>\n<button type="roll" value="''' + c['pcard'] + '''">Use</button>\n</div>\n</div>\n'''
        div_str += '''</div>\n</div>\n'''
    div_str += '''</div>\n'''
div_str += '''</div>\n'''

# %%
print(div_str[0])
# Out:
# <div class="grid-container"><div class="grid-item grid-concoction">Elixir's</div>
# <div class="grid-container">
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_bear" />    Bear
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Gain +1d6 to your Vigor Defense.<label>Doses<input type="number" name="attr_conc_bear_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Bear Elixir
# --Rank|1
# --Result Set|[[ [$conc|XPND] 1d6]]
# --Effect|Gain +[^conc.total]  to your Vigor Defense.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Gain +1d6+2 to your Vigor Defense.<label>Doses<input type="number" name="attr_conc_bear_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Bear Elixir
# --Rank|2
# --Result Set|[[ [$conc|XPND] 1d6+2]]
# --Effect|Gain +[^conc.total]  to your Vigor Defense.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Gain +2d6 to your Vigor Defense.<label>Doses<input type="number" name="attr_conc_bear_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Bear Elixir
# --Rank|3
# --Result Set|[[ [$conc|XPND] 2d6]]
# --Effect|Gain +[^conc.total]  to your Vigor Defense.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_crocodile" />    Crocodile
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Recover 1d4+1 Hits to your Primary Defense.<label>Doses<input type="number" name="attr_conc_crocodile_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Crocodile Elixir
# --Rank|1
# --Result Set|[[ [$conc|XPND] 1d4+1]]
# --Effect|Recover [^conc.total]  Hits to your Primary Defense.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Recover 1d4+2 Hits to your Primary Defense.<label>Doses<input type="number" name="attr_conc_crocodile_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Crocodile Elixir
# --Rank|2
# --Result Set|[[ [$conc|XPND] 1d4+2]]
# --Effect|Recover [^conc.total]  Hits to your Primary Defense.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Recover 2d4+4 Hits to your Primary Defense.<label>Doses<input type="number" name="attr_conc_crocodile_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Crocodile Elixir
# --Rank|3
# --Result Set|[[ [$conc|XPND] 2d4+4]]
# --Effect|Recover [^conc.total]  Hits to your Primary Defense.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_dove" />    Dove
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Gain +1d6 to your Nerve Defense.<label>Doses<input type="number" name="attr_conc_dove_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Dove Elixir
# --Rank|1
# --Result Set|[[ [$conc|XPND] 1d6]]
# --Effect|Gain +[^conc.total]  to your Nerve Defense.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Gain +1d6+2 to your Nerve Defense.<label>Doses<input type="number" name="attr_conc_dove_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Dove Elixir
# --Rank|2
# --Result Set|[[ [$conc|XPND] 1d6+2]]
# --Effect|Gain +[^conc.total]  to your Nerve Defense.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Gain +2d6 to your Nerve Defense.<label>Doses<input type="number" name="attr_conc_dove_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Dove Elixir
# --Rank|3
# --Result Set|[[ [$conc|XPND] 2d6]]
# --Effect|Gain +[^conc.total]  to your Nerve Defense.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_phoenix" />    Phoenix
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Regain 1d4+1 Hits to your Grit.<label>Doses<input type="number" name="attr_conc_phoenix_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Phoenix Elixir
# --Rank|2
# --Result Set|[[ [$conc|XPND] 1d4+1]]
# --Effect|Regain [^conc.total]  Hits to your Grit.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Regain 1d4+1 Hits to your Grit.<label>Doses<input type="number" name="attr_conc_phoenix_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Phoenix Elixir
# --Rank|3
# --Result Set|[[ [$conc|XPND] 1d4+1]]
# --Effect|Regain [^conc.total]  Hits to your Grit.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# Regain 2d4+1 Hits to your Grit.<label>Doses<input type="number" name="attr_conc_phoenix_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Phoenix Elixir
# --Rank|4
# --Result Set|[[ [$conc|XPND] 2d4+1]]
# --Effect|Regain [^conc.total]  Hits to your Grit.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_scorpion" />    Scorpion
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Reduce one Status Rating by -1d4.<label>Doses<input type="number" name="attr_conc_scorpion_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Scorpion Elixir
# --Rank|1
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Reduce one Status Rating by -[^conc.total] .
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Reduce one Status Rating by -2d4.<label>Doses<input type="number" name="attr_conc_scorpion_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Scorpion Elixir
# --Rank|2
# --Result Set|[[ [$conc|XPND] 2d4]]
# --Effect|Reduce one Status Rating by -[^conc.total] .
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Reduce one Status Rating by -3d4.<label>Doses<input type="number" name="attr_conc_scorpion_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Scorpion Elixir
# --Rank|3
# --Result Set|[[ [$conc|XPND] 3d4]]
# --Effect|Reduce one Status Rating by -[^conc.total] .
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_spider" />    Spider
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Reduce the effects of one (1) Poison by -1d4.<label>Doses<input type="number" name="attr_conc_spider_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Spider Elixir
# --Rank|1
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Reduce the effects of one (1) Poison by -[^conc.total] .
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Reduce the effects of one (1) Poison by -1d4.<label>Doses<input type="number" name="attr_conc_spider_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Spider Elixir
# --Rank|2
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Reduce the effects of one (1) Poison by -[^conc.total] .
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Reduce the effects of one (1) Poison by -2d4.<label>Doses<input type="number" name="attr_conc_spider_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Spider Elixir
# --Rank|3
# --Result Set|[[ [$conc|XPND] 2d4]]
# --Effect|Reduce the effects of one (1) Poison by -[^conc.total] .
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_starfish" />    Starfish
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# This turn and on each of your next 3 turns you regain +1 Grit.<label>Doses<input type="number" name="attr_conc_starfish_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Starfish Elixir
# --Rank|2
#
# --Effect|This turn and on each of your next 3 turns you regain +1 Grit.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# This turn and on each of your next 3 turns you regain +2 Grit.<label>Doses<input type="number" name="attr_conc_starfish_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Starfish Elixir
# --Rank|3
#
# --Effect|This turn and on each of your next 3 turns you regain +2 Grit.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# This turn and on each of your next 3 turns you regain +3 Grit.<label>Doses<input type="number" name="attr_conc_starfish_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Starfish Elixir
# --Rank|4
#
# --Effect|This turn and on each of your next 3 turns you regain +3 Grit.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_wyrm" />    Wyrm
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Choose one (1): Recover +1d4 Hits to your Primary Defense, Gain +2 Current, Gain +1 Concordance, Gain +1 Attunement, Reduce your Strain by -1d4+1<label>Doses<input type="number" name="attr_conc_wyrm_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Wyrm Elixir
# --Rank|1
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Choose one (1): Recover +[^conc.total]  Hits to your Primary Defense, Gain +2 Current, Gain +1 Concordance, Gain +1 Attunement, Reduce your Strain by -[^conc.total]
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Choose one (1): Recover +1d6+1 Hits to your Primary Defense, Gain +3 Current, Gain +2 Concordance, Gain +2 Attunement, Reduce your Strain by -1d6+1<label>Doses<input type="number" name="attr_conc_wyrm_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Wyrm Elixir
# --Rank|2
# --Result Set|[[ [$conc|XPND] 1d6+1]]
# --Effect|Choose one (1): Recover +[^conc.total]  Hits to your Primary Defense, Gain +3 Current, Gain +2 Concordance, Gain +2 Attunement, Reduce your Strain by -[^conc.total]
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Choose one (1): Recover +2d6 Hits to your Primary Defense, Gain +4 Current, Gain +3 Concordance, Gain +3 Attunement, Reduce your Strain by 2d6+1<label>Doses<input type="number" name="attr_conc_wyrm_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Wyrm Elixir
# --Rank|3
# --Result Set|[[ [$conc|XPND] 2d6]]
# --Effect|Choose one (1): Recover +[^conc.total]  Hits to your Primary Defense, Gain +4 Current, Gain +3 Concordance, Gain +3 Attunement, Reduce your Strain by [^conc.total]
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">Oil's</div>
# <div class="grid-container">
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_agonist's" />    Agonist's
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 2+ Hits against one target, the target gains Fatigued 1.<label>Doses<input type="number" name="attr_conc_agonist's_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Agonist's Oil
# --Rank|1
#
# --Effect|Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 2+ Hits against one target, the target gains Fatigued 1.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 2+ Hits against one target, the target gains Fatigued 1.<label>Doses<input type="number" name="attr_conc_agonist's_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Agonist's Oil
# --Rank|2
#
# --Effect|Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 2+ Hits against one target, the target gains Fatigued 1.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Your next 3 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score +1d4 Hits against one target, the target gains Fatigued 1.<label>Doses<input type="number" name="attr_conc_agonist's_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Agonist's Oil
# --Rank|3
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Your next 3 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score +[^conc.total]  Hits against one target, the target gains Fatigued 1.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_brushfire" />    Brushfire
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Add +2 Bonus Hits to your next 2 Actions using Shoot or Strike. These bonus Hits cause fire damge.<label>Doses<input type="number" name="attr_conc_brushfire_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Brushfire Oil
# --Rank|2
#
# --Effect|Add +2 Bonus Hits to your next 2 Actions using Shoot or Strike. These bonus Hits cause fire damge.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Add +1d4 Bonus Hits to your next 2 Actions using Shoot or Strike. These bonus Hits cause fire damge.<label>Doses<input type="number" name="attr_conc_brushfire_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Brushfire Oil
# --Rank|3
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Add +[^conc.total]  Bonus Hits to your next 2 Actions using Shoot or Strike. These bonus Hits cause fire damge.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# Add +1d4 Bonus Hits to your next 3 Actions using Shoot or Strike. These bonus Hits cause fire damge.<label>Doses<input type="number" name="attr_conc_brushfire_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Brushfire Oil
# --Rank|4
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Add +[^conc.total]  Bonus Hits to your next 3 Actions using Shoot or Strike. These bonus Hits cause fire damge.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_conductive" />    Conductive
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Any target you score Hits against using Shoot or Strike gains Vulnerable 1 to any Hits from lightning or Tempest effects.<label>Doses<input type="number" name="attr_conc_conductive_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Conductive Oil
# --Rank|2
#
# --Effect|Any target you score Hits against using Shoot or Strike gains Vulnerable 1 to any Hits from lightning or Tempest effects.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Any target you score Hits against using Shoot or Strike gains Vulnerable 1 to any Hits from lightning or Tempest effects.<label>Doses<input type="number" name="attr_conc_conductive_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Conductive Oil
# --Rank|3
#
# --Effect|Any target you score Hits against using Shoot or Strike gains Vulnerable 1 to any Hits from lightning or Tempest effects.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# Any target you score Hits against using Shoot or Strike gains Vulnerable 2 to any Hits from lightning or Tempest effects.<label>Doses<input type="number" name="attr_conc_conductive_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Conductive Oil
# --Rank|4
#
# --Effect|Any target you score Hits against using Shoot or Strike gains Vulnerable 2 to any Hits from lightning or Tempest effects.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_executioner's" />    Executioner's
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Add +1 Bonus Hits to your next 2 Actions using Strike.<label>Doses<input type="number" name="attr_conc_executioner's_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Executioner's Oil
# --Rank|1
#
# --Effect|Add +1 Bonus Hits to your next 2 Actions using Strike.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Add +1d4 Bonus Hits to your next 2 Actions using Strike.<label>Doses<input type="number" name="attr_conc_executioner's_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Executioner's Oil
# --Rank|2
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Add +[^conc.total]  Bonus Hits to your next 2 Actions using Strike.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Add +1d4 Bonus Hits to your next 4 Actions using Strike.<label>Doses<input type="number" name="attr_conc_executioner's_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Executioner's Oil
# --Rank|3
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Add +[^conc.total]  Bonus Hits to your next 4 Actions using Strike.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_glacier" />    Glacier
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 2+ Hits against one target, the target gains Frozen 1.<label>Doses<input type="number" name="attr_conc_glacier_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Glacier Oil
# --Rank|1
#
# --Effect|Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 2+ Hits against one target, the target gains Frozen 1.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 2+ Hits against one target, the target gains Frozen 3.<label>Doses<input type="number" name="attr_conc_glacier_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Glacier Oil
# --Rank|2
#
# --Effect|Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 2+ Hits against one target, the target gains Frozen 3.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you 1+ Hits against one target, the target gains Frozen 3.<label>Doses<input type="number" name="attr_conc_glacier_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Glacier Oil
# --Rank|3
#
# --Effect|Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you 1+ Hits against one target, the target gains Frozen 3.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_holy" />    Holy
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Add +1d4 Bonus Hits against any target with the Undead keyword on your next 3 Actions using Shoot or Strike.<label>Doses<input type="number" name="attr_conc_holy_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Holy Oil
# --Rank|1
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Add +[^conc.total]  Bonus Hits against any target with the Undead keyword on your next 3 Actions using Shoot or Strike.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Add +1d4 Bonus Hits against any target with the Undead keyword on your next 3 Actions using Shoot or Strike.<label>Doses<input type="number" name="attr_conc_holy_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Holy Oil
# --Rank|2
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Add +[^conc.total]  Bonus Hits against any target with the Undead keyword on your next 3 Actions using Shoot or Strike.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Add +1d4 Bonus Hits against any target with the Undead keyword on your next 5 Actions using Shoot or Strike.<label>Doses<input type="number" name="attr_conc_holy_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Holy Oil
# --Rank|3
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Add +[^conc.total]  Bonus Hits against any target with the Undead keyword on your next 5 Actions using Shoot or Strike.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_rusting" />    Rusting
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 3+ Hits against one target, reduce the Gear rating of your target's Armor by -2.<label>Doses<input type="number" name="attr_conc_rusting_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Rusting Oil
# --Rank|1
#
# --Effect|Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 3+ Hits against one target, reduce the Gear rating of your target's Armor by -2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 3+ Hits against one target, reduce the Gear rating of your target's Armor by -2.<label>Doses<input type="number" name="attr_conc_rusting_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Rusting Oil
# --Rank|2
#
# --Effect|Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 3+ Hits against one target, reduce the Gear rating of your target's Armor by -2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Your next 3 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 3+ Hits against one target, reduce the Gear rating of your target's Armor by -2.<label>Doses<input type="number" name="attr_conc_rusting_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Rusting Oil
# --Rank|3
#
# --Effect|Your next 3 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 3+ Hits against one target, reduce the Gear rating of your target's Armor by -2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_stone's eye" />    Stone's Eye
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 3+ Hits against one target, the target gains Blind 1.<label>Doses<input type="number" name="attr_conc_stone's eye_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Stone's Eye Oil
# --Rank|1
#
# --Effect|Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 3+ Hits against one target, the target gains Blind 1.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 3+ Hits against one target, the target gains Blind 2.<label>Doses<input type="number" name="attr_conc_stone's eye_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Stone's Eye Oil
# --Rank|2
#
# --Effect|Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 3+ Hits against one target, the target gains Blind 2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 2+ Hits against one target, the target gains Blind 2.<label>Doses<input type="number" name="attr_conc_stone's eye_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Stone's Eye Oil
# --Rank|3
#
# --Effect|Your next 2 Actions using Shoot or Strike gain the following Trigger: Trigger &mdash; When you score 2+ Hits against one target, the target gains Blind 2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">Poison's</div>
# <div class="grid-container">
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_bloodletter's" />    Bloodletter's
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# This turn and on each of your next 3 turns you lose -1 Grit.<label>Doses<input type="number" name="attr_conc_bloodletter's_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Bloodletter's Poison
# --Rank|2
#
# --Effect|This turn and on each of your next 3 turns you lose -1 Grit.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# This turn and on each of your next 3 turns you lose -1 Grit.<label>Doses<input type="number" name="attr_conc_bloodletter's_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Bloodletter's Poison
# --Rank|3
#
# --Effect|This turn and on each of your next 3 turns you lose -1 Grit.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# This turn and on each of your next 3 turns you lose -3 Grit.<label>Doses<input type="number" name="attr_conc_bloodletter's_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Bloodletter's Poison
# --Rank|4
#
# --Effect|This turn and on each of your next 3 turns you lose -3 Grit.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_eclipsing" />    Eclipsing
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# You gain Blind 2.<label>Doses<input type="number" name="attr_conc_eclipsing_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Eclipsing Poison
# --Rank|2
#
# --Effect|You gain Blind 2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# You gain Blind 3.<label>Doses<input type="number" name="attr_conc_eclipsing_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Eclipsing Poison
# --Rank|3
#
# --Effect|You gain Blind 3.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# You gain Blind 4.<label>Doses<input type="number" name="attr_conc_eclipsing_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Eclipsing Poison
# --Rank|4
#
# --Effect|You gain Blind 4.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_enerva" />    Enerva
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# You gain Fatigued 2.<label>Doses<input type="number" name="attr_conc_enerva_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Enerva Poison
# --Rank|2
#
# --Effect|You gain Fatigued 2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# You gain Fatigued 2.<label>Doses<input type="number" name="attr_conc_enerva_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Enerva Poison
# --Rank|3
#
# --Effect|You gain Fatigued 2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# You gain Fatigued 3.<label>Doses<input type="number" name="attr_conc_enerva_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Enerva Poison
# --Rank|4
#
# --Effect|You gain Fatigued 3.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_leper's" />    Leper's
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# You gain Fatigued 1 and Vulnerable 1.<label>Doses<input type="number" name="attr_conc_leper's_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Leper's Poison
# --Rank|2
#
# --Effect|You gain Fatigued 1 and Vulnerable 1.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# You gain Fatigued 1 and Vulnerable 2.<label>Doses<input type="number" name="attr_conc_leper's_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Leper's Poison
# --Rank|3
#
# --Effect|You gain Fatigued 1 and Vulnerable 2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# You gain Fatigued 2 and Vulnerable 2.<label>Doses<input type="number" name="attr_conc_leper's_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Leper's Poison
# --Rank|4
#
# --Effect|You gain Fatigued 2 and Vulnerable 2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_madman's" />    Madman's
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# You gain Dazed 1 and Confused 1.<label>Doses<input type="number" name="attr_conc_madman's_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Madman's Poison
# --Rank|1
#
# --Effect|You gain Dazed 1 and Confused 1.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# You gain Dazed 2 and Confused 1.<label>Doses<input type="number" name="attr_conc_madman's_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Madman's Poison
# --Rank|2
#
# --Effect|You gain Dazed 2 and Confused 1.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# You gain Dazed 2 and Confused 2.<label>Doses<input type="number" name="attr_conc_madman's_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Madman's Poison
# --Rank|3
#
# --Effect|You gain Dazed 2 and Confused 2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_muter's" />    Muter's
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# You gain Silent 3.<label>Doses<input type="number" name="attr_conc_muter's_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Muter's Poison
# --Rank|1
#
# --Effect|You gain Silent 3.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# You gain Silent 4.<label>Doses<input type="number" name="attr_conc_muter's_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Muter's Poison
# --Rank|2
#
# --Effect|You gain Silent 4.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# You gain Silent 5.<label>Doses<input type="number" name="attr_conc_muter's_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Muter's Poison
# --Rank|3
#
# --Effect|You gain Silent 5.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_sleeper's" />    Sleeper's
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# You gain Unconscious 2.<label>Doses<input type="number" name="attr_conc_sleeper's_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Sleeper's Poison
# --Rank|2
#
# --Effect|You gain Unconscious 2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# You gain Unconscious 3.<label>Doses<input type="number" name="attr_conc_sleeper's_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Sleeper's Poison
# --Rank|3
#
# --Effect|You gain Unconscious 3.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# You gain Unconscious 5.<label>Doses<input type="number" name="attr_conc_sleeper's_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Sleeper's Poison
# --Rank|4
#
# --Effect|You gain Unconscious 5.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_surgeon's" />    Surgeon's
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# You become Prone, and gain Restrained 2 and Silent 2.<label>Doses<input type="number" name="attr_conc_surgeon's_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Surgeon's Poison
# --Rank|2
#
# --Effect|You become Prone, and gain Restrained 2 and Silent 2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# You become Prone, and gain Restrained 3 and Silent 2.<label>Doses<input type="number" name="attr_conc_surgeon's_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Surgeon's Poison
# --Rank|3
#
# --Effect|You become Prone, and gain Restrained 3 and Silent 2.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# You become Prone, and gain Restrained 5 and Silent 3.<label>Doses<input type="number" name="attr_conc_surgeon's_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Surgeon's Poison
# --Rank|4
#
# --Effect|You become Prone, and gain Restrained 5 and Silent 3.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">Potion's</div>
# <div class="grid-container">
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_fox" />    Fox
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Gain Aura 2. While this Aura persists, you add +1d4 Bonus Hits the the result set of any Action using Analyze, Cosmology, History, Investigate, Nature, Perceive, Research, Skrimisiology, or Theology.<label>Doses<input type="number" name="attr_conc_fox_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Fox Potion
# --Rank|1
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Gain Aura 2. While this Aura persists, you add +[^conc.total]  Bonus Hits the the result set of any Action using Analyze, Cosmology, History, Investigate, Nature, Perceive, Research, Skrimisiology, or Theology.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Gain Aura 3. While this Aura persists, you add +1d4 Bonus Hits the the result set of any Action using Analyze, Cosmology, History, Investigate, Nature, Perceive, Research, Skrimisiology, or Theology.<label>Doses<input type="number" name="attr_conc_fox_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Fox Potion
# --Rank|2
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Gain Aura 3. While this Aura persists, you add +[^conc.total]  Bonus Hits the the result set of any Action using Analyze, Cosmology, History, Investigate, Nature, Perceive, Research, Skrimisiology, or Theology.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Gain Aura 5. While this Aura persists, you add +1d4 Bonus Hits the the result set of any Action using Analyze, Cosmology, History, Investigate, Nature, Perceive, Research, Skrimisiology, or Theology.<label>Doses<input type="number" name="attr_conc_fox_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Fox Potion
# --Rank|3
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Gain Aura 5. While this Aura persists, you add +[^conc.total]  Bonus Hits the the result set of any Action using Analyze, Cosmology, History, Investigate, Nature, Perceive, Research, Skrimisiology, or Theology.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_hare" />    Hare
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Gain +4 to your Reflexes Defense and gain Aura 2. While this Aura persists, you gain an additional Shift on each of your turns. When this Aura ends, you gain Fatigued.<label>Doses<input type="number" name="attr_conc_hare_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Hare Potion
# --Rank|1
#
# --Effect|Gain +4 to your Reflexes Defense and gain Aura 2. While this Aura persists, you gain an additional Shift on each of your turns. When this Aura ends, you gain Fatigued.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Gain +4 to your Reflexes Defense and gain Aura 2. While this Aura persists, you gain an additional Shift on each of your turns. When this Aura ends, you gain Fatigued.<label>Doses<input type="number" name="attr_conc_hare_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Hare Potion
# --Rank|2
#
# --Effect|Gain +4 to your Reflexes Defense and gain Aura 2. While this Aura persists, you gain an additional Shift on each of your turns. When this Aura ends, you gain Fatigued.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Gain +4 to your Reflexes Defense and gain Aura 2. While this Aura persists, you gain an additional Shift on each of your turns. If you do not use a Shift on your turn, you gain 1 additional Aciton. When this Aura ends, you gain Fatigued.<label>Doses<input type="number" name="attr_conc_hare_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Hare Potion
# --Rank|3
#
# --Effect|Gain +4 to your Reflexes Defense and gain Aura 2. While this Aura persists, you gain an additional Shift on each of your turns. If you do not use a Shift on your turn, you gain 1 additional Aciton. When this Aura ends, you gain Fatigued.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_hawk" />    Hawk
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Gain Aura 3. While this Aura persists, you gain the Flying keyword.<label>Doses<input type="number" name="attr_conc_hawk_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Hawk Potion
# --Rank|2
#
# --Effect|Gain Aura 3. While this Aura persists, you gain the Flying keyword.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Gain Aura 3. While this Aura persists, you gain the Flying keyword.<label>Doses<input type="number" name="attr_conc_hawk_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Hawk Potion
# --Rank|3
#
# --Effect|Gain Aura 3. While this Aura persists, you gain the Flying keyword.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# Gain Aura 4. While this Aura persists, you gain the Flying keyword.<label>Doses<input type="number" name="attr_conc_hawk_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Hawk Potion
# --Rank|4
#
# --Effect|Gain Aura 4. While this Aura persists, you gain the Flying keyword.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_marlin" />    Marlin
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Gain Aura 3. While this Aura persists, you gain the Aquatic keyword.<label>Doses<input type="number" name="attr_conc_marlin_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Marlin Potion
# --Rank|2
#
# --Effect|Gain Aura 3. While this Aura persists, you gain the Aquatic keyword.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Gain Aura 3. While this Aura persists, you gain the Aquatic keyword.<label>Doses<input type="number" name="attr_conc_marlin_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Marlin Potion
# --Rank|3
#
# --Effect|Gain Aura 3. While this Aura persists, you gain the Aquatic keyword.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# Gain Aura 5. While this Aura persists, you gain the Aquatic keyword.<label>Doses<input type="number" name="attr_conc_marlin_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Marlin Potion
# --Rank|4
#
# --Effect|Gain Aura 5. While this Aura persists, you gain the Aquatic keyword.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_mouse" />    Mouse
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Gain Aura 3. While this Aura persists, you gain the Invisible keyword.<label>Doses<input type="number" name="attr_conc_mouse_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Mouse Potion
# --Rank|2
#
# --Effect|Gain Aura 3. While this Aura persists, you gain the Invisible keyword.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Gain Aura 3. While this Aura persists, you gain the Invisible keyword.<label>Doses<input type="number" name="attr_conc_mouse_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Mouse Potion
# --Rank|3
#
# --Effect|Gain Aura 3. While this Aura persists, you gain the Invisible keyword.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# Gain Aura 4. While this Aura persists, you gain the Invisible keyword.<label>Doses<input type="number" name="attr_conc_mouse_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Mouse Potion
# --Rank|4
#
# --Effect|Gain Aura 4. While this Aura persists, you gain the Invisible keyword.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_owl" />    Owl
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Choose one (1):<label>Doses<input type="number" name="attr_conc_owl_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Owl Potion
# --Rank|2
#
# --Effect|Choose one (1):
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Choose one (1):<label>Doses<input type="number" name="attr_conc_owl_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Owl Potion
# --Rank|3
#
# --Effect|Choose one (1):
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# Choose two (2):<label>Doses<input type="number" name="attr_conc_owl_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Owl Potion
# --Rank|4
#
# --Effect|Choose two (2):
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_ringtail" />    Ringtail
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Gain Aura 3. While this Aura persists, you gain the Nightvision keyword.<label>Doses<input type="number" name="attr_conc_ringtail_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Ringtail Potion
# --Rank|1
#
# --Effect|Gain Aura 3. While this Aura persists, you gain the Nightvision keyword.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Gain Aura 3. While this Aura persists, you gain the Nightvision keyword.<label>Doses<input type="number" name="attr_conc_ringtail_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Ringtail Potion
# --Rank|2
#
# --Effect|Gain Aura 3. While this Aura persists, you gain the Nightvision keyword.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Gain Aura 5. While this Aura persists, you gain the Nightvision keyword.<label>Doses<input type="number" name="attr_conc_ringtail_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Ringtail Potion
# --Rank|3
#
# --Effect|Gain Aura 5. While this Aura persists, you gain the Nightvision keyword.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_snake" />    Snake
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Gain Aura 2. While this Aura persists, you cannot gain the Fatigued Status and are immune to the effects of Poisons.<label>Doses<input type="number" name="attr_conc_snake_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Snake Potion
# --Rank|2
#
# --Effect|Gain Aura 2. While this Aura persists, you cannot gain the Fatigued Status and are immune to the effects of Poisons.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Gain Aura 2. While this Aura persists, you cannot gain the Fatigued Status and are immune to the effects of Poisons.<label>Doses<input type="number" name="attr_conc_snake_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Snake Potion
# --Rank|3
#
# --Effect|Gain Aura 2. While this Aura persists, you cannot gain the Fatigued Status and are immune to the effects of Poisons.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# Gain Aura 3. While this Aura persists, you cannot gain the Fatigued Status and are immune to the effects of Poisons.<label>Doses<input type="number" name="attr_conc_snake_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Snake Potion
# --Rank|4
#
# --Effect|Gain Aura 3. While this Aura persists, you cannot gain the Fatigued Status and are immune to the effects of Poisons.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_titan" />    Titan
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 1
# <div class="grid-container grid-concoction">
# Gain Aura 2. While this Aura persists, +1 Bonus Hits to Exert, Grapple, Martial Arts, Strike, or Throw.<label>Doses<input type="number" name="attr_conc_titan_r1" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Titan Potion
# --Rank|1
#
# --Effect|Gain Aura 2. While this Aura persists, +1 Bonus Hits to Exert, Grapple, Martial Arts, Strike, or Throw.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 2
# <div class="grid-container grid-concoction">
# Gain Aura 2. While this Aura persists, +1 Bonus Hits to Exert, Grapple, Martial Arts, Strike, or Throw.<label>Doses<input type="number" name="attr_conc_titan_r2" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Titan Potion
# --Rank|2
#
# --Effect|Gain Aura 2. While this Aura persists, +1 Bonus Hits to Exert, Grapple, Martial Arts, Strike, or Throw.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Gain Aura 2. While this Aura persists, +1d4 Bonus Hits to Exert, Grapple, Martial Arts, Strike, or Throw.<label>Doses<input type="number" name="attr_conc_titan_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Titan Potion
# --Rank|3
# --Result Set|[[ [$conc|XPND] 1d4]]
# --Effect|Gain Aura 2. While this Aura persists, +[^conc.total]  Bonus Hits to Exert, Grapple, Martial Arts, Strike, or Throw.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-item grid-concoction">
# <input type="checkbox" name="attr_conc_has_tortoise" />    Tortoise
# <div class="grid-container-concoction">
# <div class="grid-item">Rank 3
# <div class="grid-container grid-concoction">
# Gain Aura 1. While this Aura persists, prevent all Hits to your Defenses and Grit.<label>Doses<input type="number" name="attr_conc_tortoise_r3" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Tortoise Potion
# --Rank|3
#
# --Effect|Gain Aura 1. While this Aura persists, prevent all Hits to your Defenses and Grit.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 4
# <div class="grid-container grid-concoction">
# Gain Aura 2. While this Aura persists, prevent all Hits to your Defenses and Grit.<label>Doses<input type="number" name="attr_conc_tortoise_r4" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Tortoise Potion
# --Rank|4
#
# --Effect|Gain Aura 2. While this Aura persists, prevent all Hits to your Defenses and Grit.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# <div class="grid-item">Rank 5
# <div class="grid-container grid-concoction">
# Gain Aura 3. While this Aura persists, prevent all Hits to your Defenses and Grit.<label>Doses<input type="number" name="attr_conc_tortoise_r5" value="0" min="0" step="1" /></label>
# <button type="roll" value="!power {{
# --name|@{character_name} - Tortoise Potion
# --Rank|5
#
# --Effect|Gain Aura 3. While this Aura persists, prevent all Hits to your Defenses and Grit.
# --format|shiftcheck
# }}">Use</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
df_concoctions.groupby(['type', 'name'])['ranks'].count()
# Out:
# type    name
# Elixir  Bear             3
#         Crocodile        3
#         Dove             3
#         Phoenix          3
#         Scorpion         3
#         Spider           3
#         Starfish         3
#         Wyrm             3
# Oil     Agonist's        3
#         Brushfire        3
#         Conductive       3
#         Executioner's    3
#         Glacier          3
#         Holy             3
#         Rusting          3
#         Stone's Eye      3
# Poison  Bloodletter's    3
#         Eclipsing        3
#         Enerva           3
#         Leper's          3
#         Madman's         3
#         Muter's          3
#         Sleeper's        3
#         Surgeon's        3
# Potion  Fox              3
#         Hare             3
#         Hawk             3
#         Marlin           3
#         Mouse            3
#         Owl              3
#         Ringtail         3
#         Snake            3
#         Titan            3
#         Tortoise         3
# Name: ranks, dtype: int64

# %% [markdown]
# ### Techniques start

# %%
df_techniques = pd.DataFrame.from_records(powers_data['techniques'])

# %%
df_techniques[df_techniques['current'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, type, skill, cost, effect, current, threshold, requires, keywords]
# Index: []

# %%
df_techniques['pcard'] = ''
df_techniques['cost'] = df_techniques['cost'].astype('int')
df_techniques['current'] = df_techniques['current'].astype('int')

# %%
t = df_techniques[(df_techniques['name']=='Invoke the Dawn') & (df_techniques['skill']=='Lux')].copy()
i = 1
for t in t['threshold']:
    for i in t:
        clean_effect = i['effect'].replace('choose', '**choose').replace(':<ul><li>', '**:^^^^**').replace('</li><li>', '^^^^').replace('</li></ul>', '**')
        print(clean_effect)
# Out:
# Target your Current or an Adjacent Zone, then **choose one (1)**:^^^^**All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.^^^^All allies in the targeted Zone recover 3 Hits to their Primary Defense and regain up to 2 Grit.**
# Target your Current or an Adjacent Zone, then **choose one or both**:^^^^**All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.^^^^All allies in the targeted Zone recover 4 Hits to their Primary Defense and regain up to 2 Grit.**

# %% [markdown]
# #### Build Tech Powercards

# %%
tech_pcards = []
for index, t in df_techniques.iterrows():
    skill_clean = t['skill'].lower()
    res = '''!power {{
--Name|@{character_name} - ''' + t['name'] + '''
--Cost|''' + str(t['cost']) + '''
--Current|''' + str(t['current']) + '''
--api_setattr|_name @{character_name} _current|''' + str(t['current']) + '''
--Result Set|[[ [$tech|XPND] @{Cosm|challenge}d@{skill_''' + skill_clean + '''}>@{Cosm|target}]]
--Hits|[^tech.ss]
--1s|[^tech.ones]
--format|powercheck\n'''
    if len(t['threshold']) > 1:
        for i in range(len(t['threshold'])):
            if i < len(t['threshold']) - 1:
                clean_effect = t['threshold'][i]['effect'].replace('choose', '**choose').replace(':<ul><li>', '**:^^^^**').replace('</li><li>', '^^^^').replace('</li></ul>', '**')
                res += '''--?? $tech.ss >= ''' + str(t['threshold'][i]['hits']) + ''' AND $tech.ss < ''' + str(t['threshold'][i+1]['hits']) + ''' ?? Effect:|**//Threshold - [^tech.ss]//**^^''' + clean_effect + '\n'
            else:
                clean_effect = t['threshold'][i]['effect'].replace('choose', '**choose').replace(':<ul><li>', '**:^^^^**').replace('</li><li>', '^^^^').replace('</li></ul>', '**')
                res += '''--?? $tech.ss >= ''' + str(t['threshold'][i]['hits']) + ''' ?? Effect:|**//Threshold - [^tech.ss]//**^^''' + clean_effect + '\n'
    else:
        for r in t['threshold']:
            clean_effect = r['effect'].replace('choose', '**choose').replace(':<ul><li>', '**:^^^^**').replace('</li><li>', '^^^^').replace('</li></ul>', '**')
            res += '''--?? $tech.ss >= ''' + str(r['hits']) + ''' ?? Effect:|**//Threshold - [^tech.ss]//**^^''' + clean_effect + '\n'
    if t['skill'] == 'Vivus':
        res += '''--?? $tech.ones > 0 ?? Trigger:|The Cycle's Drain \n'''
    else:
        res += '''--?? $tech.ones > 0 ?? Trigger:|Recoil \n'''
    res += '''}}'''
    print(res)
    tech_pcards.append(res)
    # print(t['pcard'])
# Out:
# !power {{
# --Name|@{name} - Aether Spike
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Send a bolt of cosmic energy at a target in your Current or an Adjacent Zone, scoring 1 Hit.
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Send a bolt of cosmic energy at a target in your Current or an Adjacent Zone, scoring 2 Hits.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Aether Gust
# --Cost|4
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Send a wave of energy outward, pushing all targets in your Current Zone to the Adjacent Zone closest to them.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Aether Tunnel
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Open a cosmic tunnel between your Current Zone and a linear Zone up to 2 Zones adjacent Ongoing.  While the tunnel persists, characters can Shift to Move between the tunnel's endpoints without incurring Hazard.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Open a cosmic tunnel between your Current Zone and a linear Zone up to 2 Zones adjacent.  While the tunnel persists, you and your allies can Shift to Move between the tunnel's endpoints without incurring Hazard.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Bring the Ending
# --Cost|3
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^The current Timer expires.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^The current Timer expires.  The next Timer is set to 4.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Essence Flux
# --Cost|2
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^When one of your allies you can see suffers Hits from an attack, you momentarily send them to the Aether, reducing the Hits they take by Hits in the result set.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^When one of your allies you can see suffers Hits from an attack, you momentarily send them to the Aether, reducing the Hits they take by Hits in the result set.  Create 1 Advantage in the target ally's Current Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Drain Current
# --Cost|2
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Gain X Hits to your Current, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Invoke the Flame
# --Cost|3
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 3 Hits to up to 2 targets in your Current or Adjacent Zone.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 3 Hits to up to 3 targets in your Current or Adjacent Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Kindle
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 1 + X Hits to one target in your Current Zone, where X is equal to the number of consecutive turns you have used this technique.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Immolation
# --Cost|1
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target you can see in your Current Zone gains Aura 2 as you wrap them in flames.  They suffer 2 Hits to their Grit on each of their turns while this Aura persists, and they add +2 Bonus Hits in fire damage when they use Grapple, Strike or Martial Arts.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target you can see in your Current Zone gains Aura 2 as you wrap them in flames.  They suffer 2 Hits to their Grit on each of their turns while this Aura persists, and they add +3 Bonus Hits inin fire damage when they use Grapple, Strike or Martial Arts.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Rending Flames
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 3 Hits to one target in your Current or Adjacent Zone.  If that target dies, deal 2 Hits to another target in the same Zone.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 5 Hits to one target in your Current or Adjacent Zone.  If that target dies, deal 3 Hits to another target in the same Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Fiery Volley
# --Cost|1
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 2 Hits to up to 3 targets in an Adjacent Zone.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 3 Hits to up to 4 targets in an Adjacent Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Pyroclasm
# --Cost|4
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current and all Adjacent Zones.  Deal 2 Hits to all targets in the targeted Zone.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current and all Adjacent Zones.  Deal 4 Hits to all targets in the targeted Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Invoke the Dawn
# --Cost|3
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one (1)**:^^^^**All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.^^^^All allies in the targeted Zone recover 3 Hits to their Primary Defense and regain up to 2 Grit.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one or both**:^^^^**All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.^^^^All allies in the targeted Zone recover 4 Hits to their Primary Defense and regain up to 2 Grit.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Radiant Mending
# --Cost|2
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone recover 3 Hits to their Primary Defense and all their Gear repairs +1 rating.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Luminous Volley
# --Cost|1
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 2 Hits to up to 3 targets in an Adjacent Zone.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 3 Hits to up to 4 targets in an Adjacent Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Energizing Ray
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone recovers X to their Primary Defense and reduces all Statuses by X, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Beaming Defiance
# --Cost|3
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^When you suffer Hits from a melee attack, reduce the Hits taken by X + 1, where X is equal to Hits in this Technique's result set, and the attacker gains Blind 1
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Sweltering Rays
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 3 targets in your Current or an Adjacent Zone take 3 Hits and gain Fatigued 2.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 3 targets in your Current or an Adjacent Zone take 3 Hits and gain Fatigued 2. Gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Mind Rot
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mentis}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone gains Confused 2.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone gains Confused 1.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Tormenting Voice
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mentis}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone recover gains Dazed X and Confused X, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Mind Spike
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mentis}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes X Hits or gains Stunned 2, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Psychic Lance
# --Cost|3
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mentis}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select one target in your Current or an Adjacent Zone and **choose one (1)**:^^^^**The target takes X Hits to their Nerve, where X is equal to Hits in the result set.^^^^The target gains Dazed 2 and Confused 2.^^^^You gain +4 Current.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select one target in your Current or an Adjacent Zone and **choose two (2)**:^^^^**The target takes X Hits to their Nerve, where X is equal to Hits in the result set.^^^^The target gains Dazed 2 and Confused 2.^^^^You gain +4 Current.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Invoke Death
# --Cost|4
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to three targets in your Current or an Adjacent Zone lose X Grit, where X is equal to Hits in the result set.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to three targets in your Current or an Adjacent Zone lose X Grit, where X is equal to Hits in the result set.  You gain +3 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Mortality Spear
# --Cost|3
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= None ?? Effect:|**//Threshold - [^tech.ss]//**^^Spend 3 Grit, then 1 target in your Current or an Adjacent Zone loses X +3 Grit, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Merciless Resolve
# --Cost|3
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^Spend 2 Momentum.  You gain +4 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Alms of Vivus
# --Cost|0
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone loses X Grit, where X is equal to Hits in the result set.
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone loses X Grit and one other target in your Current Zone regains X Grit, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Death's Touch
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone gains Wounded 1.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone gains Wounded 1.  You gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Culling Ritual
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^When a target in your Current Zone dies, increase the Entropy +1 and one other target in your Current or an Adjacent Zone loses X +2 Grit, where X is equal to Hits in the result set.
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^When a target in your Current Zone dies, increase the Entropy +1 and one other target in your Current or an Adjacent Zone loses X +2 Grit.  You gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Invoke Despair
# --Cost|3
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one (1)**:^^^^**All targets in the targeted Zone gain Afraidd 2 and gain Confused 2.^^^^Increase the Entropy by +1 and you gain +3 Current.**
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one or both**:^^^^**All hostile targets in the targeted Zone gain Afraidd 2 and gain Confused 2.^^^^Increase the Entropy by +1 and you gain +3 Current.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Negation Blast
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select a target in your Current or an Adjacent Zone and then **choose one (1)**:^^^^**The target takes X Hits and gains Vulnerable 1, where X is equal to Hits in the result set.^^^^The target loses all Auras and loses 2 Grit.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Void Rift
# --Cost|1
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^All targets in your Current or an Adjacent Zone becomee Prone and gain Vulnerable 1.  Increase the Entropy by +1.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Enter the Infinite
# --Cost|5
# --Current|8
# --api_setattr|_name @{name} _current|8
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^Increase the Entropy +2 and immediately take X Actions, where X is equal to Hits in the result set.
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^Spend 5 Entropy and immediately take X Actions, X . . .  The Momentum equals 5.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Shadow Lance
# --Cost|2
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select one target in your Current or an Adjacent Zone and **choose one (1)**:^^^^**The target takes X Hits to their Nerve, where X is equal to Hits in the result set.^^^^The target gains Afraidd 2 and Wounded 1.^^^^You gain +3 Current.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select one target in your Current or an Adjacent Zone and **choose two (2)**:^^^^**The target takes X Hits to their Nerve, where X is equal to Hits in the result set.^^^^The target gains Afraidd 2 and Wounded 1.^^^^You gain +3 Current.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Dark Ritual
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^Increase the Entropy by +1.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Dread Fugue
# --Cost|2
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone gains Vulnerable 2.  You gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Umbral Juke
# --Cost|1
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^When you suffer Hits from an effect you can see, you may increase the Entropy by +2. If you do, you immediately Shift to Move to an Adjacent Zone and suffer 0 Hits.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Subtle Strike
# --Cost|2
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select a target in your Current or an Adjacent Zone and then **choose one (1)**:^^^^**The target gains Fatigued 1.^^^^The target takes 2 Hits to Nerve.**
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select a target in your Current or an Adjacent Zone and then **choose one or both**:^^^^**The target gains Fatigued 1.^^^^The target takes 2 Hits to Nerve.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Vengeance of Shadows
# --Cost|3
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Your Current or an Adjacent Zone gains Hazard 1.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^All targets in your Current or an Adjacent Zone gain Blind 2.  The targeted zone gains Hazard 1.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Eclipse
# --Cost|3
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^All targets in those Zones gain Blind 1 Ongoing.  You gain +X Current, where X is the number of targets Blinded this way.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Spreading Darkness
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^All light in your Current Zone are extinguished and all targets in your Current Zone gain Blind 1 Ongoing.<br><br>At the beginning of each of your turns while this Technique is Ongoing, copy its effect to all Adjacent Zones.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Eyes of Night
# --Cost|0
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^You can see in absolute darkness and are immune to the Blind status.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Pain Bolt
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_plaga}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes 1 Hit to Grit and gains Wounded 1.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Ghost Pain
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_plaga}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes 2 Hits to Grit.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Searing Pain
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_plaga}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes 3 Hits and gains Vulnerable 1.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Crushing Pain
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_plaga}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes 6 Hits and gains Fatigued 1.  Increase the Entropy by +1.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Painful Lesson
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_plaga}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^When you suffer Hits from a melee attack form a target you can see, you may deal X Hits to that target and have them gain Fatigued 1, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Extort Affliction
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_plaga}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes 2 Hits to Grit.  If that target was Vulnerable, you gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Hear Their Gasps
# --Cost|2
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_plaga}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^All targets except you in your Current Zone gain Vulnerable 1.  You gain +X Current, wher eX is euqal to the number of targets that gained Vulnerable from this technique.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Consume Their Suffering
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_plaga}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^If you score 3+ Hits on the next Technique you use this turn, gain +3 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Invoke Suffering
# --Cost|3
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_plaga}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one (1)**:^^^^**All targets except for you in the targeted Zone gain Fatigued 1 and lose 2 Grit.^^^^Increase the Entropy by +1 and you gain +2 Current.**
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one or both**:^^^^**All targets except for you in the targeted Zone gain Fatigued 1 and lose 2 Grit.^^^^Increase the Entropy by +1 and you gain +2 Current.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Choke the Life
# --Cost|2
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_plaga}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone loses 3 Grit.  If the target dies, you gain +3 Current.  Otherwise, the target gains Vulnerable 2.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Wrath of Frost
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_rime}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current Zone take 4 Hits and gains Frozen 1.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Cold Snap
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_rime}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^All targets except you in your Current Zone gains Frozen 4.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Forstbite
# --Cost|3
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_rime}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^When you suffer Hits from a melee attack form a target you can see, you may deal 2 Hits to that target and have them gain Frozen 2.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Glacial Spike
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_rime}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes X Hits and gains Slowed 1.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Invoke the Wintr
# --Cost|3
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_rime}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one (1)**:^^^^**The targeted Zone gains Hazard 3.  All targets in the targeted Zone take 1 Hits and gain Slowed 1 Ongoing.^^^^The targeted Zone gains Hazard 1.  All targets in the targeted Zone gain Fatigued 1 Ongoing.  You gain +2 Current.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one or both**:^^^^**The targeted Zone gains Hazard 3.  All targets in the targeted Zone take 1 Hits and gain Slowed 1 Ongoing.^^^^The targeted Zone gains Hazard 1.  All targets in the targeted Zone gain Fatigued 1 Ongoing.  You gain +2 Current.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Invoke the Winds
# --Cost|3
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_squall}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one (1)**:^^^^**All targets in the targeted Zone take become Prone and gain Dazed 2.^^^^All targets in the targeted Zone are moved to an Adjacent Zone and you gain +4 Current.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one or both**:^^^^**All targets in the targeted Zone take become Prone and gain Dazed 2.^^^^All targets in the targeted Zone are moved to an Adjacent Zone and you gain +4 Current.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Stride of the Clouds
# --Cost|2
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_squall}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone gains the Fly keyword.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone gain the Fly keyword.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Zephyr Strike
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_squall}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current Zone take X Hits and is moved to an Adjacent Zone, where X is equal to Hits in the result set.
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Divide X Hits among up to 3 targets in yoru Current Zone, where X is equal to Hits in the result set.  The targets are all moved to an Adjacent Zone,
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Whirlwind
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_squall}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone loses the Fly keyword Ongoing.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to X targets in your Current or an Adjacent Zone loses the Fly keyword Ongoing, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Seismic Surge
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_tellus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adacent Zone.  The targeted Zone gains Hazard 2 and all targets in the Zone take 3 Hits.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Invoke Calamity
# --Cost|2
# --Current|7
# --api_setattr|_name @{name} _current|7
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_tellus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one (1)**:^^^^**Increase the Entropy by +2.  All targets in the targeted Zone take become Prone and take X Hits, where X is equal to Hits in the result set.^^^^Increase the Entropy by +3 and increase the Momentum by +3.<br>All targets in the targeted Zone gain Confused 2 and take X Hits, where X is equal to Hits in the result set.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one or both**:^^^^**Increase the Entropy by +2.  All targets in the targeted Zone take become Prone and take X Hits, where X is equal to Hits in the result set.^^^^Increase the Entropy by +3 and increase the Momentum by +3.<br>All targets in the targeted Zone gain Confused 2 and take X Hits, where X is equal to Hits in the result set.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Return to Nature
# --Cost|1
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_tellus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current Zone reduces one Status by -2.
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current Zone reduces one Status by X, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Crystal Volley
# --Cost|1
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_tellus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 2 Hits to up to 3 targets in an Adjacent Zone.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 2 Hits to up to 5 targets in an Adjacent Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Slagstorm
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_tellus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current and an Adjacent Zone to gain Hazard 3.  Deal 3 Hits to all targets in the targeted Zones.
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current and an Adjacent Zone to gain Hazard 3.  Deal 3 Hits to all targets in the targeted Zones.<br>You gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Thunderous Charge
# --Cost|0
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Move to any Adjacent Zone ignoring Hazards.  One target in the destination Zone takes 1 Hits and becomes Prone, where X is equal to Hits in the result set.
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Move to any Adjacent Zone ignoring Hazards.  One target in the destination Zone takes X Hits and becomes Prone, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Lightning Strike
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Thunderous Bolt
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes 2 Hits and gains Stunned 2.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Invoke the Storm
# --Cost|2
# --Current|7
# --api_setattr|_name @{name} _current|7
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_tellus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one (1)**:^^^^**Increase the Entropy by +1.  All targets in the targeted Zone take gain Stunned 1 Ongoing.^^^^Increase the Entropy by +2 and increase the Momentum by +3.<br>All targets in the targeted Zone take X Hits, where X is equal to Hits in the result set.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one or both**:^^^^**Increase the Entropy by +1.  All targets in the targeted Zone take gain Stunned 1 Ongoing.^^^^Increase the Entropy by +2 and increase the Momentum by +3.<br>All targets in the targeted Zone take X Hits, where X is equal to Hits in the result set.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Hydro Blast
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes 2 Hits and gains Dazed 1.
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes 2 Hits and gains Dazed 1.  You gain +1 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Current's Flow
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^You gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Water Spout
# --Cost|3
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes 2 Hits and becomes Prone.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone take 2 Hits and become Prone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Cascade
# --Cost|0
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^If you score 3+ Hits on the next Technique you use this turn, you gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Riptide
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current Zone gains Confused 2.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 3 targets in your Current Zone gain Confused 2.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Water Whip
# --Cost|2
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set., then **choose one (1)**:^^^^**The target gains Restrained 3.^^^^You pull the target into your Current Zone.^^^^You gain +2 Current.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Tangle Wave
# --Cost|4
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone.  All targets in the targeted Zone gain Restrained 2.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Soothing Waters
# --Cost|2
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current Zone can **choose one (1)**:^^^^**Regain X Grit, where X is equal to Hits in the result set.^^^^Reduce one Status by X, where X is equal to Hits in the result set.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 3 targets in your Current Zone can **choose one (1)**:^^^^**Regain X Grit, where X is equal to Hits in the result set.^^^^Reduce one Status by X, where X is equal to Hits in the result set.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Crashing Wave
# --Cost|3
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^All targets except you in yoru Current Zone take 3 Hits and become Prone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - One With Water
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^You gain Aura X, where X is equal to Hits in the result set.  While this Aura persists, your can breathe underwater and ignore Hazards in underwater Zones.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Be Like Water
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Recover X to your Primary Defense, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Undertow
# --Cost|2
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in an Adjacent Zone is moved into your Current Zone.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 3 targets in an Adjacent Zone are moved into your Current Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}
# !power {{
# --Name|@{name} - Revitalize
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone recovers X +2 to their Primary Defense and regains X Grit, where X is equal to Hits in the result set.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone recovers X +2 to their Primary Defense and regains X Grit, where X is equal to Hits in the result set.  You gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|The Cycle's Drain
# }}
# !power {{
# --Name|@{name} - Invoke the Dawn
# --Cost|3
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one (1)**:^^^^**All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.^^^^All allies in the targeted Zone recover 3 Hits to their Primary Defense and regain up to 2 Grit.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one or both**:^^^^**All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.^^^^All allies in the targeted Zone recover 4 Hits to their Primary Defense and regain up to 2 Grit.**
# --?? $tech.ones > 0 ?? Trigger:|The Cycle's Drain
# }}
# !power {{
# --Name|@{name} - Revitalizing Ray
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone recovers X to their Primary Defense and reduces all Statuses by X, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|The Cycle's Drain
# }}
# !power {{
# --Name|@{name} - Rush of Vitality
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in yoru Current Zone regains X Grit, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|The Cycle's Drain
# }}

# %%
t
# Out:
# name                                          Rush of Vitality
# type                                                   Ability
# skill                                                    Vivus
# cost                                                         2
# effect                                                    None
# current                                                      3
# threshold    [{'hits': 2, 'effect': 'One target in yoru Cur...
# requires                                                  None
# keywords                                                    []
# pcard
# Name: 84, dtype: object

# %%
df_techniques['pcard'] = tech_pcards

# %%
type='Shift'
t_type = df_techniques[(df_techniques['type']==type) & (df_techniques['name'] != '')].copy()
div_str = ''
for p in df_techniques['skill'].unique():
    div_str += '''<div class="grid-container-talents">\n<input class="sheet-powers-affinity" type="hidden" name="attr_affinity_1" value="None" />\n<input class="sheet-powers-affinity" type="hidden" name="attr_affinity_2" value="None" />\n<div class="sheet-power-'''+ p.lower() +'''">\n<h4 class="grid-talents-label" style="margin-bottom:4px;">''' + p + '''</h4>\n<div class="grid-container-talents">\n'''
    for s in ['Shift', 'Ability', 'Trigger']:
        techs = df_techniques[(df_techniques['skill']==p) & (df_techniques['type']==s)]
        for index, tech in techs.iterrows():
            div_str += '''<div class="grid-item-talents">\n''' 
            div_str +='''<label style="font-size:12pt; margin-bottom: 4px;">''' + tech['name'] + '''<br><em><span style="font-size:10pt;">''' + tech['type'] + '''<br><span style="font-size:8pt;">Cost:  ''' + str(tech['cost']) + '''</span></label>\n''' 
            for t in tech['threshold']:
                div_str += '''<p><strong>Threshold &mdash; ''' + str(t['hits']) + '''</strong><br> ''' + t['effect'] + '''</p>\n'''
            if tech['pcard'] is not None:
                div_str +='''<button class="skill-button" type="roll" value="''' + tech['pcard'] +'''">\n</button>\n'''
            else:
                div_str +='''<button class="skill-button" type="roll" value="!power {{
            --name|@{Name} - ''' + tal['name'] + '''
            --Effect|''' + tal['effect'] + '''
            --format|powercheck
            }}">\n</button>\n'''
            div_str +='''</div>\n'''
    div_str +='''</div>\n</div>\n</div>\n'''

print(div_str)
# Out:
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_2" value="None" />
# <div class="sheet-power-aether">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Aether</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Aether Spike<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  0</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> Send a bolt of cosmic energy at a target in your Current or an Adjacent Zone, scoring 1 Hit.</p>
# <p><strong>Threshold &mdash; 3</strong><br> Send a bolt of cosmic energy at a target in your Current or an Adjacent Zone, scoring 2 Hits.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Aether Spike
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Send a bolt of cosmic energy at a target in your Current or an Adjacent Zone, scoring 1 Hit.
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Send a bolt of cosmic energy at a target in your Current or an Adjacent Zone, scoring 2 Hits.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Aether Gust<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  4</span></label>
# <p><strong>Threshold &mdash; 4</strong><br> Send a wave of energy outward, pushing all targets in your Current Zone to the Adjacent Zone closest to them.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Aether Gust
# --Cost|4
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Send a wave of energy outward, pushing all targets in your Current Zone to the Adjacent Zone closest to them.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Aether Tunnel<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Open a cosmic tunnel between your Current Zone and a linear Zone up to 2 Zones adjacent Ongoing.  While the tunnel persists, characters can Shift to Move between the tunnel's endpoints without incurring Hazard.</p>
# <p><strong>Threshold &mdash; 4</strong><br> Open a cosmic tunnel between your Current Zone and a linear Zone up to 2 Zones adjacent.  While the tunnel persists, you and your allies can Shift to Move between the tunnel's endpoints without incurring Hazard.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Aether Tunnel
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Open a cosmic tunnel between your Current Zone and a linear Zone up to 2 Zones adjacent Ongoing.  While the tunnel persists, characters can Shift to Move between the tunnel's endpoints without incurring Hazard.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Open a cosmic tunnel between your Current Zone and a linear Zone up to 2 Zones adjacent.  While the tunnel persists, you and your allies can Shift to Move between the tunnel's endpoints without incurring Hazard.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Bring the Ending<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> The current Timer expires.</p>
# <p><strong>Threshold &mdash; 4</strong><br> The current Timer expires.  The next Timer is set to 4.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Bring the Ending
# --Cost|3
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^The current Timer expires.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^The current Timer expires.  The next Timer is set to 4.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Drain Current<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Gain X Hits to your Current, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Drain Current
# --Cost|2
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Gain X Hits to your Current, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Flux<br><em><span style="font-size:10pt;">Trigger<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> When one of your allies you can see suffers Hits from an attack, you momentarily send them to the Aether, reducing the Hits they take by Hits in the result set.</p>
# <p><strong>Threshold &mdash; 4</strong><br> When one of your allies you can see suffers Hits from an attack, you momentarily send them to the Aether, reducing the Hits they take by Hits in the result set.  Create 1 Advantage in the target ally's Current Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Flux
# --Cost|2
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^When one of your allies you can see suffers Hits from an attack, you momentarily send them to the Aether, reducing the Hits they take by Hits in the result set.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^When one of your allies you can see suffers Hits from an attack, you momentarily send them to the Aether, reducing the Hits they take by Hits in the result set.  Create 1 Advantage in the target ally's Current Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_2" value="None" />
# <div class="sheet-power-inferno">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Inferno</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Invoke the Flame<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Deal 3 Hits to up to 2 targets in your Current or Adjacent Zone.</p>
# <p><strong>Threshold &mdash; 5</strong><br> Deal 3 Hits to up to 3 targets in your Current or Adjacent Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Invoke the Flame
# --Cost|3
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 3 Hits to up to 2 targets in your Current or Adjacent Zone.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 3 Hits to up to 3 targets in your Current or Adjacent Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Kindle<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Deal 1 + X Hits to one target in your Current Zone, where X is equal to the number of consecutive turns you have used this technique.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Kindle
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 1 + X Hits to one target in your Current Zone, where X is equal to the number of consecutive turns you have used this technique.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Immolation<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> One target you can see in your Current Zone gains Aura 2 as you wrap them in flames.  They suffer 2 Hits to their Grit on each of their turns while this Aura persists, and they add +2 Bonus Hits in fire damage when they use Grapple, Strike or Martial Arts.</p>
# <p><strong>Threshold &mdash; 4</strong><br> One target you can see in your Current Zone gains Aura 2 as you wrap them in flames.  They suffer 2 Hits to their Grit on each of their turns while this Aura persists, and they add +3 Bonus Hits inin fire damage when they use Grapple, Strike or Martial Arts.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Immolation
# --Cost|1
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target you can see in your Current Zone gains Aura 2 as you wrap them in flames.  They suffer 2 Hits to their Grit on each of their turns while this Aura persists, and they add +2 Bonus Hits in fire damage when they use Grapple, Strike or Martial Arts.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target you can see in your Current Zone gains Aura 2 as you wrap them in flames.  They suffer 2 Hits to their Grit on each of their turns while this Aura persists, and they add +3 Bonus Hits inin fire damage when they use Grapple, Strike or Martial Arts.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Rending Flames<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Deal 3 Hits to one target in your Current or Adjacent Zone.  If that target dies, deal 2 Hits to another target in the same Zone.</p>
# <p><strong>Threshold &mdash; 5</strong><br> Deal 5 Hits to one target in your Current or Adjacent Zone.  If that target dies, deal 3 Hits to another target in the same Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Rending Flames
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 3 Hits to one target in your Current or Adjacent Zone.  If that target dies, deal 2 Hits to another target in the same Zone.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 5 Hits to one target in your Current or Adjacent Zone.  If that target dies, deal 3 Hits to another target in the same Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Fiery Volley<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  1</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Deal 2 Hits to up to 3 targets in an Adjacent Zone.</p>
# <p><strong>Threshold &mdash; 5</strong><br> Deal 3 Hits to up to 4 targets in an Adjacent Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Fiery Volley
# --Cost|1
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 2 Hits to up to 3 targets in an Adjacent Zone.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 3 Hits to up to 4 targets in an Adjacent Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Pyroclasm<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  4</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Target your Current and all Adjacent Zones.  Deal 2 Hits to all targets in the targeted Zone.</p>
# <p><strong>Threshold &mdash; 5</strong><br> Target your Current and all Adjacent Zones.  Deal 4 Hits to all targets in the targeted Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Pyroclasm
# --Cost|4
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current and all Adjacent Zones.  Deal 2 Hits to all targets in the targeted Zone.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current and all Adjacent Zones.  Deal 4 Hits to all targets in the targeted Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_2" value="None" />
# <div class="sheet-power-lux">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Lux</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Beaming Defiance<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> When you suffer Hits from a melee attack, reduce the Hits taken by X + 1, where X is equal to Hits in this Technique's result set, and the attacker gains Blind 1</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Beaming Defiance
# --Cost|3
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^When you suffer Hits from a melee attack, reduce the Hits taken by X + 1, where X is equal to Hits in this Technique's result set, and the attacker gains Blind 1
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Invoke the Dawn<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Target your Current or an Adjacent Zone, then choose one (1):<ul><li>All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.</li><li>All allies in the targeted Zone recover 3 Hits to their Primary Defense and regain up to 2 Grit.</li></ul></p>
# <p><strong>Threshold &mdash; 4</strong><br> Target your Current or an Adjacent Zone, then choose one or both:<ul><li>All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.</li><li>All allies in the targeted Zone recover 4 Hits to their Primary Defense and regain up to 2 Grit.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Invoke the Dawn
# --Cost|3
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one (1)**:^^^^**All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.^^^^All allies in the targeted Zone recover 3 Hits to their Primary Defense and regain up to 2 Grit.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one or both**:^^^^**All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.^^^^All allies in the targeted Zone recover 4 Hits to their Primary Defense and regain up to 2 Grit.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Radiant Mending<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> One target in your Current or an Adjacent Zone recover 3 Hits to their Primary Defense and all their Gear repairs +1 rating.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Radiant Mending
# --Cost|2
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone recover 3 Hits to their Primary Defense and all their Gear repairs +1 rating.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Luminous Volley<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  1</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Deal 2 Hits to up to 3 targets in an Adjacent Zone.</p>
# <p><strong>Threshold &mdash; 5</strong><br> Deal 3 Hits to up to 4 targets in an Adjacent Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Luminous Volley
# --Cost|1
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 2 Hits to up to 3 targets in an Adjacent Zone.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Deal 3 Hits to up to 4 targets in an Adjacent Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Energizing Ray<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> One target in your Current or an Adjacent Zone recovers X to their Primary Defense and reduces all Statuses by X, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Energizing Ray
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone recovers X to their Primary Defense and reduces all Statuses by X, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Sweltering Rays<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Up to 3 targets in your Current or an Adjacent Zone take 3 Hits and gain Fatigued 2.</p>
# <p><strong>Threshold &mdash; 5</strong><br> Up to 3 targets in your Current or an Adjacent Zone take 3 Hits and gain Fatigued 2. Gain +2 Current.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Sweltering Rays
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 3 targets in your Current or an Adjacent Zone take 3 Hits and gain Fatigued 2.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 3 targets in your Current or an Adjacent Zone take 3 Hits and gain Fatigued 2. Gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_2" value="None" />
# <div class="sheet-power-mentis">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Mentis</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Mind Rot<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> One target in your Current or an Adjacent Zone gains Confused 2.</p>
# <p><strong>Threshold &mdash; 4</strong><br> Up to 2 targets in your Current or an Adjacent Zone gains Confused 1.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Mind Rot
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mentis}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone gains Confused 2.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone gains Confused 1.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Tormenting Voice<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> One target in your Current or an Adjacent Zone recover gains Dazed X and Confused X, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Tormenting Voice
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mentis}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone recover gains Dazed X and Confused X, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Mind Spike<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  0</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> One target in your Current or an Adjacent Zone takes X Hits or gains Stunned 2, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Mind Spike
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mentis}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes X Hits or gains Stunned 2, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Psychic Lance<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Select one target in your Current or an Adjacent Zone and choose one (1):<ul><li>The target takes X Hits to their Nerve, where X is equal to Hits in the result set.</li><li>The target gains Dazed 2 and Confused 2.</li><li>You gain +4 Current.</li></ul></p>
# <p><strong>Threshold &mdash; 4</strong><br> Select one target in your Current or an Adjacent Zone and choose two (2):<ul><li>The target takes X Hits to their Nerve, where X is equal to Hits in the result set.</li><li>The target gains Dazed 2 and Confused 2.</li><li>You gain +4 Current.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Psychic Lance
# --Cost|3
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mentis}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select one target in your Current or an Adjacent Zone and **choose one (1)**:^^^^**The target takes X Hits to their Nerve, where X is equal to Hits in the result set.^^^^The target gains Dazed 2 and Confused 2.^^^^You gain +4 Current.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select one target in your Current or an Adjacent Zone and **choose two (2)**:^^^^**The target takes X Hits to their Nerve, where X is equal to Hits in the result set.^^^^The target gains Dazed 2 and Confused 2.^^^^You gain +4 Current.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_2" value="None" />
# <div class="sheet-power-mori">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Mori</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Merciless Resolve<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> Spend 2 Momentum.  You gain +4 Current.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Merciless Resolve
# --Cost|3
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^Spend 2 Momentum.  You gain +4 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Invoke Death<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  4</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Up to three targets in your Current or an Adjacent Zone lose X Grit, where X is equal to Hits in the result set.</p>
# <p><strong>Threshold &mdash; 5</strong><br> Up to three targets in your Current or an Adjacent Zone lose X Grit, where X is equal to Hits in the result set.  You gain +3 Current.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Invoke Death
# --Cost|4
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to three targets in your Current or an Adjacent Zone lose X Grit, where X is equal to Hits in the result set.
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to three targets in your Current or an Adjacent Zone lose X Grit, where X is equal to Hits in the result set.  You gain +3 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Mortality Spear<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; None</strong><br> Spend 3 Grit, then 1 target in your Current or an Adjacent Zone loses X +3 Grit, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Mortality Spear
# --Cost|3
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= None ?? Effect:|**//Threshold - [^tech.ss]//**^^Spend 3 Grit, then 1 target in your Current or an Adjacent Zone loses X +3 Grit, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Alms of Vivus<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  0</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> One target in your Current or an Adjacent Zone loses X Grit, where X is equal to Hits in the result set.</p>
# <p><strong>Threshold &mdash; 3</strong><br> One target in your Current or an Adjacent Zone loses X Grit and one other target in your Current Zone regains X Grit, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Alms of Vivus
# --Cost|0
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone loses X Grit, where X is equal to Hits in the result set.
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone loses X Grit and one other target in your Current Zone regains X Grit, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Death's Touch<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> One target in your Current or an Adjacent Zone gains Wounded 1.</p>
# <p><strong>Threshold &mdash; 4</strong><br> One target in your Current or an Adjacent Zone gains Wounded 1.  You gain +2 Current.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Death's Touch
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone gains Wounded 1.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone gains Wounded 1.  You gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Culling Ritual<br><em><span style="font-size:10pt;">Trigger<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> When a target in your Current Zone dies, increase the Entropy +1 and one other target in your Current or an Adjacent Zone loses X +2 Grit, where X is equal to Hits in the result set.</p>
# <p><strong>Threshold &mdash; 3</strong><br> When a target in your Current Zone dies, increase the Entropy +1 and one other target in your Current or an Adjacent Zone loses X +2 Grit.  You gain +2 Current.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Culling Ritual
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^When a target in your Current Zone dies, increase the Entropy +1 and one other target in your Current or an Adjacent Zone loses X +2 Grit, where X is equal to Hits in the result set.
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^When a target in your Current Zone dies, increase the Entropy +1 and one other target in your Current or an Adjacent Zone loses X +2 Grit.  You gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_2" value="None" />
# <div class="sheet-power-nihil">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Nihil</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Enter the Infinite<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Cost:  5</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Increase the Entropy +2 and immediately take X Actions, where X is equal to Hits in the result set.</p>
# <p><strong>Threshold &mdash; 2</strong><br> Spend 5 Entropy and immediately take X Actions, X . . .  The Momentum equals 5.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Enter the Infinite
# --Cost|5
# --Current|8
# --api_setattr|_name @{name} _current|8
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^Increase the Entropy +2 and immediately take X Actions, where X is equal to Hits in the result set.
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^Spend 5 Entropy and immediately take X Actions, X . . .  The Momentum equals 5.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Invoke Despair<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Target your Current or an Adjacent Zone, then choose one (1):<ul><li>All targets in the targeted Zone gain Afraidd 2 and gain Confused 2.</li><li>Increase the Entropy by +1 and you gain +3 Current.</li></ul></p>
# <p><strong>Threshold &mdash; 5</strong><br> Target your Current or an Adjacent Zone, then choose one or both:<ul><li>All hostile targets in the targeted Zone gain Afraidd 2 and gain Confused 2.</li><li>Increase the Entropy by +1 and you gain +3 Current.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Invoke Despair
# --Cost|3
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 AND $tech.ss < 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one (1)**:^^^^**All targets in the targeted Zone gain Afraidd 2 and gain Confused 2.^^^^Increase the Entropy by +1 and you gain +3 Current.**
# --?? $tech.ss >= 5 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one or both**:^^^^**All hostile targets in the targeted Zone gain Afraidd 2 and gain Confused 2.^^^^Increase the Entropy by +1 and you gain +3 Current.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Negation Blast<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Select a target in your Current or an Adjacent Zone and then choose one (1):<ul><li>The target takes X Hits and gains Vulnerable 1, where X is equal to Hits in the result set.</li><li>The target loses all Auras and loses 2 Grit.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Negation Blast
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select a target in your Current or an Adjacent Zone and then **choose one (1)**:^^^^**The target takes X Hits and gains Vulnerable 1, where X is equal to Hits in the result set.^^^^The target loses all Auras and loses 2 Grit.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Void Rift<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> All targets in your Current or an Adjacent Zone becomee Prone and gain Vulnerable 1.  Increase the Entropy by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Void Rift
# --Cost|1
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^All targets in your Current or an Adjacent Zone becomee Prone and gain Vulnerable 1.  Increase the Entropy by +1.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_2" value="None" />
# <div class="sheet-power-nox">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Nox</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Dark Ritual<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Cost:  1</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> Increase the Entropy by +1.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Dark Ritual
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^Increase the Entropy by +1.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Subtle Strike<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> Select a target in your Current or an Adjacent Zone and then choose one (1):<ul><li>The target gains Fatigued 1.</li><li>The target takes 2 Hits to Nerve.</li></ul></p>
# <p><strong>Threshold &mdash; 3</strong><br> Select a target in your Current or an Adjacent Zone and then choose one or both:<ul><li>The target gains Fatigued 1.</li><li>The target takes 2 Hits to Nerve.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Subtle Strike
# --Cost|2
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select a target in your Current or an Adjacent Zone and then **choose one (1)**:^^^^**The target gains Fatigued 1.^^^^The target takes 2 Hits to Nerve.**
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select a target in your Current or an Adjacent Zone and then **choose one or both**:^^^^**The target gains Fatigued 1.^^^^The target takes 2 Hits to Nerve.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Eyes of Night<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Cost:  0</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> You can see in absolute darkness and are immune to the Blind status.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Eyes of Night
# --Cost|0
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^You can see in absolute darkness and are immune to the Blind status.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Shadow Lance<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Select one target in your Current or an Adjacent Zone and choose one (1):<ul><li>The target takes X Hits to their Nerve, where X is equal to Hits in the result set.</li><li>The target gains Afraidd 2 and Wounded 1.</li><li>You gain +3 Current.</li></ul></p>
# <p><strong>Threshold &mdash; 4</strong><br> Select one target in your Current or an Adjacent Zone and choose two (2):<ul><li>The target takes X Hits to their Nerve, where X is equal to Hits in the result set.</li><li>The target gains Afraidd 2 and Wounded 1.</li><li>You gain +3 Current.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Shadow Lance
# --Cost|2
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select one target in your Current or an Adjacent Zone and **choose one (1)**:^^^^**The target takes X Hits to their Nerve, where X is equal to Hits in the result set.^^^^The target gains Afraidd 2 and Wounded 1.^^^^You gain +3 Current.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Select one target in your Current or an Adjacent Zone and **choose two (2)**:^^^^**The target takes X Hits to their Nerve, where X is equal to Hits in the result set.^^^^The target gains Afraidd 2 and Wounded 1.^^^^You gain +3 Current.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Dread Fugue<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> One target in your Current or an Adjacent Zone gains Vulnerable 2.  You gain +2 Current.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Dread Fugue
# --Cost|2
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone gains Vulnerable 2.  You gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Vengeance of Shadows<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Your Current or an Adjacent Zone gains Hazard 1.</p>
# <p><strong>Threshold &mdash; 4</strong><br> All targets in your Current or an Adjacent Zone gain Blind 2.  The targeted zone gains Hazard 1.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Vengeance of Shadows
# --Cost|3
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Your Current or an Adjacent Zone gains Hazard 1.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^All targets in your Current or an Adjacent Zone gain Blind 2.  The targeted zone gains Hazard 1.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Eclipse<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 4</strong><br> All targets in those Zones gain Blind 1 Ongoing.  You gain +X Current, where X is the number of targets Blinded this way.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Eclipse
# --Cost|3
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^All targets in those Zones gain Blind 1 Ongoing.  You gain +X Current, where X is the number of targets Blinded this way.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Spreading Darkness<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> All light in your Current Zone are extinguished and all targets in your Current Zone gain Blind 1 Ongoing.<br><br>At the beginning of each of your turns while this Technique is Ongoing, copy its effect to all Adjacent Zones.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Spreading Darkness
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# ...
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Cascade
# --Cost|0
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^If you score 3+ Hits on the next Technique you use this turn, you gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">One With Water<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Cost:  0</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> You gain Aura X, where X is equal to Hits in the result set.  While this Aura persists, your can breathe underwater and ignore Hazards in underwater Zones.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - One With Water
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 ?? Effect:|**//Threshold - [^tech.ss]//**^^You gain Aura X, where X is equal to Hits in the result set.  While this Aura persists, your can breathe underwater and ignore Hazards in underwater Zones.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Hydro Blast<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  0</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> One target in your Current or an Adjacent Zone takes 2 Hits and gains Dazed 1.</p>
# <p><strong>Threshold &mdash; 3</strong><br> One target in your Current or an Adjacent Zone takes 2 Hits and gains Dazed 1.  You gain +1 Current.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Hydro Blast
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes 2 Hits and gains Dazed 1.
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes 2 Hits and gains Dazed 1.  You gain +1 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Current's Flow<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  0</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> You gain +2 Current.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Current's Flow
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^You gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Water Spout<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> One target in your Current or an Adjacent Zone takes 2 Hits and becomes Prone.</p>
# <p><strong>Threshold &mdash; 4</strong><br> Up to 2 targets in your Current or an Adjacent Zone take 2 Hits and become Prone.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Water Spout
# --Cost|3
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone takes 2 Hits and becomes Prone.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone take 2 Hits and become Prone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Riptide<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> One target in your Current Zone gains Confused 2.</p>
# <p><strong>Threshold &mdash; 4</strong><br> Up to 3 targets in your Current Zone gain Confused 2.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Riptide
# --Cost|3
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current Zone gains Confused 2.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 3 targets in your Current Zone gain Confused 2.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Tangle Wave<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  4</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Target your Current or an Adjacent Zone.  All targets in the targeted Zone gain Restrained 2.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Tangle Wave
# --Cost|4
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone.  All targets in the targeted Zone gain Restrained 2.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Soothing Waters<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> One target in your Current Zone can choose one (1):<ul><li>Regain X Grit, where X is equal to Hits in the result set.</li><li>Reduce one Status by X, where X is equal to Hits in the result set.</li></ul></p>
# <p><strong>Threshold &mdash; 4</strong><br> Up to 3 targets in your Current Zone can choose one (1):<ul><li>Regain X Grit, where X is equal to Hits in the result set.</li><li>Reduce one Status by X, where X is equal to Hits in the result set.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Soothing Waters
# --Cost|2
# --Current|1
# --api_setattr|_name @{name} _current|1
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current Zone can **choose one (1)**:^^^^**Regain X Grit, where X is equal to Hits in the result set.^^^^Reduce one Status by X, where X is equal to Hits in the result set.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 3 targets in your Current Zone can **choose one (1)**:^^^^**Regain X Grit, where X is equal to Hits in the result set.^^^^Reduce one Status by X, where X is equal to Hits in the result set.**
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Crashing Wave<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> All targets except you in yoru Current Zone take 3 Hits and become Prone.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Crashing Wave
# --Cost|3
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^All targets except you in yoru Current Zone take 3 Hits and become Prone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Be Like Water<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Recover X to your Primary Defense, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Be Like Water
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^Recover X to your Primary Defense, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Undertow<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> One target in an Adjacent Zone is moved into your Current Zone.</p>
# <p><strong>Threshold &mdash; 4</strong><br> Up to 3 targets in an Adjacent Zone are moved into your Current Zone.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Undertow
# --Cost|2
# --Current|4
# --api_setattr|_name @{name} _current|4
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in an Adjacent Zone is moved into your Current Zone.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Up to 3 targets in an Adjacent Zone are moved into your Current Zone.
# --?? $tech.ones > 0 ?? Trigger:|Recoil
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_affinity_2" value="None" />
# <div class="sheet-power-vivus">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Vivus</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Revitalize<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  0</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> One target in your Current or an Adjacent Zone recovers X +2 to their Primary Defense and regains X Grit, where X is equal to Hits in the result set.</p>
# <p><strong>Threshold &mdash; 4</strong><br> One target in your Current or an Adjacent Zone recovers X +2 to their Primary Defense and regains X Grit, where X is equal to Hits in the result set.  You gain +2 Current.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Revitalize
# --Cost|0
# --Current|2
# --api_setattr|_name @{name} _current|2
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 1 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone recovers X +2 to their Primary Defense and regains X Grit, where X is equal to Hits in the result set.
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone recovers X +2 to their Primary Defense and regains X Grit, where X is equal to Hits in the result set.  You gain +2 Current.
# --?? $tech.ones > 0 ?? Trigger:|The Cycle's Drain
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Invoke the Dawn<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  3</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Target your Current or an Adjacent Zone, then choose one (1):<ul><li>All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.</li><li>All allies in the targeted Zone recover 3 Hits to their Primary Defense and regain up to 2 Grit.</li></ul></p>
# <p><strong>Threshold &mdash; 4</strong><br> Target your Current or an Adjacent Zone, then choose one or both:<ul><li>All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.</li><li>All allies in the targeted Zone recover 4 Hits to their Primary Defense and regain up to 2 Grit.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Invoke the Dawn
# --Cost|3
# --Current|5
# --api_setattr|_name @{name} _current|5
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 AND $tech.ss < 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one (1)**:^^^^**All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.^^^^All allies in the targeted Zone recover 3 Hits to their Primary Defense and regain up to 2 Grit.**
# --?? $tech.ss >= 4 ?? Effect:|**//Threshold - [^tech.ss]//**^^Target your Current or an Adjacent Zone, then **choose one or both**:^^^^**All hostile targets in the targeted Zone take 3 Hits and gain Dazed 2.^^^^All allies in the targeted Zone recover 4 Hits to their Primary Defense and regain up to 2 Grit.**
# --?? $tech.ones > 0 ?? Trigger:|The Cycle's Drain
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Revitalizing Ray<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  1</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> One target in your Current or an Adjacent Zone recovers X to their Primary Defense and reduces all Statuses by X, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Revitalizing Ray
# --Cost|1
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 3 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in your Current or an Adjacent Zone recovers X to their Primary Defense and reduces all Statuses by X, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|The Cycle's Drain
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Rush of Vitality<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Cost:  2</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> One target in yoru Current Zone regains X Grit, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Rush of Vitality
# --Cost|2
# --Current|3
# --api_setattr|_name @{name} _current|3
# --Result Set|[[ [$tech|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^tech.ss]
# --1s|[^tech.ones]
# --format|powercheck
# --?? $tech.ss >= 2 ?? Effect:|**//Threshold - [^tech.ss]//**^^One target in yoru Current Zone regains X Grit, where X is equal to Hits in the result set.
# --?? $tech.ones > 0 ?? Trigger:|The Cycle's Drain
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>

# %% [markdown]
# ### Marvels start

# %%
df_marvels = pd.DataFrame.from_records(powers_data['marvels'])
df_marvels.sort_values(by=['skill', 'rank'], inplace=True)

# %%
df_marvels.head()
# Out:
#               name rank   skill     type  \
# 0  Essence Barrier    1  Aether  Ability
# 1      Essence Ray    1  Aether  Ability
# 2   Essence Strike    1  Aether  Ability
# 7    Essence Surge    1  Aether    Shift
# 8     Essence Veil    1  Aether    Shift
#
#                                               effect  \
# 0                                               None
# 1                                               None
# 2                                               None
# 7  Add +1d4 Bonus Hits to your next Action this t...
# 8                                   You gain Aura X.
#
#                                            threshold   keywords hits
# 0  [{'hits': '2', 'effect': 'Your Current Zone ga...  Ongoing 2  NaN
# 1  [{'hits': '2', 'effect': 'Select one target in...  Ongoing 1  NaN
# 2  [{'hits': '1', 'effect': 'One target in your C...             NaN
# 7                                               None             NaN
# 8                                               None       Aura  NaN

# %%
df_marvels['pcard'] = ''
# df_techniques['cost'] = df_techniques['cost'].astype('int')
# df_techniques['current'] = df_techniques['current'].astype('int')

# %%
t = df_marvels[(df_marvels['name']=='Essence Ray') & (df_marvels['skill']=='Lux')].copy()
i = 1
for t in t['threshold']:
    for i in t:
        clean_effect = i['effect'].replace('choose', '**choose').replace(':<ul><li>', '**:^^^^**').replace('</li><li>', '^^^^').replace('</li></ul>', '**')
        print(clean_effect)
# Out:
# Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**

# %% [markdown]
# #### Build Mrvl Powercards

# %%
t
# Out:
# [{'hits': '2',
#   'effect': "Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following:<ul><li>The target takes 1d4 Bonus Hits.</li><li>Increase one of the target's Statuses one Status by +1.</li><li>Decrease one of the target's Statuses one Status by -1.</li></ul>"}]

# %%
mrvl_pcards = []
for index, t in df_marvels.iterrows():
    skill_clean = t['skill'].lower()
    res = '''!power {{
--Name|@{character_name} - ''' + t['name'] + '''
--Rank|''' + str(t['rank']) + '''
--Result Set|[[ [$mrvl|XPND] @{Cosm|challenge}d@{skill_''' + skill_clean + '''}>@{Cosm|target}]]
--Hits|[^mrvl.ss]
--1s|[^mrvl.ones]
--format|powercheck\n'''
    if t['threshold'] is not None and len(t['threshold']) > 1:
        for i in range(len(t['threshold'])):
            if i < len(t['threshold']) - 1:
                clean_effect = t['threshold'][i]['effect'].replace('choose', '**choose').replace(':<ul><li>', '**:^^^^**').replace('</li><li>', '^^^^').replace('</li></ul>', '**')
                res += '''--?? $mrvl.ss >= ''' + str(t['threshold'][i]['hits']) + ''' AND $mrvl.ss < ''' + str(t['threshold'][i+1]['hits']) + ''' ?? Effect:|**//Threshold - [^mrvl.ss]//**^^''' + clean_effect + '\n'
            else:
                clean_effect = t['threshold'][i]['effect'].replace('choose', '**choose').replace(':<ul><li>', '**:^^^^**').replace('</li><li>', '^^^^').replace('</li></ul>', '**')
                res += '''--?? $mrvl.ss >= ''' + str(t['threshold'][i]['hits']) + ''' ?? Effect:|**//Threshold - [^mrvl.ss]//**^^''' + clean_effect + '\n'
    elif t['threshold'] is not None:
        for r in t['threshold']:
            clean_effect = r['effect'].replace('choose', '**choose').replace(':<ul><li>', '**:^^^^**').replace('</li><li>', '^^^^').replace('</li></ul>', '**')
            res += '''--?? $mrvl.ss >= ''' + str(r['hits']) + ''' ?? Effect:|**//Threshold - [^mrvl.ss]//**^^''' + clean_effect + '\n'
    res += '''--?? $mrvl.ones > 0 ?? Trigger:|Your Attunement decreases by -[^mrvl.ss].\n'''
    # res += '''--?? $mrvl.ones > 0 ?? api_setattr|_name @{name} _attunement|[[ @{attunement} - [^mrvl.ss] ]]'''
    res += '''}}'''
    print(res)
    mrvl_pcards.append(res)
    # print(t['pcard'])
# Out:
# !power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^One target in your Current Zone takes X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Infusion
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Agent of the Aether
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Wield the Aether
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Aether Outburst
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^One target in your Current Zone takes X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Infusion
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Agent of Chaos
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Wield Chaos
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Violent Outburst
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Infusion
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Agent of Fire
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Wield the Inferno
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Fiery Outburst
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Infusion
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Agent of Light
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Wied the Light
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Radiant Outburst
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Infusion
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Agent of Death
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Wield Death
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Lethal Outburst
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Infusion
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Agent of the Nothing
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Wield the Nothing
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Void Effusion
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nihil}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Infusion
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Agent of Darkness
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Wield Shadow
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Dark Outburst
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_nox}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Infusion
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Agent of Order
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Wield Order
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Effuse with Law
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_ordi}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# ...
# }}
# !power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Agent of Storms
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Wield the Storm
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Stormbreak Outburst
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_tempest}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Infusion
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Agent of Waves
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Wield the Depths
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Sudden Deluge
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Infusion
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Agent of Life
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Wield the Lifeforce
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Effuse with Life
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}
# !power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}

# %%
df_marvels['pcard'] = mrvl_pcards

# %%
type='Shift'
t_type = df_marvels[(df_marvels['type']==type) & (df_marvels['name'] != '')].copy()
div_str = ''
for p in df_marvels['skill'].unique():
    div_str += '''<div class="grid-container-talents">\n<input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_1" value="None" />\n<input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_2" value="None" />\n<input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_3" value="None" />\n<input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_4" value="None" />\n<input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_5" value="None" />\n<input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_6" value="None" />\n<input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_7" value="None" />\n<div class="sheet-power-'''+ p.lower() +'''">\n<h4 class="grid-talents-label" style="margin-bottom:4px;">''' + p + '''</h4>\n<div class="grid-container-talents">\n'''
    for s in ['Shift', 'Ability', 'Trigger']:
        mrvls = df_marvels[(df_marvels['skill']==p) & (df_marvels['type']==s)]
        for index, mrvl in mrvls.iterrows():
            div_str += '''<div class="grid-item-talents">\n''' 
            div_str +='''<label style="font-size:12pt; margin-bottom: 4px;">''' + mrvl['name'] + '''<br><em><span style="font-size:10pt;">''' + mrvl['type'] + '''<br><span style="font-size:8pt;">Rank:  ''' + str(mrvl['rank']) + '''</span></label>\n''' 
            if mrvl['threshold'] is not None:
                for t in mrvl['threshold']:
                    div_str += '''<p><strong>Threshold &mdash; ''' + str(t['hits']) + '''</strong><br> ''' + t['effect'] + '''</p>\n'''
            if mrvl['pcard'] is not None:
                div_str +='''<button class="skill-button" type="roll" value="''' + mrvl['pcard'] +'''">\n</button>\n'''
            else:
                div_str +='''<button class="skill-button" type="roll" value="!power {{
            --name|@{Name} - ''' + tal['name'] + '''
            --Effect|''' + tal['effect'] + '''
            --format|powercheck
            }}">\n</button>\n'''
            div_str +='''</div>\n'''
    div_str +='''</div>\n</div>\n</div>\n'''

print(div_str)
# Out:
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_2" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_3" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_4" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_5" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_6" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_7" value="None" />
# <div class="sheet-power-aether">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Aether</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Surge<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Veil<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Warding Essence<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Volley<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Aether Outburst<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Aether Outburst
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Barrier<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Ray<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following:<ul><li>The target takes 1d4 Bonus Hits.</li><li>Increase one of the target's Statuses one Status by +1.</li><li>Decrease one of the target's Statuses one Status by -1.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Strike<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> One target in your Current Zone takes X Hits, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^One target in your Current Zone takes X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Blast<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Rift<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Binding Essence<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Barrage<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Storm<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Wave<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Nova<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Burst<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  4</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_aether}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_2" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_3" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_4" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_5" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_6" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_7" value="None" />
# <div class="sheet-power-bellor">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Bellor</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Surge<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Veil<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Warding Essence<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Volley<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Violent Outburst<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Violent Outburst
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Barrier<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Ray<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following:<ul><li>The target takes 1d4 Bonus Hits.</li><li>Increase one of the target's Statuses one Status by +1.</li><li>Decrease one of the target's Statuses one Status by -1.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Strike<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> One target in your Current Zone takes X Hits, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^One target in your Current Zone takes X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Blast<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Rift<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Binding Essence<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Barrage<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Storm<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following:<ul><li>Move the Storm one Adjacent Zone.</li><li>One ally in the Storm's Zone may immediately use the Recover Action</li><li>One target in the Storm's Zone takes 1d4 Bonus Hits.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Wave<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Nova<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Burst<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  4</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_bellor}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_2" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_3" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_4" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_5" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_6" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_7" value="None" />
# <div class="sheet-power-inferno">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Inferno</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Surge<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Veil<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Warding Essence<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Volley<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Fiery Outburst<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Fiery Outburst
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Barrier<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Ray<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following:<ul><li>The target takes 1d4 Bonus Hits.</li><li>Increase one of the target's Statuses one Status by +1.</li><li>Decrease one of the target's Statuses one Status by -1.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Strike<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Blast<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Rift<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Binding Essence<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Barrage<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Storm<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following:<ul><li>Move the Storm one Adjacent Zone.</li><li>One ally in the Storm's Zone may immediately use the Recover Action</li><li>One target in the Storm's Zone takes 1d4 Bonus Hits.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Wave<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Nova<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Burst<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  4</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_inferno}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_2" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_3" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_4" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_5" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_6" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_7" value="None" />
# <div class="sheet-power-lux">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Lux</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Surge<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Veil<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Warding Essence<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Volley<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Radiant Outburst<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Radiant Outburst
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Barrier<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Ray<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following:<ul><li>The target takes 1d4 Bonus Hits.</li><li>Increase one of the target's Statuses one Status by +1.</li><li>Decrease one of the target's Statuses one Status by -1.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Strike<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Blast<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Rift<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Binding Essence<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Barrage<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Storm<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following:<ul><li>Move the Storm one Adjacent Zone.</li><li>One ally in the Storm's Zone may immediately use the Recover Action</li><li>One target in the Storm's Zone takes 1d4 Bonus Hits.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Wave<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Nova<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Burst<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  4</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_lux}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_2" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_3" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_4" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_5" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_6" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_7" value="None" />
# <div class="sheet-power-mori">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Mori</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Surge<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_mori}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Veil<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# ...
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Binding Essence<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Barrage<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Storm<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following:<ul><li>Move the Storm one Adjacent Zone.</li><li>One ally in the Storm's Zone may immediately use the Recover Action</li><li>One target in the Storm's Zone takes 1d4 Bonus Hits.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Wave<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Nova<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Burst<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  4</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_torrent}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container-talents">
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_1" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_2" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_3" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_4" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_5" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_6" value="None" />
# <input class="sheet-powers-affinity" type="hidden" name="attr_essence_affinity_7" value="None" />
# <div class="sheet-power-vivus">
# <h4 class="grid-talents-label" style="margin-bottom:4px;">Vivus</h4>
# <div class="grid-container-talents">
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Surge<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Surge
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Veil<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Veil
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Warding Essence<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Warding Essence
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Volley<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Volley
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Effuse with Life<br><em><span style="font-size:10pt;">Shift<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Effuse with Life
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Barrier<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Barrier
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Your Current Zone gains Hazard 2 Ongoing.  It requires 2 Shifts to Move into or out of your Current Zone Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Ray<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <p><strong>Threshold &mdash; 2</strong><br> Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following:<ul><li>The target takes 1d4 Bonus Hits.</li><li>Increase one of the target's Statuses one Status by +1.</li><li>Decrease one of the target's Statuses one Status by -1.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Ray
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 2 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Select one target in your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**The target takes 1d4 Bonus Hits.^^^^Increase one of the target's Statuses one Status by +1.^^^^Decrease one of the target's Statuses one Status by -1.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Strike<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  1</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Strike
# --Rank|1
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Blast<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Blast
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Rift<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Rift
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target one Zone up to 2 Zone Adjacent to your Current Zone. The targetted Zone gains +1 Hazard Ongoing.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Binding Essence<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Binding Essence
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Barrage<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  2</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Barrage
# --Rank|2
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Storm<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <p><strong>Threshold &mdash; 1</strong><br> Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following:<ul><li>Move the Storm one Adjacent Zone.</li><li>One ally in the Storm's Zone may immediately use the Recover Action</li><li>One target in the Storm's Zone takes 1d4 Bonus Hits.</li></ul></p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Storm
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 1 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Target your Current or an Adjacent Zone.  This turn, and on each of your turns Ongoing, you may use a Shift for one of the following**:^^^^**Move the Storm one Adjacent Zone.^^^^One ally in the Storm's Zone may immediately use the Recover Action^^^^One target in the Storm's Zone takes 1d4 Bonus Hits.**
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Wave<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Wave
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Nova<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  3</span></label>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Nova
# --Rank|3
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# <div class="grid-item-talents">
# <label style="font-size:12pt; margin-bottom: 4px;">Essence Burst<br><em><span style="font-size:10pt;">Ability<br><span style="font-size:8pt;">Rank:  4</span></label>
# <p><strong>Threshold &mdash; 3</strong><br> Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.</p>
# <button class="skill-button" type="roll" value="!power {{
# --Name|@{name} - Essence Burst
# --Rank|4
# --Result Set|[[ [$mrvl|XPND] @{BAMF|challenge}d@{skill_vivus}>@{BAMF|target}]]
# --Hits|[^mrvl.ss]
# --1s|[^mrvl.ones]
# --format|powercheck
# --?? $mrvl.ss >= 3 ?? Effect:|**//Threshold - [^mrvl.ss]//**^^Up to 3 Targets in your Current Zone take X Hits, where X is equal to Hits in the result set.
# --?? $mrvl.ones > 0 ?? Trigger:|Your Attunement reduces by [^mrvl.ss].
# }}">
# </button>
# </div>
# </div>
# </div>
# </div>

# %% [markdown]
# ### Spells Start

# %%
df_spells = pd.DataFrame(powers_data['spells'])

# %%
df_spells['attr_spell_rank'] = '''attr_spell_rank_''' + df_spells['name'].str.lower().str.replace(' ', '_')

# %%
df_spells.head()
# Out:
#              name     type max_ranks  \
# 0   Arc Lightning  Ability         4
# 1          Arrest  Ability         4
# 2      Asphyxiate  Ability         2
# 3  Augment Senses    Shift         2
# 4     Biting Rain  Ability         2
#
#                                               effect  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  All targets in your Current or an Adjacent Zon...
#
#                                            threshold requires  \
# 0  [{'hits': 2, 'effect': 'Choose 3 targets you c...     None
# 1  [{'hits': 1, 'effect': 'One target you can see...     None
# 2  [{'hits': 2, 'effect': 'You pull the air from ...     None
# 3  [{'hits': 2, 'effect': 'Score 2+ Hits touch on...     None
# 4  [{'hits': 2, 'effect': ''}, {'hits': 4, 'effec...     None
#
#                    keywords                 attr_spell_rank
# 0                 [Tempest]   attr_spell_rank_arc_lightning
# 1  [Ongoing 2, Lux, Aether]          attr_spell_rank_arrest
# 2     [Plaga, Mori, Squall]      attr_spell_rank_asphyxiate
# 3    [Vivus, Mentis, Forma]  attr_spell_rank_augment_senses
# 4                   [Plaga]     attr_spell_rank_biting_rain

# %%
spell_pcards = []
for index, t in df_spells.iterrows():
    spell_attr = t['attr_spell_rank'].replace('attr_', '')
    res = '''!power {{
--Name|@{character_name} - ''' + t['name'] + '''
--Rank|d@''' + spell_attr + '''
--Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{''' + spell_attr + '''}>@{Cosm|target}]]
--Hits|[^spell.ss]
--1s|[^spell.ones]
--format|powercheck\n'''
    if t['threshold'] is not None and len(t['threshold']) > 1:
        for i in range(len(t['threshold'])):
            if i < len(t['threshold']) - 1:
                clean_effect = t['threshold'][i]['effect'].replace('choose', '**choose').replace(':<ul><li>', '**:^^^^**').replace('</li><li>', '^^^^').replace('</li></ul>', '**')
                res += '''--?? $spell.ss >= ''' + str(t['threshold'][i]['hits']) + ''' AND $spell.ss < ''' + str(t['threshold'][i+1]['hits']) + ''' ?? Effect:|**//Threshold - [^spell.ss]//**^^''' + clean_effect + '\n'
            else:
                clean_effect = t['threshold'][i]['effect'].replace('choose', '**choose').replace(':<ul><li>', '**:^^^^**').replace('</li><li>', '^^^^').replace('</li></ul>', '**')
                res += '''--?? $spell.ss >= ''' + str(t['threshold'][i]['hits']) + ''' ?? Effect:|**//Threshold - [^spell.ss]//**^^''' + clean_effect + '\n'
    elif t['threshold'] is not None:
        for r in t['threshold']:
            clean_effect = r['effect'].replace('choose', '**choose').replace(':<ul><li>', '**:^^^^**').replace('</li><li>', '^^^^').replace('</li></ul>', '**')
            res += '''--?? $spell.ss >= ''' + str(r['hits']) + ''' ?? Effect:|**//Threshold - [^spell.ss]//**^^''' + clean_effect + '\n'
    res += '''--?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** ''' + str(t['threshold'][0]['hits']) + '''\n'''
    # res += '''--?? $spell.ones > 0 ?? api_setattr|_name @{name} _attunement|[[ @{attunement} - [^spell.ss] ]]'''
    res += '''}}'''
    print(res)
    spell_pcards.append(res)
# Out:
# !power {{
# --Name|@{character_name} - Arc Lightning
# --Rank|d@spell_rank_arc_lightning
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_arc_lightning}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Choose 3 targets you can see in your Current Zone. Deal 1 Hit to each target.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Choose 3 targets you can see in your Current Zone.  Deal 3 Hits the first target, 2 Hits to the second target, & 1 Hit to the third.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Arrest
# --Rank|d@spell_rank_arrest
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_arrest}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target you can see in your Current or an Adjacent Zone gains Restrained X, where X is equal to Hits.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target you can see in your Current or an Adjacent Zone gains Restrained <em>x</em>, where <em>x</em> is equal to Hits +2.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Asphyxiate
# --Rank|d@spell_rank_asphyxiate
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_asphyxiate}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^You pull the air from the lungs of one target you can see in your Current Zone.  They gain Vulnerable 2 and Dazed X, where X is equal to Hits in the result set.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^You pull the air from the lungs of one target you can see in your Current Zone.  They gain Stunned and Vulnerable X, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Augment Senses
# --Rank|d@spell_rank_augment_senses
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_augment_senses}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^Score 2+ Hits touch one target you can seei n your Current Zone, allowing them to add +1d4 Bonus Hits to their next result set for any of the follosing Skills:<br><em>Focus, Insight, Investigate, Operate, Perceive</em>
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Biting Rain
# --Rank|d@spell_rank_biting_rain
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_biting_rain}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^All targets in your Current or an Adjacent Zone suffer 2 Hit to their Primary Defense.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Blazing Volley
# --Rank|d@spell_rank_blazing_volley
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_blazing_volley}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Deal 2 Hits to up to 3 targets in an Adjacent Zone.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Deal 3 Hits to up to 4 targets in an Adjacent Zone.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Blinding Flare
# --Rank|d@spell_rank_blinding_flare
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_blinding_flare}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gain Blind 1.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^make one target in your Current or an Adjacent Zone gain Blind 3.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Call to the Netherworld
# --Rank|d@spell_rank_call_to_the_netherworld
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_call_to_the_netherworld}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 ?? Effect:|**//Threshold - [^spell.ss]//**^^Reach out to the spirits of the dead when you are in their presence to ask X questions, where X is the number of Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Chain Lightning
# --Rank|d@spell_rank_chain_lightning
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_chain_lightning}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Deal X to one Target in your Current or an Adjacent Zone, where X is equal to Hits in the result set.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^<em><strong>Trigger</strong></em> &mdash cast this spell again choosing a different target.  This copy uses the last target's Zone as its Current Zone.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Charm Target
# --Rank|d@spell_rank_charm_target
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_charm_target}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Charmed X, where X is equal to Hits in the results set.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current Zone gain Charmed X, where X is equal to Hits in the results set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Chill of the Grave
# --Rank|d@spell_rank_chill_of_the_grave
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_chill_of_the_grave}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone becomees Afraidd of you and gains Fatigued X, where x is equal to Hits in the result set.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to two targets in your Current Zone becomee Afraidd of you and gains Fatigued X, where x is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Chill to the Bone
# --Rank|d@spell_rank_chill_to_the_bone
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_chill_to_the_bone}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Slowed 2 and Fatigued X, where x is equal to Hits in the result set.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to two targets in your Current Zone gains Slowed 2 and Fatigued X, where x is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Choking Fumes
# --Rank|d@spell_rank_choking_fumes
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_choking_fumes}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to X targets in your Current or an Adjacent Zone gain Fatigued 1, where X is equal to Hits in the result set.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to X targets in your Current or an Adjacent Zone gain Fatigued 1, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Circle of Affliction
# --Rank|d@spell_rank_circle_of_affliction
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_circle_of_affliction}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gain Wounded 1 Ongoing.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Wounded 3 Ongoing.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Circle of Confinement
# --Rank|d@spell_rank_circle_of_confinement
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_circle_of_confinement}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Restrained 1 at the start of each of its turns.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Restrained 3 at the start of each of its turns.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Comet Storm
# --Rank|d@spell_rank_comet_storm
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_comet_storm}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^All targets in your Current or an Adjacent Zone suffer 4 Hits.
# --?? $spell.ss >= 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^All targets in up to 3 Zones Current and Adjacent to you suffer 6 Hits.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Contact Other Plane
# --Rank|d@spell_rank_contact_other_plane
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_contact_other_plane}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^You establish contact with someone or something.  You can ask X questions, where X is number of Hits in the reuslt set.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Same as above, but decrease the Entropy by -2.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Crippling Blight
# --Rank|d@spell_rank_crippling_blight
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_crippling_blight}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Touch one target you can see in your Current Zone.  They gain Vulnerable 1 and gain Fatigue X, where X is equal to Hits in the result set.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Touch up to 2 targets you can see in your Current Zone.  They gain Vulnerable 1 and gain Fatigue X, where X is euqla to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Cyclone
# --Rank|d@spell_rank_cyclone
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_cyclone}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^Target your Current or an Adjacent Zone.  Up to 3 targets in are pushed to a different Zone adjacent to targeted Zone, and the targeted Zone gains Hazard 3.
# --?? $spell.ss >= 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^Target your Current or an Adjacent Zone.  Up to X targets in are pushed to a different Zone adjacent to targeted Zone, and the targeted Zone gains Hazard X, where X is equal to Hits in the resul set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Damping Pulse
# --Rank|d@spell_rank_damping_pulse
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_damping_pulse}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone gain Fatigued 2.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in your Current or an Adjacent Zone gain Fatigued 2.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Dark Blast
# --Rank|d@spell_rank_dark_blast
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_dark_blast}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone loses X Grit, where X is equal to Hits in the result set.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone loses X + 2 Grit, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Dazzling Lights
# --Rank|d@spell_rank_dazzling_lights
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_dazzling_lights}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in your Current Zone gain Dazed 1.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in your Current Zone gain Confused 2.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Death Cloud
# --Rank|d@spell_rank_death_cloud
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_death_cloud}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^All creatures in your Current or an Adjacent Zone gain Wounded 1 and lose 3 Grit.
# --?? $spell.ss >= 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^All creatures in your Current or an Adjacent Zone becomee Wounded 3 and lose X Grit, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Deathmark
# --Rank|d@spell_rank_deathmark
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_deathmark}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gain Vulnerable 2.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Vulnerable 2 at the beginning of each of your turns.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Detect Magic
# --Rank|d@spell_rank_detect_magic
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_detect_magic}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Gain Aura X to sense any presence any magical Power in your Current Zone, where X is equal to Hits in thes result set.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Gain Aura X to sense any presence  any magical Power in your Current Zone, where X is equal to Hits in thes result set.  Add +1d4 Bonus Hits to any Action you use to identify the nature or source of the Power.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Detention Sphere
# --Rank|d@spell_rank_detention_sphere
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_detention_sphere}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone cannot be the target of any Actions and gain Stunned 2 and Unconscious 1 Ongoing.  You may use a Shift on each of your turns to Move the Detention Sphere.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Same as above, except the target gain Stunned X +1 and Unconscious X Ongoing, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Dimension Door
# --Rank|d@spell_rank_dimension_door
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_dimension_door}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Allow one target in your Current Zone to move to any Zone up to 2 adjacencies away ignoring Hazards.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Allow up to 2 targets in your Current Zone to move to any Zone up to 2 adjacencies away ignoring Hazards.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Disintegrate
# --Rank|d@spell_rank_disintegrate
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_disintegrate}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 8 ?? Effect:|**//Threshold - [^spell.ss]//**^^Spend 5 Momentum to have one target in your Current or an Adjacent Zone takes X + 2 Hits, where X is equal to Hits in the result set.
# --?? $spell.ss >= 8 ?? Effect:|**//Threshold - [^spell.ss]//**^^Spend 5 Momentum to have one target in your Current or an Adjacent Zone loses all Grit.  If the target can gain the Dying status, they do.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Dispel
# --Rank|d@spell_rank_dispel
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_dispel}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Reduce the rating of one Aura you can sense in your Current Zone by 2.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Reduce the rating of one Aura you can sense in your Current Zone by X, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Displacement Wave
# --Rank|d@spell_rank_displacement_wave
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_displacement_wave}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Move up to 3 targets in your Current Zone into an Adjacent Zone.  They each becomee Prone.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Push up to X targets in your Current Zone into an Adjacent Zone, where X is equal to Hits in the result set.  They each becomee Prone.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Doom Blade
# --Rank|d@spell_rank_doom_blade
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_doom_blade}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Curent Zone loses 4 Grit.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Curent Zone loses X Grit, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Ethereal Haze
# --Rank|d@spell_rank_ethereal_haze
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_ethereal_haze}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Prevent any Hits to Defenses or Grit until the end of your next turn.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Prevent any Hits to Defenses or Grit until the end of your next turn.  Increase the Timer by +1.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Exsanguinate
# --Rank|d@spell_rank_exsanguinate
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_exsanguinate}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone loses X Grit and you regain 2 Grit, where X is equal to Hits in the result set.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone loses X + 2 Grit and you regain X Grit, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Feather Fall
# --Rank|d@spell_rank_feather_fall
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_feather_fall}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 ?? Effect:|**//Threshold - [^spell.ss]//**^^When a target you can see is falling from a height that risks harming them, spend 1 Momentum and score 1+ Hits to allow them to float down gracefully.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Fiery Fingers
# --Rank|d@spell_rank_fiery_fingers
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_fiery_fingers}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Currrent or an Adjacent Zone take X Hits, where X is equal to Hits in the result set.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in your Currrent or an Adjacent Zone take X Hits, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Gambit of the Cosm
# --Rank|d@spell_rank_gambit_of_the_cosm
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_gambit_of_the_cosm}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone takes 3 Hits.
# --?? $spell.ss >= 3 AND $spell.ss < 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^All targets in your Current Zone takes 3 Hits.
# --?? $spell.ss >= 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^Reduce the Entropy by -3 and immediately take another Action.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Fireball
# --Rank|d@spell_rank_fireball
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_fireball}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 4 AND $spell.ss < 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 4 targets in your Currrent or an Adjacent Zone take X Hits, where X is equal to Hits in the result set.
# --?? $spell.ss >= 6 AND $spell.ss < 8 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 4 targets in your Currrent or an Adjacent Zone take X + 2 Hits, where X is equal to Hits in the result set.
# --?? $spell.ss >= 8 ?? Effect:|**//Threshold - [^spell.ss]//**^^All targets in your Currrent or an Adjacent Zone take X + 2 Hits, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 4
# }}
# !power {{
# --Name|@{character_name} - Firebreathing
# --Rank|d@spell_rank_firebreathing
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_firebreathing}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Currrent Zone take 3 Hits and gain Vulnerable 1.
# --?? $spell.ss >= 4 AND $spell.ss < 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in your Currrent Zone take 3 Hits and gain Vulnerable 1.
# --?? $spell.ss >= 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in your Currrent Zone take X Hits and gain Vulnerable 1, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Flame Slash
# --Rank|d@spell_rank_flame_slash
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_flame_slash}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone takes X Hits, where X is equal to Hits in the result set.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone takes X + 2 Hits, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Fly
# --Rank|d@spell_rank_fly
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_fly}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains the Fly keyword.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current Zone gains the Fly keyword.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Fog of War
# --Rank|d@spell_rank_fog_of_war
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_fog_of_war}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Target your Current or an Adjacent Zone.  targeted Zone gains Hazard 1 and all targets in the targeted Zone gain Confused 1 that the start of each of their turns while you Maintain Focus on this spell.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Target your Current and all Adjacent Zones.  targeted Zone gains Hazard 1 and all targets in the targeted Zones gain Confused 1 that the start of each of their turns while you Maintain Focus on this spell.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Forked Bolt
# --Rank|d@spell_rank_forked_bolt
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_forked_bolt}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Divide 3 Hits between up to 2 target in your Current or an Adjacent Zone.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Divide X Hits between up to 2 target in your Current or an Adjacent Zone.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Frost Bite
# --Rank|d@spell_rank_frost_bite
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_frost_bite}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 ?? Effect:|**//Threshold - [^spell.ss]//**^^One taget in your Current Zone takes X Hits and gain Slowed 2, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Frost Breath
# --Rank|d@spell_rank_frost_breath
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_frost_breath}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 1 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Currrent Zone take 2 Hits and gain Slowed 2.
# --?? $spell.ss >= 1 AND $spell.ss < 1 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in your Currrent Zone take 2 Hits and gain Slowed 2.
# --?? $spell.ss >= 1 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in your Currrent Zone take 2 Hits and gain Slowed X, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Galvanic Blast
# --Rank|d@spell_rank_galvanic_blast
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_galvanic_blast}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone take 2 Hits.
# --?? $spell.ss >= 3 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone take 3 Hits.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone take X Hits, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Galvanic Bombardment
# --Rank|d@spell_rank_galvanic_bombardment
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_galvanic_bombardment}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone takes 3 Hits.<br><h4 style='margin: 3px;'>Trigger &emdash</h4> If you cast this Spell last turn, the target takes 3 + X Hits instead, where X is the number of consecutive turns you have cast this spell.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Gate
# --Rank|d@spell_rank_gate
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_gate}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 4 AND $spell.ss < 7 ?? Effect:|**//Threshold - [^spell.ss]//**^^Open an arcane gateway in your Current Zone to a location in a different world of the Cosm.  You cannot **choose the destination.
# --?? $spell.ss >= 7 ?? Effect:|**//Threshold - [^spell.ss]//**^^Open an arcane gateway in your Current Zone to a destination in a different world of the Cosm.  You **choose the destination.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 4
# }}
# !power {{
# --Name|@{character_name} - Geistblast
# --Rank|d@spell_rank_geistblast
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_geistblast}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone takes 2 Hits and gains Afraidd 2.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone takes 2 Hits and gains Afraidd X, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Glacial Ray
# --Rank|d@spell_rank_glacial_ray
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_glacial_ray}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gains Restrained 2 and Slowed 4.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gains Restrained 2, Slowed 4, and Vulnerable 2.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Grow / Shrink Target
# --Rank|d@spell_rank_grow_/_shrink_target
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_grow_/_shrink_target}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^Touch one target in your Current Zone and **choose one (1)**:^^^^**The target grows in size, gaining +5 Grit, +5 Vigor, and adding +1d4 Bonus Hits to any result set using Endure, Exert, Strike, or Grapple Ongoing.^^^^The target shrinks in size, gaining +5 Reflexes and adding +1d4 Bonus Hits to any result set using Stealth or Tumple.**
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Hungry Flames
# --Rank|d@spell_rank_hungry_flames
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_hungry_flames}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone takes 2 Hits.  If the target dies, one other target in your Current Zone takes 2 Hits.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone takes 3 Hits.  If the target dies, repeat this effect until the target does not die or there are no other target in your Current Zone.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Ice Cage
# --Rank|d@spell_rank_ice_cage
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_ice_cage}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Icy Blast
# --Rank|d@spell_rank_icy_blast
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_icy_blast}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone takes X Hits and gains Slowed 1, where X is equal to Hits in the result set.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone loses X + 2 Hits and gains Slowed 1, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Incinerate
# --Rank|d@spell_rank_incinerate
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_incinerate}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to X dead targets and Gear in your Current Zone are reduced to ashes, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Incite
# --Rank|d@spell_rank_incite
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_incite}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone becomees Provoked Ongoing.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone becomees Provoked by another target in the same Zone Ongoing.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Invisibility
# --Rank|d@spell_rank_invisibility
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_invisibility}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone becomees Invisible Ongoing.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current Zone becomees Invisible Ongoing.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Lash of Malice
# --Rank|d@spell_rank_lash_of_malice
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_lash_of_malice}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone takes X Hits, where X is equal to Hits in the result set., then **choose one (1)**:^^^^**The target gains Restrained 3.^^^^You pull the target into your Current Zone.^^^^The target gains Afraid 2.**
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone, where X is equal to Hits in the result set., then **choose two (2)**:^^^^**The target gains Restrained 3.^^^^You pull the target into your Current Zone.^^^^The target gains Afraid 2.**
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Lash of Thorns
# --Rank|d@spell_rank_lash_of_thorns
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_lash_of_thorns}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone or an Adjacent takes 2 Hits, then **choose one (1)**:^^^^**The target gains Restrained 3.^^^^You pull the target into your Current Zone.^^^^The target gains Wounded 1.**
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone or an Adjacent takes 2 Hits, then **choose two (2)**:^^^^**The target gains Restrained 3.^^^^You pull the target into your Current Zone.^^^^The target gains Wounded 1.**
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Lightning Axe
# --Rank|d@spell_rank_lightning_axe
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_lightning_axe}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Increase the Entropy by +3 and one target in your Current or an Adjacent Zone takes X +2 Hits, where X is equal to Hits in the result set.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Increase the Entropy by +2 and one target in your Current or an Adjacent Zone takes X +3 Hits, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Lightning Bolt
# --Rank|d@spell_rank_lightning_bolt
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_lightning_bolt}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in up to 4 Linear Zones take X Hits, where X is equal to Hits in the result set.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in up to 4 Linear Zones take X Hits and gain Stunned 2, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Lightning Storm
# --Rank|d@spell_rank_lightning_storm
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_lightning_storm}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Conjure a Lightning Storm in your Current or an Adjacent Zone Ongoing.  On each of your turns your can use a Shift to move the Lightning Storm one Adjacent Zone or have one target in the Lightning Storm's Current Zone take +2d4 Bonus Hits.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Conjure a Lightning Storm in your Current or an Adjacent Zone Ongoing.  On each of your turns your can use a Shift to move the Lightning Storm one Adjacent Zone or have up to 2 targets in the Lightning Storm's Current Zone take +2d4 Bonus Hits.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Mage Hand
# --Rank|d@spell_rank_mage_hand
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_mage_hand}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 ?? Effect:|**//Threshold - [^spell.ss]//**^^Conjure a telekenetic Hand in your Current or an Adjacent Zone to lift and carry up to X Gear, where X is equal to Hits in the result set.  The Hand can use one Shift on each of your turns and you may use a Shift on each of your turns to have the Hand take 1 Action.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Mage armor
# --Rank|d@spell_rank_mage_armor
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_mage_armor}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 ?? Effect:|**//Threshold - [^spell.ss]//**^^You gain an Armor Defense X until you cast this spell again, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Magic Missile
# --Rank|d@spell_rank_magic_missile
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_magic_missile}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Create 3 magical darts that each deal 2 Hits.  You may target up to 3 targets in your Current or an Adjacent Zone.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Create X magical darts that each deal 2 Hits, where X is equal to Hits in the result set.  You may target up to X targets in your Current or an Adjacent Zone.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Malevolent Whispers
# --Rank|d@spell_rank_malevolent_whispers
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_malevolent_whispers}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gains Afraidd 1 and Vulnerable 1 on each of their turns Ongoing.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone gains Afraidd 1 and Vulnerable 1 on each of their turns Ongoing.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Message
# --Rank|d@spell_rank_message
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_message}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^You may contact one target you know personally who is on your current plane, sending a message of 15 words or less.  The target may reply.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^You may contact one target you know personally who is on your current plane, sending X message of 15 words or less, X . . .  The target may reply to each message.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Might of Oaks
# --Rank|d@spell_rank_might_of_oaks
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_might_of_oaks}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Aura 2 to add +1d4 Bonus Hits to any Action using Exert, Grapple, Strike, or Martial Arts.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Aura X to add +1d4 Bonus Hits to any Action using Exert, Grapple, Strike, or Martial Arts, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Mindstatic
# --Rank|d@spell_rank_mindstatic
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_mindstatic}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gains Confused 2.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 target in your Current or an Adjacent Zone gain Confused 2.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Misty Step
# --Rank|d@spell_rank_misty_step
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_misty_step}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Move to any Adjacent Zone up ignoring Hazards.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Move to any Zone up to 2 adjacencies away ignoring Hazards.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Necrotic Fumes
# --Rank|d@spell_rank_necrotic_fumes
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_necrotic_fumes}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 target in your Current or an Adjacent Zone gain lose 1 Grit and gain Fatigued 1.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^All targets in your Current or an Adjacent Zone gain lose 1 Grit and gain Fatigued 1.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Plummet
# --Rank|d@spell_rank_plummet
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_plummet}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone loses the Flying keyword until the beginning of your next turn.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone lose the Flying keyword until the beginning of your next turn.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Psychic Spear
# --Rank|d@spell_rank_psychic_spear
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_psychic_spear}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Select one target in your Current or an Adjacent Zone and **choose one (1)**:^^^^**The target takes X Hits to their Nerve, where X is equal to Hits in the result set.^^^^The target gains Dazed 2 and Confused 2.^^^^You read the targets surface thoughts.**
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Select one target in your Current or an Adjacent Zone and **choose two (2)**:^^^^**The target takes X Hits to their Nerve, where X is equal to Hits in the result set.^^^^The target gains Dazed 2 and Confused 2.^^^^You read the targets surface thoughts.**
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Restrain Target
# --Rank|d@spell_rank_restrain_target
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_restrain_target}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gains Restrained 2 at the start of each of its turns Ongoing.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to two targets in your Current or an Adjacent Zone gain Restrained 2 at the start of each of its turns Ongoing.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Rolling Thunder
# --Rank|d@spell_rank_rolling_thunder
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_rolling_thunder}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# ...
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone becomees trapped in the Ina.  If you Maintain Focus for 4+ rounds, the target reappears in a random location across the Cosm.  Otherwise, they reappear in the Zone where they were before this effect occured.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 4
# }}
# !power {{
# --Name|@{character_name} - Sending
# --Rank|d@spell_rank_sending
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_sending}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^You may contact one target anywhere in the Cosm, sending a message of 25 words or less.  The target may reply.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Shadow Step
# --Rank|d@spell_rank_shadow_step
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_shadow_step}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Move to any Adjacent Zone ignoring Hazards.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Move to any Zone up to 2 adjacencies away ignoring Hazards.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Shard Volley
# --Rank|d@spell_rank_shard_volley
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_shard_volley}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Deal 2 Hits to up to 3 targets in an Adjacent Zone.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Deal 3 Hits to up to 4 targets in an Adjacent Zone.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Shield
# --Rank|d@spell_rank_shield
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_shield}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 ?? Effect:|**//Threshold - [^spell.ss]//**^^When you suffer Hits from an effect you can see, gain an Armor Defnse X until the beginning of your next turn, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Shift Planes
# --Rank|d@spell_rank_shift_planes
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_shift_planes}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 4 AND $spell.ss < 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to X +2 targets that you can see and allow you immediately Shift to a different world of the Cosm, where X is equal to Hits in the result set.  You cannot **choose the destination world.
# --?? $spell.ss >= 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to X +2 targets that you can see and allow you immediately Shift to a different world of the Cosm, where X is equal to Hits in the result set.  You **choose the destination world.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 4
# }}
# !power {{
# --Name|@{character_name} - Silence
# --Rank|d@spell_rank_silence
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_silence}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to X targets in your Current Zone make no noise Ongoing, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Sleep
# --Rank|d@spell_rank_sleep
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_sleep}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Choose one target in your Current Zone.  If X is greater than their current Nerve, they gain Unconscious 2, where X is equal to Hits in the result set.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Choose one target in your Current Zone.  If X is greater than their current Nerve, they gain Unconscious 5, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Make the Time
# --Rank|d@spell_rank_make_the_time
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_make_the_time}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Spend 1 Momentum and increase the current Timer by 1.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Spend 1 Momentum and increase the current Timer by 2.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Strangling Spores
# --Rank|d@spell_rank_strangling_spores
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_strangling_spores}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone take 1 Hit to Grit and gain Fatigued 1.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone take 3 Hits to Grit and gain Fatigued 1.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Stun Target
# --Rank|d@spell_rank_stun_target
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_stun_target}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Curent Zone gains Stunned 3.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Curent Zone gains Stunned 5.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Summon Spirit Animal
# --Rank|d@spell_rank_summon_spirit_animal
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_summon_spirit_animal}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 ?? Effect:|**//Threshold - [^spell.ss]//**^^You may recruit a Beast of cost 1 or less from the Beast Minions table.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}
# !power {{
# --Name|@{character_name} - Sweltering Sunlight
# --Rank|d@spell_rank_sweltering_sunlight
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_sweltering_sunlight}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in your Current or an Adjacent Zone take 3 Hits and gain Fatigued 2.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^All targets in your Current or an Adjacent Zone take 3 Hits and gain Fatigued 2.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Tainted Strikes
# --Rank|d@spell_rank_tainted_strikes
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_tainted_strikes}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains the following Aura 2:<h4 style='margin: 3px;'>Trigger &mdash </h4> When you Shoot, Strike, or use your Martial Arts and score 1+ Hits, your target gains Fatigued 1.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Teleport
# --Rank|d@spell_rank_teleport
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_teleport}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^You and up to X willing targets in your Current Zone immediately transport to destination on this world, where X is equal to Hits in the result set.  If you are unfamiliar with the destination, you will arrive at a location close to, but not precisely at, the destination.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^You and up to X +3 willing targets in your Current Zone immediately transport to destination on this world, where X is equal to Hits in the result set.  If you are unfamiliar with the destination, you will arrive at a location close to, but not precisely at, the destination.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Thunder Clap
# --Rank|d@spell_rank_thunder_clap
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_thunder_clap}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^All targets in your Current Zone gain Dazed 2.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^All targets except you in your Current Zone gain Dazed 2.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Time Stop
# --Rank|d@spell_rank_time_stop
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_time_stop}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^Choose 3 targets in your Current Zone.  Those targets gain 2 full rounds to act before the current Initative and Timer resume.
# --?? $spell.ss >= 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^Choose X targets in your Current Zone, where X is equal to Hits in the result set.  Those targets gain 2 full rounds to act before the current Initative and Timer resume.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Trumpet Blast
# --Rank|d@spell_rank_trumpet_blast
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_trumpet_blast}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone add +1d4 Bonus Hits to any action using Compsure, Endure, Exert, Focus, Grapple, Shoot, Strike, or Martial Arts on their next turn.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to x targets in your Current or an Adjacent Zone add +1d4 Bonus Hits to any action using Compsure, Endure, Exert, Focus, Grapple, Shoot, Strike, or Martial Arts on their next turn, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Twincast
# --Rank|d@spell_rank_twincast
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_twincast}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Increase the Entropy by +1 Momentum to copy the effects of the next spell you cast this turn.  You may **choose different targets for the copy.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Vine Snare
# --Rank|d@spell_rank_vine_snare
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_vine_snare}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gains Restrained 3.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gains Restrained X, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Void Snare
# --Rank|d@spell_rank_void_snare
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_void_snare}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^When a target you can see moves into your Current Zone, they blink momentarily into the Ina, ending their turn.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Void Step
# --Rank|d@spell_rank_void_step
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_void_step}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 0 ?? Effect:|**//Threshold - [^spell.ss]//**^^Increase the Entropy by +1 and Move to an Adjacent Zone ignoring Hazards.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 0
# }}
# !power {{
# --Name|@{character_name} - Volcanic Fallout
# --Rank|d@spell_rank_volcanic_fallout
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_volcanic_fallout}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Target your Current or an Adjacent Zone.  All targets in the targeted Zone take X Hits and the targeted Zone gains X Hazards, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Volcanic Hammer
# --Rank|d@spell_rank_volcanic_hammer
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_volcanic_hammer}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone takes 3 Hits, becomees Prone, and gains Vulnerable 1.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Waterknot
# --Rank|d@spell_rank_waterknot
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_waterknot}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gain Restrained 4.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone gain Restrained 4.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}
# !power {{
# --Name|@{character_name} - Wildfire
# --Rank|d@spell_rank_wildfire
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_wildfire}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Increase the Entropy by +2 and target your Current or an Adjacent Zone.  The targeted Zone and all adjacent Zones gain Hazard 2, and all targets currently in those Zones take 3 Hits.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Increase the Entropy by +3, icrease the Momentum by +2, and target your Current or an Adjacent Zone.  The targeted Zone and all adjacent Zones gain Hazard 2, and all targets currently in those Zones take 3 Hits.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}
# !power {{
# --Name|@{character_name} - Wish
# --Rank|d@spell_rank_wish
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_wish}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 500 ?? Effect:|**//Threshold - [^spell.ss]//**^^Kleist commits Genocide
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 500
# }}
# !power {{
# --Name|@{character_name} - Withercrown
# --Rank|d@spell_rank_withercrown
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_withercrown}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gains Fatigued 1 Ongoing.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}

# %%
df_spells['pcard'] = spell_pcards

# %%
div_str = '''<div class="grid-container-spells">\n'''
for i, s in df_spells.iterrows():
    div_str += '''<div class="grid-item-spells">\n<div class="grid-spells-name">''' + s['name'] + '''</div>\n<div class="grid-spells-ranks">\n<label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="''' + str(s['max_ranks']) + '''" /></label>\n</div><div class="grid-spells-kwords">\n'''
    if len(s['keywords']) > 0:
        for k in s['keywords']:
            div_str += '''<span style="background-color: #096491;border-radius: 4px">''' + k + '''</span>\n'''
    div_str += '''</div>\n<div class="talent-rollbox grid-spells-btn">\n<button class="txt-btn" type="roll" value="''' + s['pcard'] + '''">Roll</button></div>\n<div class="grid-spells-effects">\n<details>\n<summary>&#10010;</summary>\nMax Ranks: ''' + str(s['max_ranks'])
    if s['effect'] is not None:
        div_str += ''''\n<p>\n<strong>Effect &mdash; </strong><br>''' + s['effect'] + '''</p>'''
    if len(s['threshold']) > 0:
        for t in s['threshold']:
            div_str += '''\n<p>\n<strong>Threshold &mdash; ''' + str(t['hits']) + '''</strong>\n<br>''' + t['effect'] + '''\n</p>'''
    div_str += '''\n</details></div>\n</div>'''
div_str += '''</div>'''

# %%
print(div_str)
# Out:
# <div class="grid-container-spells">
# <div class="grid-item-spells">
# <div class="grid-spells-name">Arc Lightning</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Tempest</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Arc Lightning
# --Rank|d@spell_rank_arc_lightning
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_arc_lightning}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Choose 3 targets you can see in your Current Zone. Deal 1 Hit to each target.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Choose 3 targets you can see in your Current Zone.  Deal 3 Hits the first target, 2 Hits to the second target, & 1 Hit to the third.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>Choose 3 targets you can see in your Current Zone. Deal 1 Hit to each target.
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>Choose 3 targets you can see in your Current Zone.  Deal 3 Hits the first target, 2 Hits to the second target, & 1 Hit to the third.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Arrest</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Ongoing 2</span>
# <span style="background-color: #096491;border-radius: 4px">Lux</span>
# <span style="background-color: #096491;border-radius: 4px">Aether</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Arrest
# --Rank|d@spell_rank_arrest
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_arrest}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target you can see in your Current or an Adjacent Zone gains Restrained X, where X is equal to Hits.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target you can see in your Current or an Adjacent Zone gains Restrained <em>x</em>, where <em>x</em> is equal to Hits +2.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 1</strong>
# <br>One target you can see in your Current or an Adjacent Zone gains Restrained X, where X is equal to Hits.
# </p>
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>One target you can see in your Current or an Adjacent Zone gains Restrained <em>x</em>, where <em>x</em> is equal to Hits +2.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Asphyxiate</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="2" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Plaga</span>
# <span style="background-color: #096491;border-radius: 4px">Mori</span>
# <span style="background-color: #096491;border-radius: 4px">Squall</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Asphyxiate
# --Rank|d@spell_rank_asphyxiate
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_asphyxiate}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^You pull the air from the lungs of one target you can see in your Current Zone.  They gain Vulnerable 2 and Dazed X, where X is equal to Hits in the result set.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^You pull the air from the lungs of one target you can see in your Current Zone.  They gain Stunned and Vulnerable X, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 2
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>You pull the air from the lungs of one target you can see in your Current Zone.  They gain Vulnerable 2 and Dazed X, where X is equal to Hits in the result set.
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>You pull the air from the lungs of one target you can see in your Current Zone.  They gain Stunned and Vulnerable X, where X is equal to Hits in the result set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Augment Senses</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="2" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Vivus</span>
# <span style="background-color: #096491;border-radius: 4px">Mentis</span>
# <span style="background-color: #096491;border-radius: 4px">Forma</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Augment Senses
# --Rank|d@spell_rank_augment_senses
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_augment_senses}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^Score 2+ Hits touch one target you can seei n your Current Zone, allowing them to add +1d4 Bonus Hits to their next result set for any of the follosing Skills:<br><em>Focus, Insight, Investigate, Operate, Perceive</em>
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 2
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>Score 2+ Hits touch one target you can seei n your Current Zone, allowing them to add +1d4 Bonus Hits to their next result set for any of the follosing Skills:<br><em>Focus, Insight, Investigate, Operate, Perceive</em>
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Biting Rain</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="2" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Plaga</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Biting Rain
# --Rank|d@spell_rank_biting_rain
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_biting_rain}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^All targets in your Current or an Adjacent Zone suffer 2 Hit to their Primary Defense.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 2'
# <p>
# <strong>Effect &mdash; </strong><br>All targets in your Current or an Adjacent Zone suffer 1 Hit to their Primary Defenses.</p>
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>All targets in your Current or an Adjacent Zone suffer 2 Hit to their Primary Defense.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Blazing Volley</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Inferno</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Blazing Volley
# --Rank|d@spell_rank_blazing_volley
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_blazing_volley}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Deal 2 Hits to up to 3 targets in an Adjacent Zone.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Deal 3 Hits to up to 4 targets in an Adjacent Zone.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>Deal 2 Hits to up to 3 targets in an Adjacent Zone.
# </p>
# <p>
# <strong>Threshold &mdash; 5</strong>
# <br>Deal 3 Hits to up to 4 targets in an Adjacent Zone.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Blinding Flare</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Inferno</span>
# <span style="background-color: #096491;border-radius: 4px">Lux</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Blinding Flare
# --Rank|d@spell_rank_blinding_flare
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_blinding_flare}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gain Blind 1.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^make one target in your Current or an Adjacent Zone gain Blind 3.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>One target in your Current or an Adjacent Zone gain Blind 1.
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>make one target in your Current or an Adjacent Zone gain Blind 3.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Call to the Netherworld</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Mori</span>
# <span style="background-color: #096491;border-radius: 4px">Vivus</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Call to the Netherworld
# --Rank|d@spell_rank_call_to_the_netherworld
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_call_to_the_netherworld}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 ?? Effect:|**//Threshold - [^spell.ss]//**^^Reach out to the spirits of the dead when you are in their presence to ask X questions, where X is the number of Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 1</strong>
# <br>Reach out to the spirits of the dead when you are in their presence to ask X questions, where X is the number of Hits in the result set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Chain Lightning</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="5" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Tempest</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Chain Lightning
# --Rank|d@spell_rank_chain_lightning
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_chain_lightning}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Deal X to one Target in your Current or an Adjacent Zone, where X is equal to Hits in the result set.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^<em><strong>Trigger</strong></em> &mdash cast this spell again choosing a different target.  This copy uses the last target's Zone as its Current Zone.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 5
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>Deal X to one Target in your Current or an Adjacent Zone, where X is equal to Hits in the result set.
# </p>
# <p>
# <strong>Threshold &mdash; 5</strong>
# <br><em><strong>Trigger</strong></em> &mdash cast this spell again choosing a different target.  This copy uses the last target's Zone as its Current Zone.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Charm Target</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="2" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Mentis</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Charm Target
# --Rank|d@spell_rank_charm_target
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_charm_target}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Charmed X, where X is equal to Hits in the results set.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current Zone gain Charmed X, where X is equal to Hits in the results set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 2
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>One target in your Current Zone gains Charmed X, where X is equal to Hits in the results set.
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>Up to 2 targets in your Current Zone gain Charmed X, where X is equal to Hits in the results set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Chill of the Grave</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="2" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Mori</span>
# <span style="background-color: #096491;border-radius: 4px">Rime</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Chill of the Grave
# --Rank|d@spell_rank_chill_of_the_grave
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_chill_of_the_grave}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone becomees Afraidd of you and gains Fatigued X, where x is equal to Hits in the result set.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to two targets in your Current Zone becomee Afraidd of you and gains Fatigued X, where x is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 2
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>One target in your Current Zone becomees Afraidd of you and gains Fatigued X, where x is equal to Hits in the result set.
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>Up to two targets in your Current Zone becomee Afraidd of you and gains Fatigued X, where x is equal to Hits in the result set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Chill to the Bone</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Mori</span>
# <span style="background-color: #096491;border-radius: 4px">Rime</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Chill to the Bone
# --Rank|d@spell_rank_chill_to_the_bone
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_chill_to_the_bone}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Slowed 2 and Fatigued X, where x is equal to Hits in the result set.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to two targets in your Current Zone gains Slowed 2 and Fatigued X, where x is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>One target in your Current Zone gains Slowed 2 and Fatigued X, where x is equal to Hits in the result set.
# </p>
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>Up to two targets in your Current Zone gains Slowed 2 and Fatigued X, where x is equal to Hits in the result set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Choking Fumes</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Mori</span>
# <span style="background-color: #096491;border-radius: 4px">Plaga</span>
# <span style="background-color: #096491;border-radius: 4px">Squall</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Choking Fumes
# --Rank|d@spell_rank_choking_fumes
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_choking_fumes}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to X targets in your Current or an Adjacent Zone gain Fatigued 1, where X is equal to Hits in the result set.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to X targets in your Current or an Adjacent Zone gain Fatigued 1, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>Up to X targets in your Current or an Adjacent Zone gain Fatigued 1, where X is equal to Hits in the result set.
# </p>
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>Up to X targets in your Current or an Adjacent Zone gain Fatigued 1, where X is equal to Hits in the result set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Circle of Affliction</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Aether</span>
# <span style="background-color: #096491;border-radius: 4px">Locus</span>
# <span style="background-color: #096491;border-radius: 4px">Lux</span>
# <span style="background-color: #096491;border-radius: 4px">Ongoing 2</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Circle of Affliction
# --Rank|d@spell_rank_circle_of_affliction
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_circle_of_affliction}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gain Wounded 1 Ongoing.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Wounded 3 Ongoing.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>One target in your Current Zone gain Wounded 1 Ongoing.
# </p>
# <p>
# <strong>Threshold &mdash; 5</strong>
# <br>One target in your Current Zone gains Wounded 3 Ongoing.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Circle of Confinement</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Aether</span>
# <span style="background-color: #096491;border-radius: 4px">Locus</span>
# <span style="background-color: #096491;border-radius: 4px">Lux</span>
# <span style="background-color: #096491;border-radius: 4px">Ongoing 3</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Circle of Confinement
# --Rank|d@spell_rank_circle_of_confinement
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_circle_of_confinement}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Restrained 1 at the start of each of its turns.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Restrained 3 at the start of each of its turns.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>One target in your Current Zone gains Restrained 1 at the start of each of its turns.
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>One target in your Current Zone gains Restrained 3 at the start of each of its turns.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Comet Storm</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Aether</span>
# <span style="background-color: #096491;border-radius: 4px">Locus</span>
# <span style="background-color: #096491;border-radius: 4px">Inferno</span>
# <span style="background-color: #096491;border-radius: 4px">Tellus</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Comet Storm
# --Rank|d@spell_rank_comet_storm
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_comet_storm}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^All targets in your Current or an Adjacent Zone suffer 4 Hits.
# --?? $spell.ss >= 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^All targets in up to 3 Zones Current and Adjacent to you suffer 6 Hits.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>All targets in your Current or an Adjacent Zone suffer 4 Hits.
# </p>
# <p>
# <strong>Threshold &mdash; 6</strong>
# <br>All targets in up to 3 Zones Current and Adjacent to you suffer 6 Hits.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Contact Other Plane</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Contact Other Plane
# --Rank|d@spell_rank_contact_other_plane
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_contact_other_plane}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^You establish contact with someone or something.  You can ask X questions, where X is number of Hits in the reuslt set.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Same as above, but decrease the Entropy by -2.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4'
# <p>
# <strong>Effect &mdash; </strong><br>Increase the Entropy by +5 to reach out to the Cosm.</p>
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>You establish contact with someone or something.  You can ask X questions, where X is number of Hits in the reuslt set.
# </p>
# <p>
# <strong>Threshold &mdash; 5</strong>
# <br>Same as above, but decrease the Entropy by -2.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Crippling Blight</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Mori</span>
# <span style="background-color: #096491;border-radius: 4px">Plaga</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Crippling Blight
# --Rank|d@spell_rank_crippling_blight
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_crippling_blight}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Touch one target you can see in your Current Zone.  They gain Vulnerable 1 and gain Fatigue X, where X is equal to Hits in the result set.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Touch up to 2 targets you can see in your Current Zone.  They gain Vulnerable 1 and gain Fatigue X, where X is euqla to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 1</strong>
# <br>Touch one target you can see in your Current Zone.  They gain Vulnerable 1 and gain Fatigue X, where X is equal to Hits in the result set.
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>Touch up to 2 targets you can see in your Current Zone.  They gain Vulnerable 1 and gain Fatigue X, where X is euqla to Hits in the result set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Cyclone</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="None" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Ongoing 2</span>
# <span style="background-color: #096491;border-radius: 4px">Aether</span>
# <span style="background-color: #096491;border-radius: 4px">Squall</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Cyclone
# --Rank|d@spell_rank_cyclone
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_cyclone}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^Target your Current or an Adjacent Zone.  Up to 3 targets in are pushed to a different Zone adjacent to targeted Zone, and the targeted Zone gains Hazard 3.
# --?? $spell.ss >= 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^Target your Current or an Adjacent Zone.  Up to X targets in are pushed to a different Zone adjacent to targeted Zone, and the targeted Zone gains Hazard X, where X is equal to Hits in the resul set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: None
# <p>
# <strong>Threshold &mdash; 1</strong>
# <br>Target your Current or an Adjacent Zone.  Up to 3 targets in are pushed to a different Zone adjacent to targeted Zone, and the targeted Zone gains Hazard 3.
# </p>
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>Target your Current or an Adjacent Zone.  Up to X targets in are pushed to a different Zone adjacent to targeted Zone, and the targeted Zone gains Hazard X, where X is equal to Hits in the resul set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Damping Pulse</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="None" /></label>
# </div><div class="grid-spells-kwords">
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Damping Pulse
# --Rank|d@spell_rank_damping_pulse
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_damping_pulse}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone gain Fatigued 2.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in your Current or an Adjacent Zone gain Fatigued 2.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: None
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>Up to 2 targets in your Current or an Adjacent Zone gain Fatigued 2.
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>Up to 3 targets in your Current or an Adjacent Zone gain Fatigued 2.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Dark Blast</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="2" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Mori</span>
# <span style="background-color: #096491;border-radius: 4px">Nox</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Dark Blast
# --Rank|d@spell_rank_dark_blast
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_dark_blast}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone loses X Grit, where X is equal to Hits in the result set.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone loses X + 2 Grit, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 2
# <p>
# <strong>Threshold &mdash; 1</strong>
# <br>One target in your Current or an Adjacent Zone loses X Grit, where X is equal to Hits in the result set.
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>One target in your Current or an Adjacent Zone loses X + 2 Grit, where X is equal to Hits in the result set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Dazzling Lights</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Aether</span>
# <span style="background-color: #096491;border-radius: 4px">Lux</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Dazzling Lights
# --Rank|d@spell_rank_dazzling_lights
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_dazzling_lights}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in your Current Zone gain Dazed 1.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 3 targets in your Current Zone gain Confused 2.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 1</strong>
# <br>Up to 3 targets in your Current Zone gain Dazed 1.
# </p>
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>Up to 3 targets in your Current Zone gain Confused 2.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Death Cloud</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Mori</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Death Cloud
# --Rank|d@spell_rank_death_cloud
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_death_cloud}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^All creatures in your Current or an Adjacent Zone gain Wounded 1 and lose 3 Grit.
# --?? $spell.ss >= 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^All creatures in your Current or an Adjacent Zone becomee Wounded 3 and lose X Grit, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>All creatures in your Current or an Adjacent Zone gain Wounded 1 and lose 3 Grit.
# </p>
# <p>
# <strong>Threshold &mdash; 6</strong>
# <br>All creatures in your Current or an Adjacent Zone becomee Wounded 3 and lose X Grit, where X is equal to Hits in the result set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Deathmark</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="None" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Ongoing 3</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Deathmark
# --Rank|d@spell_rank_deathmark
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_deathmark}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gain Vulnerable 2.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone gains Vulnerable 2 at the beginning of each of your turns.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: None
# <p>
# <strong>Threshold &mdash; 1</strong>
# <br>One target in your Current Zone gain Vulnerable 2.
# </p>
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>One target in your Current Zone gains Vulnerable 2 at the beginning of each of your turns.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Detect Magic</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Aura</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Detect Magic
# --Rank|d@spell_rank_detect_magic
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_detect_magic}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Gain Aura X to sense any presence any magical Power in your Current Zone, where X is equal to Hits in thes result set.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Gain Aura X to sense any presence  any magical Power in your Current Zone, where X is equal to Hits in thes result set.  Add +1d4 Bonus Hits to any Action you use to identify the nature or source of the Power.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 1</strong>
# <br>Gain Aura X to sense any presence any magical Power in your Current Zone, where X is equal to Hits in thes result set.
# </p>
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>Gain Aura X to sense any presence  any magical Power in your Current Zone, where X is equal to Hits in thes result set.  Add +1d4 Bonus Hits to any Action you use to identify the nature or source of the Power.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Detention Sphere</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Ongoing 4</span>
# <span style="background-color: #096491;border-radius: 4px">Aether</span>
# <span style="background-color: #096491;border-radius: 4px">Lux</span>
# <span style="background-color: #096491;border-radius: 4px">Ordi</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Detention Sphere
# --Rank|d@spell_rank_detention_sphere
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_detention_sphere}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current Zone cannot be the target of any Actions and gain Stunned 2 and Unconscious 1 Ongoing.  You may use a Shift on each of your turns to Move the Detention Sphere.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Same as above, except the target gain Stunned X +1 and Unconscious X Ongoing, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>One target in your Current Zone cannot be the target of any Actions and gain Stunned 2 and Unconscious 1 Ongoing.  You may use a Shift on each of your turns to Move the Detention Sphere.
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>Same as above, except the target gain Stunned X +1 and Unconscious X Ongoing, where X is equal to Hits in the result set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Dimension Door</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Locus</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Dimension Door
# --Rank|d@spell_rank_dimension_door
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_dimension_door}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 1 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Allow one target in your Current Zone to move to any Zone up to 2 adjacencies away ignoring Hazards.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Allow up to 2 targets in your Current Zone to move to any Zone up to 2 adjacencies away ignoring Hazards.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 1
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 1</strong>
# <br>Allow one target in your Current Zone to move to any Zone up to 2 adjacencies away ignoring Hazards.
# </p>
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>Allow up to 2 targets in your Current Zone to move to any Zone up to 2 adjacencies away ignoring Hazards.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Disintegrate</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Inferno</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Disintegrate
# --Rank|d@spell_rank_disintegrate
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_disintegrate}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 8 ?? Effect:|**//Threshold - [^spell.ss]//**^^Spend 5 Momentum to have one target in your Current or an Adjacent Zone takes X + 2 Hits, where X is equal to Hits in the result set.
# --?? $spell.ss >= 8 ?? Effect:|**//Threshold - [^spell.ss]//**^^Spend 5 Momentum to have one target in your Current or an Adjacent Zone loses all Grit.  If the target can gain the Dying status, they do.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>Spend 5 Momentum to have one target in your Current or an Adjacent Zone takes X + 2 Hits, where X is equal to Hits in the result set.
# </p>
# <p>
# <strong>Threshold &mdash; 8</strong>
# <br>Spend 5 Momentum to have one target in your Current or an Adjacent Zone loses all Grit.  If the target can gain the Dying status, they do.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Dispel</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Nihil</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Dispel
# --Rank|d@spell_rank_dispel
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_dispel}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Reduce the rating of one Aura you can sense in your Current Zone by 2.
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Reduce the rating of one Aura you can sense in your Current Zone by X, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>Reduce the rating of one Aura you can sense in your Current Zone by 2.
# </p>
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>Reduce the rating of one Aura you can sense in your Current Zone by X, where X is equal to Hits in the result set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Displacement Wave</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Torrent</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Displacement Wave
# --Rank|d@spell_rank_displacement_wave
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_displacement_wave}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Move up to 3 targets in your Current Zone into an Adjacent Zone.  They each becomee Prone.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Push up to X targets in your Current Zone into an Adjacent Zone, where X is equal to Hits in the result set.  They each becomee Prone.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>Move up to 3 targets in your Current Zone into an Adjacent Zone.  They each becomee Prone.
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>Push up to X targets in your Current Zone into an Adjacent Zone, where X is equal to Hits in the result set.  They each becomee Prone.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Doom Blade</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Mori</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Doom Blade
# --Rank|d@spell_rank_doom_blade
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_doom_blade}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Curent Zone loses 4 Grit.
# ...
# --Rank|d@spell_rank_time_stop
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_time_stop}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^Choose 3 targets in your Current Zone.  Those targets gain 2 full rounds to act before the current Initative and Timer resume.
# --?? $spell.ss >= 6 ?? Effect:|**//Threshold - [^spell.ss]//**^^Choose X targets in your Current Zone, where X is equal to Hits in the result set.  Those targets gain 2 full rounds to act before the current Initative and Timer resume.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>Choose 3 targets in your Current Zone.  Those targets gain 2 full rounds to act before the current Initative and Timer resume.
# </p>
# <p>
# <strong>Threshold &mdash; 6</strong>
# <br>Choose X targets in your Current Zone, where X is equal to Hits in the result set.  Those targets gain 2 full rounds to act before the current Initative and Timer resume.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Trumpet Blast</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Bellor</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Trumpet Blast
# --Rank|d@spell_rank_trumpet_blast
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_trumpet_blast}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone add +1d4 Bonus Hits to any action using Compsure, Endure, Exert, Focus, Grapple, Shoot, Strike, or Martial Arts on their next turn.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to x targets in your Current or an Adjacent Zone add +1d4 Bonus Hits to any action using Compsure, Endure, Exert, Focus, Grapple, Shoot, Strike, or Martial Arts on their next turn, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>Up to 2 targets in your Current or an Adjacent Zone add +1d4 Bonus Hits to any action using Compsure, Endure, Exert, Focus, Grapple, Shoot, Strike, or Martial Arts on their next turn.
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>Up to x targets in your Current or an Adjacent Zone add +1d4 Bonus Hits to any action using Compsure, Endure, Exert, Focus, Grapple, Shoot, Strike, or Martial Arts on their next turn, where X is equal to Hits in the result set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Twincast</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Twincast
# --Rank|d@spell_rank_twincast
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_twincast}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Increase the Entropy by +1 Momentum to copy the effects of the next spell you cast this turn.  You may **choose different targets for the copy.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>Increase the Entropy by +1 Momentum to copy the effects of the next spell you cast this turn.  You may choose different targets for the copy.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Vine Snare</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Phylla</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Vine Snare
# --Rank|d@spell_rank_vine_snare
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_vine_snare}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gains Restrained 3.
# --?? $spell.ss >= 4 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gains Restrained X, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>One target in your Current or an Adjacent Zone gains Restrained 3.
# </p>
# <p>
# <strong>Threshold &mdash; 4</strong>
# <br>One target in your Current or an Adjacent Zone gains Restrained X, where X is equal to Hits in the result set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Void Snare</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Nihil</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Void Snare
# --Rank|d@spell_rank_void_snare
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_void_snare}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^When a target you can see moves into your Current Zone, they blink momentarily into the Ina, ending their turn.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>When a target you can see moves into your Current Zone, they blink momentarily into the Ina, ending their turn.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Void Step</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="None" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Nihil</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Void Step
# --Rank|d@spell_rank_void_step
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_void_step}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 0 ?? Effect:|**//Threshold - [^spell.ss]//**^^Increase the Entropy by +1 and Move to an Adjacent Zone ignoring Hazards.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 0
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: None
# <p>
# <strong>Threshold &mdash; 0</strong>
# <br>Increase the Entropy by +1 and Move to an Adjacent Zone ignoring Hazards.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Volcanic Fallout</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Tellus</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Volcanic Fallout
# --Rank|d@spell_rank_volcanic_fallout
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_volcanic_fallout}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 ?? Effect:|**//Threshold - [^spell.ss]//**^^Target your Current or an Adjacent Zone.  All targets in the targeted Zone take X Hits and the targeted Zone gains X Hazards, where X is equal to Hits in the result set.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>Target your Current or an Adjacent Zone.  All targets in the targeted Zone take X Hits and the targeted Zone gains X Hazards, where X is equal to Hits in the result set.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Volcanic Hammer</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Tellus</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Volcanic Hammer
# --Rank|d@spell_rank_volcanic_hammer
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_volcanic_hammer}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone takes 3 Hits, becomees Prone, and gains Vulnerable 1.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>One target in your Current or an Adjacent Zone takes 3 Hits, becomees Prone, and gains Vulnerable 1.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Waterknot</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Torrent</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Waterknot
# --Rank|d@spell_rank_waterknot
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_waterknot}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 3 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gain Restrained 4.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Up to 2 targets in your Current or an Adjacent Zone gain Restrained 4.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 3
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 3</strong>
# <br>One target in your Current or an Adjacent Zone gain Restrained 4.
# </p>
# <p>
# <strong>Threshold &mdash; 5</strong>
# <br>Up to 2 targets in your Current or an Adjacent Zone gain Restrained 4.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Wildfire</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="4" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Ongoing 2</span>
# <span style="background-color: #096491;border-radius: 4px">Inferno</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Wildfire
# --Rank|d@spell_rank_wildfire
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_wildfire}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 AND $spell.ss < 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Increase the Entropy by +2 and target your Current or an Adjacent Zone.  The targeted Zone and all adjacent Zones gain Hazard 2, and all targets currently in those Zones take 3 Hits.
# --?? $spell.ss >= 5 ?? Effect:|**//Threshold - [^spell.ss]//**^^Increase the Entropy by +3, icrease the Momentum by +2, and target your Current or an Adjacent Zone.  The targeted Zone and all adjacent Zones gain Hazard 2, and all targets currently in those Zones take 3 Hits.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 4
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>Increase the Entropy by +2 and target your Current or an Adjacent Zone.  The targeted Zone and all adjacent Zones gain Hazard 2, and all targets currently in those Zones take 3 Hits.
# </p>
# <p>
# <strong>Threshold &mdash; 5</strong>
# <br>Increase the Entropy by +3, icrease the Momentum by +2, and target your Current or an Adjacent Zone.  The targeted Zone and all adjacent Zones gain Hazard 2, and all targets currently in those Zones take 3 Hits.
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Wish</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="1" /></label>
# </div><div class="grid-spells-kwords">
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Wish
# --Rank|d@spell_rank_wish
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_wish}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 500 ?? Effect:|**//Threshold - [^spell.ss]//**^^Kleist commits Genocide
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 500
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 1
# <p>
# <strong>Threshold &mdash; 500</strong>
# <br>Kleist commits Genocide
# </p>
# </details></div>
# </div><div class="grid-item-spells">
# <div class="grid-spells-name">Withercrown</div>
# <div class="grid-spells-ranks">
# <label>Rank: <input type="number" name="spell_rank_arc_lightning" value="0" step="1" max="3" /></label>
# </div><div class="grid-spells-kwords">
# <span style="background-color: #096491;border-radius: 4px">Ongoing 2</span>
# <span style="background-color: #096491;border-radius: 4px">Mori</span>
# <span style="background-color: #096491;border-radius: 4px">Nihil</span>
# <span style="background-color: #096491;border-radius: 4px">Plaga</span>
# </div>
# <div class="talent-rollbox grid-spells-btn">
# <button class="txt-btn" type="roll" value="!power {{
# --Name|@{character_name} - Withercrown
# --Rank|d@spell_rank_withercrown
# --Result Set|[[ [$spell|XPND] @{Cosm|challenge}d@{spell_rank_withercrown}>@{Cosm|target}]]
# --Hits|[^spell.ss]
# --1s|[^spell.ones]
# --format|powercheck
# --?? $spell.ss >= 2 ?? Effect:|**//Threshold - [^spell.ss]//**^^One target in your Current or an Adjacent Zone gains Fatigued 1 Ongoing.
# --?? $spell.ones > 0 ?? Trigger:|**//Spellburn://** 2
# }}">Roll</button></div>
# <div class="grid-spells-effects">
# <details>
# <summary>&#10010;</summary>
# Max Ranks: 3
# <p>
# <strong>Threshold &mdash; 2</strong>
# <br>One target in your Current or an Adjacent Zone gains Fatigued 1 Ongoing.
# </p>
# </details></div>
# </div></div>

# %%
f = open('powers_spells.html', 'w')
f.write(div_str)
f.close()

# %% [markdown]
# ### Minions Start

# %%
f = open('./docs/_data/minions.json', 'r')
minions_data = json.load(f)
f.close()

# %%
df_minions = pd.DataFrame(minions_data['minions'])

# %%
is_retainer = []
for i, m in df_minions.iterrows():
    for k in m['keywords']:
        if k == 'Retainer':
            is_retainer.append(1)
        else:
            is_retainer.append(0)
df_minions['is_retainer'] = is_retainer

opt_groups = []
for m in df_minions['keywords']:
    for k in m:
        if k not in opt_groups and k != 'Retainer':
            opt_groups.append(k)
opt_groups

minion_type = []
for i, m in df_minions.iterrows():
    for k in m['keywords']:
        if k in opt_groups:
            minion_type.append(k)
        else:
            minion_type.append(None)
df_minions['minion_type'] = minion_type

# %%
df_minions[df_minions['is_retainer'] == 0]
# Out:
#          name  rating  grit  melee  ranged  \
# 0     Stalker       2     6      1       0
# 1    Ambusher       2     4      0       0
# 2     Ravager       3     6      1       0
# 3       Hardy       2    10      1       0
# 4     Watcher       1     3      0       0
# 5     Tracker       1     4      0       0
# 6     Striker       1     6      2       0
# 7     Charger       2     5      1       0
# 8      Sentry       1     8      1       0
# 9       Decoy       1     3      0       0
# 10     Sapper       1     4      0       0
# 11     Spu Ki       0     4      0       0
# 12  Bodyguard       2     5      1       0
# 13   Enforcer       1     4      1       0
# 14    Battler       1     3      2       1
# 15      Piker       2     3      1       0
# 16   Arcanist       2     4      0       2
# 17      Medic       2     2      0       0
# 18     Archer       1     2      1       2
# 19      Rogue       1     2      1       1
# 20    Veteran       3     5      3       1
# 21  Cutthroat       2     2      3       0
# 22   Consular       1     2      0       0
# 23      Agent       1     2      1       1
#
#                                               trigger    keywords  \
# 0   [When this Minion Shifts to Move, it gains Hid...     [Beast]
# 1   [When this Minion attacks a target while Hidde...     [Beast]
# 2   [When this Minion scores Hits against one targ...     [Beast]
# 3   [When you use the Recover Action, this minion ...     [Beast]
# 4   [When you attempt to Perceive your surrounding...     [Beast]
# 5   [When you or an ally attempts to use Survival ...     [Beast]
# 6   [When this Minion does not use a Shift to Move...     [Beast]
# 7   [When this Minion Shifts to Move to an Adjacen...     [Beast]
# 8   [When your or your allies are the target of an...     [Beast]
# 9   [When this Minion Shifts to Move within its Cu...     [Beast]
# 10  [When this Minon would score Hits against a ta...     [Beast]
# 11  [When this Minon would score Hits against a ta...    [Undead]
# 12  [When you suffer Hits from a target you can se...  [Henchmen]
# 13  [When you Lead your Minions to score Hits agai...  [Henchmen]
# 14                                                 []  [Henchmen]
# 15  [When a target uses a Shift to Move past this ...  [Henchmen]
# 16  [When you or your allies use Cosmology, Histor...  [Henchmen]
# 17  [When you or your allies use the Recover Acito...  [Henchmen]
# 18  [When you Lead your Minions to score Hits agai...  [Henchmen]
# 19  [When this Minon uses a Shifts to Move, you ma...  [Henchmen]
# 20  [When you Lead your Minions to score Hits agai...  [Henchmen]
# 21  [When you Lead your Minions to score Hits agai...  [Henchmen]
# 22  [When you send this Minion to manage diplomacy...  [Henchmen]
# 23  [When this Minon uses a Shifts to Move, you ma...  [Henchmen]
#
#     is_retainer                                             pcards minion_type
# 0             0  [!power {{\nname|@{character_name} - Stalker\n...       Beast
# 1             0  [!power {{\nname|@{character_name} - Ambusher\...       Beast
# 2             0  [!power {{\nname|@{character_name} - Ravager\n...       Beast
# 3             0  [!power {{\nname|@{character_name} - Hardy\nTr...       Beast
# 4             0  [!power {{\nname|@{character_name} - Watcher\n...       Beast
# 5             0  [!power {{\nname|@{character_name} - Tracker\n...       Beast
# 6             0  [!power {{\nname|@{character_name} - Striker\n...       Beast
# 7             0  [!power {{\nname|@{character_name} - Charger\n...       Beast
# 8             0  [!power {{\nname|@{character_name} - Sentry\nT...       Beast
# 9             0  [!power {{\nname|@{character_name} - Decoy\nTr...       Beast
# 10            0  [!power {{\nname|@{character_name} - Sapper\nT...       Beast
# 11            0  [!power {{\nname|@{character_name} - Spu Ki\nT...      Undead
# 12            0  [!power {{\nname|@{character_name} - Bodyguard...    Henchmen
# 13            0  [!power {{\nname|@{character_name} - Enforcer\...    Henchmen
# 14            0  [!power {{\nname|@{character_name} - Battler\n...    Henchmen
# 15            0  [!power {{\nname|@{character_name} - Piker\nTr...    Henchmen
# 16            0  [!power {{\nname|@{character_name} - Arcanist\...    Henchmen
# 17            0  [!power {{\nname|@{character_name} - Medic\nTr...    Henchmen
# 18            0  [!power {{\nname|@{character_name} - Archer\nT...    Henchmen
# 19            0  [!power {{\nname|@{character_name} - Rogue\nTr...    Henchmen
# 20            0  [!power {{\nname|@{character_name} - Veteran\n...    Henchmen
# 21            0  [!power {{\nname|@{character_name} - Cutthroat...    Henchmen
# 22            0  [!power {{\nname|@{character_name} - Consular\...    Henchmen
# 23            0  [!power {{\nname|@{character_name} - Agent\nTr...    Henchmen

# %%
minion_pcard = []
for i, m in df_minions.iterrows():
    if m['is_retainer'] == 1:
        pcard = None
    else:
        pcard = []
        for t in m['trigger']:
            pcard.append('''!power {{
name|@{character_name} - ''' + m['name'] + '''
Trigger| ''' + t + '''
format|triggercheck
}}''')
    minion_pcard.append(pcard)

# %%
df_minions['pcards'] = minion_pcard

# %%
df_minions.head()
# Out:
#        name  rating  grit  melee  ranged  \
# 0   Stalker       2     6      1       0
# 1  Ambusher       2     4      0       0
# 2   Ravager       3     6      1       0
# 3     Hardy       2    10      1       0
# 4   Watcher       1     3      0       0
#
#                                              trigger keywords  is_retainer  \
# 0  [When this Minion Shifts to Move, it gains Hid...  [Beast]            0
# 1  [When this Minion attacks a target while Hidde...  [Beast]            0
# 2  [When this Minion scores Hits against one targ...  [Beast]            0
# 3  [When you use the Recover Action, this minion ...  [Beast]            0
# 4  [When you attempt to Perceive your surrounding...  [Beast]            0
#
#                                               pcards minion_type
# 0  [!power {{\nname|@{character_name} - Stalker\n...       Beast
# 1  [!power {{\nname|@{character_name} - Ambusher\...       Beast
# 2  [!power {{\nname|@{character_name} - Ravager\n...       Beast
# 3  [!power {{\nname|@{character_name} - Hardy\nTr...       Beast
# 4  [!power {{\nname|@{character_name} - Watcher\n...       Beast

# %%
'''
    <label>Rating:  <input class="trait-input"  name="attr_minon1_rating" type="number" value="2 /></label>
    <label>Grit:  <input class="trait-input"  name="attr_minon1_grit" type="number" value="6 /></label>
    <label>Melee:  <input class="trait-input"  name="attr_minon1_melee" type="number" value="1 /></label>
    <label>Ranged:  <input class="trait-input"  name="attr_minon1_ranged" type="number" value="0 /></label>
<div class="grid-item"><strong>Trigger &mdash; </strong>When this Minion Shifts to Move, it gains Hidden 3.</div>
<h4 style='margin: 3px;'><span style='background-color: #096491;border-radius: 4px'>Beast</span></h4>
'''
# Out:
# '\n    <label>Rating:  <input class="trait-input"  name="attr_minon1_rating" type="number" value="2 /></label>\n    <label>Grit:  <input class="trait-input"  name="attr_minon1_grit" type="number" value="6 /></label>\n    <label>Melee:  <input class="trait-input"  name="attr_minon1_melee" type="number" value="1 /></label>\n    <label>Ranged:  <input class="trait-input"  name="attr_minon1_ranged" type="number" value="0 /></label>\n<div class="grid-item"><strong>Trigger &mdash; </strong>When this Minion Shifts to Move, it gains Hidden 3.</div>\n<h4 style=\'margin: 3px;\'><span style=\'background-color: #096491;border-radius: 4px\'>Beast</span></h4>\n'

# %%
pick_list = ''''''
for opt in opt_groups:
    pick_list += '''<optgroup label="''' + opt + '''">\n'''
    mins = df_minions[df_minions['minion_type']==opt].copy()
    for i, m in mins.iterrows():
        pick_list += '''<option value="''' + m['name'].lower() + '''">''' + m['name'] + '''</option>\n'''
    pick_list += '''</optgroup>'''

# %%
print(pick_list)
# Out:
# <optgroup label="Beast">
# <option value="stalker">Stalker</option>
# <option value="ambusher">Ambusher</option>
# <option value="ravager">Ravager</option>
# <option value="hardy">Hardy</option>
# <option value="watcher">Watcher</option>
# <option value="tracker">Tracker</option>
# <option value="striker">Striker</option>
# <option value="charger">Charger</option>
# <option value="sentry">Sentry</option>
# <option value="decoy">Decoy</option>
# <option value="sapper">Sapper</option>
# </optgroup><optgroup label="Undead">
# <option value="spu ki">Spu Ki</option>
# </optgroup><optgroup label="Henchmen">
# <option value="bodyguard">Bodyguard</option>
# <option value="enforcer">Enforcer</option>
# <option value="battler">Battler</option>
# <option value="piker">Piker</option>
# <option value="arcanist">Arcanist</option>
# <option value="medic">Medic</option>
# <option value="archer">Archer</option>
# <option value="rogue">Rogue</option>
# <option value="veteran">Veteran</option>
# <option value="cutthroat">Cutthroat</option>
# <option value="consular">Consular</option>
# <option value="agent">Agent</option>
# </optgroup>

# %%
div_str = '''<div class="grid-container">\n<div class="grid-item triat-header">Minions\n<div class="grid-container grid-3col">\n'''
slot_list = ['Minion ' + str(i+1) for i in range(9)]
mins = df_minions[df_minions['is_retainer'] == 0]
for slot in slot_list:
    slot_attr = slot.lower().replace(' ', '')
    div_str += '''<div class="grid-item">\n<div class="grid-item-minions">\n''' + slot + '''&mdash;\n<select name="attr_''' + slot_attr + '''_name">\n<option value="">Select to Recruit</option>\n''' + pick_list + '''</select>\n'''
    for i, m in mins.iterrows():
        minion_name_clean = m['name'].lower().replace(' ', '_')
        div_str += '''<div class="grid-container grid-2col grid-item-''' + minion_name_clean + '''">\n<div class="grid-item">'''
        for k in m['keywords']:
            div_str += '''<h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">''' + k + '''</span>\n</h4>\n'''
        div_str += '''</div>\n<label>Rating: <input class="trait-input" name="attr_''' + slot_attr + '''_rating" type="number" value="''' + str(m['rating']) + '''" min="0" step="1" /></label>\n</div><div class="grid-container grid-3col grid-item-''' + minion_name_clean + '''">'''
        div_str += '''<label>Grit: <input class="trait-input" name="attr_''' + slot_attr + '''_grit" type="number" value="''' + str(m['grit']) + '''" min="0" step="1" /></label>\n'''
        div_str += '''<label>Melee: <input class="trait-input" name="attr_''' + slot_attr + '''_melee" type="number" value="''' + str(m['melee']) + '''" min="0" step="1" /></label>\n'''
        div_str += '''<label>Ranged: <input class="trait-input" name="attr_''' + slot_attr + '''_ranged" type="number" value="''' + str(m['ranged']) + '''" min="0" step="1" /></label>\n'''
        div_str += '''</div>\n<div class="grid-container grid-item-''' + minion_name_clean + '''">\n'''
        for t, p in zip(m['trigger'], m['pcards']):
            div_str += '''<div class="grid-item">\n<strong>Trigger &mdash; </strong>''' + t + '''<button type='roll' value="''' + p + '''">Show</button></div>\n'''
        div_str += '''</div>\n'''
    div_str += '''</div>\n</div>\n'''
div_str += '''</div>\n</div>\n</div>'''

# %%
print(div_str)
# Out:
# <div class="grid-container">
# <div class="grid-item triat-header">Minions
# <div class="grid-container grid-3col">
# <div class="grid-item">
# <div class="grid-item-minions">
# Minion 1&mdash;
# <select name="attr_minion1_name">
# <option value="">Select to Recruit</option>
# <optgroup label="Beast">
# <option value="stalker">Stalker</option>
# <option value="ambusher">Ambusher</option>
# <option value="ravager">Ravager</option>
# <option value="hardy">Hardy</option>
# <option value="watcher">Watcher</option>
# <option value="tracker">Tracker</option>
# <option value="striker">Striker</option>
# <option value="charger">Charger</option>
# <option value="sentry">Sentry</option>
# <option value="decoy">Decoy</option>
# <option value="sapper">Sapper</option>
# </optgroup><optgroup label="Undead">
# <option value="spu ki">Spu Ki</option>
# </optgroup><optgroup label="Henchmen">
# <option value="bodyguard">Bodyguard</option>
# <option value="enforcer">Enforcer</option>
# <option value="battler">Battler</option>
# <option value="piker">Piker</option>
# <option value="arcanist">Arcanist</option>
# <option value="medic">Medic</option>
# <option value="archer">Archer</option>
# <option value="rogue">Rogue</option>
# <option value="veteran">Veteran</option>
# <option value="cutthroat">Cutthroat</option>
# <option value="consular">Consular</option>
# <option value="agent">Agent</option>
# </optgroup></select>
# <div class="grid-container grid-2col grid-item-stalker">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-stalker"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="6" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-stalker">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minion Shifts to Move, it gains Hidden 3.<button type='roll' value="!power {{
# name|@{character_name} - Stalker
# Trigger| When this Minion Shifts to Move, it gains Hidden 3.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-ambusher">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-ambusher"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="4" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-ambusher">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minion attacks a target while Hidden, add +2 bonus the the result set.<button type='roll' value="!power {{
# name|@{character_name} - Ambusher
# Trigger| When this Minion attacks a target while Hidden, add +2 bonus the the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-ravager">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="3" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-ravager"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="6" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-ravager">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minion scores Hits against one target in its Current Zone and the target takes 5+ Hits this turn, the target gains Vulnerable 2.<button type='roll' value="!power {{
# name|@{character_name} - Ravager
# Trigger| When this Minion scores Hits against one target in its Current Zone and the target takes 5+ Hits this turn, the target gains Vulnerable 2.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-hardy">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-hardy"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="10" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-hardy">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you use the Recover Action, this minion regains +2 Grit.<button type='roll' value="!power {{
# name|@{character_name} - Hardy
# Trigger| When you use the Recover Action, this minion regains +2 Grit.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-watcher">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-watcher"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="3" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-watcher">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you attempt to Perceive your surroundings, you may choose to Perceive your Current Zone or this Minion's Current Zone.  If you and this Minion are in the same Current Zone, add +2 Bnous Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Watcher
# Trigger| When you attempt to Perceive your surroundings, you may choose to Perceive your Current Zone or this Minion's Current Zone.  If you and this Minion are in the same Current Zone, add +2 Bnous Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-tracker">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-tracker"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="4" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-tracker">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you or an ally attempts to use Survival skills to track a target while in this Minion's Current Zone, add +1d4 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Tracker
# Trigger| When you or an ally attempts to use Survival skills to track a target while in this Minion's Current Zone, add +1d4 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-striker">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-striker"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="6" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="2" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-striker">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minion does not use a Shift to Move on your turn, it may score X Hits against one target in its Current Zone, where X is equal to its Melle Rating.<button type='roll' value="!power {{
# name|@{character_name} - Striker
# Trigger| When this Minion does not use a Shift to Move on your turn, it may score X Hits against one target in its Current Zone, where X is equal to its Melle Rating.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-charger">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-charger"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="5" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-charger">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minion Shifts to Move to an Adjacent Zone and attack a target, it may ignores Hazards and its target becomes Prone.<button type='roll' value="!power {{
# name|@{character_name} - Charger
# Trigger| When this Minion Shifts to Move to an Adjacent Zone and attack a target, it may ignores Hazards and its target becomes Prone.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-sentry">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-sentry"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="8" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-sentry">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When your or your allies are the target of an Ambush while in this Minion's Current Zone, you may add +1d4 bonus hits to the Initiative Test.<button type='roll' value="!power {{
# name|@{character_name} - Sentry
# Trigger| When your or your allies are the target of an Ambush while in this Minion's Current Zone, you may add +1d4 bonus hits to the Initiative Test.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-decoy">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-decoy"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="3" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-decoy">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minion Shifts to Move within its Current or into an Adjacent Zone, X targets in its Current Zone gain Provoked, where X is equal to this Minion's Current Grit.<button type='roll' value="!power {{
# name|@{character_name} - Decoy
# Trigger| When this Minion Shifts to Move within its Current or into an Adjacent Zone, X targets in its Current Zone gain Provoked, where X is equal to this Minion's Current Grit.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-sapper">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-sapper"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="4" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-sapper">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minon would score Hits against a target in its Current Zone, the target gains Fatigued 1.<button type='roll' value="!power {{
# name|@{character_name} - Sapper
# Trigger| When this Minon would score Hits against a target in its Current Zone, the target gains Fatigued 1.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-spu_ki">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Undead</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="0" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-spu_ki"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="4" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-spu_ki">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minon would score Hits against a target in its Current Zone, the target gains Fatigued 1.<button type='roll' value="!power {{
# name|@{character_name} - Spu Ki
# Trigger| When this Minon would score Hits against a target in its Current Zone, the target gains Fatigued 1.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-bodyguard">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-bodyguard"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="5" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-bodyguard">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you suffer Hits from a target you can see and this Minion is in your Current Zone, you may redirect the Hits to this Minion.<button type='roll' value="!power {{
# name|@{character_name} - Bodyguard
# Trigger| When you suffer Hits from a target you can see and this Minion is in your Current Zone, you may redirect the Hits to this Minion.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-enforcer">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-enforcer"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="4" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-enforcer">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you Lead your Minions to score Hits against a target in this Minion's Current Zone, add +2 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Enforcer
# Trigger| When you Lead your Minions to score Hits against a target in this Minion's Current Zone, add +2 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-battler">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-battler"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="3" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="2" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="1" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-battler">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong><button type='roll' value="!power {{
# name|@{character_name} - Battler
# Trigger|
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-piker">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-piker"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="3" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-piker">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When a target uses a Shift to Move past this Minion, the target adds an additional +1 Hazard to their team's next roll.<button type='roll' value="!power {{
# name|@{character_name} - Piker
# Trigger| When a target uses a Shift to Move past this Minion, the target adds an additional +1 Hazard to their team's next roll.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-arcanist">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-arcanist"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="4" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="2" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-arcanist">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you or your allies use Cosmology, History, Researhc, Skrimisiology, or Theology and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Arcanist
# Trigger| When you or your allies use Cosmology, History, Researhc, Skrimisiology, or Theology and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-medic">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-medic"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="2" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-medic">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you or your allies use the Recover Aciton and this Minion is in your Current Zone, you regain +1 Grit.<button type='roll' value="!power {{
# name|@{character_name} - Medic
# Trigger| When you or your allies use the Recover Aciton and this Minion is in your Current Zone, you regain +1 Grit.
# format|triggercheck
# }}">Show</button></div>
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you or your allies use Medicine and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Medic
# Trigger| When you or your allies use Medicine and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-archer">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-archer"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="2" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="2" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-archer">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you Lead your Minions to score Hits against a target in a Zone Adjacent to this Minion's Current Zone, add +2 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Archer
# Trigger| When you Lead your Minions to score Hits against a target in a Zone Adjacent to this Minion's Current Zone, add +2 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-rogue">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-rogue"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="2" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="1" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-rogue">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minon uses a Shifts to Move, you may have it gain Hidden 2.<button type='roll' value="!power {{
# name|@{character_name} - Rogue
# Trigger| When this Minon uses a Shifts to Move, you may have it gain Hidden 2.
# format|triggercheck
# }}">Show</button></div>
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you or your allies use your Implements and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Rogue
# Trigger| When you or your allies use your Implements and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-veteran">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="3" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-veteran"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="5" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="3" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="1" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-veteran">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you Lead your Minions to score Hits against a target in this Minion's Current Zone and the target dies, you may have this Minion deal X hits to another target in its Current Zone, where X is equal to this Minions Melee rating.<button type='roll' value="!power {{
# name|@{character_name} - Veteran
# Trigger| When you Lead your Minions to score Hits against a target in this Minion's Current Zone and the target dies, you may have this Minion deal X hits to another target in its Current Zone, where X is equal to this Minions Melee rating.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-cutthroat">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-cutthroat"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="2" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="3" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-cutthroat">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you Lead your Minions to score Hits against a target in this Minion's Current Zone and the target dies, you may have this Minion gain an additional Shift this turn.<button type='roll' value="!power {{
# name|@{character_name} - Cutthroat
# Trigger| When you Lead your Minions to score Hits against a target in this Minion's Current Zone and the target dies, you may have this Minion gain an additional Shift this turn.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-consular">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-consular"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="2" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-consular">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you send this Minion to manage diplomacy in your stead, you may roll Lead instead of Deceive or Persaude to conduct the deliberations.<button type='roll' value="!power {{
# name|@{character_name} - Consular
# Trigger| When you send this Minion to manage diplomacy in your stead, you may roll Lead instead of Deceive or Persaude to conduct the deliberations.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-agent">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion1_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-agent"><label>Grit: <input class="trait-input" name="attr_minion1_grit" type="number" value="2" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion1_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion1_ranged" type="number" value="1" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-agent">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minon uses a Shifts to Move, you may have it gain Hidden 2.<button type='roll' value="!power {{
# name|@{character_name} - Agent
# Trigger| When this Minon uses a Shifts to Move, you may have it gain Hidden 2.
# format|triggercheck
# }}">Show</button></div>
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you or your allies Perceive and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Agent
# Trigger| When you or your allies Perceive and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# </div>
# </div>
# <div class="grid-item">
# <div class="grid-item-minions">
# Minion 2&mdash;
# <select name="attr_minion2_name">
# <option value="">Select to Recruit</option>
# <optgroup label="Beast">
# <option value="stalker">Stalker</option>
# <option value="ambusher">Ambusher</option>
# <option value="ravager">Ravager</option>
# <option value="hardy">Hardy</option>
# <option value="watcher">Watcher</option>
# <option value="tracker">Tracker</option>
# <option value="striker">Striker</option>
# <option value="charger">Charger</option>
# <option value="sentry">Sentry</option>
# <option value="decoy">Decoy</option>
# <option value="sapper">Sapper</option>
# </optgroup><optgroup label="Undead">
# <option value="spu ki">Spu Ki</option>
# </optgroup><optgroup label="Henchmen">
# <option value="bodyguard">Bodyguard</option>
# <option value="enforcer">Enforcer</option>
# <option value="battler">Battler</option>
# <option value="piker">Piker</option>
# <option value="arcanist">Arcanist</option>
# <option value="medic">Medic</option>
# <option value="archer">Archer</option>
# <option value="rogue">Rogue</option>
# <option value="veteran">Veteran</option>
# <option value="cutthroat">Cutthroat</option>
# <option value="consular">Consular</option>
# <option value="agent">Agent</option>
# </optgroup></select>
# <div class="grid-container grid-2col grid-item-stalker">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion2_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-stalker"><label>Grit: <input class="trait-input" name="attr_minion2_grit" type="number" value="6" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion2_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion2_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-stalker">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minion Shifts to Move, it gains Hidden 3.<button type='roll' value="!power {{
# name|@{character_name} - Stalker
# Trigger| When this Minion Shifts to Move, it gains Hidden 3.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-ambusher">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion2_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-ambusher"><label>Grit: <input class="trait-input" name="attr_minion2_grit" type="number" value="4" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion2_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion2_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-ambusher">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minion attacks a target while Hidden, add +2 bonus the the result set.<button type='roll' value="!power {{
# name|@{character_name} - Ambusher
# Trigger| When this Minion attacks a target while Hidden, add +2 bonus the the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-ravager">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion2_rating" type="number" value="3" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-ravager"><label>Grit: <input class="trait-input" name="attr_minion2_grit" type="number" value="6" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion2_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion2_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-ravager">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minion scores Hits against one target in its Current Zone and the target takes 5+ Hits this turn, the target gains Vulnerable 2.<button type='roll' value="!power {{
# name|@{character_name} - Ravager
# Trigger| When this Minion scores Hits against one target in its Current Zone and the target takes 5+ Hits this turn, the target gains Vulnerable 2.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-hardy">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion2_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-hardy"><label>Grit: <input class="trait-input" name="attr_minion2_grit" type="number" value="10" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion2_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion2_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-hardy">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you use the Recover Action, this minion regains +2 Grit.<button type='roll' value="!power {{
# name|@{character_name} - Hardy
# Trigger| When you use the Recover Action, this minion regains +2 Grit.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-watcher">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion2_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-watcher"><label>Grit: <input class="trait-input" name="attr_minion2_grit" type="number" value="3" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion2_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion2_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-watcher">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you attempt to Perceive your surroundings, you may choose to Perceive your Current Zone or this Minion's Current Zone.  If you and this Minion are in the same Current Zone, add +2 Bnous Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Watcher
# Trigger| When you attempt to Perceive your surroundings, you may choose to Perceive your Current Zone or this Minion's Current Zone.  If you and this Minion are in the same Current Zone, add +2 Bnous Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-tracker">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion2_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-tracker"><label>Grit: <input class="trait-input" name="attr_minion2_grit" type="number" value="4" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion2_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion2_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-tracker">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you or an ally attempts to use Survival skills to track a target while in this Minion's Current Zone, add +1d4 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Tracker
# Trigger| When you or an ally attempts to use Survival skills to track a target while in this Minion's Current Zone, add +1d4 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-striker">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion2_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-striker"><label>Grit: <input class="trait-input" name="attr_minion2_grit" type="number" value="6" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion2_melee" type="number" value="2" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion2_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-striker">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minion does not use a Shift to Move on your turn, it may score X Hits against one target in its Current Zone, where X is equal to its Melle Rating.<button type='roll' value="!power {{
# name|@{character_name} - Striker
# Trigger| When this Minion does not use a Shift to Move on your turn, it may score X Hits against one target in its Current Zone, where X is equal to its Melle Rating.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-charger">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion2_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-charger"><label>Grit: <input class="trait-input" name="attr_minion2_grit" type="number" value="5" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion2_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion2_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-charger">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minion Shifts to Move to an Adjacent Zone and attack a target, it may ignores Hazards and its target becomes Prone.<button type='roll' value="!power {{
# name|@{character_name} - Charger
# Trigger| When this Minion Shifts to Move to an Adjacent Zone and attack a target, it may ignores Hazards and its target becomes Prone.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-sentry">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion2_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-sentry"><label>Grit: <input class="trait-input" name="attr_minion2_grit" type="number" value="8" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion2_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion2_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-sentry">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When your or your allies are the target of an Ambush while in this Minion's Current Zone, you may add +1d4 bonus hits to the Initiative Test.<button type='roll' value="!power {{
# name|@{character_name} - Sentry
# Trigger| When your or your allies are the target of an Ambush while in this Minion's Current Zone, you may add +1d4 bonus hits to the Initiative Test.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-decoy">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion2_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-decoy"><label>Grit: <input class="trait-input" name="attr_minion2_grit" type="number" value="3" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion2_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion2_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-decoy">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minion Shifts to Move within its Current or into an Adjacent Zone, X targets in its Current Zone gain Provoked, where X is equal to this Minion's Current Grit.<button type='roll' value="!power {{
# name|@{character_name} - Decoy
# Trigger| When this Minion Shifts to Move within its Current or into an Adjacent Zone, X targets in its Current Zone gain Provoked, where X is equal to this Minion's Current Grit.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-sapper">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Beast</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion2_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-sapper"><label>Grit: <input class="trait-input" name="attr_minion2_grit" type="number" value="4" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion2_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion2_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-sapper">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minon would score Hits against a target in its Current Zone, the target gains Fatigued 1.<button type='roll' value="!power {{
# name|@{character_name} - Sapper
# Trigger| When this Minon would score Hits against a target in its Current Zone, the target gains Fatigued 1.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-spu_ki">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Undead</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion2_rating" type="number" value="0" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-spu_ki"><label>Grit: <input class="trait-input" name="attr_minion2_grit" type="number" value="4" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion2_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion2_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-spu_ki">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minon would score Hits against a target in its Current Zone, the target gains Fatigued 1.<button type='roll' value="!power {{
# name|@{character_name} - Spu Ki
# Trigger| When this Minon would score Hits against a target in its Current Zone, the target gains Fatigued 1.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-bodyguard">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion2_rating" type="number" value="2" min="0" step="1" /></label>
# ...
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-bodyguard">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion9_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-bodyguard"><label>Grit: <input class="trait-input" name="attr_minion9_grit" type="number" value="5" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion9_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion9_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-bodyguard">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you suffer Hits from a target you can see and this Minion is in your Current Zone, you may redirect the Hits to this Minion.<button type='roll' value="!power {{
# name|@{character_name} - Bodyguard
# Trigger| When you suffer Hits from a target you can see and this Minion is in your Current Zone, you may redirect the Hits to this Minion.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-enforcer">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion9_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-enforcer"><label>Grit: <input class="trait-input" name="attr_minion9_grit" type="number" value="4" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion9_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion9_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-enforcer">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you Lead your Minions to score Hits against a target in this Minion's Current Zone, add +2 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Enforcer
# Trigger| When you Lead your Minions to score Hits against a target in this Minion's Current Zone, add +2 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-battler">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion9_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-battler"><label>Grit: <input class="trait-input" name="attr_minion9_grit" type="number" value="3" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion9_melee" type="number" value="2" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion9_ranged" type="number" value="1" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-battler">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong><button type='roll' value="!power {{
# name|@{character_name} - Battler
# Trigger|
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-piker">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion9_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-piker"><label>Grit: <input class="trait-input" name="attr_minion9_grit" type="number" value="3" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion9_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion9_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-piker">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When a target uses a Shift to Move past this Minion, the target adds an additional +1 Hazard to their team's next roll.<button type='roll' value="!power {{
# name|@{character_name} - Piker
# Trigger| When a target uses a Shift to Move past this Minion, the target adds an additional +1 Hazard to their team's next roll.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-arcanist">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion9_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-arcanist"><label>Grit: <input class="trait-input" name="attr_minion9_grit" type="number" value="4" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion9_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion9_ranged" type="number" value="2" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-arcanist">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you or your allies use Cosmology, History, Researhc, Skrimisiology, or Theology and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Arcanist
# Trigger| When you or your allies use Cosmology, History, Researhc, Skrimisiology, or Theology and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-medic">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion9_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-medic"><label>Grit: <input class="trait-input" name="attr_minion9_grit" type="number" value="2" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion9_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion9_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-medic">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you or your allies use the Recover Aciton and this Minion is in your Current Zone, you regain +1 Grit.<button type='roll' value="!power {{
# name|@{character_name} - Medic
# Trigger| When you or your allies use the Recover Aciton and this Minion is in your Current Zone, you regain +1 Grit.
# format|triggercheck
# }}">Show</button></div>
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you or your allies use Medicine and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Medic
# Trigger| When you or your allies use Medicine and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-archer">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion9_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-archer"><label>Grit: <input class="trait-input" name="attr_minion9_grit" type="number" value="2" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion9_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion9_ranged" type="number" value="2" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-archer">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you Lead your Minions to score Hits against a target in a Zone Adjacent to this Minion's Current Zone, add +2 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Archer
# Trigger| When you Lead your Minions to score Hits against a target in a Zone Adjacent to this Minion's Current Zone, add +2 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-rogue">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion9_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-rogue"><label>Grit: <input class="trait-input" name="attr_minion9_grit" type="number" value="2" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion9_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion9_ranged" type="number" value="1" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-rogue">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minon uses a Shifts to Move, you may have it gain Hidden 2.<button type='roll' value="!power {{
# name|@{character_name} - Rogue
# Trigger| When this Minon uses a Shifts to Move, you may have it gain Hidden 2.
# format|triggercheck
# }}">Show</button></div>
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you or your allies use your Implements and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Rogue
# Trigger| When you or your allies use your Implements and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-veteran">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion9_rating" type="number" value="3" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-veteran"><label>Grit: <input class="trait-input" name="attr_minion9_grit" type="number" value="5" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion9_melee" type="number" value="3" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion9_ranged" type="number" value="1" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-veteran">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you Lead your Minions to score Hits against a target in this Minion's Current Zone and the target dies, you may have this Minion deal X hits to another target in its Current Zone, where X is equal to this Minions Melee rating.<button type='roll' value="!power {{
# name|@{character_name} - Veteran
# Trigger| When you Lead your Minions to score Hits against a target in this Minion's Current Zone and the target dies, you may have this Minion deal X hits to another target in its Current Zone, where X is equal to this Minions Melee rating.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-cutthroat">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion9_rating" type="number" value="2" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-cutthroat"><label>Grit: <input class="trait-input" name="attr_minion9_grit" type="number" value="2" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion9_melee" type="number" value="3" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion9_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-cutthroat">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you Lead your Minions to score Hits against a target in this Minion's Current Zone and the target dies, you may have this Minion gain an additional Shift this turn.<button type='roll' value="!power {{
# name|@{character_name} - Cutthroat
# Trigger| When you Lead your Minions to score Hits against a target in this Minion's Current Zone and the target dies, you may have this Minion gain an additional Shift this turn.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-consular">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion9_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-consular"><label>Grit: <input class="trait-input" name="attr_minion9_grit" type="number" value="2" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion9_melee" type="number" value="0" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion9_ranged" type="number" value="0" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-consular">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you send this Minion to manage diplomacy in your stead, you may roll Lead instead of Deceive or Persaude to conduct the deliberations.<button type='roll' value="!power {{
# name|@{character_name} - Consular
# Trigger| When you send this Minion to manage diplomacy in your stead, you may roll Lead instead of Deceive or Persaude to conduct the deliberations.
# format|triggercheck
# }}">Show</button></div>
# </div>
# <div class="grid-container grid-2col grid-item-agent">
# <div class="grid-item"><h4 style="margin: 3px"><span style="background-color: #096491;border-radius: 4px">Henchmen</span>
# </h4>
# </div>
# <label>Rating: <input class="trait-input" name="attr_minion9_rating" type="number" value="1" min="0" step="1" /></label>
# </div><div class="grid-container grid-3col grid-item-agent"><label>Grit: <input class="trait-input" name="attr_minion9_grit" type="number" value="2" min="0" step="1" /></label>
# <label>Melee: <input class="trait-input" name="attr_minion9_melee" type="number" value="1" min="0" step="1" /></label>
# <label>Ranged: <input class="trait-input" name="attr_minion9_ranged" type="number" value="1" min="0" step="1" /></label>
# </div>
# <div class="grid-container grid-item-agent">
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When this Minon uses a Shifts to Move, you may have it gain Hidden 2.<button type='roll' value="!power {{
# name|@{character_name} - Agent
# Trigger| When this Minon uses a Shifts to Move, you may have it gain Hidden 2.
# format|triggercheck
# }}">Show</button></div>
# <div class="grid-item">
# <strong>Trigger &mdash; </strong>When you or your allies Perceive and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.<button type='roll' value="!power {{
# name|@{character_name} - Agent
# Trigger| When you or your allies Perceive and this Minion is in your Current Zone, add +2 Bonus Hits to the result set.
# format|triggercheck
# }}">Show</button></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
f = open('minions_minions.html', 'w')
f.write(div_str)
f.close()
